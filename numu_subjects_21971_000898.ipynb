# %% [markdown]
# # Phase 2: Subject Creation
#
# **Description:**
#
# This notebook is to act as the resulting summary file for the creation and upload of subjects for the IceCube Zooniverse project currently called *Name that Neutrino!*. The project is currently being maintained by Elizabeth Warrick (as of March 2023). In this notebook, we take the i3 file and run it through several filters. [note: describe more later].
#
# > Nu Type: NuMu
#
# > Run: 21971
#
# > SubRun: 000898
#
# ### Summary Stats:
#
# To be filled in after completing process. Also need to figure out global variables.
#
# **Subject Set Name:**

# %%
#Imports

#My functions: 
from uniformenergydist_filter import *

#General:
import numpy as np
import sys
import os
import subprocess
import argparse
import csv
from tables import *
import pandas as pd
from matplotlib import pyplot as plt
import h5py

#Zooniverse:
from panoptes_client import Panoptes, Project, SubjectSet, Subject
import magic
import glob

#IceCube:
from icecube.icetray import I3Units
import icecube.MuonGun
from icecube import dataio, dataclasses, icetray, MuonGun
from I3Tray import *
from icecube.hdfwriter import I3HDFWriter
from mc_labeler import MCLabeler #make sure that mc_labeler script is in current directory.

# %%
#Specify file paths:

#Initial I3 File:
numu = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst'

#Desired output directory. Note that creation of this directory is not yet coded and is done manually. 
phase1_dir = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/'

# %%
#Run Filter 1 to label MC truth.
filter1(numu,phase1_dir)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/mc_labeler.py:523: UserWarning: Couldn't find OMKey in MCPESeriesMap
#   warnings.warn("Couldn't find OMKey in MCPESeriesMap")

# %% [markdown]
# Note that the above cell might return an "exception" warning that the *MCPESeriesMap could not be found*. I am unsure why it does that because when I check the i3 file in dataio-shovel, I see the specified mc_pid_series_map (look at mc_labeler.py for exact name of specified key). The resulting file size should be around 400 MB.

# %%
#Path of hdf from above filter.
numu_hdf = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/\
Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst.hd5'

# %%
#Run uniformenergy_events function which requires hdf from filter 1, 
#number of bins, size of each random choice, and a random seed. 

uniformenergy_events(numu_hdf,25,40,12,subrun = True)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['binned_log10E'] = pd.cut(x = np.log10(df_filtered['energy']), bins = bins, labels = labels, include_lowest = True) #might throw an error?
# Number of Bins: 25
# Number of Events per Bin: 40
# Total Number of Events: 1000
# Initial Number of Events: 8718
# Number of Events after filtering: 7991
# Please input subrun number:
# 000898

# %% [markdown]
# The above function throws another warning about pd.cut, currently that is not a problem but I don't know if a new version of pandas will allow this.

# %%
#Path to Random Events CSV
numu_csv = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/random_events_uniform_energy_distrib_21971_000898.csv'

# %%
#Run event_characterization_plots function whick makes some quick 
#plots to get an idea of what data you're dealing with.
#Note that I want to update the plot types, maybe make a 2D histogram as Mike K suggested. 
#For truth labels, check out enums.py or in the .py file that holds the functions.

event_characterization_plots(numu_csv)

# %% [markdown]
# Now that we have the events for this phase chosen, we run the second filter to pick out only those events.

# %%
#Path to i3 file from filter1 with MC truth labels. 
numu_filter1 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst'

# %%
#Run function to perform second filter which passes through only selected event IDs chosen from 
#the uniformenergy_events function. 
filter2(numu_filter1,phase1_dir,numu_csv)

# %%
#Path to i3 file from filter 2 that holds only specified events. 
numu_filter2 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst'

# %%
#Run function to perform third filter, which returns only the DAQ frames of the specified events.
#DAQ only file is then split up into many smaller i3 files since SteamShovel can't handle making videos of large
#i3 files at one time. Size limit is approx 2E6 MB (? unsure of units)
filter3(numu_filter2,21971_000898,phase1_dir)

# %%
#Path to NuMu Daq Only folder
numu_daq = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/'

# %%
get_steamshovel(numu_daq,21971000898)
# Out:
# List of files:
# ['/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0009_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0010_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0011_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0012_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0013_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0014_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0015_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0016_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0017_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0018_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0019_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq ...
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0009_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0010_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0011_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0012_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0013_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0014_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0015_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0016_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0017_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0018_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0019_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0020_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0021_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0022_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000898/daq_only-0023_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000898.i3.zst

# %% [markdown]
# Ideas for Compression:
# - Use GUI to add files to queue and send to one compression folder.
# - Add a subprocess line in movie script to compress the video after making it and direct it to save in the compression folder.

# %%
compressed_path = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/'

# %% [markdown]
# Can't get manifest yet since some subjects are missing and lining it up won't work.

# %%
get_manifest(compressed_path, numu_csv)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:417: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   dict_manifest = s3.to_dict('dict')
# {'/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_8527_origidx_8_RF22.mp4': {'event': 8527,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.3107100427150726,
#   'pred_cascade': 0.0640772208571434,
#   'pred_tgtrack': 0.4691827297210693,
#   'pred_starttrack': 0.0323334336280822,
#   'pred_stoptrack': 0.1236965283751487,
#   'energy': 119.6454850069144,
#   'zenith': 0.434753759940837,
#   'oneweight': 22645600.984469693,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.4691827297210693,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_7216_origidx_5_RF22.mp4': {'event': 7216,
#   'run': 21971,
#   'truth_classification': 7,
#   'pred_skim': 2.0881865566479973e-05,
#   'pred_cascade': 0.8542471528053284,
#   'pred_tgtrack': 3.721366374520585e-05,
#   'pred_starttrack': 0.1456633955240249,
#   'pred_stoptrack': 3.1396994017995894e-05,
#   'energy': 2671.263070965063,
#   'zenith': 2.360259442912671,
#   'oneweight': 164598498624.02008,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.8542471528053284,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_21924_origidx_14_RF22.mp4': {'event': 21924,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.4507708847522735,
#   'pred_cascade': 0.0949052795767784,
#   'pred_tgtrack': 0.0265709273517131,
#   'pred_starttrack': 0.0685795545578002,
#   'pred_stoptrack': 0.3591733276844024,
#   'energy': 143.72698087711925,
#   'zenith': 2.48136439773184,
#   'oneweight': 20445931.407463063,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.4507708847522735,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_18455_origidx_11_RF22.mp4': {'event': 18455,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.0074744476005434,
#   'pred_cascade': 0.002623765496537,
#   'pred_tgtrack': 0.9172622561454772,
#   'pred_starttrack': 0.0707641169428825,
#   'pred_stoptrack': 0.0018754407064989,
#   'energy': 17436.104460255752,
#   'zenith': 1.962584744125792,
#   'oneweight': 21650262360389.39,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9172622561454772,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_16221_origidx_14_RF22.mp4': {'event': 16221,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0126976976171135,
#   'pred_cascade': 0.0047143730334937,
#   'pred_tgtrack': 0.7438206076622009,
#   'pred_starttrack': 0.0162008497864007,
#   'pred_stoptrack': 0.222566470503807,
#   'energy': 502023.8637101906,
#   'zenith': 1.394554359958322,
#   'oneweight': 1.4713080593680992e+16,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.7438206076622009,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_1211_origidx_32_RF22.mp4': {'event': 1211,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0006566806696355,
#   'pred_cascade': 0.0003393663500901,
#   'pred_tgtrack': 0.2046119570732116,
#   'pred_starttrack': 0.1066787019371986,
#   'pred_stoptrack': 0.6877132654190063,
#   'energy': 4750.1747479497,
#   'zenith': 1.6456640803495814,
#   'oneweight': 680667113793.5394,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.6877132654190063,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_3089_origidx_42_RF22.mp4': {'event': 3089,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.1641513705253601,
#   'pred_cascade': 0.0002938294492196,
#   'pred_tgtrack': 0.792441725730896,
#   'pred_starttrack': 0.0188511107116937,
#   'pred_stoptrack': 0.0242618694901466,
#   'energy': 438.1747310413348,
#   'zenith': 1.2725213495182512,
#   'oneweight': 771141577.9464071,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.792441725730896,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_25104_origidx_8_RF22.mp4': {'event': 25104,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 7.689681660849601e-05,
#   'pred_cascade': 1.8363469280302525e-05,
#   'pred_tgtrack': 0.9973154664039612,
#   'pred_starttrack': 0.0022816031705588,
#   'pred_stoptrack': 0.0003076702996622,
#   'energy': 758184.7530994335,
#   'zenith': 0.931788009248802,
#   'oneweight': 1.0929377594978864e+16,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9973154664039612,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_3018_origidx_38_RF22.mp4': {'event': 3018,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0066117425449192,
#   'pred_cascade': 0.0013847207883372,
#   'pred_tgtrack': 0.9376645684242249,
#   'pred_starttrack': 0.0379098132252693,
#   'pred_stoptrack': 0.0164290741086006,
#   'energy': 26371.57063266888,
#   'zenith': 1.0634530054568236,
#   'oneweight': 9333245616950.549,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9376645684242249,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_21981_origidx_16_RF22.mp4': {'event': 21981,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.9403484463691713,
#   'pred_cascade': 9.639556930451931e-10,
#   'pred_tgtrack': 0.0596483945846557,
#   'pred_starttrack': 2.9456336392286175e-07,
#   'pred_stoptrack': 2.7685305212798994e-06,
#   'energy': 185495.0655258445,
#   'zenith': 2.7867329727450976,
#   'oneweight': 743408140178140.9,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9403484463691713,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_25281_origidx_17_RF22.mp4': {'event': 25281,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.5033625960350037,
#   'pred_cascade': 0.0836016237735748,
#   'pred_tgtrack': 0.3184644281864166,
#   'pred_starttrack': 0.0531370192766189,
#   'pred_stoptrack': 0.0414342544972896,
#   'energy': 3349.489690754437,
#   'zenith': 0.5610057655585103,
#   'oneweight': 62080830702.79307,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.5033625960350037,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_10019_origidx_17_RF22.mp4': {'event': 10019,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.0657323077321052,
#   'pred_cascade': 0.0161491930484771,
#   'pred_tgtrack': 0.8761676549911499,
#   'pred_starttrack': 0.0226376466453075,
#   'pred_stoptrack': 0.019313272088766,
#   'energy': 593062.971892756,
#   'zenith': 2.503125141793035,
#   'oneweight': 173752689427920.5,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.8761676549911499,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_27332_origidx_15_RF22.mp4': {'event': 27332,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.3825454413890838,
#   'pred_cascade': 0.1165103688836097,
#   'pred_tgtrack': 0.3397780656814575,
#   'pred_starttrack': 0.0563996843993663,
#   'pred_stoptrack': 0.1047664731740951,
#   'energy': 822.9949928459198,
#   'zenith': 0.6444352703245612,
#   'oneweight': 1912185754.386383,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3825454413890838,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_22070_origidx_21_RF22.mp4': {'event': 22070,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 3.7677677028113976e-05,
#   'pred_cascade': 4.0494207496522e-05,
#   'pred_tgtrack': 0.4682361185550689,
#   'pred_starttrack': 0.5312290191650391,
#   'pred_stoptrack': 0.0004566960851661,
#   'energy': 20777.57946215488,
#   'zenith': 1.2671995798032765,
#   'oneweight': 10619341456212.254,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.5312290191650391,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_22099_origidx_23_RF22.mp4': {'event': 22099,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 2.281050183228217e-05,
#   'pred_cascade': 1.7923687209986383e-06,
#   'pred_tgtrack': 0.9462783336639404,
#   'pred_starttrack': 0.0536473542451858,
#   'pred_stoptrack': 4.976677882950753e-05,
#   'energy': 291977.0533220505,
#   'zenith': 0.9743128764493976,
#   'oneweight': 2198966538046434.8,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9462783336639404,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_32121_origidx_30_RF22.mp4': {'event': 32121,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.0210407450795173,
#   'pred_cascade': 0.0094626806676387,
#   'pred_tgtrack': 0.6213911771774292,
#   'pred_starttrack': 0.0054492764174938,
#   'pred_stoptrack': 0.342656135559082,
#   'energy': 332.7543477465142,
#   'zenith': 1.7624255311118058,
#   'oneweight': 195962824.4029801,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.6213911771774292,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_8726_origidx_17_RF22.mp4': {'event': 8726,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.9994285702705384,
#   'pred_cascade': 1.479651388081038e-07,
#   'pred_tgtrack': 0.0004152313049416,
#   'pred_starttrack': 6.331291842798237e-06,
#   'pred_stoptrack': 0.0001498052297392,
#   'energy': 55832.81026648826,
#   'zenith': 0.857084573530973,
#   'oneweight': 68374121017354.32,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9994285702705384,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_214_origidx_10_RF22.mp4': {'event': 214,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.0535190515220165,
#   'pred_cascade': 0.0129148131236433,
#   'pred_tgtrack': 0.9031379222869872,
#   'pred_starttrack': 0.0157640781253576,
#   'pred_stoptrack': 0.0146641563624143,
#   'energy': 627.964251704552,
#   'zenith': 1.6712577727757092,
#   'oneweight': 2575547467.421905,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9031379222869872,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_11951_origidx_7_RF22.mp4': {'event': 11951,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 6.14315940765664e-05,
#   'pred_cascade': 4.503233412833652e-06,
#   'pred_tgtrack': 0.982269823551178,
#   'pred_starttrack': 0.0081025203689932,
#   'pred_stoptrack': 0.0095616308972239,
#   'energy': 526.8916266356414,
#   'zenith': 1.638095533630456,
#   'oneweight': 1228204973.2121248,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.982269823551178,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_1976_origidx_6_RF22.mp4': {'event': 1976,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.1126972734928131,
#   'pred_cascade': 0.0303536113351583,
#   'pred_tgtrack': 0.7697160243988037,
#   'pred_starttrack': 0.0482901595532894,
#   'pred_stoptrack': 0.0389428734779357,
#   'energy': 8515.487824444685,
#   'zenith': 0.5931426223805868,
#   'oneweight': 943902926430.858,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.7697160243988037,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_22231_origidx_29_RF22.mp4': {'event': 22231,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0463057719171047,
#   'pred_cascade': 0.0265177581459283,
#   'pred_tgtrack': 0.6397157311439514,
#   'pred_starttrack': 0.0169928818941116,
#   'pred_stoptrack': 0.2704678475856781,
#   'energy': 103653.11942654148,
#   'zenith': 1.3240975266646045,
#   'oneweight': 386863753867298.06,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.6397157311439514,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_31350_origidx_11_RF22.mp4': {'event': 31350,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.0013958809431642,
#   'pred_cascade': 0.0003467356145847,
#   'pred_tgtrack': 0.3422133922576904,
#   'pred_starttrack': 0.0002844631671905,
#   'pred_stoptrack': 0.6557595133781433,
#   'energy': 174233.74480917843,
#   'zenith': 1.0621518515300248,
#   'oneweight': 970011623798281.0,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.6557595133781433,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_27067_origidx_8_RF22.mp4': {'event': 27067,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.0865550190210342,
#   'pred_cascade': 0.0278982203453779,
#   'pred_tgtrack': 0.0451719351112842,
#   'pred_starttrack': 0.0115288607776165,
#   'pred_stoptrack': 0.8288459181785583,
#   'energy': 3939.1534286853152,
#   'zenith': 1.4773577515905425,
#   'oneweight': 250716699974.18335,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.8288459181785583,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_25930_origidx_34_RF22.mp4': {'event': 25930,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.2375321686267852,
#   'pred_cascade': 0.0217821598052978,
#   'pred_tgtrack': 0.4653025865554809,
#   'pred_starttrack': 0.0624406561255455,
#   'pred_stoptrack': 0.2129423916339874,
#   'energy': 599.859526583992,
#   'zenith': 2.2160562759552263,
#   'oneweight': 1692620013.3263917,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.4653025865554809,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_21711_origidx_4_RF22.mp4': {'event': 21711,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0897663459181785,
#   'pred_cascade': 0.0164838284254074,
#   'pred_tgtrack': 0.8474258184432983,
#   'pred_starttrack': 0.0282970480620861,
#   'pred_stoptrack': 0.0180269572883844,
#   'energy': 38237.30170335121,
#   'zenith': 0.8871424141132355,
#   'oneweight': 23781322943564.33,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.8474258184432983,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_28382_origidx_13_RF22.mp4': {'event': 28382,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.9996997117996216,
#   'pred_cascade': 1.960891449215296e-09,
#   'pred_tgtrack': 9.98778996290639e-05,
#   'pred_starttrack': 1.056064213855734e-08,
#   'pred_stoptrack': 0.000200467169634,
#   'energy': 27085.80964943431,
#   'zenith': 0.9708124594451036,
#   'oneweight': 17229708526437.371,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9996997117996216,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_7892_origidx_22_RF22.mp4': {'event': 7892,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 8.082533753395182e-09,
#   'pred_cascade': 1.2016515915451964e-14,
#   'pred_tgtrack': 0.9999996423721312,
#   'pred_starttrack': 3.5189906100185915e-08,
#   'pred_stoptrack': 3.7480921832866443e-07,
#   'energy': 364340.424724252,
#   'zenith': 2.103622288078296,
#   'oneweight': 5814408423423021.0,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9999996423721312,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_16788_origidx_31_RF22.mp4': {'event': 16788,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.0654681250452995,
#   'pred_cascade': 0.0136038856580853,
#   'pred_tgtrack': 0.0662327632308006,
#   'pred_starttrack': 0.7478270530700684,
#   'pred_stoptrack': 0.1068682670593261,
#   'energy': 226.41698471476383,
#   'zenith': 1.2099123125571616,
#   'oneweight': 50381197.08579368,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.7478270530700684,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_17812_origidx_24_RF22.mp4': {'event': 17812,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 9.810519259190189e-06,
#   'pred_cascade': 4.3908476854426234e-09,
#   'pred_tgtrack': 0.9996838569641112,
#   'pred_starttrack': 9.172209502139594e-06,
#   'pred_stoptrack': 0.0002971925132442,
#   'energy': 86076.91740492189,
#   'zenith': 2.11900516243068,
#   'oneweight': 76393103410710.61,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9996838569641112,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_10235_origidx_23_RF22.mp4': {'event': 10235,
#   'run': 21971,
#   'truth_classification': 7,
#   'pred_skim': 0.0002940665581263,
#   'pred_cascade': 0.7055303454399109,
#   'pred_tgtrack': 3.338249007356353e-05,
#   'pred_starttrack': 0.2836555242538452,
#   'pred_stoptrack': 0.0104867564514279,
#   'energy': 867.731021079155,
#   'zenith': 0.8318681751479889,
#   'oneweight': 5260152157.660255,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.7055303454399109,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_19527_origidx_6_RF22.mp4': {'event': 19527,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.0646233260631561,
#   'pred_cascade': 0.0207653399556875,
#   'pred_tgtrack': 0.1138970255851745,
#   'pred_starttrack': 0.0161660425364971,
#   'pred_stoptrack': 0.7845482230186462,
#   'energy': 121.99914271445044,
#   'zenith': 2.265300429318384,
#   'oneweight': 15783402.68782299,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.7845482230186462,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_16249_origidx_17_RF22.mp4': {'event': 16249,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0002525083255022,
#   'pred_cascade': 5.047498780186288e-05,
#   'pred_tgtrack': 0.998849391937256,
#   'pred_starttrack': 0.0005056202062405,
#   'pred_stoptrack': 0.0003420095017645,
#   'energy': 343942.9404791795,
#   'zenith': 2.266635069084211,
#   'oneweight': 5371694319509658.0,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.998849391937256,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_10578_origidx_5_RF22.mp4': {'event': 10578,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 1.6353961882487056e-06,
#   'pred_cascade': 3.287388608441688e-05,
#   'pred_tgtrack': 0.0011470727622509,
#   'pred_starttrack': 0.9988125562667848,
#   'pred_stoptrack': 5.777092155767605e-06,
#   'energy': 450.6964295541016,
#   'zenith': 1.7220188904285785,
#   'oneweight': 803249634.9998809,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.9988125562667848,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_7522_origidx_13_RF22.mp4': {'event': 7522,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 9.175461855193134e-06,
#   'pred_cascade': 1.4542137250828093e-05,
#   'pred_tgtrack': 0.8342757225036621,
#   'pred_starttrack': 0.1645602881908416,
#   'pred_stoptrack': 0.0011403707321733,
#   'energy': 154235.54956949037,
#   'zenith': 1.6145982224613082,
#   'oneweight': 3286136564449088.0,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.8342757225036621,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_2699_origidx_29_RF22.mp4': {'event': 2699,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.122868537902832,
#   'pred_cascade': 0.0386155657470226,
#   'pred_tgtrack': 0.6812754273414612,
#   'pred_starttrack': 0.0189804881811141,
#   'pred_stoptrack': 0.138259932398796,
#   'energy': 150.10312525233465,
#   'zenith': 1.467216851661589,
#   'oneweight': 28658673.483605634,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6812754273414612,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_9687_origidx_10_RF22.mp4': {'event': 9687,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 5.3838528401684016e-05,
#   'pred_cascade': 4.638819063984556e-06,
#   'pred_tgtrack': 0.5110189318656921,
#   'pred_starttrack': 0.0001691009383648,
#   'pred_stoptrack': 0.4887534976005554,
#   'energy': 2629.625338011152,
#   'zenith': 1.952142076146042,
#   'oneweight': 161025383863.01382,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.5110189318656921,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_25098_origidx_7_RF22.mp4': {'event': 25098,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 9.816238161874937e-06,
#   'pred_cascade': 8.424831321462989e-07,
#   'pred_tgtrack': 0.9987406134605408,
#   'pred_starttrack': 0.0005456912331283,
#   'pred_stoptrack': 0.0007030764827504,
#   'energy': 207528.561812396,
#   'zenith': 1.496885950495286,
#   'oneweight': 6021241497787793.0,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9987406134605408,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_22196_origidx_28_RF22.mp4': {'event': 22196,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 1.3061728168395348e-05,
#   'pred_cascade': 9.668292832998302e-10,
#   'pred_tgtrack': 0.9991427659988404,
#   'pred_starttrack': 4.841987902182154e-06,
#   'pred_stoptrack': 0.0008392392192035,
#   'energy': 99344.51143775156,
#   'zenith': 2.8317714834219267,
#   'oneweight': 321120008326144.1,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9991427659988404,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_5264_origidx_12_RF22.mp4': {'event': 5264,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.000228764838539,
#   'pred_cascade': 1.9308172340970486e-05,
#   'pred_tgtrack': 0.9955660700798036,
#   'pred_starttrack': 0.0039570620283484,
#   'pred_stoptrack': 0.0002287589741172,
#   'energy': 71750.91977100204,
#   'zenith': 1.080329587246238,
#   'oneweight': 98088095376185.2,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9955660700798036,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_29435_origidx_4_RF22.mp4': {'event': 29435,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.052900306880474,
#   'pred_cascade': 0.0069410684518516,
#   'pred_tgtrack': 0.8947626352310181,
#   'pred_starttrack': 0.0128134228289127,
#   'pred_stoptrack': 0.0325825251638889,
#   'energy': 295.73621079013435,
#   'zenith': 1.5722641820378869,
#   'oneweight': 122875527.7126792,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.8947626352310181,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_26372_origidx_43_RF22.mp4': {'event': 26372,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 5.7484718126943335e-05,
#   'pred_cascade': 1.210603386425646e-06,
#   'pred_tgtrack': 0.9996538162231444,
#   'pred_starttrack': 8.938595419749618e-05,
#   'pred_stoptrack': 0.0001981116074603,
#   'energy': 30243.131711209917,
#   'zenith': 0.6843784735843769,
#   'oneweight': 17381422487546.256,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9996538162231444,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_1020_origidx_31_RF22.mp4': {'event': 1020,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.0875724628567695,
#   'pred_cascade': 0.0347331017255783,
#   'pred_tgtrack': 0.6359838843345642,
#   'pred_starttrack': 0.0237146560102701,
#   'pred_stoptrack': 0.2179958522319793,
#   'energy': 500.8823797314101,
#   'zenith': 2.4003501955819453,
#   'oneweight': 1031173729.9694414,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.6359838843345642,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_2413_origidx_19_RF22.mp4': {'event': 2413,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 9.57711600996225e-12,
#   'pred_cascade': 3.178926956740047e-12,
#   'pred_tgtrack': 0.999504566192627,
#   'pred_starttrack': 0.0004787906364072,
#   'pred_stoptrack': 1.667422111495398e-05,
#   'energy': 238434.91140306,
#   'zenith': 2.953589088822432,
#   'oneweight': 1612128803834964.2,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.999504566192627,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_17400_origidx_13_RF22.mp4': {'event': 17400,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 3.110059321187464e-09,
#   'pred_cascade': 1.6237355904280548e-10,
#   'pred_tgtrack': 0.1491656601428985,
#   'pred_starttrack': 0.8508340716362,
#   'pred_stoptrack': 2.97591810749509e-07,
#   'energy': 26816.137518804266,
#   'zenith': 2.502824793034378,
#   'oneweight': 70024248197569.94,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.8508340716362,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_1364_origidx_38_RF22.mp4': {'event': 1364,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.9529488682746888,
#   'pred_cascade': 2.3049311494105496e-05,
#   'pred_tgtrack': 0.046340674161911,
#   'pred_starttrack': 7.76864089857554e-06,
#   'pred_stoptrack': 0.0006796037196181,
#   'energy': 440510.3205451193,
#   'zenith': 0.1980069128129502,
#   'oneweight': 2750184855721536.5,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9529488682746888,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_7188_origidx_4_RF22.mp4': {'event': 7188,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.235048621892929,
#   'pred_cascade': 0.0203663706779479,
#   'pred_tgtrack': 0.5636650919914246,
#   'pred_starttrack': 0.02036052942276,
#   'pred_stoptrack': 0.1605593562126159,
#   'energy': 504.7968895950252,
#   'zenith': 2.270166203643525,
#   'oneweight': 468518355.2978221,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.5636650919914246,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_4957_origidx_4_RF22.mp4': {'event': 4957,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.3596266210079193,
#   'pred_cascade': 0.0640864819288253,
#   'pred_tgtrack': 0.0240078512579202,
#   'pred_starttrack': 0.0542520321905612,
#   'pred_stoptrack': 0.498026967048645,
#   'energy': 11655.725964736615,
#   'zenith': 1.3448364398372876,
#   'oneweight': 1681850155904.231,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.498026967048645,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_2672_origidx_28_RF22.mp4': {'event': 2672,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.9975952506065368,
#   'pred_cascade': 2.7000638510799035e-05,
#   'pred_tgtrack': 0.0010403004707768,
#   'pred_starttrack': 5.316470196703449e-05,
#   'pred_stoptrack': 0.0012842358555644,
#   'energy': 71051.81096055199,
#   'zenith': 1.700894828955989,
#   'oneweight': 509479526210409.94,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9975952506065368,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_22151_origidx_27_RF22.mp4': {'event': 22151,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.4654785096645355,
#   'pred_cascade': 0.0985371023416519,
#   'pred_tgtrack': 0.0097162211313843,
#   'pred_starttrack': 0.0568564385175704,
#   'pred_stoptrack': 0.3694117069244385,
#   'energy': 12417.647139968538,
#   'zenith': 0.6718895521647377,
#   'oneweight': 1036880711265.4636,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.4654785096645355,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_1218_origidx_33_RF22.mp4': {'event': 1218,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.1617502272129058,
#   'pred_cascade': 0.0347754582762718,
#   'pred_tgtrack': 0.7470304369926453,
#   'pred_starttrack': 0.0170283503830432,
#   'pred_stoptrack': 0.0394155383110046,
#   'energy': 60952.705838237984,
#   'zenith': 1.1147180690091274,
#   'oneweight': 66790072340232.63,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.7470304369926453,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_9935_origidx_13_RF22.mp4': {'event': 9935,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 1.269201220566174e-05,
#   'pred_cascade': 3.936821979522165e-10,
#   'pred_tgtrack': 0.9856448173522948,
#   'pred_starttrack': 1.8685713598642906e-07,
#   'pred_stoptrack': 0.0143423322588205,
#   'energy': 10036.101349177865,
#   'zenith': 2.0779585192295755,
#   'oneweight': 4038454791573.9736,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9856448173522948,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_31960_origidx_22_RF22.mp4': {'event': 31960,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 5.475364741869271e-05,
#   'pred_cascade': 6.683789251837879e-06,
#   'pred_tgtrack': 0.8269029855728149,
#   'pred_starttrack': 0.173021912574768,
#   'pred_stoptrack': 1.3678364666702691e-05,
#   'energy': 90827.41170796686,
#   'zenith': 1.1713358917062302,
#   'oneweight': 293968586576420.0,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.8269029855728149,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_22143_origidx_25_RF22.mp4': {'event': 22143,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 1.7424814359401353e-05,
#   'pred_cascade': 1.6643078879496898e-06,
#   'pred_tgtrack': 0.6690861582756042,
#   'pred_starttrack': 0.0105558773502707,
#   'pred_stoptrack': 0.3203389644622803,
#   'energy': 2210.5765945450908,
#   'zenith': 1.6616563537257365,
#   'oneweight': 81547921269.70424,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.6690861582756042,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_25237_origidx_15_RF22.mp4': {'event': 25237,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 3.216664481442422e-05,
#   'pred_cascade': 1.0086609108839184e-05,
#   'pred_tgtrack': 0.9968247413635254,
#   'pred_starttrack': 0.0030967039056122,
#   'pred_stoptrack': 3.621722134994343e-05,
#   'energy': 525257.9810536316,
#   'zenith': 1.2797316932025182,
#   'oneweight': 1.3099862887866518e+16,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9968247413635254,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_25119_origidx_10_RF22.mp4': {'event': 25119,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.1599328219890594,
#   'pred_cascade': 1.605534453119617e-05,
#   'pred_tgtrack': 0.8397915363311768,
#   'pred_starttrack': 2.326274625374936e-05,
#   'pred_stoptrack': 0.0002364034153288,
#   'energy': 234867.40864959848,
#   'zenith': 0.8786372994546092,
#   'oneweight': 1403599731504735.8,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.8397915363311768,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_2035_origidx_8_RF22.mp4': {'event': 2035,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.1518236696720123,
#   'pred_cascade': 0.0333901718258857,
#   'pred_tgtrack': 0.0022391695529222,
#   'pred_starttrack': 0.0348980464041233,
#   'pred_stoptrack': 0.77764892578125,
#   'energy': 315.7411409181726,
#   'zenith': 1.6431343876477875,
#   'oneweight': 118353534.18896128,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.77764892578125,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_17674_origidx_21_RF22.mp4': {'event': 17674,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.996948778629303,
#   'pred_cascade': 6.242678978196636e-07,
#   'pred_tgtrack': 0.0028694672510027,
#   'pred_starttrack': 4.834222181671066e-06,
#   'pred_stoptrack': 0.0001763371983543,
#   'energy': 337333.9905580354,
#   'zenith': 0.6499924876756346,
#   'oneweight': 2521416072354884.0,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.996948778629303,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_23477_origidx_7_RF22.mp4': {'event': 23477,
#   'run': 21971,
#   'truth_classification': 3,
#   'pred_skim': 0.0001348978257738,
#   'pred_cascade': 3.187232869095169e-05,
#   'pred_tgtrack': 0.1531504541635513,
#   'pred_starttrack': 0.0681191384792327,
#   'pred_stoptrack': 0.7785636782646179,
#   'energy': 1711.999492456477,
#   'zenith': 2.9327469713826715,
#   'oneweight': 37060760533.08784,
#   'truth_classification_label': 'stopping_track',
#   'max_score_val': 0.7785636782646179,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_7387_origidx_10_RF22.mp4': {'event': 7387,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.1734977066516876,
#   'pred_cascade': 0.0663753822445869,
#   'pred_tgtrack': 0.5171435475349426,
#   'pred_starttrack': 0.1767298877239227,
#   'pred_stoptrack': 0.0662535279989242,
#   'energy': 783.5412601816345,
#   'zenith': 1.042570019125906,
#   'oneweight': 5180654711.473343,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.5171435475349426,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_17724_origidx_22_RF22.mp4': {'event': 17724,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.0092669930309057,
#   'pred_cascade': 0.0021717599593102,
#   'pred_tgtrack': 0.0008814727189019,
#   'pred_starttrack': 0.0043018669821321,
#   'pred_stoptrack': 0.9833779335021972,
#   'energy': 160.0965048051245,
#   'zenith': 1.9829576756937333,
#   'oneweight': 10211908.476177769,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9833779335021972,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_10007_origidx_15_RF22.mp4': {'event': 10007,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0032118789386004,
#   'pred_cascade': 6.994714567554183e-07,
#   'pred_tgtrack': 0.9967593550682068,
#   'pred_starttrack': 2.5775259473448382e-06,
#   'pred_stoptrack': 2.5377166821272112e-05,
#   'energy': 234536.80181404564,
#   'zenith': 0.8937775742963957,
#   'oneweight': 1186413266608296.8,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9967593550682068,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_28224_origidx_6_RF22.mp4': {'event': 28224,
#   'run': 21971,
#   'truth_classification': 3,
#   'pred_skim': 0.0012774539645761,
#   'pred_cascade': 0.0006242230883799,
#   'pred_tgtrack': 3.010794534930028e-05,
#   'pred_starttrack': 0.0027252570725977,
#   'pred_stoptrack': 0.9953429698944092,
#   'energy': 142097.71081443338,
#   'zenith': 2.013319929223729,
#   'oneweight': 3311664264645176.5,
#   'truth_classification_label': 'stopping_track',
#   'max_score_val': 0.9953429698944092,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_18430_origidx_8_RF22.mp4': {'event': 18430,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.0040016202256083,
#   'pred_cascade': 0.1289795190095901,
#   'pred_tgtrack': 0.3177139461040497,
#   'pred_starttrack': 0.4537349939346313,
#   'pred_stoptrack': 0.0955699980258941,
#   'energy': 199.76573149684077,
#   'zenith': 2.7709209688561134,
#   'oneweight': 35536788.39010358,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.4537349939346313,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_18492_origidx_12_RF22.mp4': {'event': 18492,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.0227131396532058,
#   'pred_cascade': 0.0040037333965301,
#   'pred_tgtrack': 0.964377760887146,
#   'pred_starttrack': 0.0029313052073121,
#   'pred_stoptrack': 0.0059740315191447,
#   'energy': 501.951402321093,
#   'zenith': 1.5463499553726674,
#   'oneweight': 866789164.8978605,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.964377760887146,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_8128_origidx_28_RF22.mp4': {'event': 8128,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.1083576306700706,
#   'pred_cascade': 0.0137797724455595,
#   'pred_tgtrack': 0.0222778562456369,
#   'pred_starttrack': 0.1206632107496261,
#   'pred_stoptrack': 0.7349215149879456,
#   'energy': 3803.635013513392,
#   'zenith': 2.166538332752499,
#   'oneweight': 273304178860.78857,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7349215149879456,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_88_origidx_7_RF22.mp4': {'event': 88,
#   'run': 21971,
#   'truth_classification': 7,
#   'pred_skim': 5.127432359586237e-06,
#   'pred_cascade': 0.9886031150817872,
#   'pred_tgtrack': 2.576205986315472e-07,
#   'pred_starttrack': 0.0113902334123849,
#   'pred_stoptrack': 1.154033952843747e-06,
#   'energy': 848030.2580256243,
#   'zenith': 0.6719649674017107,
#   'oneweight': 1.384607144048299e+16,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9886031150817872,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_7660_origidx_16_RF22.mp4': {'event': 7660,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.9064078330993652,
#   'pred_cascade': 0.0001226916065206,
#   'pred_tgtrack': 0.0886551141738891,
#   'pred_starttrack': 0.000405914557632,
#   'pred_stoptrack': 0.0044084032997488,
#   'energy': 226484.0765005634,
#   'zenith': 0.3179037874478354,
#   'oneweight': 789229155732686.1,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9064078330993652,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_8798_origidx_21_RF22.mp4': {'event': 8798,
#   'run': 21971,
#   'truth_classification': 3,
#   'pred_skim': 0.0223427098244428,
#   'pred_cascade': 0.0037820211146026,
#   'pred_tgtrack': 0.00280202482827,
#   'pred_starttrack': 0.0192344076931476,
#   'pred_stoptrack': 0.9518388509750366,
#   'energy': 335.2422307771389,
#   'zenith': 1.3725521323629275,
#   'oneweight': 201599120.55085683,
#   'truth_classification_label': 'stopping_track',
#   'max_score_val': 0.9518388509750366,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_18355_origidx_5_RF22.mp4': {'event': 18355,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.3980904519557953,
#   'pred_cascade': 0.1130289882421493,
#   'pred_tgtrack': 0.2032631486654281,
#   'pred_starttrack': 0.1765603125095367,
#   'pred_stoptrack': 0.109057068824768,
#   'energy': 171.15646079601268,
#   'zenith': 0.3768348475110197,
#   'oneweight': 15119127.935503429,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.3980904519557953,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_26170_origidx_41_RF22.mp4': {'event': 26170,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.1409512907266616,
#   'pred_cascade': 0.0203846432268619,
#   'pred_tgtrack': 0.632435142993927,
#   'pred_starttrack': 0.0625132843852043,
#   'pred_stoptrack': 0.1437156647443771,
#   'energy': 116.31065714716144,
#   'zenith': 0.7466898112347748,
#   'oneweight': 3341008.428811572,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.632435142993927,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_19960_origidx_18_RF22.mp4': {'event': 19960,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 3.399353021293905e-11,
#   'pred_cascade': 7.248043232266356e-08,
#   'pred_tgtrack': 3.124124248188309e-08,
#   'pred_starttrack': 0.9999998807907104,
#   'pred_stoptrack': 1.8295380488364543e-10,
#   'energy': 30456.68320195081,
#   'zenith': 0.6799013069391842,
#   'oneweight': 11409607696399.137,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.9999998807907104,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_19646_origidx_9_RF22.mp4': {'event': 19646,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.0585460476577281,
#   'pred_cascade': 0.0164210572838783,
#   'pred_tgtrack': 0.4096642434597015,
#   'pred_starttrack': 0.2828584611415863,
#   'pred_stoptrack': 0.2325101494789123,
#   'energy': 193603.04789277108,
#   'zenith': 1.5410276207461029,
#   'oneweight': 5382540875493997.0,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.4096642434597015,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 21},
# ...
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_10379_origidx_31_RF22.mp4': {'event': 10379,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.125240758061409,
#   'pred_cascade': 6.60279838484712e-05,
#   'pred_tgtrack': 0.8640672564506531,
#   'pred_starttrack': 0.0014571453211829,
#   'pred_stoptrack': 0.0091687217354774,
#   'energy': 26155.491111904958,
#   'zenith': 0.6296128920139177,
#   'oneweight': 11984857446288.14,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.8640672564506531,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_27561_origidx_25_RF22.mp4': {'event': 27561,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 6.792340172978584e-06,
#   'pred_cascade': 7.528135029133409e-06,
#   'pred_tgtrack': 0.9965938925743104,
#   'pred_starttrack': 0.0033146957866847,
#   'pred_stoptrack': 7.694802479818463e-05,
#   'energy': 611743.0886921947,
#   'zenith': 0.9144498099633932,
#   'oneweight': 7718712338984411.0,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9965938925743104,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_3053_origidx_41_RF22.mp4': {'event': 3053,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0010378872975707,
#   'pred_cascade': 6.552292575179308e-08,
#   'pred_tgtrack': 0.9988192915916444,
#   'pred_starttrack': 0.0001178332968265,
#   'pred_stoptrack': 2.4938683054642752e-05,
#   'energy': 41695.12238475962,
#   'zenith': 1.8040835836266007,
#   'oneweight': 181607705337511.4,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9988192915916444,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_5221_origidx_9_RF22.mp4': {'event': 5221,
#   'run': 21971,
#   'truth_classification': 7,
#   'pred_skim': 4.679335688706488e-05,
#   'pred_cascade': 0.9991735816001892,
#   'pred_tgtrack': 7.087420073048635e-08,
#   'pred_starttrack': 0.0007795137935318,
#   'pred_stoptrack': 1.9447609744815963e-08,
#   'energy': 425321.273441878,
#   'zenith': 1.2673252008673634,
#   'oneweight': 7378329092413094.0,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9991735816001892,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_27850_origidx_38_RF22.mp4': {'event': 27850,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.0475337170064449,
#   'pred_cascade': 0.0157160777598619,
#   'pred_tgtrack': 0.7918919324874878,
#   'pred_starttrack': 0.0075007425621151,
#   'pred_stoptrack': 0.137357547879219,
#   'energy': 844449.9386264703,
#   'zenith': 2.181162928724389,
#   'oneweight': 5516485417952399.0,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.7918919324874878,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_8739_origidx_19_RF22.mp4': {'event': 8739,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.3199162185192108,
#   'pred_cascade': 0.1300368010997772,
#   'pred_tgtrack': 0.3799476027488708,
#   'pred_starttrack': 0.0561485663056373,
#   'pred_stoptrack': 0.1139508262276649,
#   'energy': 6907.773584179908,
#   'zenith': 0.7185634666815001,
#   'oneweight': 464329393076.3142,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.3799476027488708,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_192_origidx_9_RF22.mp4': {'event': 192,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 1.6441577827208675e-05,
#   'pred_cascade': 1.943816698712908e-07,
#   'pred_tgtrack': 0.95233416557312,
#   'pred_starttrack': 5.545919520955067e-06,
#   'pred_stoptrack': 0.0476435422897338,
#   'energy': 2382.8438625474646,
#   'zenith': 1.976676654956638,
#   'oneweight': 118805425827.85956,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.95233416557312,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_9617_origidx_8_RF22.mp4': {'event': 9617,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 0.0003413617669139,
#   'pred_cascade': 0.0001498932979302,
#   'pred_tgtrack': 0.000299590115901,
#   'pred_starttrack': 0.9991687536239624,
#   'pred_stoptrack': 4.055125828017481e-05,
#   'energy': 1512.2878119249688,
#   'zenith': 0.5429507382409665,
#   'oneweight': 15030981134.002794,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.9991687536239624,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_16790_origidx_32_RF22.mp4': {'event': 16790,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.011032878421247,
#   'pred_cascade': 0.0018174941651523,
#   'pred_tgtrack': 0.8249709010124207,
#   'pred_starttrack': 0.1317493021488189,
#   'pred_stoptrack': 0.0304294526576995,
#   'energy': 336.7185459524566,
#   'zenith': 1.3419375756929064,
#   'oneweight': 202582317.8127676,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.8249709010124207,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_2974_origidx_35_RF22.mp4': {'event': 2974,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.0899104103446006,
#   'pred_cascade': 0.0225532464683055,
#   'pred_tgtrack': 0.8332794904708862,
#   'pred_starttrack': 0.0151607329025864,
#   'pred_stoptrack': 0.0390961095690727,
#   'energy': 223.384920873676,
#   'zenith': 2.31080172185756,
#   'oneweight': 102136137.14765568,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.8332794904708862,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_19844_origidx_14_RF22.mp4': {'event': 19844,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0033721416257321,
#   'pred_cascade': 0.0009528994560241,
#   'pred_tgtrack': 0.986014485359192,
#   'pred_starttrack': 0.008917779661715,
#   'pred_stoptrack': 0.000742573000025,
#   'energy': 41069.64959293526,
#   'zenith': 0.6314791693697006,
#   'oneweight': 31802331404249.598,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.986014485359192,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_14741_origidx_9_RF22.mp4': {'event': 14741,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0009673111489973,
#   'pred_cascade': 1.3210009974784498e-08,
#   'pred_tgtrack': 0.9977338314056396,
#   'pred_starttrack': 0.0011416693450883,
#   'pred_stoptrack': 0.0001571256434544,
#   'energy': 12060.97596540132,
#   'zenith': 2.23334772318828,
#   'oneweight': 9645628740218.123,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9977338314056396,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_2640_origidx_27_RF22.mp4': {'event': 2640,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.999699592590332,
#   'pred_cascade': 1.1783201898651896e-06,
#   'pred_tgtrack': 0.0001069050995283,
#   'pred_starttrack': 1.1633896974672098e-05,
#   'pred_stoptrack': 0.0001806918880902,
#   'energy': 548419.0107717715,
#   'zenith': 1.0041018446528254,
#   'oneweight': 7191119124115907.0,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.999699592590332,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_21852_origidx_12_RF22.mp4': {'event': 21852,
#   'run': 21971,
#   'truth_classification': 3,
#   'pred_skim': 0.0002936635864898,
#   'pred_cascade': 3.636541441665031e-05,
#   'pred_tgtrack': 0.0012364418944343,
#   'pred_starttrack': 0.0051533100195229,
#   'pred_stoptrack': 0.9932802319526672,
#   'energy': 2134.879987578203,
#   'zenith': 1.53419243075628,
#   'oneweight': 42594088229.50905,
#   'truth_classification_label': 'stopping_track',
#   'max_score_val': 0.9932802319526672,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_3798_origidx_5_RF22.mp4': {'event': 3798,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.9999922513961792,
#   'pred_cascade': 1.2208435862248734e-07,
#   'pred_tgtrack': 4.83983001231536e-07,
#   'pred_starttrack': 5.707694981538225e-06,
#   'pred_stoptrack': 1.4575950899597956e-06,
#   'energy': 402023.0471799376,
#   'zenith': 0.9159218432728896,
#   'oneweight': 4476224791524610.5,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9999922513961792,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_16743_origidx_29_RF22.mp4': {'event': 16743,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0002787680714391,
#   'pred_cascade': 5.4742806241847575e-05,
#   'pred_tgtrack': 0.996695876121521,
#   'pred_starttrack': 0.0026546900626271,
#   'pred_stoptrack': 0.000315978686558,
#   'energy': 142093.00139627655,
#   'zenith': 1.2012723262909206,
#   'oneweight': 649601058029679.8,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.996695876121521,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_32083_origidx_26_RF22.mp4': {'event': 32083,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 7.537968485848978e-05,
#   'pred_cascade': 2.2036381778889336e-05,
#   'pred_tgtrack': 0.000731160514988,
#   'pred_starttrack': 0.9991027116775512,
#   'pred_stoptrack': 6.87021019984968e-05,
#   'energy': 1630.32092025572,
#   'zenith': 1.1469092741486082,
#   'oneweight': 32386888190.696835,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.9991027116775512,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_26110_origidx_37_RF22.mp4': {'event': 26110,
#   'run': 21971,
#   'truth_classification': 7,
#   'pred_skim': 3.614502202253789e-05,
#   'pred_cascade': 0.9208863377571106,
#   'pred_tgtrack': 1.88451031135628e-05,
#   'pred_starttrack': 0.0789772123098373,
#   'pred_stoptrack': 8.148553752107546e-05,
#   'energy': 1415.7377242159876,
#   'zenith': 2.145001974766854,
#   'oneweight': 16665183484.097448,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9208863377571106,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_22026_origidx_19_RF22.mp4': {'event': 22026,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.4833212792873382,
#   'pred_cascade': 0.0788209810853004,
#   'pred_tgtrack': 0.2581682801246643,
#   'pred_starttrack': 0.0563561804592609,
#   'pred_stoptrack': 0.1233333051204681,
#   'energy': 3149.6187564859883,
#   'zenith': 1.6941680211511914,
#   'oneweight': 193221195015.7627,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4833212792873382,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_31135_origidx_5_RF22.mp4': {'event': 31135,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 5.579252047027694e-07,
#   'pred_cascade': 3.8758307674413567e-10,
#   'pred_tgtrack': 0.9791202545166016,
#   'pred_starttrack': 3.0873088689986616e-05,
#   'pred_stoptrack': 0.0208481643348932,
#   'energy': 426221.5010436883,
#   'zenith': 2.519578710771086,
#   'oneweight': 8963216494790779.0,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9791202545166016,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_21925_origidx_15_RF22.mp4': {'event': 21925,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0131306992843747,
#   'pred_cascade': 0.0048926193267107,
#   'pred_tgtrack': 0.96497905254364,
#   'pred_starttrack': 0.0133327646180987,
#   'pred_stoptrack': 0.0036648605018854,
#   'energy': 70987.51803877538,
#   'zenith': 1.2778268520666447,
#   'oneweight': 127491322820460.69,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.96497905254364,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_2585_origidx_25_RF22.mp4': {'event': 2585,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0025995983742177,
#   'pred_cascade': 0.0003670897567644,
#   'pred_tgtrack': 0.6726024746894836,
#   'pred_starttrack': 0.0083202142268419,
#   'pred_stoptrack': 0.3161106407642364,
#   'energy': 462331.240782503,
#   'zenith': 1.4810991378239275,
#   'oneweight': 2.094604857395701e+16,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.6726024746894836,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_19669_origidx_11_RF22.mp4': {'event': 19669,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.8493888974189758,
#   'pred_cascade': 0.0002172000095015,
#   'pred_tgtrack': 0.148509532213211,
#   'pred_starttrack': 0.0008783075027167,
#   'pred_stoptrack': 0.0010060409549623,
#   'energy': 20144.23029232704,
#   'zenith': 0.7803124176951014,
#   'oneweight': 5708937417884.308,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.8493888974189758,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000898/compressed_run_21971_event_453_origidx_17_RF22.mp4': {'event': 453,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.047156985849142,
#   'pred_cascade': 0.0088055869564414,
#   'pred_tgtrack': 0.4340479075908661,
#   'pred_starttrack': 0.0360470488667488,
#   'pred_stoptrack': 0.4739423990249634,
#   'energy': 10657.164446499251,
#   'zenith': 0.399771774436667,
#   'oneweight': 883278106449.5916,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.4739423990249634,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 13}}

# %%
make_subject_set('numu_run_21971_subrun_000898_phase2')
# Out:
# Subject Set Name: numu_run_21971_subrun_000898_phase2
# Subject Set ID: 112464
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>]

# %%
uploader(compressed_path,numu_csv,112464)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:468: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   dict_manifest = s3.to_dict('dict')
# Confirm if subject set 112464 is listed below.
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>]
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>]
# Number of times loop has ran: 1
# Number of times loop has ran: 2
# Number of times loop has ran: 3
# Number of times loop has ran: 4
# Number of times loop has ran: 5
# Number of times loop has ran: 6
# Number of times loop has ran: 7
# Number of times loop has ran: 8
# Number of times loop has ran: 9
# Number of times loop has ran: 10
# Number of times loop has ran: 11
# Number of times loop has ran: 12
# Number of times loop has ran: 13
# Number of times loop has ran: 14
# Number of times loop has ran: 15
# Number of times loop has ran: 16
# Number of times loop has ran: 17
# Number of times loop has ran: 18
# Number of times loop has ran: 19
# Number of times loop has ran: 20
# Number of times loop has ran: 21
# Number of times loop has ran: 22
# Number of times loop has ran: 23
# Number of times loop has ran: 24
# Number of times loop has ran: 25
# Number of times loop has ran: 26
# Number of times loop has ran: 27
# Number of times loop has ran: 28
# Number of times loop has ran: 29
# Number of times loop has ran: 30
# Number of times loop has ran: 31
# Number of times loop has ran: 32
# Number of times loop has ran: 33
# Number of times loop has ran: 34
# Number of times loop has ran: 35
# Number of times loop has ran: 36
# Number of times loop has ran: 37
# Number of times loop has ran: 38
# Number of times loop has ran: 39
# Number of times loop has ran: 40
# Number of times loop has ran: 41
# Number of times loop has ran: 42
# Number of times loop has ran: 43
# Number of times loop has ran: 44
# Number of times loop has ran: 45
# Number of times loop has ran: 46
# Number of times loop has ran: 47
# Number of times loop has ran: 48
# Number of times loop has ran: 49
# Number of times loop has ran: 50
# Number of times loop has ran: 51
# Number of times loop has ran: 52
# Number of times loop has ran: 53
# Number of times loop has ran: 54
# Number of times loop has ran: 55
# Number of times loop has ran: 56
# Number of times loop has ran: 57
# Number of times loop has ran: 58
# Number of times loop has ran: 59
# Number of times loop has ran: 60
# Number of times loop has ran: 61
# Number of times loop has ran: 62
# Number of times loop has ran: 63
# Number of times loop has ran: 64
# Number of times loop has ran: 65
# Number of times loop has ran: 66
# Number of times loop has ran: 67
# Number of times loop has ran: 68
# Number of times loop has ran: 69
# Number of times loop has ran: 70
# Number of times loop has ran: 71
# Number of times loop has ran: 72
# Number of times loop has ran: 73
# Number of times loop has ran: 74
# Number of times loop has ran: 75
# Number of times loop has ran: 76
# Number of times loop has ran: 77
# Number of times loop has ran: 78
# Number of times loop has ran: 79
# Number of times loop has ran: 80
# Number of times loop has ran: 81
# Number of times loop has ran: 82
# Number of times loop has ran: 83
# Number of times loop has ran: 84
# Number of times loop has ran: 85
# Number of times loop has ran: 86
# Number of times loop has ran: 87
# Number of times loop has ran: 88
# Number of times loop has ran: 89
# Number of times loop has ran: 90
# Number of times loop has ran: 91
# Number of times loop has ran: 92
# Number of times loop has ran: 93
# Number of times loop has ran: 94
# Number of times loop has ran: 95
# Number of times loop has ran: 96
# Number of times loop has ran: 97
# Number of times loop has ran: 98
# Number of times loop has ran: 99
# Number of times loop has ran: 100
# Number of times loop has ran: 101
# Number of times loop has ran: 102
# Number of times loop has ran: 103
# Number of times loop has ran: 104
# Number of times loop has ran: 105
# Number of times loop has ran: 106
# Number of times loop has ran: 107
# Number of times loop has ran: 108
# Number of times loop has ran: 109
# Number of times loop has ran: 110
# Number of times loop has ran: 111
# Number of times loop has ran: 112
# Number of times loop has ran: 113
# Number of times loop has ran: 114
# Number of times loop has ran: 115
# Number of times loop has ran: 116
# Number of times loop has ran: 117
# Number of times loop has ran: 118
# Number of times loop has ran: 119
# Number of times loop has ran: 120
# Number of times loop has ran: 121
# Number of times loop has ran: 122
# Number of times loop has ran: 123
# Number of times loop has ran: 124
# Number of times loop has ran: 125
# Number of times loop has ran: 126
# Number of times loop has ran: 127
# Number of times loop has ran: 128
# Number of times loop has ran: 129
# Number of times loop has ran: 130
# Number of times loop has ran: 131
# Number of times loop has ran: 132
# Number of times loop has ran: 133
# Number of times loop has ran: 134
# Number of times loop has ran: 135
# Number of times loop has ran: 136
# Number of times loop has ran: 137
# Number of times loop has ran: 138
# Number of times loop has ran: 139
# Number of times loop has ran: 140
# Number of times loop has ran: 141
# Number of times loop has ran: 142
# Number of times loop has ran: 143
# Number of times loop has ran: 144
# Number of times loop has ran: 145
# Number of times loop has ran: 146
# Number of times loop has ran: 147
# Number of times loop has ran: 148
# Number of times loop has ran: 149
# Number of times loop has ran: 150
# Number of times loop has ran: 151
# Number of times loop has ran: 152
# Number of times loop has ran: 153
# Number of times loop has ran: 154
# Number of times loop has ran: 155
# Number of times loop has ran: 156
# Number of times loop has ran: 157
# Number of times loop has ran: 158
# Number of times loop has ran: 159
# Number of times loop has ran: 160
# Number of times loop has ran: 161
# Number of times loop has ran: 162
# Number of times loop has ran: 163
# Number of times loop has ran: 164
# Number of times loop has ran: 165
# Number of times loop has ran: 166
# Number of times loop has ran: 167
# Number of times loop has ran: 168
# Number of times loop has ran: 169
# Number of times loop has ran: 170
# Number of times loop has ran: 171
# Number of times loop has ran: 172
# Number of times loop has ran: 173
# Number of times loop has ran: 174
# Number of times loop has ran: 175
# Number of times loop has ran: 176
# Number of times loop has ran: 177
# Number of times loop has ran: 178
# Number of times loop has ran: 179
# Number of times loop has ran: 180
# Number of times loop has ran: 181
# Number of times loop has ran: 182
# Number of times loop has ran: 183
# Number of times loop has ran: 184
# Number of times loop has ran: 185
# Number of times loop has ran: 186
# Number of times loop has ran: 187
# Number of times loop has ran: 188
# Number of times loop has ran: 189
# Number of times loop has ran: 190
# Number of times loop has ran: 191
# Number of times loop has ran: 192
# Number of times loop has ran: 193
# Number of times loop has ran: 194
# Number of times loop has ran: 195
# Number of times loop has ran: 196
# Number of times loop has ran: 197
# Number of times loop has ran: 198
# Number of times loop has ran: 199
# Number of times loop has ran: 200
# Number of times loop has ran: 201
# Number of times loop has ran: 202
# Number of times loop has ran: 203
# Number of times loop has ran: 204
# Number of times loop has ran: 205
# Number of times loop has ran: 206
# Number of times loop has ran: 207
# Number of times loop has ran: 208
# Number of times loop has ran: 209
# Number of times loop has ran: 210
# Number of times loop has ran: 211
# Number of times loop has ran: 212
# Number of times loop has ran: 213
# Number of times loop has ran: 214
# Number of times loop has ran: 215
# Number of times loop has ran: 216
# Number of times loop has ran: 217
# Number of times loop has ran: 218
# Number of times loop has ran: 219
# Number of times loop has ran: 220
# Number of times loop has ran: 221
# Number of times loop has ran: 222
# Number of times loop has ran: 223
# Number of times loop has ran: 224
# Number of times loop has ran: 225
# Number of times loop has ran: 226
# Number of times loop has ran: 227
# Number of times loop has ran: 228
# Number of times loop has ran: 229
# Number of times loop has ran: 230
# Number of times loop has ran: 231
# Number of times loop has ran: 232
# Number of times loop has ran: 233
# Number of times loop has ran: 234
# Number of times loop has ran: 235
# Number of times loop has ran: 236
# Number of times loop has ran: 237
# Number of times loop has ran: 238
# Number of times loop has ran: 239
# Number of times loop has ran: 240
# Number of times loop has ran: 241
# Number of times loop has ran: 242
# Number of times loop has ran: 243
# Number of times loop has ran: 244
# Number of times loop has ran: 245
# Number of times loop has ran: 246
# Number of times loop has ran: 247
# Number of times loop has ran: 248
# Number of times loop has ran: 249
# Number of times loop has ran: 250
# Number of times loop has ran: 251
# Number of times loop has ran: 252
# Number of times loop has ran: 253
# Number of times loop has ran: 254
# Number of times loop has ran: 255
# Number of times loop has ran: 256
# Number of times loop has ran: 257
# Number of times loop has ran: 258
# Number of times loop has ran: 259
# Number of times loop has ran: 260
# Number of times loop has ran: 261
# Number of times loop has ran: 262
# Number of times loop has ran: 263
# Number of times loop has ran: 264
# Number of times loop has ran: 265
# Number of times loop has ran: 266
# Number of times loop has ran: 267
# Number of times loop has ran: 268
# Number of times loop has ran: 269
# Number of times loop has ran: 270
# Number of times loop has ran: 271
# Number of times loop has ran: 272
# Number of times loop has ran: 273
# Number of times loop has ran: 274
# Number of times loop has ran: 275
# Number of times loop has ran: 276
# Number of times loop has ran: 277
# Number of times loop has ran: 278
# Number of times loop has ran: 279
# Number of times loop has ran: 280
# Number of times loop has ran: 281
# Number of times loop has ran: 282
# Number of times loop has ran: 283
# Number of times loop has ran: 284
# Number of times loop has ran: 285
# Number of times loop has ran: 286
# Number of times loop has ran: 287
# Number of times loop has ran: 288
# Number of times loop has ran: 289
# Number of times loop has ran: 290
# Number of times loop has ran: 291
# Number of times loop has ran: 292
# Number of times loop has ran: 293
# Number of times loop has ran: 294
# Number of times loop has ran: 295
# Number of times loop has ran: 296
# Number of times loop has ran: 297
# Number of times loop has ran: 298
# Number of times loop has ran: 299
# Number of times loop has ran: 300
# Number of times loop has ran: 301
# Number of times loop has ran: 302
# Number of times loop has ran: 303
# Number of times loop has ran: 304
# Number of times loop has ran: 305
# Number of times loop has ran: 306
# Number of times loop has ran: 307
# Number of times loop has ran: 308
# Number of times loop has ran: 309
# Number of times loop has ran: 310
# Number of times loop has ran: 311
# Number of times loop has ran: 312
# Number of times loop has ran: 313
# Number of times loop has ran: 314
# Number of times loop has ran: 315
# Number of times loop has ran: 316
# Number of times loop has ran: 317
# Number of times loop has ran: 318
# Number of times loop has ran: 319
# Number of times loop has ran: 320
# Number of times loop has ran: 321
# Number of times loop has ran: 322
# Number of times loop has ran: 323
# Number of times loop has ran: 324
# Number of times loop has ran: 325
# Number of times loop has ran: 326
# Number of times loop has ran: 327
# Number of times loop has ran: 328
# Number of times loop has ran: 329
# Number of times loop has ran: 330
# Number of times loop has ran: 331
# Number of times loop has ran: 332
# Number of times loop has ran: 333
# Number of times loop has ran: 334
# Number of times loop has ran: 335
# Number of times loop has ran: 336
# Number of times loop has ran: 337
# Number of times loop has ran: 338
# Number of times loop has ran: 339
# Number of times loop has ran: 340
# Number of times loop has ran: 341
# Number of times loop has ran: 342
# Number of times loop has ran: 343
# Number of times loop has ran: 344
# Number of times loop has ran: 345
# Number of times loop has ran: 346
# Number of times loop has ran: 347
# Number of times loop has ran: 348
# Number of times loop has ran: 349
# Number of times loop has ran: 350
# Number of times loop has ran: 351
# Number of times loop has ran: 352
# Number of times loop has ran: 353
# Number of times loop has ran: 354
# Number of times loop has ran: 355
# Number of times loop has ran: 356
# Number of times loop has ran: 357
# Number of times loop has ran: 358
# Number of times loop has ran: 359
# Number of times loop has ran: 360
# Number of times loop has ran: 361
# Number of times loop has ran: 362
# Number of times loop has ran: 363
# Number of times loop has ran: 364
# Number of times loop has ran: 365
# Number of times loop has ran: 366
# Number of times loop has ran: 367
# Number of times loop has ran: 368
# Number of times loop has ran: 369
# Number of times loop has ran: 370
# Number of times loop has ran: 371
# Number of times loop has ran: 372
# Number of times loop has ran: 373
# Number of times loop has ran: 374
# Number of times loop has ran: 375
# Number of times loop has ran: 376
# Number of times loop has ran: 377
# Number of times loop has ran: 378
# Number of times loop has ran: 379
# Number of times loop has ran: 380
# Number of times loop has ran: 381
# Number of times loop has ran: 382
# Number of times loop has ran: 383
# Number of times loop has ran: 384
# Number of times loop has ran: 385
# Number of times loop has ran: 386
# Number of times loop has ran: 387
# Number of times loop has ran: 388
# Number of times loop has ran: 389
# Number of times loop has ran: 390
# Number of times loop has ran: 391
# Number of times loop has ran: 392
# Number of times loop has ran: 393
# Number of times loop has ran: 394
# Number of times loop has ran: 395
# Number of times loop has ran: 396
# Number of times loop has ran: 397
# Number of times loop has ran: 398
# Number of times loop has ran: 399
# Number of times loop has ran: 400
# Number of times loop has ran: 401
# Number of times loop has ran: 402
# Number of times loop has ran: 403
# Number of times loop has ran: 404
# Number of times loop has ran: 405
# Number of times loop has ran: 406
# Number of times loop has ran: 407
# Number of times loop has ran: 408
# Number of times loop has ran: 409
# Number of times loop has ran: 410
# Number of times loop has ran: 411
# Number of times loop has ran: 412
# Number of times loop has ran: 413
# Number of times loop has ran: 414
# Number of times loop has ran: 415
# Number of times loop has ran: 416
# Number of times loop has ran: 417
# Number of times loop has ran: 418
# Number of times loop has ran: 419
# Number of times loop has ran: 420
# Number of times loop has ran: 421
# Number of times loop has ran: 422
# Number of times loop has ran: 423
# Number of times loop has ran: 424
# Number of times loop has ran: 425
# Number of times loop has ran: 426
# Number of times loop has ran: 427
# Number of times loop has ran: 428
# Number of times loop has ran: 429
# Number of times loop has ran: 430
# Number of times loop has ran: 431
# Number of times loop has ran: 432
# Number of times loop has ran: 433
# Number of times loop has ran: 434
# Number of times loop has ran: 435
# Number of times loop has ran: 436
# Number of times loop has ran: 437
# Number of times loop has ran: 438
# Number of times loop has ran: 439
# Number of times loop has ran: 440
# Number of times loop has ran: 441
# Number of times loop has ran: 442
# Number of times loop has ran: 443
# Number of times loop has ran: 444
# Number of times loop has ran: 445
# Number of times loop has ran: 446
# Number of times loop has ran: 447
# Number of times loop has ran: 448
# Number of times loop has ran: 449
# Number of times loop has ran: 450
# Number of times loop has ran: 451
# Number of times loop has ran: 452
# Number of times loop has ran: 453
# Number of times loop has ran: 454
# Number of times loop has ran: 455
# Number of times loop has ran: 456
# Number of times loop has ran: 457
# Number of times loop has ran: 458
# Number of times loop has ran: 459
# Number of times loop has ran: 460
# Number of times loop has ran: 461
# Number of times loop has ran: 462
# Number of times loop has ran: 463
# Number of times loop has ran: 464
# Number of times loop has ran: 465
# Number of times loop has ran: 466
# Number of times loop has ran: 467
# Number of times loop has ran: 468
# Number of times loop has ran: 469
# Number of times loop has ran: 470
# Number of times loop has ran: 471
# Number of times loop has ran: 472
# Number of times loop has ran: 473
# Number of times loop has ran: 474
# Number of times loop has ran: 475
# Number of times loop has ran: 476
# Number of times loop has ran: 477
# Number of times loop has ran: 478
# Number of times loop has ran: 479
# Number of times loop has ran: 480
# Number of times loop has ran: 481
# Number of times loop has ran: 482
# Number of times loop has ran: 483
# Number of times loop has ran: 484
# Number of times loop has ran: 485
# Number of times loop has ran: 486
# Number of times loop has ran: 487
# Number of times loop has ran: 488
# Number of times loop has ran: 489
# Number of times loop has ran: 490
# Number of times loop has ran: 491
# Number of times loop has ran: 492
# Number of times loop has ran: 493
# Number of times loop has ran: 494
# Number of times loop has ran: 495
# Number of times loop has ran: 496
# Number of times loop has ran: 497
# Number of times loop has ran: 498
# Number of times loop has ran: 499
# Number of times loop has ran: 500
