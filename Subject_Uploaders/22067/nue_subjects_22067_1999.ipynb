# %% [markdown]
# # Phase 1: Subject Creation
#
# **Description:**
#
# This notebook is to act as the resulting summary file for the creation and upload of subjects for the IceCube Zooniverse project currently called *Name that Neutrino!*. The project is currently being maintained by Elizabeth Warrick (as of March 2023). In this notebook, we take the i3 file and run it through several filters. [note: describe more later].
#
# > Nu Type: NuE
#
# > Run: 22076
#
# > SubRun: 001999
#
# ### Summary Stats:
#
# To be filled in after completing process. Also need to figure out global variables.
#
# **Subject Set Name:**

# %%
#Imports

#My functions: 
from uniformenergydist_filter import *

#General:
import numpy as np
import sys
import os
import subprocess
import argparse
import csv
from tables import *
import pandas as pd
from matplotlib import pyplot as plt
import h5py

#Zooniverse:
from panoptes_client import Panoptes, Project, SubjectSet, Subject
import magic
import glob

#IceCube:
from icecube.icetray import I3Units
import icecube.MuonGun
from icecube import dataio, dataclasses, icetray, MuonGun
from I3Tray import *
from icecube.hdfwriter import I3HDFWriter
from mc_labeler import MCLabeler #make sure that mc_labeler script is in current directory.

# %%
#Specify file paths:

#Initial I3 File:
nue = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst'

#Desired output directory. Note that creation of this directory is not yet coded and is done manually. 
phase1_dir = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/'

# %%
#Run Filter 1 to label MC truth.
filter1(nue,phase1_dir)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/mc_labeler.py:523: UserWarning: Couldn't find OMKey in MCPESeriesMap
#   warnings.warn("Couldn't find OMKey in MCPESeriesMap")

# %% [markdown]
# Note that the above cell might return an "exception" warning that the *MCPESeriesMap could not be found*. I am unsure why it does that because when I check the i3 file in dataio-shovel, I see the specified mc_pid_series_map (look at mc_labeler.py for exact name of specified key). The resulting file size should be around 400 MB.

# %%
#Path of hdf from above filter.
nue_hdf = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/\
Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst.hd5'

# %%
#Run uniformenergy_events function which requires hdf from filter 1, 
#number of bins, size of each random choice, and a random seed. 

uniformenergy_events(nue_hdf,25,10,12,subrun = True)
# Out:
# Number of Bins: 25
# Number of Events per Bin: 10
# Total Number of Events: 250
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['binned_log10E'] = pd.cut(x = np.log10(df_filtered['energy']), bins = bins, labels = labels, include_lowest = True) #might throw an error?
# Initial Number of Events: 2730
# Number of Events after filtering: 2661
# Please input subrun number:
# 1999

# %% [markdown]
# The above function throws another warning about pd.cut, currently that is not a problem but I don't know if a new version of pandas will allow this.

# %%
#Path to Random Events CSV
nue_csv = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/random_events_uniform_energy_distrib_22067_1999.csv'

# %%
#Run event_characterization_plots function whick makes some quick 
#plots to get an idea of what data you're dealing with.
#Note that I want to update the plot types, maybe make a 2D histogram as Mike K suggested. 
#For truth labels, check out enums.py or in the .py file that holds the functions.

event_characterization_plots(nue_csv)

# %% [markdown]
# Now that we have the events for this phase chosen, we run the second filter to pick out only those events.

# %%
#Path to i3 file from filter1 with MC truth labels. 
nue_filter1 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst'

# %%
#Run function to perform second filter which passes through only selected event IDs chosen from 
#the uniformenergy_events function. 
filter2(nue_filter1,phase1_dir,nue_csv)

# %%
#Path to i3 file from filter 2 that holds only specified events. 
nue_filter2 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst'

# %%
#Run function to perform third filter, which returns only the DAQ frames of the specified events.
#DAQ only file is then split up into many smaller i3 files since SteamShovel can't handle making videos of large
#i3 files at one time. Size limit is approx 2E6 MB (? unsure of units)
filter3(nue_filter2,22067_1999,phase1_dir)

# %%
#Path to NuMu Daq Only folder
nue_daq = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220671999/'

# %%
get_steamshovel(nue_daq,220671999)#forgot to run with right run id
# Out:
# Finished Videos in: daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst
# Finished Videos in: daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst
# Finished Videos in: daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst
# Finished Videos in: daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst
# Finished Videos in: daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst
# Finished Videos in: daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst
# Finished Videos in: daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst
# Finished Videos in: daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst
# List of files:
# ['/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220671999/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220671999/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220671999/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220671999/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220671999/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220671999/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220671999/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220671999/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst']
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220671999/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220671999/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220671999/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220671999/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220671999/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220671999/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220671999/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220671999/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.001999.i3.zst

# %% [markdown]
# Ideas for Compression:
# - Use GUI to add files to queue and send to one compression folder.
# - Add a subprocess line in movie script to compress the video after making it and direct it to save in the compression folder.

# %%
compressed_path = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/'

# %% [markdown]
# Can't get manifest yet since some subjects are missing and lining it up won't work.

# %%
get_manifest(compressed_path,nue_csv)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:417: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   dict_manifest = s3.to_dict('dict')
# {'/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7218_origidx_7_RF22.mp4': {'event': 7218,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0266916528344154,
#   'pred_cascade': 0.3911727368831634,
#   'pred_tgtrack': 0.0001253877708222,
#   'pred_starttrack': 0.3972038328647613,
#   'pred_stoptrack': 0.1848064213991165,
#   'energy': 169.17779008764165,
#   'zenith': 1.1684076233771328,
#   'oneweight': 48868954.0493837,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.3972038328647613,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7306_origidx_12_RF22.mp4': {'event': 7306,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 4.13783982367022e-06,
#   'pred_cascade': 0.9401035904884338,
#   'pred_tgtrack': 1.6650839143039775e-06,
#   'pred_starttrack': 0.0598791800439357,
#   'pred_stoptrack': 1.1461884241725784e-05,
#   'energy': 1931.0764649730745,
#   'zenith': 1.8617683227071036,
#   'oneweight': 13667962138.327932,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9401035904884338,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7278_origidx_9_RF22.mp4': {'event': 7278,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0001777631405275,
#   'pred_cascade': 0.9981790781021118,
#   'pred_tgtrack': 1.8035700932728105e-08,
#   'pred_starttrack': 0.0016423002816736,
#   'pred_stoptrack': 8.816739409667207e-07,
#   'energy': 95484.21261338456,
#   'zenith': 1.550543408316004,
#   'oneweight': 76984827064876.8,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9981790781021118,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_510_origidx_16_RF22.mp4': {'event': 510,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9944961667060852,
#   'pred_cascade': 2.583271907496965e-07,
#   'pred_tgtrack': 0.0023709507659077,
#   'pred_starttrack': 2.639681895288959e-07,
#   'pred_stoptrack': 0.0031324364244937,
#   'energy': 85781.60399752118,
#   'zenith': 2.5498107166023427,
#   'oneweight': 12894658839219.207,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9944961667060852,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_6096_origidx_17_RF22.mp4': {'event': 6096,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9991136193275452,
#   'pred_cascade': 3.2953312967265453e-08,
#   'pred_tgtrack': 0.0007685297750867,
#   'pred_starttrack': 3.41794716973709e-08,
#   'pred_stoptrack': 0.0001178335223812,
#   'energy': 216995.83269020572,
#   'zenith': 1.3272569645830514,
#   'oneweight': 486777381417269.4,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9991136193275452,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_3805_origidx_7_RF22.mp4': {'event': 3805,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9957757592201232,
#   'pred_cascade': 0.0007914609741419,
#   'pred_tgtrack': 0.0028062376659363,
#   'pred_starttrack': 0.0001989670854527,
#   'pred_stoptrack': 0.0004277542466297,
#   'energy': 8093.412064467433,
#   'zenith': 2.2672993687664613,
#   'oneweight': 360180795910.9352,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9957757592201232,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_6107_origidx_18_RF22.mp4': {'event': 6107,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1614129692316055,
#   'pred_cascade': 0.0407106466591358,
#   'pred_tgtrack': 0.7073336839675903,
#   'pred_starttrack': 0.0197179242968559,
#   'pred_stoptrack': 0.0708248987793922,
#   'energy': 380.79129205365,
#   'zenith': 2.483291503484412,
#   'oneweight': 373723877.9708245,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7073336839675903,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_3892_origidx_8_RF22.mp4': {'event': 3892,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.7666219472885132,
#   'pred_cascade': 0.2123014777898788,
#   'pred_tgtrack': 0.0013265354791656,
#   'pred_starttrack': 0.0190648064017295,
#   'pred_stoptrack': 0.0006852275691926,
#   'energy': 255263.8774781284,
#   'zenith': 0.756180368065312,
#   'oneweight': 566279605043773.8,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7666219472885132,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_2808_origidx_5_RF22.mp4': {'event': 2808,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0317114330828189,
#   'pred_cascade': 0.9259256720542908,
#   'pred_tgtrack': 7.856522643123753e-06,
#   'pred_starttrack': 0.0388493463397026,
#   'pred_stoptrack': 0.0035056134220212,
#   'energy': 47365.8140004351,
#   'zenith': 2.956411388885304,
#   'oneweight': 3624109615680.264,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9259256720542908,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_405_origidx_15_RF22.mp4': {'event': 405,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 5.211260213400237e-05,
#   'pred_cascade': 0.9826191663742064,
#   'pred_tgtrack': 5.013548161514336e-06,
#   'pred_starttrack': 0.0172952022403478,
#   'pred_stoptrack': 2.8445107091101814e-05,
#   'energy': 2213.168250128919,
#   'zenith': 0.4378128503686931,
#   'oneweight': 21299196452.716293,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9826191663742064,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_615_origidx_18_RF22.mp4': {'event': 615,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9979239702224731,
#   'pred_cascade': 1.4739111975359265e-07,
#   'pred_tgtrack': 0.0016404202906414,
#   'pred_starttrack': 2.73467918532333e-07,
#   'pred_stoptrack': 0.0004351596289779,
#   'energy': 33205.21202958944,
#   'zenith': 1.5922882119683754,
#   'oneweight': 6654817470807.806,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9979239702224731,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_2605_origidx_4_RF22.mp4': {'event': 2605,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.998646914958954,
#   'pred_cascade': 5.607339062407846e-06,
#   'pred_tgtrack': 0.0002203715848736,
#   'pred_starttrack': 4.467270628083497e-06,
#   'pred_stoptrack': 0.001122580259107,
#   'energy': 24699.303320685573,
#   'zenith': 1.485552451761347,
#   'oneweight': 4650515420134.45,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.998646914958954,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_9977_origidx_12_RF22.mp4': {'event': 9977,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.0013934433227404,
#   'pred_cascade': 0.917654037475586,
#   'pred_tgtrack': 1.1337285741319647e-06,
#   'pred_starttrack': 0.0809422582387924,
#   'pred_stoptrack': 9.115661669056864e-06,
#   'energy': 726995.6084276288,
#   'zenith': 0.942448532149448,
#   'oneweight': 1.303579467189403e+16,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.917654037475586,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_5894_origidx_12_RF22.mp4': {'event': 5894,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999997615814209,
#   'pred_cascade': 1.4803707305138802e-13,
#   'pred_tgtrack': 1.223336766997818e-06,
#   'pred_starttrack': 4.7860409212174826e-12,
#   'pred_stoptrack': 1.1407516922190553e-06,
#   'energy': 801069.9700584527,
#   'zenith': 1.825445349629588,
#   'oneweight': 4824086422312149.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999997615814209,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_814_origidx_5_RF22.mp4': {'event': 814,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1349475085735321,
#   'pred_cascade': 0.0180754270404577,
#   'pred_tgtrack': 0.7924622893333435,
#   'pred_starttrack': 0.0374298356473445,
#   'pred_stoptrack': 0.0170849729329347,
#   'energy': 774908.1531808857,
#   'zenith': 0.9292844227979749,
#   'oneweight': 3082558747719383.5,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7924622893333435,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7117_origidx_4_RF22.mp4': {'event': 7117,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 5.269999292067951e-06,
#   'pred_cascade': 0.6375067830085754,
#   'pred_tgtrack': 4.833242655877257e-06,
#   'pred_starttrack': 0.3624780774116516,
#   'pred_stoptrack': 5.097605026094243e-06,
#   'energy': 3185.4908122192032,
#   'zenith': 0.143869058795601,
#   'oneweight': 41113632968.42951,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.6375067830085754,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_952_origidx_10_RF22.mp4': {'event': 952,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0766573697328567,
#   'pred_cascade': 0.0105430083349347,
#   'pred_tgtrack': 0.786241352558136,
#   'pred_starttrack': 0.0296402107924222,
#   'pred_stoptrack': 0.0969180464744567,
#   'energy': 1458.8413927845993,
#   'zenith': 2.316134625414602,
#   'oneweight': 5559147835.306025,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.786241352558136,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_799_origidx_4_RF22.mp4': {'event': 799,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999860525131226,
#   'pred_cascade': 2.0744229944913428e-10,
#   'pred_tgtrack': 4.668556357501075e-06,
#   'pred_starttrack': 9.537668432813007e-10,
#   'pred_stoptrack': 9.258343197871e-06,
#   'energy': 198662.56356194068,
#   'zenith': 1.221675656563986,
#   'oneweight': 380669848108338.06,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999860525131226,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_1049_origidx_13_RF22.mp4': {'event': 1049,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 8.197349234251305e-05,
#   'pred_cascade': 0.9485923647880554,
#   'pred_tgtrack': 4.811700819118414e-06,
#   'pred_starttrack': 0.0512956790626049,
#   'pred_stoptrack': 2.5186855054926127e-05,
#   'energy': 18402.7869616157,
#   'zenith': 2.3354256194090173,
#   'oneweight': 4169926818693.386,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9485923647880554,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_6199_origidx_22_RF22.mp4': {'event': 6199,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 5.134116690896917e-06,
#   'pred_cascade': 0.8331512808799744,
#   'pred_tgtrack': 3.040836872969521e-06,
#   'pred_starttrack': 0.1665762364864349,
#   'pred_stoptrack': 0.0002642612962517,
#   'energy': 215.0256975122132,
#   'zenith': 2.217171196405479,
#   'oneweight': 83253558.27624294,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8331512808799744,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_6081_origidx_16_RF22.mp4': {'event': 6081,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999445676803588,
#   'pred_cascade': 4.766458800986584e-07,
#   'pred_tgtrack': 2.7794532797997817e-05,
#   'pred_starttrack': 2.032824522757437e-05,
#   'pred_stoptrack': 6.8086669671174604e-06,
#   'energy': 59536.54449478874,
#   'zenith': 2.337249296280856,
#   'oneweight': 364960529510750.4,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999445676803588,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7614_origidx_22_RF22.mp4': {'event': 7614,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0114317573606967,
#   'pred_cascade': 0.0015365164726972,
#   'pred_tgtrack': 0.0016372126992791,
#   'pred_starttrack': 0.0012772070476785,
#   'pred_stoptrack': 0.984117329120636,
#   'energy': 189.61289366504735,
#   'zenith': 1.555323110063026,
#   'oneweight': 41016098.27640548,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.984117329120636,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7285_origidx_10_RF22.mp4': {'event': 7285,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0163705479353666,
#   'pred_cascade': 0.0045997523702681,
#   'pred_tgtrack': 0.0305181685835123,
#   'pred_starttrack': 0.2656817138195038,
#   'pred_stoptrack': 0.6828297972679138,
#   'energy': 457145.983328665,
#   'zenith': 0.7646116684657033,
#   'oneweight': 3386473656904895.5,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6828297972679138,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7799_origidx_6_RF22.mp4': {'event': 7799,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1543932557106018,
#   'pred_cascade': 0.0430787205696105,
#   'pred_tgtrack': 0.4950330257415771,
#   'pred_starttrack': 0.1310781687498092,
#   'pred_stoptrack': 0.1764168292284011,
#   'energy': 148831.77522859356,
#   'zenith': 1.7536250507455362,
#   'oneweight': 54090171425601.24,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4950330257415771,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7304_origidx_11_RF22.mp4': {'event': 7304,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.3032383024692535,
#   'pred_cascade': 0.5983997583389282,
#   'pred_tgtrack': 2.8045356884831563e-05,
#   'pred_starttrack': 0.0982419624924659,
#   'pred_stoptrack': 9.20423844945617e-05,
#   'energy': 565568.0889427459,
#   'zenith': 1.2221072789480207,
#   'oneweight': 3178827964792632.0,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.5983997583389282,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_3787_origidx_6_RF22.mp4': {'event': 3787,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0523497126996517,
#   'pred_cascade': 0.0147840362042188,
#   'pred_tgtrack': 0.8992912173271179,
#   'pred_starttrack': 0.030171975493431,
#   'pred_stoptrack': 0.0034030855167657,
#   'energy': 293616.7386412282,
#   'zenith': 2.1498144730201605,
#   'oneweight': 1.5596907333414784e+16,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8992912173271179,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7146_origidx_5_RF22.mp4': {'event': 7146,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.155596575903473e-06,
#   'pred_cascade': 0.9217320680618286,
#   'pred_tgtrack': 2.8725489755743183e-06,
#   'pred_starttrack': 0.0782602205872535,
#   'pred_stoptrack': 2.637875240907306e-06,
#   'energy': 17340.078418279834,
#   'zenith': 1.039071960777924,
#   'oneweight': 2529940360528.93,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9217320680618286,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7362_origidx_14_RF22.mp4': {'event': 7362,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0010847300291061,
#   'pred_cascade': 0.8458589315414429,
#   'pred_tgtrack': 0.0004202573327347,
#   'pred_starttrack': 0.1498655974864959,
#   'pred_stoptrack': 0.0027704467065632,
#   'energy': 416.6409180075921,
#   'zenith': 2.82788548229291,
#   'oneweight': 382500091.2666223,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8458589315414429,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_3619_origidx_4_RF22.mp4': {'event': 3619,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9998316764831544,
#   'pred_cascade': 6.99329705255991e-10,
#   'pred_tgtrack': 3.5655735700856894e-05,
#   'pred_starttrack': 1.8107707555614638e-09,
#   'pred_stoptrack': 0.0001326521160081,
#   'energy': 89484.50266207216,
#   'zenith': 0.1422925032142035,
#   'oneweight': 68631063137248.016,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9998316764831544,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_1018_origidx_12_RF22.mp4': {'event': 1018,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.7298604249954224,
#   'pred_cascade': 0.0477439872920513,
#   'pred_tgtrack': 0.1169784143567085,
#   'pred_starttrack': 0.0310013219714164,
#   'pred_stoptrack': 0.0744158029556274,
#   'energy': 353299.02780468087,
#   'zenith': 1.3261757158562173,
#   'oneweight': 892648698104529.8,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7298604249954224,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_5747_origidx_10_RF22.mp4': {'event': 5747,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0127347623929381,
#   'pred_cascade': 0.0030682755168527,
#   'pred_tgtrack': 0.0087481262162327,
#   'pred_starttrack': 0.0042737363837659,
#   'pred_stoptrack': 0.9711750745773317,
#   'energy': 686128.2289380598,
#   'zenith': 1.673031688571191,
#   'oneweight': 8.318158711917366e+16,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9711750745773317,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_9646_origidx_4_RF22.mp4': {'event': 9646,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.2546904599730624e-06,
#   'pred_cascade': 0.9978312849998474,
#   'pred_tgtrack': 2.93230062453631e-09,
#   'pred_starttrack': 0.002167374594137,
#   'pred_stoptrack': 2.5317056895346468e-08,
#   'energy': 42774.56835718225,
#   'zenith': 1.158274495643573,
#   'oneweight': 18324523135865.71,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9978312849998474,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_5386_origidx_4_RF22.mp4': {'event': 5386,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.6564377549220808e-05,
#   'pred_cascade': 0.9594972133636476,
#   'pred_tgtrack': 3.233614734199364e-06,
#   'pred_starttrack': 0.0403433293104171,
#   'pred_stoptrack': 0.0001297615235671,
#   'energy': 460.2958958224526,
#   'zenith': 0.909223149251118,
#   'oneweight': 591910002.1303076,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9594972133636476,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_389_origidx_13_RF22.mp4': {'event': 389,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9991878867149352,
#   'pred_cascade': 7.344922892116301e-07,
#   'pred_tgtrack': 0.0002384346444159,
#   'pred_starttrack': 7.957737011565769e-07,
#   'pred_stoptrack': 0.0005721975467167,
#   'energy': 352143.4158192786,
#   'zenith': 0.9824407283911832,
#   'oneweight': 1569548274910933.5,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9991878867149352,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_5936_origidx_13_RF22.mp4': {'event': 5936,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 5.995405444991775e-05,
#   'pred_cascade': 0.9980711340904236,
#   'pred_tgtrack': 1.5896524985237193e-08,
#   'pred_starttrack': 0.001866643782705,
#   'pred_stoptrack': 2.2434333004639484e-06,
#   'energy': 49750.90537168404,
#   'zenith': 1.65314271913489,
#   'oneweight': 20783103979854.82,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9980711340904236,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_9746_origidx_9_RF22.mp4': {'event': 9746,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9948346614837646,
#   'pred_cascade': 0.0001829658576752,
#   'pred_tgtrack': 0.0016337987035512,
#   'pred_starttrack': 0.0003781499690376,
#   'pred_stoptrack': 0.002970365807414,
#   'energy': 137734.4127554415,
#   'zenith': 1.017958333653415,
#   'oneweight': 557954331240763.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9948346614837646,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_9721_origidx_8_RF22.mp4': {'event': 9721,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0172467976808547,
#   'pred_cascade': 0.0083667896687984,
#   'pred_tgtrack': 0.2908221185207367,
#   'pred_starttrack': 0.0036221565678715,
#   'pred_stoptrack': 0.6799421310424805,
#   'energy': 994513.9258212318,
#   'zenith': 2.487649303258847,
#   'oneweight': 356493559346479.3,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6799421310424805,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_5547_origidx_6_RF22.mp4': {'event': 5547,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.998554527759552,
#   'pred_cascade': 5.8794936194317415e-05,
#   'pred_tgtrack': 0.0011470405152067,
#   'pred_starttrack': 5.504113687493373e-06,
#   'pred_stoptrack': 0.0002342045481782,
#   'energy': 121908.51763983288,
#   'zenith': 1.0568766879394698,
#   'oneweight': 160088751951627.8,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.998554527759552,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_661_origidx_21_RF22.mp4': {'event': 661,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9761013388633728,
#   'pred_cascade': 4.652696588891558e-06,
#   'pred_tgtrack': 0.0233864914625883,
#   'pred_starttrack': 2.723273837546003e-06,
#   'pred_stoptrack': 0.0005047175218351,
#   'energy': 222831.3614765115,
#   'zenith': 1.4889058463221567,
#   'oneweight': 352029801563665.6,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9761013388633728,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_1324_origidx_21_RF22.mp4': {'event': 1324,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0003828456101473,
#   'pred_cascade': 0.990927755832672,
#   'pred_tgtrack': 4.201273259241134e-05,
#   'pred_starttrack': 0.0085965963080525,
#   'pred_stoptrack': 5.083327778265812e-05,
#   'energy': 23758.63730003896,
#   'zenith': 1.6457231932030758,
#   'oneweight': 4150005100456.423,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.990927755832672,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_900_origidx_9_RF22.mp4': {'event': 900,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1107036471366882,
#   'pred_cascade': 0.016669638454914,
#   'pred_tgtrack': 0.0046646855771541,
#   'pred_starttrack': 0.013798164203763,
#   'pred_stoptrack': 0.8541638255119324,
#   'energy': 12866.011739182552,
#   'zenith': 1.9191704125431253,
#   'oneweight': 1368238724324.6355,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8541638255119324,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7708_origidx_23_RF22.mp4': {'event': 7708,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3011394143104553,
#   'pred_cascade': 0.0633204728364944,
#   'pred_tgtrack': 0.0349703058600425,
#   'pred_starttrack': 0.0332070924341678,
#   'pred_stoptrack': 0.5673626661300659,
#   'energy': 4453.893290385195,
#   'zenith': 2.9141949485807506,
#   'oneweight': 348662276125.7365,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5673626661300659,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_6204_origidx_23_RF22.mp4': {'event': 6204,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9872742891311646,
#   'pred_cascade': 0.0025534625165164,
#   'pred_tgtrack': 0.0003193458542227,
#   'pred_starttrack': 0.0030465074814856,
#   'pred_stoptrack': 0.0068064085207879,
#   'energy': 5033.305846490723,
#   'zenith': 0.4041675469158793,
#   'oneweight': 157887596309.9971,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9872742891311646,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_1197_origidx_18_RF22.mp4': {'event': 1197,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 4.162979894317687e-05,
#   'pred_cascade': 0.9961073994636536,
#   'pred_tgtrack': 1.0739664730863296e-06,
#   'pred_starttrack': 0.0037942139897495,
#   'pred_stoptrack': 5.5624004744458944e-05,
#   'energy': 2932.7888602978933,
#   'zenith': 1.6321442757655875,
#   'oneweight': 33835914507.01265,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9961073994636536,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7610_origidx_21_RF22.mp4': {'event': 7610,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9997116923332214,
#   'pred_cascade': 5.305429429114383e-09,
#   'pred_tgtrack': 0.0001403075439156,
#   'pred_starttrack': 2.216696337598023e-08,
#   'pred_stoptrack': 0.0001478836784372,
#   'energy': 402542.1478372091,
#   'zenith': 0.5099173261462302,
#   'oneweight': 1255828798559553.8,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9997116923332214,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_391_origidx_14_RF22.mp4': {'event': 391,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0143688935786485,
#   'pred_cascade': 0.0046662548556923,
#   'pred_tgtrack': 0.2927710115909576,
#   'pred_starttrack': 0.002186870900914,
#   'pred_stoptrack': 0.6860069036483765,
#   'energy': 143.62167529512843,
#   'zenith': 1.4528133677268371,
#   'oneweight': 11747637.571083676,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6860069036483765,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7436_origidx_16_RF22.mp4': {'event': 7436,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.99916672706604,
#   'pred_cascade': 0.0003488165675662,
#   'pred_tgtrack': 0.000424284080509,
#   'pred_starttrack': 2.013885386986658e-05,
#   'pred_stoptrack': 4.007129246019758e-05,
#   'energy': 247965.75874502223,
#   'zenith': 2.2893903736408627,
#   'oneweight': 27655309881770.668,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.99916672706604,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_636_origidx_20_RF22.mp4': {'event': 636,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9900847673416138,
#   'pred_cascade': 1.323106243944494e-05,
#   'pred_tgtrack': 5.995610263198614e-05,
#   'pred_starttrack': 1.3660723197972402e-05,
#   'pred_stoptrack': 0.0098284082487225,
#   'energy': 5631.283833100806,
#   'zenith': 1.4474017134473691,
#   'oneweight': 164880505977.60587,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9900847673416138,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7585_origidx_20_RF22.mp4': {'event': 7585,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.5660073161125183,
#   'pred_cascade': 0.3086579442024231,
#   'pred_tgtrack': 0.0030707423575222,
#   'pred_starttrack': 0.1097875162959098,
#   'pred_stoptrack': 0.0124765262007713,
#   'energy': 1180.6343423874398,
#   'zenith': 2.3909117363641,
#   'oneweight': 5111946207.45425,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5660073161125183,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_9665_origidx_5_RF22.mp4': {'event': 9665,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 3.559718970791437e-05,
#   'pred_cascade': 0.5189615488052368,
#   'pred_tgtrack': 0.0007765656337141,
#   'pred_starttrack': 0.4800903797149658,
#   'pred_stoptrack': 0.0001359084708383,
#   'energy': 18575.24560421436,
#   'zenith': 2.4075592170724414,
#   'oneweight': 592526514512.6877,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.5189615488052368,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_9711_origidx_7_RF22.mp4': {'event': 9711,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0008214777335524,
#   'pred_cascade': 0.0002215022977907,
#   'pred_tgtrack': 0.0051178005523979,
#   'pred_starttrack': 0.0002135383983841,
#   'pred_stoptrack': 0.9936256408691406,
#   'energy': 724.8648026973698,
#   'zenith': 1.0206597773564257,
#   'oneweight': 2041270715.2721088,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9936256408691406,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_6182_origidx_21_RF22.mp4': {'event': 6182,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1043624132871627,
#   'pred_cascade': 0.0373886674642562,
#   'pred_tgtrack': 0.5446889996528625,
#   'pred_starttrack': 0.0145346792414784,
#   'pred_stoptrack': 0.2990252375602722,
#   'energy': 167097.68089407188,
#   'zenith': 1.1986027999373323,
#   'oneweight': 264713934105566.56,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5446889996528625,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_710_origidx_22_RF22.mp4': {'event': 710,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0007368180085904,
#   'pred_cascade': 0.9945645332336426,
#   'pred_tgtrack': 3.58499823960301e-06,
#   'pred_starttrack': 0.0046712872572243,
#   'pred_stoptrack': 2.3763972421875224e-05,
#   'energy': 358103.0508702755,
#   'zenith': 1.6352769751129936,
#   'oneweight': 1059806624834911.0,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9945645332336426,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_6154_origidx_19_RF22.mp4': {'event': 6154,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3304889500141144,
#   'pred_cascade': 0.0978955551981926,
#   'pred_tgtrack': 0.3803223073482513,
#   'pred_starttrack': 0.0560822710394859,
#   'pred_stoptrack': 0.1352109163999557,
#   'energy': 249479.4445390088,
#   'zenith': 2.083034085912351,
#   'oneweight': 511252024791525.06,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3803223073482513,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_1095_origidx_15_RF22.mp4': {'event': 1095,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9997091889381408,
#   'pred_cascade': 1.855093387348461e-06,
#   'pred_tgtrack': 3.063723852392286e-05,
#   'pred_starttrack': 4.728391104436014e-06,
#   'pred_stoptrack': 0.000253497128142,
#   'energy': 85029.28240168531,
#   'zenith': 1.0875698605193995,
#   'oneweight': 220556783954639.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9997091889381408,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_4_origidx_5_RF22.mp4': {'event': 4,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2556603848934173,
#   'pred_cascade': 0.0178700890392065,
#   'pred_tgtrack': 0.024170784279704,
#   'pred_starttrack': 0.0465398505330085,
#   'pred_stoptrack': 0.6557588577270508,
#   'energy': 503.20746935479815,
#   'zenith': 1.873661234376858,
#   'oneweight': 437667760.4739189,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6557588577270508,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7779_origidx_5_RF22.mp4': {'event': 7779,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.000343856139807,
#   'pred_cascade': 0.7666935324668884,
#   'pred_tgtrack': 0.0172067899256944,
#   'pred_starttrack': 0.2145351320505142,
#   'pred_stoptrack': 0.0012207356048747,
#   'energy': 2840.3479197492247,
#   'zenith': 1.9504970325742157,
#   'oneweight': 115908775351.67386,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.7666935324668884,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_3647_origidx_5_RF22.mp4': {'event': 3647,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 2.119943565048743e-05,
#   'pred_cascade': 0.859655499458313,
#   'pred_tgtrack': 5.1945484301541e-05,
#   'pred_starttrack': 0.1402444988489151,
#   'pred_stoptrack': 2.6876095944317054e-05,
#   'energy': 36725.359150608696,
#   'zenith': 2.8116731039041074,
#   'oneweight': 1352594090523.1904,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.859655499458313,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_317_origidx_12_RF22.mp4': {'event': 317,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3192023038864136,
#   'pred_cascade': 0.0444088131189346,
#   'pred_tgtrack': 0.3630066215991974,
#   'pred_starttrack': 0.085428312420845,
#   'pred_stoptrack': 0.1879538893699646,
#   'energy': 382326.8169913247,
#   'zenith': 1.487801373180238,
#   'oneweight': 1.7301973428419388e+16,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3630066215991974,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7246_origidx_8_RF22.mp4': {'event': 7246,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.000110265922558,
#   'pred_cascade': 0.9980744123458862,
#   'pred_tgtrack': 1.350741407613043e-09,
#   'pred_starttrack': 0.0018029315397143,
#   'pred_stoptrack': 1.2319677807681728e-05,
#   'energy': 24351.11950634574,
#   'zenith': 2.5156767292000164,
#   'oneweight': 356339996374.718,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9980744123458862,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_1315_origidx_20_RF22.mp4': {'event': 1315,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3188995718955993,
#   'pred_cascade': 0.0839349180459976,
#   'pred_tgtrack': 0.1913814097642898,
#   'pred_starttrack': 0.0841457322239875,
#   'pred_stoptrack': 0.3216383457183838,
#   'energy': 1568.2916515134357,
#   'zenith': 1.041152338323548,
#   'oneweight': 8627519090.022663,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3216383457183838,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7447_origidx_17_RF22.mp4': {'event': 7447,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9956899285316468,
#   'pred_cascade': 4.3702979013460215e-08,
#   'pred_tgtrack': 0.002158441580832,
#   'pred_starttrack': 2.9216424834999092e-08,
#   'pred_stoptrack': 0.0021516112610697,
#   'energy': 47937.64734888645,
#   'zenith': 2.600035904305807,
#   'oneweight': 213917307912981.5,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9956899285316468,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_20_origidx_6_RF22.mp4': {'event': 20,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1565576046705246,
#   'pred_cascade': 0.0476291738450527,
#   'pred_tgtrack': 0.7253344655036926,
#   'pred_starttrack': 0.026364454999566,
#   'pred_stoptrack': 0.0441142730414867,
#   'energy': 7875.886950965891,
#   'zenith': 2.4393434120261794,
#   'oneweight': 475417691924.2259,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7253344655036926,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_10075_origidx_13_RF22.mp4': {'event': 10075,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 5.631847307085991e-05,
#   'pred_cascade': 1.8453923985362053e-05,
#   'pred_tgtrack': 0.0623500160872936,
#   'pred_starttrack': 1.0596631000225898e-05,
#   'pred_stoptrack': 0.9375646114349364,
#   'energy': 351.96701849042944,
#   'zenith': 2.936875202504064,
#   'oneweight': 204221731.5100057,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9375646114349364,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_6079_origidx_15_RF22.mp4': {'event': 6079,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2012630999088287,
#   'pred_cascade': 0.0568907298147678,
#   'pred_tgtrack': 0.3908700048923492,
#   'pred_starttrack': 0.3264084160327911,
#   'pred_stoptrack': 0.0245677568018436,
#   'energy': 2472.543679361848,
#   'zenith': 2.744541397210864,
#   'oneweight': 27868584464.74396,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3908700048923492,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7729_origidx_24_RF22.mp4': {'event': 7729,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1309754103422165,
#   'pred_cascade': 0.0047582844272255,
#   'pred_tgtrack': 0.6039133071899414,
#   'pred_starttrack': 0.0048008300364017,
#   'pred_stoptrack': 0.2555521130561828,
#   'energy': 28192.81870192385,
#   'zenith': 1.4940289037667285,
#   'oneweight': 48644829862723.98,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6039133071899414,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7731_origidx_4_RF22.mp4': {'event': 7731,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4788198173046112,
#   'pred_cascade': 0.1322274655103683,
#   'pred_tgtrack': 0.2237483710050583,
#   'pred_starttrack': 0.0646142065525055,
#   'pred_stoptrack': 0.1005901619791984,
#   'energy': 416.508050274618,
#   'zenith': 1.047975988650104,
#   'oneweight': 187728697.1715882,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4788198173046112,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_864_origidx_6_RF22.mp4': {'event': 864,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1635074913501739,
#   'pred_cascade': 0.0027404674328863,
#   'pred_tgtrack': 0.7866560816764832,
#   'pred_starttrack': 0.0095022050663828,
#   'pred_stoptrack': 0.0375937782227993,
#   'energy': 9889.439892258788,
#   'zenith': 2.612105142018684,
#   'oneweight': 3338514286337.488,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7866560816764832,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7193_origidx_6_RF22.mp4': {'event': 7193,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0794251933693885,
#   'pred_cascade': 0.015984172001481,
#   'pred_tgtrack': 0.8249868154525757,
#   'pred_starttrack': 0.0084799453616142,
#   'pred_stoptrack': 0.0711238011717796,
#   'energy': 641.5093933041767,
#   'zenith': 1.881196074787017,
#   'oneweight': 1469871854.8410614,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8249868154525757,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_5441_origidx_5_RF22.mp4': {'event': 5441,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4192364513874054,
#   'pred_cascade': 0.0996003746986389,
#   'pred_tgtrack': 0.3504691421985626,
#   'pred_starttrack': 0.0404037572443485,
#   'pred_stoptrack': 0.09029021859169,
#   'energy': 149539.94980068348,
#   'zenith': 1.1239239538799146,
#   'oneweight': 104696867792853.8,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4192364513874054,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_897_origidx_8_RF22.mp4': {'event': 897,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2658971548080444,
#   'pred_cascade': 0.064949169754982,
#   'pred_tgtrack': 0.3191195726394653,
#   'pred_starttrack': 0.0434519536793231,
#   'pred_stoptrack': 0.3065820932388305,
#   'energy': 220112.4786174129,
#   'zenith': 0.7228725193438212,
#   'oneweight': 1044909294282852.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3191195726394653,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7536_origidx_19_RF22.mp4': {'event': 7536,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0062697529792785,
#   'pred_cascade': 0.0012254836037755,
#   'pred_tgtrack': 0.9446964859962464,
#   'pred_starttrack': 0.0466510765254497,
#   'pred_stoptrack': 0.0011572996154427,
#   'energy': 4343.937093640709,
#   'zenith': 2.4045424412371053,
#   'oneweight': 13281383837.66614,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9446964859962464,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 11},
# ...
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_9688_origidx_6_RF22.mp4': {'event': 9688,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0181251838803291,
#   'pred_cascade': 0.0080945501103997,
#   'pred_tgtrack': 0.8317741751670837,
#   'pred_starttrack': 0.1230488717555999,
#   'pred_stoptrack': 0.0189572870731353,
#   'energy': 233.13935414488884,
#   'zenith': 0.6966869534991406,
#   'oneweight': 40254064.40728311,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8317741751670837,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_9912_origidx_11_RF22.mp4': {'event': 9912,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0040986011736094,
#   'pred_cascade': 0.0018736741039901,
#   'pred_tgtrack': 0.4733096063137054,
#   'pred_starttrack': 0.0008830451406538,
#   'pred_stoptrack': 0.5198351144790649,
#   'energy': 205.7307737079229,
#   'zenith': 1.6041344055569615,
#   'oneweight': 36069760.69855372,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5198351144790649,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7509_origidx_18_RF22.mp4': {'event': 7509,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 8.458185766357929e-05,
#   'pred_cascade': 0.9251397252082824,
#   'pred_tgtrack': 6.161673809401691e-06,
#   'pred_starttrack': 0.0746244937181472,
#   'pred_stoptrack': 0.0001450171403121,
#   'energy': 424.4807999851587,
#   'zenith': 0.774945313925762,
#   'oneweight': 488263072.1187593,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9251397252082824,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_1354_origidx_22_RF22.mp4': {'event': 1354,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.1398360584280454e-06,
#   'pred_cascade': 0.9675224423408508,
#   'pred_tgtrack': 1.984833915003037e-07,
#   'pred_starttrack': 0.0324752256274223,
#   'pred_stoptrack': 1.0037235824711388e-06,
#   'energy': 6453.816964623438,
#   'zenith': 1.716347282501978,
#   'oneweight': 235004218348.58917,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9675224423408508,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_243_origidx_11_RF22.mp4': {'event': 243,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0010075381724163,
#   'pred_cascade': 0.865426778793335,
#   'pred_tgtrack': 0.0002630803792271,
#   'pred_starttrack': 0.1327467411756515,
#   'pred_stoptrack': 0.0005558576667681,
#   'energy': 2612.240591149586,
#   'zenith': 1.285444456202108,
#   'oneweight': 29875552802.85746,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.865426778793335,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_603_origidx_17_RF22.mp4': {'event': 603,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0001056071705534,
#   'pred_cascade': 0.9885733127593994,
#   'pred_tgtrack': 4.66693990119893e-08,
#   'pred_starttrack': 0.0113179227337241,
#   'pred_stoptrack': 3.174997573296423e-06,
#   'energy': 6963.630379290704,
#   'zenith': 2.1459975886751086,
#   'oneweight': 369203225607.4735,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9885733127593994,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_6178_origidx_20_RF22.mp4': {'event': 6178,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0183125976473093,
#   'pred_cascade': 0.0053930166177451,
#   'pred_tgtrack': 0.4554238617420196,
#   'pred_starttrack': 0.0049040303565561,
#   'pred_stoptrack': 0.5159664750099182,
#   'energy': 3477.343411495316,
#   'zenith': 1.3098865073586143,
#   'oneweight': 60796409714.1624,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5159664750099182,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_1195_origidx_17_RF22.mp4': {'event': 1195,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9179638624191284,
#   'pred_cascade': 4.680681377067231e-05,
#   'pred_tgtrack': 0.0019163681427016,
#   'pred_starttrack': 3.999775799456984e-05,
#   'pred_stoptrack': 0.0800328850746154,
#   'energy': 2144.277564992841,
#   'zenith': 1.898513247814516,
#   'oneweight': 19588238237.35045,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9179638624191284,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_9862_origidx_10_RF22.mp4': {'event': 9862,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9989439845085144,
#   'pred_cascade': 1.514391533419257e-05,
#   'pred_tgtrack': 0.0001642365532461,
#   'pred_starttrack': 2.0839592252741568e-05,
#   'pred_stoptrack': 0.0008558646659366,
#   'energy': 3881.719198613714,
#   'zenith': 0.5130408875995068,
#   'oneweight': 93589000617.34926,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9989439845085144,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7383_origidx_15_RF22.mp4': {'event': 7383,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0001021089192363,
#   'pred_cascade': 0.9940343499183656,
#   'pred_tgtrack': 2.748969762933484e-08,
#   'pred_starttrack': 0.0058632367290556,
#   'pred_stoptrack': 1.981411230644881e-07,
#   'energy': 956294.3510329594,
#   'zenith': 0.5373175172710414,
#   'oneweight': 9781923921181478.0,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9940343499183656,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_7349_origidx_13_RF22.mp4': {'event': 7349,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999021291732788,
#   'pred_cascade': 7.336825547099579e-07,
#   'pred_tgtrack': 3.7337395042413846e-05,
#   'pred_starttrack': 3.68310770682001e-06,
#   'pred_stoptrack': 5.614593828795478e-05,
#   'energy': 55641.35839365706,
#   'zenith': 0.7949136120710922,
#   'oneweight': 38050564257089.81,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999021291732788,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_619_origidx_19_RF22.mp4': {'event': 619,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.2727489471435547,
#   'pred_cascade': 0.459509402513504,
#   'pred_tgtrack': 0.1054577603936195,
#   'pred_starttrack': 0.1374809145927429,
#   'pred_stoptrack': 0.0248030386865139,
#   'energy': 937.3360734993428,
#   'zenith': 2.222017326522218,
#   'oneweight': 1957994517.683807,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.459509402513504,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_995_origidx_11_RF22.mp4': {'event': 995,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1977189928293228,
#   'pred_cascade': 0.0315725021064281,
#   'pred_tgtrack': 0.3610557615756988,
#   'pred_starttrack': 0.2611690759658813,
#   'pred_stoptrack': 0.1484836190938949,
#   'energy': 166.12672754501787,
#   'zenith': 2.021769632498099,
#   'oneweight': 18958818.496908832,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3610557615756988,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_5663_origidx_8_RF22.mp4': {'event': 5663,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3925921320915222,
#   'pred_cascade': 0.0411931797862052,
#   'pred_tgtrack': 0.0103421006351709,
#   'pred_starttrack': 0.0424619317054748,
#   'pred_stoptrack': 0.5134106874465942,
#   'energy': 80268.7426361308,
#   'zenith': 0.8683960965569284,
#   'oneweight': 91070780178273.48,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5134106874465942,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_1087_origidx_14_RF22.mp4': {'event': 1087,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.000169604551047,
#   'pred_cascade': 0.9971051812171936,
#   'pred_tgtrack': 2.8245902838897047e-10,
#   'pred_starttrack': 0.0027244964148849,
#   'pred_stoptrack': 7.014954803707951e-07,
#   'energy': 52672.40082923187,
#   'zenith': 1.8046215554060157,
#   'oneweight': 26524901815031.004,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9971051812171936,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_1314_origidx_19_RF22.mp4': {'event': 1314,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9998608827590942,
#   'pred_cascade': 5.663241154252319e-06,
#   'pred_tgtrack': 5.543134466279298e-05,
#   'pred_starttrack': 3.683112299768254e-05,
#   'pred_stoptrack': 4.1148628952214494e-05,
#   'energy': 846398.7946822491,
#   'zenith': 0.6590303509720672,
#   'oneweight': 5927849409274669.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9998608827590942,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_3909_origidx_9_RF22.mp4': {'event': 3909,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 1.6811267414595932e-05,
#   'pred_cascade': 0.9989175796508788,
#   'pred_tgtrack': 1.8926729627999348e-10,
#   'pred_starttrack': 0.0010654946090653,
#   'pred_stoptrack': 8.218159308626127e-08,
#   'energy': 672606.4602618468,
#   'zenith': 0.9896722821911133,
#   'oneweight': 1.1429801804805576e+16,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9989175796508788,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_51_origidx_7_RF22.mp4': {'event': 51,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.000842833193019,
#   'pred_cascade': 0.7366769313812256,
#   'pred_tgtrack': 0.0003439715364947,
#   'pred_starttrack': 0.2513821125030517,
#   'pred_stoptrack': 0.0107542276382446,
#   'energy': 157.97119512622265,
#   'zenith': 1.2818113089717162,
#   'oneweight': 31405549.84963692,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.7366769313812256,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_5662_origidx_7_RF22.mp4': {'event': 5662,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999997615814209,
#   'pred_cascade': 8.645560396064457e-13,
#   'pred_tgtrack': 9.631979764890275e-07,
#   'pred_starttrack': 2.089767074664461e-11,
#   'pred_stoptrack': 1.489507440055604e-06,
#   'energy': 389822.9733060517,
#   'zenith': 2.335716836229411,
#   'oneweight': 262563750874729.28,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999997615814209,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_5693_origidx_9_RF22.mp4': {'event': 5693,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.549217164516449,
#   'pred_cascade': 0.0070373238995671,
#   'pred_tgtrack': 0.2180223017930984,
#   'pred_starttrack': 0.0432994440197944,
#   'pred_stoptrack': 0.1824238151311874,
#   'energy': 529.7149495634567,
#   'zenith': 1.0577763024645388,
#   'oneweight': 463717910.6121051,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.549217164516449,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_196_origidx_10_RF22.mp4': {'event': 196,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 8.007738506421447e-05,
#   'pred_cascade': 0.990143060684204,
#   'pred_tgtrack': 1.4043367855265387e-06,
#   'pred_starttrack': 0.0097719002515077,
#   'pred_stoptrack': 3.521396138239652e-06,
#   'energy': 15237.903057923422,
#   'zenith': 1.7279161050775422,
#   'oneweight': 1673117491037.1362,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.990143060684204,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_6035_origidx_14_RF22.mp4': {'event': 6035,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9859707951545716,
#   'pred_cascade': 0.0009694316540844,
#   'pred_tgtrack': 0.0070565356872975,
#   'pred_starttrack': 0.0006426553009077,
#   'pred_stoptrack': 0.0053605940192937,
#   'energy': 13297.223102554706,
#   'zenith': 1.2633691792455537,
#   'oneweight': 3687224087288.464,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9859707951545716,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_193_origidx_9_RF22.mp4': {'event': 193,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9996936321258544,
#   'pred_cascade': 4.560403681352909e-07,
#   'pred_tgtrack': 5.130310455569997e-05,
#   'pred_starttrack': 8.575386800657725e-07,
#   'pred_stoptrack': 0.0002537481195759,
#   'energy': 585332.5084985238,
#   'zenith': 0.4516644549305429,
#   'oneweight': 1750617855564273.8,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9996936321258544,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220671999/compressed_run_22067_event_1145_origidx_16_RF22.mp4': {'event': 1145,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9975454211235046,
#   'pred_cascade': 4.649495508601831e-07,
#   'pred_tgtrack': 0.0003414320817682,
#   'pred_starttrack': 1.016355099636712e-06,
#   'pred_stoptrack': 0.0021116435527801,
#   'energy': 7313.214871969346,
#   'zenith': 1.865298911926048,
#   'oneweight': 352265678534.24695,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9975454211235046,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12}}

# %%
make_subject_set('nue_run_22067_subrun_1999_phase1')
# Out:
# Subject Set Name: nue_run_22067_subrun_1999_phase1
# Subject Set ID: 112119
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112109>]

# %%
uploader(compressed_path,nue_csv,112119)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:468: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   dict_manifest = s3.to_dict('dict')
# Confirm if subject set 112119 is listed below.
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112109>]
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112109>]
# Number of times loop has ran: 1
# Number of times loop has ran: 2
# Number of times loop has ran: 3
# Number of times loop has ran: 4
# Number of times loop has ran: 5
# Number of times loop has ran: 6
# Number of times loop has ran: 7
# Number of times loop has ran: 8
# Number of times loop has ran: 9
# Number of times loop has ran: 10
# Number of times loop has ran: 11
# Number of times loop has ran: 12
# Number of times loop has ran: 13
# Number of times loop has ran: 14
# Number of times loop has ran: 15
# Number of times loop has ran: 16
# Number of times loop has ran: 17
# Number of times loop has ran: 18
# Number of times loop has ran: 19
# Number of times loop has ran: 20
# Number of times loop has ran: 21
# Number of times loop has ran: 22
# Number of times loop has ran: 23
# Number of times loop has ran: 24
# Number of times loop has ran: 25
# Number of times loop has ran: 26
# Number of times loop has ran: 27
# Number of times loop has ran: 28
# Number of times loop has ran: 29
# Number of times loop has ran: 30
# Number of times loop has ran: 31
# Number of times loop has ran: 32
# Number of times loop has ran: 33
# Number of times loop has ran: 34
# Number of times loop has ran: 35
# Number of times loop has ran: 36
# Number of times loop has ran: 37
# Number of times loop has ran: 38
# Number of times loop has ran: 39
# Number of times loop has ran: 40
# Number of times loop has ran: 41
# Number of times loop has ran: 42
# Number of times loop has ran: 43
# Number of times loop has ran: 44
# Number of times loop has ran: 45
# Number of times loop has ran: 46
# Number of times loop has ran: 47
# Number of times loop has ran: 48
# Number of times loop has ran: 49
# Number of times loop has ran: 50
# Number of times loop has ran: 51
# Number of times loop has ran: 52
# Number of times loop has ran: 53
# Number of times loop has ran: 54
# Number of times loop has ran: 55
# Number of times loop has ran: 56
# Number of times loop has ran: 57
# Number of times loop has ran: 58
# Number of times loop has ran: 59
# Number of times loop has ran: 60
# Number of times loop has ran: 61
# Number of times loop has ran: 62
# Number of times loop has ran: 63
# Number of times loop has ran: 64
# Number of times loop has ran: 65
# Number of times loop has ran: 66
# Number of times loop has ran: 67
# Number of times loop has ran: 68
# Number of times loop has ran: 69
# Number of times loop has ran: 70
# Number of times loop has ran: 71
# Number of times loop has ran: 72
# Number of times loop has ran: 73
# Number of times loop has ran: 74
# Number of times loop has ran: 75
# Number of times loop has ran: 76
# Number of times loop has ran: 77
# Number of times loop has ran: 78
# Number of times loop has ran: 79
# Number of times loop has ran: 80
# Number of times loop has ran: 81
# Number of times loop has ran: 82
# Number of times loop has ran: 83
# Number of times loop has ran: 84
# Number of times loop has ran: 85
# Number of times loop has ran: 86
# Number of times loop has ran: 87
# Number of times loop has ran: 88
# Number of times loop has ran: 89
# Number of times loop has ran: 90
# Number of times loop has ran: 91
# Number of times loop has ran: 92
# Number of times loop has ran: 93
# Number of times loop has ran: 94
# Number of times loop has ran: 95
# Number of times loop has ran: 96
# Number of times loop has ran: 97
# Number of times loop has ran: 98
