# %% [markdown]
# # Phase 2: Subject Creation
#
# **Description:**
#
# This notebook is to act as the resulting summary file for the creation and upload of subjects for the IceCube Zooniverse project currently called *Name that Neutrino!*. The project is currently being maintained by Elizabeth Warrick (as of March 2023). In this notebook, we take the i3 file and run it through several filters. [note: describe more later].
#
# > Nu Type: NuE
#
# > Run: 22076
#
# > SubRun: 000348
#
# ### Summary Stats:
#
# To be filled in after completing process. Also need to figure out global variables.
#
# **Subject Set Name:**

# %%
#Imports

#My functions: 
from uniformenergydist_filter import *

#General:
import numpy as np
import sys
import os
import subprocess
import argparse
import csv
from tables import *
import pandas as pd
from matplotlib import pyplot as plt
import h5py

#Zooniverse:
from panoptes_client import Panoptes, Project, SubjectSet, Subject
import magic
import glob

#IceCube:
from icecube.icetray import I3Units
import icecube.MuonGun
from icecube import dataio, dataclasses, icetray, MuonGun
from I3Tray import *
from icecube.hdfwriter import I3HDFWriter
from mc_labeler import MCLabeler #make sure that mc_labeler script is in current directory.

# %%
#Specify file paths:

#Initial I3 File:
nue = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst'

#Desired output directory. Note that creation of this directory is not yet coded and is done manually. 
phase1_dir = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/'

# %%
#Run Filter 1 to label MC truth.
filter1(nue,phase1_dir)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/mc_labeler.py:523: UserWarning: Couldn't find OMKey in MCPESeriesMap
#   warnings.warn("Couldn't find OMKey in MCPESeriesMap")

# %% [markdown]
# Note that the above cell might return an "exception" warning that the *MCPESeriesMap could not be found*. I am unsure why it does that because when I check the i3 file in dataio-shovel, I see the specified mc_pid_series_map (look at mc_labeler.py for exact name of specified key). The resulting file size should be around 400 MB.

# %%
#Path of hdf from above filter.
nue_hdf = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/\
Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst.hd5'

# %%
#Run uniformenergy_events function which requires hdf from filter 1, 
#number of bins, size of each random choice, and a random seed. 

uniformenergy_events(nue_hdf,25,13,12,subrun = True)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['binned_log10E'] = pd.cut(x = np.log10(df_filtered['energy']), bins = bins, labels = labels, include_lowest = True) #might throw an error?
# Number of Bins: 25
# Number of Events per Bin: 13
# Total Number of Events: 325
# Initial Number of Events: 2641
# Number of Events after filtering: 2553
# Please input subrun number:
# 000348

# %% [markdown]
# The above function throws another warning about pd.cut, currently that is not a problem but I don't know if a new version of pandas will allow this.

# %%
#Path to Random Events CSV
nue_csv = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/random_events_uniform_energy_distrib_22067_000348.csv'

# %%
#Run event_characterization_plots function whick makes some quick 
#plots to get an idea of what data you're dealing with.
#Note that I want to update the plot types, maybe make a 2D histogram as Mike K suggested. 
#For truth labels, check out enums.py or in the .py file that holds the functions.

event_characterization_plots(nue_csv)

# %% [markdown]
# Now that we have the events for this phase chosen, we run the second filter to pick out only those events.

# %%
#Path to i3 file from filter1 with MC truth labels. 
nue_filter1 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst'

# %%
#Run function to perform second filter which passes through only selected event IDs chosen from 
#the uniformenergy_events function. 
filter2(nue_filter1,phase1_dir,nue_csv)

# %%
#Path to i3 file from filter 2 that holds only specified events. 
nue_filter2 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst'

# %%
#Run function to perform third filter, which returns only the DAQ frames of the specified events.
#DAQ only file is then split up into many smaller i3 files since SteamShovel can't handle making videos of large
#i3 files at one time. Size limit is approx 2E6 MB (? unsure of units)
filter3(nue_filter2,22067_000348,phase1_dir)

# %%
#Path to NuMu Daq Only folder
nue_daq = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/'

# %%
get_steamshovel(nue_daq,22067000348)
# Out:
# List of files:
# ['/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/daq_only-0009_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/daq_only-0010_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst']
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/daq_only-0009_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000348/daq_only-0010_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000348.i3.zst

# %% [markdown]
# Ideas for Compression:
# - Use GUI to add files to queue and send to one compression folder.
# - Add a subprocess line in movie script to compress the video after making it and direct it to save in the compression folder.

# %%
compressed_path = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/'

# %% [markdown]
# Can't get manifest yet since some subjects are missing and lining it up won't work.

# %%
get_manifest(compressed_path, nue_csv)
# Out:
# {'/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_6141_origidx_4_RF22.mp4': {'event': 6141,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3095766007900238,
#   'pred_cascade': 0.0959115698933601,
#   'pred_tgtrack': 0.1729442775249481,
#   'pred_starttrack': 0.1936895251274109,
#   'pred_stoptrack': 0.2278780937194824,
#   'energy': 31568.90597669892,
#   'zenith': 1.497621938974964,
#   'oneweight': 7053604673389.266,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3095766007900238,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_6179_origidx_6_RF22.mp4': {'event': 6179,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.8431504368782043,
#   'pred_cascade': 0.1104071289300918,
#   'pred_tgtrack': 0.0334232337772846,
#   'pred_starttrack': 0.0127728916704654,
#   'pred_stoptrack': 0.0002463969867676,
#   'energy': 239788.93034713136,
#   'zenith': 1.2705948437704675,
#   'oneweight': 559810038378292.9,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8431504368782043,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_1881_origidx_12_RF22.mp4': {'event': 1881,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 4.707685729954392e-05,
#   'pred_cascade': 0.915511667728424,
#   'pred_tgtrack': 3.486236664684838e-06,
#   'pred_starttrack': 0.0843126848340034,
#   'pred_stoptrack': 0.0001252112851943,
#   'energy': 1188.954183132705,
#   'zenith': 2.4536414158708,
#   'oneweight': 5022691260.846514,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.915511667728424,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_695_origidx_17_RF22.mp4': {'event': 695,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1850962191820144,
#   'pred_cascade': 0.3550743162631988,
#   'pred_tgtrack': 0.0566674284636974,
#   'pred_starttrack': 0.175518587231636,
#   'pred_stoptrack': 0.2276434600353241,
#   'energy': 3734.704629344288,
#   'zenith': 1.0672523990287002,
#   'oneweight': 129583407644.20926,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3550743162631988,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_6314_origidx_11_RF22.mp4': {'event': 6314,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.0964338798657993e-05,
#   'pred_cascade': 0.991531789302826,
#   'pred_tgtrack': 3.437478710566211e-07,
#   'pred_starttrack': 0.0084545901045203,
#   'pred_stoptrack': 2.2990636807662668e-06,
#   'energy': 19880.09927442241,
#   'zenith': 0.1153933755002702,
#   'oneweight': 2833850215683.8413,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.991531789302826,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_5263_origidx_5_RF22.mp4': {'event': 5263,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.018995362755959e-06,
#   'pred_cascade': 0.941946804523468,
#   'pred_tgtrack': 3.260863934428926e-07,
#   'pred_starttrack': 0.0580483302474021,
#   'pred_stoptrack': 3.4487093216739595e-06,
#   'energy': 1315.8298452601382,
#   'zenith': 1.245782646258304,
#   'oneweight': 6002965569.113203,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.941946804523468,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_6225_origidx_8_RF22.mp4': {'event': 6225,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1036561951041221,
#   'pred_cascade': 0.0319109745323658,
#   'pred_tgtrack': 0.8202986121177673,
#   'pred_starttrack': 0.0313674733042717,
#   'pred_stoptrack': 0.0127666611224412,
#   'energy': 411.00283392994027,
#   'zenith': 2.847384896205393,
#   'oneweight': 353081378.0121492,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8202986121177673,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_2421_origidx_6_RF22.mp4': {'event': 2421,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1128062307834625,
#   'pred_cascade': 0.032122652977705,
#   'pred_tgtrack': 0.7856197357177734,
#   'pred_starttrack': 0.017372278496623,
#   'pred_stoptrack': 0.0520791299641132,
#   'energy': 104.93124938713768,
#   'zenith': 1.9174200870031477,
#   'oneweight': 8684464.580296326,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7856197357177734,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_1818_origidx_8_RF22.mp4': {'event': 1818,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.8276691436767578,
#   'pred_cascade': 0.0182518362998962,
#   'pred_tgtrack': 0.072539635002613,
#   'pred_starttrack': 0.0081052770838141,
#   'pred_stoptrack': 0.0734341368079185,
#   'energy': 2071.786194959509,
#   'zenith': 2.105999297295066,
#   'oneweight': 17627270161.327084,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8276691436767578,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_1720_origidx_5_RF22.mp4': {'event': 1720,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 3.919351911463309e-06,
#   'pred_cascade': 0.9438246488571168,
#   'pred_tgtrack': 3.9501028226140995e-08,
#   'pred_starttrack': 0.0561494790017604,
#   'pred_stoptrack': 2.1859221305930987e-05,
#   'energy': 332.8969178560196,
#   'zenith': 1.4485759156810287,
#   'oneweight': 180392672.41275948,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9438246488571168,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_6577_origidx_20_RF22.mp4': {'event': 6577,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0152360731735825,
#   'pred_cascade': 0.0093672648072242,
#   'pred_tgtrack': 0.8095073103904724,
#   'pred_starttrack': 0.0063208662904798,
#   'pred_stoptrack': 0.1595683693885803,
#   'energy': 147.3511780196038,
#   'zenith': 1.9054936266272653,
#   'oneweight': 20509847.69179986,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8095073103904724,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_8023_origidx_26_RF22.mp4': {'event': 8023,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.0003204827953595,
#   'pred_cascade': 0.9880489706993104,
#   'pred_tgtrack': 1.939305462883567e-07,
#   'pred_starttrack': 0.0113747380673885,
#   'pred_stoptrack': 0.0002556144900154,
#   'energy': 9050.684785584495,
#   'zenith': 1.4171007714236277,
#   'oneweight': 517050278248.8449,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9880489706993104,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_8511_origidx_7_RF22.mp4': {'event': 8511,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9557024836540222,
#   'pred_cascade': 0.0074207596480846,
#   'pred_tgtrack': 0.0277633164077997,
#   'pred_starttrack': 0.0028801301959902,
#   'pred_stoptrack': 0.0062332288362085,
#   'energy': 1169.940906365105,
#   'zenith': 1.6136708911014028,
#   'oneweight': 3733980452.179159,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9557024836540222,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_6322_origidx_13_RF22.mp4': {'event': 6322,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0165327303111553,
#   'pred_cascade': 0.0048700263723731,
#   'pred_tgtrack': 0.2742771506309509,
#   'pred_starttrack': 0.0029065669514238,
#   'pred_stoptrack': 0.7014135718345642,
#   'energy': 442.0523981928877,
#   'zenith': 0.6674019553558135,
#   'oneweight': 242907590.6119181,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7014135718345642,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_66_origidx_7_RF22.mp4': {'event': 66,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 3.722805786310346e-06,
#   'pred_cascade': 0.997495710849762,
#   'pred_tgtrack': 4.721494861747999e-10,
#   'pred_starttrack': 0.002500441391021,
#   'pred_stoptrack': 9.155022695495064e-08,
#   'energy': 151077.88876314837,
#   'zenith': 1.1695685712501402,
#   'oneweight': 645238403760623.4,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.997495710849762,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_1985_origidx_18_RF22.mp4': {'event': 1985,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0290967486798763,
#   'pred_cascade': 0.768104076385498,
#   'pred_tgtrack': 0.0027243145741522,
#   'pred_starttrack': 0.1954110413789749,
#   'pred_stoptrack': 0.0046638450585305,
#   'energy': 1019.8965390101454,
#   'zenith': 1.4815568817640408,
#   'oneweight': 2678619770.346963,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.768104076385498,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_7571_origidx_8_RF22.mp4': {'event': 7571,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.0534762370516546e-06,
#   'pred_cascade': 0.9997496008872986,
#   'pred_tgtrack': 8.107230997644875e-10,
#   'pred_starttrack': 0.0002481923729646,
#   'pred_stoptrack': 1.6389728330068465e-07,
#   'energy': 150276.0553253839,
#   'zenith': 1.3972068062495042,
#   'oneweight': 225266931089250.4,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9997496008872986,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_7659_origidx_12_RF22.mp4': {'event': 7659,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9998947381973268,
#   'pred_cascade': 3.2080283318691734e-08,
#   'pred_tgtrack': 1.6993466488202102e-05,
#   'pred_starttrack': 3.147355016608344e-07,
#   'pred_stoptrack': 8.796162001090124e-05,
#   'energy': 43582.64183288354,
#   'zenith': 1.1112822619983398,
#   'oneweight': 16028945468664.385,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9998947381973268,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_7712_origidx_14_RF22.mp4': {'event': 7712,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 3.702806134242565e-05,
#   'pred_cascade': 0.9935899972915648,
#   'pred_tgtrack': 1.9555773889123884e-08,
#   'pred_starttrack': 0.0063723614439368,
#   'pred_stoptrack': 5.451078664009401e-07,
#   'energy': 25340.71147027915,
#   'zenith': 1.3090920340604684,
#   'oneweight': 5563461618048.132,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9935899972915648,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_8096_origidx_31_RF22.mp4': {'event': 8096,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0944620668888092,
#   'pred_cascade': 0.0641813576221466,
#   'pred_tgtrack': 0.0416123569011688,
#   'pred_starttrack': 0.1521637290716171,
#   'pred_stoptrack': 0.6475805044174194,
#   'energy': 185.6088111578969,
#   'zenith': 0.6601134221860445,
#   'oneweight': 57712470.79042629,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.6475805044174194,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_694_origidx_16_RF22.mp4': {'event': 694,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.7782805562019348,
#   'pred_cascade': 0.2108722329139709,
#   'pred_tgtrack': 9.259428225050216e-06,
#   'pred_starttrack': 0.0106075275689363,
#   'pred_stoptrack': 0.0002304902300238,
#   'energy': 389673.2896039939,
#   'zenith': 2.904535793834996,
#   'oneweight': 79754565671459.73,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7782805562019348,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_3476_origidx_4_RF22.mp4': {'event': 3476,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9882291555404664,
#   'pred_cascade': 0.0010907837422564,
#   'pred_tgtrack': 0.0003958276647608,
#   'pred_starttrack': 0.0011303763603791,
#   'pred_stoptrack': 0.0091538866981863,
#   'energy': 6310.301104085403,
#   'zenith': 0.9469457640638178,
#   'oneweight': 339705183964.1241,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9882291555404664,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_1827_origidx_9_RF22.mp4': {'event': 1827,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0001697036641417,
#   'pred_cascade': 0.9835980534553528,
#   'pred_tgtrack': 1.503680323367007e-06,
#   'pred_starttrack': 0.0161371361464262,
#   'pred_stoptrack': 9.367154416395353e-05,
#   'energy': 3067.234652790514,
#   'zenith': 0.3349323953115073,
#   'oneweight': 45843705130.02902,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9835980534553528,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_6414_origidx_17_RF22.mp4': {'event': 6414,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9993731379508972,
#   'pred_cascade': 1.5970547800892018e-11,
#   'pred_tgtrack': 0.0002495459339115,
#   'pred_starttrack': 2.0313242754532723e-10,
#   'pred_stoptrack': 0.0003773017087951,
#   'energy': 88320.38496010774,
#   'zenith': 1.5015549881359145,
#   'oneweight': 68427674782944.52,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9993731379508972,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_3524_origidx_5_RF22.mp4': {'event': 3524,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.8624275922775269,
#   'pred_cascade': 0.015554416924715,
#   'pred_tgtrack': 0.0054748100228607,
#   'pred_starttrack': 0.0050278715789318,
#   'pred_stoptrack': 0.1115152910351753,
#   'energy': 883.7105920089198,
#   'zenith': 1.658024390017306,
#   'oneweight': 1844974083.9969344,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8624275922775269,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_1751_origidx_7_RF22.mp4': {'event': 1751,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0030730536673218,
#   'pred_cascade': 0.8965187668800354,
#   'pred_tgtrack': 0.0005933580105192,
#   'pred_starttrack': 0.0906933918595314,
#   'pred_stoptrack': 0.0091214748099446,
#   'energy': 1328.6781482001552,
#   'zenith': 1.654987242165009,
#   'oneweight': 5241856700.496118,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8965187668800354,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_1730_origidx_6_RF22.mp4': {'event': 1730,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0001617879461264,
#   'pred_cascade': 0.9168198108673096,
#   'pred_tgtrack': 1.2103739663871238e-06,
#   'pred_starttrack': 0.0829532220959663,
#   'pred_stoptrack': 6.403607403626665e-05,
#   'energy': 1743.646142577141,
#   'zenith': 1.6644621783524227,
#   'oneweight': 10232221162.832075,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9168198108673096,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_7631_origidx_10_RF22.mp4': {'event': 7631,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9981643557548524,
#   'pred_cascade': 4.643831744033378e-06,
#   'pred_tgtrack': 0.0001435916492482,
#   'pred_starttrack': 3.19546161335893e-05,
#   'pred_stoptrack': 0.0016555306501686,
#   'energy': 2245.478784227997,
#   'zenith': 1.6501196819472104,
#   'oneweight': 51915080817.522194,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9981643557548524,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_5336_origidx_7_RF22.mp4': {'event': 5336,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.6513014998054132e-05,
#   'pred_cascade': 0.9879288077354432,
#   'pred_tgtrack': 1.0158965579876168e-07,
#   'pred_starttrack': 0.012045407667756,
#   'pred_stoptrack': 9.131484148383606e-06,
#   'energy': 2876.1539921727267,
#   'zenith': 1.017581375856732,
#   'oneweight': 44533006225.36257,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9879288077354432,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_8643_origidx_9_RF22.mp4': {'event': 8643,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 6.319897511275485e-05,
#   'pred_cascade': 0.9010759592056274,
#   'pred_tgtrack': 0.0006616967148147,
#   'pred_starttrack': 0.097918801009655,
#   'pred_stoptrack': 0.0002803874376695,
#   'energy': 2818.954761608758,
#   'zenith': 2.664079375290027,
#   'oneweight': 34814415084.11672,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9010759592056274,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_753_origidx_19_RF22.mp4': {'event': 753,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.997288465499878,
#   'pred_cascade': 1.1186640222149435e-05,
#   'pred_tgtrack': 0.0020646722987294,
#   'pred_starttrack': 1.115734085033182e-05,
#   'pred_stoptrack': 0.0006244624964892,
#   'energy': 57020.94987970678,
#   'zenith': 1.2354132508274402,
#   'oneweight': 31388623549786.9,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.997288465499878,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_7890_origidx_19_RF22.mp4': {'event': 7890,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9914143681526184,
#   'pred_cascade': 3.0751411372875737e-07,
#   'pred_tgtrack': 0.0004269070923328,
#   'pred_starttrack': 6.456582468672423e-06,
#   'pred_stoptrack': 0.0081518627703189,
#   'energy': 2526.000489271657,
#   'zenith': 1.7365291333996495,
#   'oneweight': 21138847820.85657,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9914143681526184,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_6318_origidx_12_RF22.mp4': {'event': 6318,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 7.467534032912226e-06,
#   'pred_cascade': 0.9749450087547302,
#   'pred_tgtrack': 1.875782515980973e-07,
#   'pred_starttrack': 0.0250369552522897,
#   'pred_stoptrack': 1.0504290003154892e-05,
#   'energy': 879.4554380814185,
#   'zenith': 1.279341974098107,
#   'oneweight': 3701541719.407488,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9749450087547302,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_159_origidx_8_RF22.mp4': {'event': 159,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0114555610343813,
#   'pred_cascade': 0.0022945199161767,
#   'pred_tgtrack': 0.0216143280267715,
#   'pred_starttrack': 0.0022621168754994,
#   'pred_stoptrack': 0.962373435497284,
#   'energy': 24473.93894169521,
#   'zenith': 1.0739673173467783,
#   'oneweight': 2867457728238.54,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.962373435497284,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_181_origidx_10_RF22.mp4': {'event': 181,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9899397492408752,
#   'pred_cascade': 0.0052476739510893,
#   'pred_tgtrack': 0.0002087066095555,
#   'pred_starttrack': 0.0028663449920713,
#   'pred_stoptrack': 0.0017375034512951,
#   'energy': 35625.69799030501,
#   'zenith': 0.7402641382844886,
#   'oneweight': 15275461345541.826,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9899397492408752,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_46_origidx_5_RF22.mp4': {'event': 46,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0126899424940347,
#   'pred_cascade': 0.0022857727017253,
#   'pred_tgtrack': 0.0040057091973721,
#   'pred_starttrack': 0.011583125218749,
#   'pred_stoptrack': 0.9694353938102722,
#   'energy': 3983.551480565004,
#   'zenith': 0.496318388664925,
#   'oneweight': 27694244823.00525,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9694353938102722,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_7566_origidx_7_RF22.mp4': {'event': 7566,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9453582167625428,
#   'pred_cascade': 0.0006403516163118,
#   'pred_tgtrack': 0.0079983752220869,
#   'pred_starttrack': 0.0073648728430271,
#   'pred_stoptrack': 0.0386381670832634,
#   'energy': 3584.522568350863,
#   'zenith': 2.9672873960896275,
#   'oneweight': 56461217609.43405,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9453582167625428,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_8008_origidx_25_RF22.mp4': {'event': 8008,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0303662475198507,
#   'pred_cascade': 0.0083051938563585,
#   'pred_tgtrack': 0.2221091985702514,
#   'pred_starttrack': 0.0033465605229139,
#   'pred_stoptrack': 0.735872745513916,
#   'energy': 2751.1860768052147,
#   'zenith': 1.973016598138305,
#   'oneweight': 107767937595.9225,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.735872745513916,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_7958_origidx_23_RF22.mp4': {'event': 7958,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.99970942735672,
#   'pred_cascade': 1.757902295951297e-10,
#   'pred_tgtrack': 0.0002719664480537,
#   'pred_starttrack': 2.8161850629260243e-10,
#   'pred_stoptrack': 1.861341661424376e-05,
#   'energy': 176525.8143993362,
#   'zenith': 1.785806792466481,
#   'oneweight': 362982478737780.8,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.99970942735672,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_1831_origidx_10_RF22.mp4': {'event': 1831,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.189569815993309,
#   'pred_cascade': 0.0395801700651645,
#   'pred_tgtrack': 0.0090333959087729,
#   'pred_starttrack': 0.0209368858486413,
#   'pred_stoptrack': 0.7408797740936279,
#   'energy': 183.78987367952567,
#   'zenith': 2.438825704742694,
#   'oneweight': 32994963.27095068,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7408797740936279,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_7903_origidx_20_RF22.mp4': {'event': 7903,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9988840222358704,
#   'pred_cascade': 0.0001234418450621,
#   'pred_tgtrack': 2.064571344817523e-05,
#   'pred_starttrack': 0.0005861007375642,
#   'pred_stoptrack': 0.0003858174022752,
#   'energy': 12976.461327206687,
#   'zenith': 2.489719417594136,
#   'oneweight': 1338527688347.2595,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9988840222358704,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_8032_origidx_28_RF22.mp4': {'event': 8032,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0460125021636486,
#   'pred_cascade': 0.1118198186159133,
#   'pred_tgtrack': 0.0065189572051167,
#   'pred_starttrack': 0.757025420665741,
#   'pred_stoptrack': 0.0786231979727745,
#   'energy': 856.4137860219632,
#   'zenith': 1.424376405409955,
#   'oneweight': 3085511174.669344,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.757025420665741,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_8421_origidx_4_RF22.mp4': {'event': 8421,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2382603585720062,
#   'pred_cascade': 0.0254211332648992,
#   'pred_tgtrack': 0.0114337168633937,
#   'pred_starttrack': 0.3484337031841278,
#   'pred_stoptrack': 0.3764510452747345,
#   'energy': 215.85535038596177,
#   'zenith': 2.870612926328494,
#   'oneweight': 64810766.805922695,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3764510452747345,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_8448_origidx_5_RF22.mp4': {'event': 8448,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9998254179954528,
#   'pred_cascade': 1.4071999121512135e-10,
#   'pred_tgtrack': 0.0001649785699555,
#   'pred_starttrack': 2.551934219496843e-09,
#   'pred_stoptrack': 9.67395772022428e-06,
#   'energy': 191878.52939903623,
#   'zenith': 0.8286434694415054,
#   'oneweight': 879296870294547.1,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9998254179954528,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_791_origidx_21_RF22.mp4': {'event': 791,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.7061281800270081,
#   'pred_cascade': 0.0908906310796737,
#   'pred_tgtrack': 0.0306613650172948,
#   'pred_starttrack': 0.0547604672610759,
#   'pred_stoptrack': 0.11755932867527,
#   'energy': 191.09709768167656,
#   'zenith': 1.0122695735509544,
#   'oneweight': 60495233.91243079,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7061281800270081,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_7563_origidx_6_RF22.mp4': {'event': 7563,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9944676160812378,
#   'pred_cascade': 0.0001163726265076,
#   'pred_tgtrack': 0.0010234939400106,
#   'pred_starttrack': 0.000163236822118,
#   'pred_stoptrack': 0.0042292405851185,
#   'energy': 452248.408267113,
#   'zenith': 2.672482752248408,
#   'oneweight': 354023630439777.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9944676160812378,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_8077_origidx_30_RF22.mp4': {'event': 8077,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9993521571159364,
#   'pred_cascade': 4.37774446027106e-07,
#   'pred_tgtrack': 0.000123902427731,
#   'pred_starttrack': 1.5209159300866304e-06,
#   'pred_stoptrack': 0.0005219483282417,
#   'energy': 186270.5092351212,
#   'zenith': 1.279660161230624,
#   'oneweight': 443842154120302.7,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9993521571159364,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_10044_origidx_4_RF22.mp4': {'event': 10044,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.3655409929924645e-05,
#   'pred_cascade': 0.9954521059989928,
#   'pred_tgtrack': 1.4173816680340678e-06,
#   'pred_starttrack': 0.0045190309174358,
#   'pred_stoptrack': 1.3791363926429767e-05,
#   'energy': 15422.17169953728,
#   'zenith': 0.8062992674783739,
#   'oneweight': 2209412747561.3145,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9954521059989928,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_7701_origidx_13_RF22.mp4': {'event': 7701,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3430341482162475,
#   'pred_cascade': 0.000868399918545,
#   'pred_tgtrack': 0.4085621833801269,
#   'pred_starttrack': 0.0011282096384093,
#   'pred_stoptrack': 0.2464071065187454,
#   'energy': 1090.7691700061616,
#   'zenith': 0.4794809456730069,
#   'oneweight': 1976687648.1570988,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4085621833801269,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_7740_origidx_16_RF22.mp4': {'event': 7740,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.120531678199768,
#   'pred_cascade': 0.0505714640021324,
#   'pred_tgtrack': 0.375525414943695,
#   'pred_starttrack': 0.0375142060220241,
#   'pred_stoptrack': 0.4158572852611542,
#   'energy': 974284.5973187868,
#   'zenith': 0.2396464055097115,
#   'oneweight': 6847230375009544.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4158572852611542,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_5310_origidx_6_RF22.mp4': {'event': 5310,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 6.081938408897258e-06,
#   'pred_cascade': 0.8991512060165405,
#   'pred_tgtrack': 8.228231536122621e-07,
#   'pred_starttrack': 0.1008214950561523,
#   'pred_stoptrack': 2.0396177205839194e-05,
#   'energy': 415.1587392918408,
#   'zenith': 1.2710191472798311,
#   'oneweight': 352755607.26716864,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8991512060165405,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_1969_origidx_15_RF22.mp4': {'event': 1969,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 7.248326437547803e-05,
#   'pred_cascade': 0.9282765984535216,
#   'pred_tgtrack': 4.385971408282785e-07,
#   'pred_starttrack': 0.0716489776968956,
#   'pred_stoptrack': 1.5384371181426104e-06,
#   'energy': 158810.5017085779,
#   'zenith': 0.6987745969441167,
#   'oneweight': 509892364144791.7,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9282765984535216,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_2399_origidx_4_RF22.mp4': {'event': 2399,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.6002567410469055,
#   'pred_cascade': 0.1853262782096862,
#   'pred_tgtrack': 0.0004471811698749,
#   'pred_starttrack': 0.1720757782459259,
#   'pred_stoptrack': 0.0418940410017967,
#   'energy': 1518.8586725303564,
#   'zenith': 1.1093727830051427,
#   'oneweight': 10052180543.521248,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6002567410469055,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_1975_origidx_16_RF22.mp4': {'event': 1975,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3865385949611664,
#   'pred_cascade': 0.0993654057383537,
#   'pred_tgtrack': 0.0598705932497978,
#   'pred_starttrack': 0.1179262101650238,
#   'pred_stoptrack': 0.3362992107868194,
#   'energy': 110.36874883410876,
#   'zenith': 0.9405975232697956,
#   'oneweight': 4404000.776115327,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3865385949611664,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_1714_origidx_4_RF22.mp4': {'event': 1714,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.7690937966108322e-05,
#   'pred_cascade': 0.8683081865310669,
#   'pred_tgtrack': 4.7015888071655365e-07,
#   'pred_starttrack': 0.1316328346729278,
#   'pred_stoptrack': 4.087933484697714e-05,
#   'energy': 741.3489072167238,
#   'zenith': 1.700342945224502,
#   'oneweight': 1309548922.5174944,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8683081865310669,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_7853_origidx_18_RF22.mp4': {'event': 7853,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 4.329594230512157e-05,
#   'pred_cascade': 0.9151427149772644,
#   'pred_tgtrack': 1.965529736480676e-05,
#   'pred_starttrack': 0.0846767574548721,
#   'pred_stoptrack': 0.0001175950965262,
#   'energy': 506.273766981488,
#   'zenith': 2.072510644322966,
#   'oneweight': 584237205.5939995,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9151427149772644,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_1984_origidx_17_RF22.mp4': {'event': 1984,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0165879856795072,
#   'pred_cascade': 0.0045494227670133,
#   'pred_tgtrack': 0.0042263455688953,
#   'pred_starttrack': 0.0046247583813965,
#   'pred_stoptrack': 0.9700114727020264,
#   'energy': 426.2497415784204,
#   'zenith': 0.2045735365417214,
#   'oneweight': 271760162.90367705,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9700114727020264,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_8126_origidx_32_RF22.mp4': {'event': 8126,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999035596847534,
#   'pred_cascade': 2.9396190370789558e-08,
#   'pred_tgtrack': 8.195357622753363e-06,
#   'pred_starttrack': 5.133820764058328e-07,
#   'pred_stoptrack': 8.777468610787764e-05,
#   'energy': 247784.160677305,
#   'zenith': 1.899800376551681,
#   'oneweight': 1.006532919916719e+16,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999035596847534,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_2403_origidx_5_RF22.mp4': {'event': 2403,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2310544550418853,
#   'pred_cascade': 0.0707724243402481,
#   'pred_tgtrack': 0.3931422233581543,
#   'pred_starttrack': 0.0306764692068099,
#   'pred_stoptrack': 0.2743544578552246,
#   'energy': 120.92948831923026,
#   'zenith': 1.7300834414606128,
#   'oneweight': 21313505.204420503,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3931422233581543,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_6195_origidx_7_RF22.mp4': {'event': 6195,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.9536697638832266e-06,
#   'pred_cascade': 0.1069745421409607,
#   'pred_tgtrack': 3.614178058342077e-05,
#   'pred_starttrack': 0.8929852843284607,
#   'pred_stoptrack': 1.0544197266426636e-06,
#   'energy': 128775.4566156704,
#   'zenith': 1.2862304524986574,
#   'oneweight': 158686582495339.06,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8929852843284607,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_6583_origidx_21_RF22.mp4': {'event': 6583,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0050851162523031,
#   'pred_cascade': 0.0020609840285032,
#   'pred_tgtrack': 0.5971708297729492,
#   'pred_starttrack': 0.0008901099208742,
#   'pred_stoptrack': 0.3947928845882416,
#   'energy': 7388.244986115896,
#   'zenith': 1.80584660248161,
#   'oneweight': 1586246566036.4065,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5971708297729492,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_420_origidx_14_RF22.mp4': {'event': 420,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.8192899823188782,
#   'pred_cascade': 0.032960083335638,
#   'pred_tgtrack': 0.0244764443486928,
#   'pred_starttrack': 0.0637168288230896,
#   'pred_stoptrack': 0.0595566406846046,
#   'energy': 17016.61376456352,
#   'zenith': 1.552253936594005,
#   'oneweight': 1710628825222.627,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8192899823188782,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_6265_origidx_10_RF22.mp4': {'event': 6265,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1015105322003364,
#   'pred_cascade': 0.043724350631237,
#   'pred_tgtrack': 0.6945053339004517,
#   'pred_starttrack': 0.0432914718985557,
#   'pred_stoptrack': 0.1169682294130325,
#   'energy': 101.6043058829391,
#   'zenith': 0.8773709836802143,
#   'oneweight': 8299000.073952792,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6945053339004517,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_281_origidx_12_RF22.mp4': {'event': 281,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9994854927062988,
#   'pred_cascade': 5.559001010624343e-07,
#   'pred_tgtrack': 0.000208576224395,
#   'pred_starttrack': 1.3581363873527152e-06,
#   'pred_stoptrack': 0.0003039707662537,
#   'energy': 167779.46492653782,
#   'zenith': 0.3460153105875246,
#   'oneweight': 404532260481090.7,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9994854927062988,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_7734_origidx_15_RF22.mp4': {'event': 7734,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0902414321899414,
#   'pred_cascade': 0.0195353906601667,
#   'pred_tgtrack': 0.7980101704597473,
#   'pred_starttrack': 0.07489013671875,
#   'pred_stoptrack': 0.0173227973282337,
#   'energy': 390.1557949764099,
#   'zenith': 2.084220971208288,
#   'oneweight': 325365961.60151184,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7980101704597473,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_6234_origidx_9_RF22.mp4': {'event': 6234,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3156757056713104,
#   'pred_cascade': 0.0889973118901252,
#   'pred_tgtrack': 0.1448661834001541,
#   'pred_starttrack': 0.3454803228378296,
#   'pred_stoptrack': 0.1049804762005806,
#   'energy': 296.64680761249025,
#   'zenith': 1.8758618979419384,
#   'oneweight': 153706975.58028084,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3454803228378296,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_777_origidx_20_RF22.mp4': {'event': 777,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4412158727645874,
#   'pred_cascade': 0.1992455571889877,
#   'pred_tgtrack': 0.0070520010776817,
#   'pred_starttrack': 0.2172392308712005,
#   'pred_stoptrack': 0.1352473795413971,
#   'energy': 1098.5739895365707,
#   'zenith': 2.5119248924516517,
#   'oneweight': 4340568767.416705,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4412158727645874,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_8932_origidx_5_RF22.mp4': {'event': 8932,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.000173585693119,
#   'pred_cascade': 0.975702941417694,
#   'pred_tgtrack': 1.636424968864958e-07,
#   'pred_starttrack': 0.0240918602794408,
#   'pred_stoptrack': 3.157106038997881e-05,
#   'energy': 1828.94884589391,
#   'zenith': 2.0974841334857404,
#   'oneweight': 15431333330.709888,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.975702941417694,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_5355_origidx_8_RF22.mp4': {'event': 5355,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2701687216758728,
#   'pred_cascade': 0.6177169680595398,
#   'pred_tgtrack': 0.020499724894762,
#   'pred_starttrack': 0.0842688605189323,
#   'pred_stoptrack': 0.0073457560501992,
#   'energy': 6953.332521764829,
#   'zenith': 1.6585579073069991,
#   'oneweight': 233070736011.75223,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6177169680595398,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_1961_origidx_14_RF22.mp4': {'event': 1961,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0287104472517967,
#   'pred_cascade': 0.0076875290833413,
#   'pred_tgtrack': 0.9330888986587524,
#   'pred_starttrack': 0.0072418893687427,
#   'pred_stoptrack': 0.0232712067663669,
#   'energy': 144521.80945714007,
#   'zenith': 1.9265879030327768,
#   'oneweight': 2767426400717562.5,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9330888986587524,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_5254_origidx_4_RF22.mp4': {'event': 5254,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0022450278047472,
#   'pred_cascade': 0.9720600247383118,
#   'pred_tgtrack': 3.021164332039916e-07,
#   'pred_starttrack': 0.0256925299763679,
#   'pred_stoptrack': 2.090085899908445e-06,
#   'energy': 494699.4209950295,
#   'zenith': 1.1701878577358316,
#   'oneweight': 2611829875877253.0,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9720600247383118,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_2026_origidx_20_RF22.mp4': {'event': 2026,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 8.298649481730536e-05,
#   'pred_cascade': 0.9968196153640748,
#   'pred_tgtrack': 9.26810272972034e-09,
#   'pred_starttrack': 0.0030856330413371,
#   'pred_stoptrack': 1.1727009223250208e-05,
#   'energy': 15630.64215559216,
#   'zenith': 1.9108183059885449,
#   'oneweight': 1976105828567.8904,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9968196153640748,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
# ...
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_2016_origidx_19_RF22.mp4': {'event': 2016,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0321829132735729,
#   'pred_cascade': 0.0100573189556598,
#   'pred_tgtrack': 0.387175977230072,
#   'pred_starttrack': 0.0048517021350562,
#   'pred_stoptrack': 0.5657320618629456,
#   'energy': 132.31920505650035,
#   'zenith': 2.600665675941933,
#   'oneweight': 5859895.603197988,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5657320618629456,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_588_origidx_15_RF22.mp4': {'event': 588,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9997995495796204,
#   'pred_cascade': 7.015965053369656e-08,
#   'pred_tgtrack': 7.274139352375641e-05,
#   'pred_starttrack': 1.3613066585094202e-07,
#   'pred_stoptrack': 0.0001275613176403,
#   'energy': 52359.03922810572,
#   'zenith': 1.0305684087457214,
#   'oneweight': 55974136559089.055,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9997995495796204,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_7994_origidx_24_RF22.mp4': {'event': 7994,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999783456325531,
#   'pred_cascade': 2.073664745694259e-06,
#   'pred_tgtrack': 6.194973684614524e-05,
#   'pred_starttrack': 4.400603302201489e-06,
#   'pred_stoptrack': 0.0001481731160311,
#   'energy': 187904.6128771325,
#   'zenith': 2.6024138639219934,
#   'oneweight': 59108927668463.78,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999783456325531,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_371_origidx_13_RF22.mp4': {'event': 371,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.853320300579071,
#   'pred_cascade': 0.0384673699736595,
#   'pred_tgtrack': 0.0004528927383944,
#   'pred_starttrack': 0.0211650300770998,
#   'pred_stoptrack': 0.0865944772958755,
#   'energy': 1145.7262923083192,
#   'zenith': 1.6524210229244145,
#   'oneweight': 3652452050.562098,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.853320300579071,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_7545_origidx_5_RF22.mp4': {'event': 7545,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999854564666748,
#   'pred_cascade': 4.914392781607545e-10,
#   'pred_tgtrack': 1.1125733863082132e-06,
#   'pred_starttrack': 6.749086622903634e-08,
#   'pred_stoptrack': 1.335219894826878e-05,
#   'energy': 449946.9277796389,
#   'zenith': 0.8418126775549711,
#   'oneweight': 4437807527672751.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999854564666748,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_2094_origidx_21_RF22.mp4': {'event': 2094,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999886751174928,
#   'pred_cascade': 5.4608091382135634e-09,
#   'pred_tgtrack': 1.16227147373138e-06,
#   'pred_starttrack': 2.0384165466680315e-08,
#   'pred_stoptrack': 1.0160882084164768e-05,
#   'energy': 117413.54532001232,
#   'zenith': 1.6425491934009528,
#   'oneweight': 125415180076672.22,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999886751174928,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_1870_origidx_11_RF22.mp4': {'event': 1870,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0504435673356056,
#   'pred_cascade': 0.0188512410968542,
#   'pred_tgtrack': 0.877305805683136,
#   'pred_starttrack': 0.0280091483145952,
#   'pred_stoptrack': 0.025390226393938,
#   'energy': 141.04095282546555,
#   'zenith': 1.6306792540026582,
#   'oneweight': 12406543.377407452,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.877305805683136,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_8025_origidx_27_RF22.mp4': {'event': 8025,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2479698807001114,
#   'pred_cascade': 0.3374565243721008,
#   'pred_tgtrack': 0.0356735438108444,
#   'pred_starttrack': 0.2022959440946579,
#   'pred_stoptrack': 0.1766041368246078,
#   'energy': 258.9235407599376,
#   'zenith': 0.7426212660291123,
#   'oneweight': 82965670.22458352,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3374565243721008,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_8189_origidx_33_RF22.mp4': {'event': 8189,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999846339225769,
#   'pred_cascade': 3.868912690219161e-10,
#   'pred_tgtrack': 4.714368515124079e-06,
#   'pred_starttrack': 3.911177159920953e-09,
#   'pred_stoptrack': 0.0001489209680585,
#   'energy': 298789.1974829099,
#   'zenith': 2.023035446352178,
#   'oneweight': 1042964606004967.8,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999846339225769,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_8916_origidx_4_RF22.mp4': {'event': 8916,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0807515904307365,
#   'pred_cascade': 0.0148704312741756,
#   'pred_tgtrack': 0.4379030466079712,
#   'pred_starttrack': 0.0288378223776817,
#   'pred_stoptrack': 0.4376371204853058,
#   'energy': 1235.80378898277,
#   'zenith': 2.053319222484669,
#   'oneweight': 2067764832.3028145,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4379030466079712,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_701_origidx_18_RF22.mp4': {'event': 701,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.0100870486348867,
#   'pred_cascade': 0.5745777487754822,
#   'pred_tgtrack': 0.0036476594395935,
#   'pred_starttrack': 0.3840997815132141,
#   'pred_stoptrack': 0.0275877695530653,
#   'energy': 4017.319393582138,
#   'zenith': 2.2539416978129734,
#   'oneweight': 335500114517.86115,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.5745777487754822,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_5424_origidx_9_RF22.mp4': {'event': 5424,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0004843000206165,
#   'pred_cascade': 0.9602415561676024,
#   'pred_tgtrack': 0.0003750131290871,
#   'pred_starttrack': 0.0387981943786144,
#   'pred_stoptrack': 0.0001008475446724,
#   'energy': 175214.8362087131,
#   'zenith': 1.091672008363539,
#   'oneweight': 680407738999614.4,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9602415561676024,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_7798_origidx_17_RF22.mp4': {'event': 7798,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.0001596015645191,
#   'pred_cascade': 0.989325761795044,
#   'pred_tgtrack': 1.96660653273284e-06,
#   'pred_starttrack': 0.0104885036125779,
#   'pred_stoptrack': 2.4173061319743283e-05,
#   'energy': 16957.609645979785,
#   'zenith': 0.1218486395558502,
#   'oneweight': 1889476414894.046,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.989325761795044,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_7597_origidx_9_RF22.mp4': {'event': 7597,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.5193166732788086,
#   'pred_cascade': 0.3502416014671325,
#   'pred_tgtrack': 0.0175026040524244,
#   'pred_starttrack': 0.0814706981182098,
#   'pred_stoptrack': 0.0314685180783271,
#   'energy': 1473.360593770511,
#   'zenith': 2.099904474961513,
#   'oneweight': 8799602054.024975,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5193166732788086,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_8597_origidx_8_RF22.mp4': {'event': 8597,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9298477172851562,
#   'pred_cascade': 0.0598908886313438,
#   'pred_tgtrack': 1.9882685592165217e-05,
#   'pred_starttrack': 0.0096844993531703,
#   'pred_stoptrack': 0.0005570090725086,
#   'energy': 256855.41810946583,
#   'zenith': 2.541559442748901,
#   'oneweight': 36054477270106.8,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9298477172851562,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_6677_origidx_22_RF22.mp4': {'event': 6677,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1000505313277244,
#   'pred_cascade': 0.0272890720516443,
#   'pred_tgtrack': 0.7332452535629272,
#   'pred_starttrack': 0.0275529511272907,
#   'pred_stoptrack': 0.1118622422218322,
#   'energy': 504.26425366864726,
#   'zenith': 1.6548876878114624,
#   'oneweight': 921565030.6380008,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7332452535629272,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_6170_origidx_5_RF22.mp4': {'event': 6170,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3263979852199554,
#   'pred_cascade': 0.1190056800842285,
#   'pred_tgtrack': 0.2938466966152191,
#   'pred_starttrack': 0.0905824303627014,
#   'pred_stoptrack': 0.1701671630144119,
#   'energy': 4531.779948460219,
#   'zenith': 1.183644094668837,
#   'oneweight': 42492975600.82876,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3263979852199554,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_2439_origidx_7_RF22.mp4': {'event': 2439,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.8903658986091614,
#   'pred_cascade': 0.0904178842902183,
#   'pred_tgtrack': 0.0003870334476232,
#   'pred_starttrack': 0.0100835002958774,
#   'pred_stoptrack': 0.0087456842884421,
#   'energy': 6178.951500099264,
#   'zenith': 1.270332350853756,
#   'oneweight': 226902786428.9216,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8903658986091614,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_839_origidx_22_RF22.mp4': {'event': 839,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9998682737350464,
#   'pred_cascade': 8.337194046248442e-09,
#   'pred_tgtrack': 8.655233978061005e-05,
#   'pred_starttrack': 4.87424394179925e-08,
#   'pred_stoptrack': 4.504129174165428e-05,
#   'energy': 92358.2179559351,
#   'zenith': 0.7005187322462858,
#   'oneweight': 91318786336379.56,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9998682737350464,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_7528_origidx_4_RF22.mp4': {'event': 7528,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 5.001217505196109e-05,
#   'pred_cascade': 0.902999997138977,
#   'pred_tgtrack': 1.211789708577271e-06,
#   'pred_starttrack': 0.0968041718006134,
#   'pred_stoptrack': 0.0001445523957954,
#   'energy': 2003.87765438084,
#   'zenith': 1.9875010467860663,
#   'oneweight': 18030266300.40433,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.902999997138977,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_6885_origidx_4_RF22.mp4': {'event': 6885,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 9.92274976852059e-07,
#   'pred_cascade': 0.9619956612586976,
#   'pred_tgtrack': 2.669897867235705e-07,
#   'pred_starttrack': 0.0380002483725547,
#   'pred_stoptrack': 2.809496209010831e-06,
#   'energy': 3517.316604484819,
#   'zenith': 0.4997121915586134,
#   'oneweight': 74750169926.4399,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9619956612586976,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_7909_origidx_22_RF22.mp4': {'event': 7909,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0001601785043021,
#   'pred_cascade': 0.8837381601333618,
#   'pred_tgtrack': 0.0001734170509735,
#   'pred_starttrack': 0.115607351064682,
#   'pred_stoptrack': 0.0003208668495062,
#   'energy': 451.2377696498195,
#   'zenith': 0.5507900954165483,
#   'oneweight': 390325204.81593895,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8837381601333618,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_6338_origidx_14_RF22.mp4': {'event': 6338,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9964145421981812,
#   'pred_cascade': 2.8353428206173703e-05,
#   'pred_tgtrack': 0.0005713690188713,
#   'pred_starttrack': 0.0001233152870554,
#   'pred_stoptrack': 0.0028624578844755,
#   'energy': 6413.782549917039,
#   'zenith': 0.3899464939703234,
#   'oneweight': 262882100072.3592,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9964145421981812,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000348/compressed_run_22067_event_55_origidx_6_RF22.mp4': {'event': 55,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0557629168033599,
#   'pred_cascade': 0.0150049971416592,
#   'pred_tgtrack': 0.2886725068092346,
#   'pred_starttrack': 0.6301034092903137,
#   'pred_stoptrack': 0.0104560982435941,
#   'energy': 394.6145278590717,
#   'zenith': 1.190991152143871,
#   'oneweight': 256824297.2683084,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6301034092903137,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 4}}

# %%
make_subject_set('nue_run_22067_subrun_000348_phase2')
# Out:
# Subject Set Name: nue_run_22067_subrun_000348_phase2
# Subject Set ID: 112467
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>, <SubjectSet 112464>]

# %%
uploader(compressed_path,nue_csv,112467)
# Out:
# Confirm if subject set 112467 is listed below.
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>, <SubjectSet 112464>]
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>, <SubjectSet 112464>]
# Number of times loop has ran: 1
# Number of times loop has ran: 2
# Number of times loop has ran: 3
# Number of times loop has ran: 4
# Number of times loop has ran: 5
# Number of times loop has ran: 6
# Number of times loop has ran: 7
# Number of times loop has ran: 8
# Number of times loop has ran: 9
# Number of times loop has ran: 10
# Number of times loop has ran: 11
# Number of times loop has ran: 12
# Number of times loop has ran: 13
# Number of times loop has ran: 14
# Number of times loop has ran: 15
# Number of times loop has ran: 16
# Number of times loop has ran: 17
# Number of times loop has ran: 18
# Number of times loop has ran: 19
# Number of times loop has ran: 20
# Number of times loop has ran: 21
# Number of times loop has ran: 22
# Number of times loop has ran: 23
# Number of times loop has ran: 24
# Number of times loop has ran: 25
# Number of times loop has ran: 26
# Number of times loop has ran: 27
# Number of times loop has ran: 28
# Number of times loop has ran: 29
# Number of times loop has ran: 30
# Number of times loop has ran: 31
# Number of times loop has ran: 32
# Number of times loop has ran: 33
# Number of times loop has ran: 34
# Number of times loop has ran: 35
# Number of times loop has ran: 36
# Number of times loop has ran: 37
# Number of times loop has ran: 38
# Number of times loop has ran: 39
# Number of times loop has ran: 40
# Number of times loop has ran: 41
# Number of times loop has ran: 42
# Number of times loop has ran: 43
# Number of times loop has ran: 44
# Number of times loop has ran: 45
# Number of times loop has ran: 46
# Number of times loop has ran: 47
# Number of times loop has ran: 48
# Number of times loop has ran: 49
# Number of times loop has ran: 50
# Number of times loop has ran: 51
# Number of times loop has ran: 52
# Number of times loop has ran: 53
# Number of times loop has ran: 54
# Number of times loop has ran: 55
# Number of times loop has ran: 56
# Number of times loop has ran: 57
# Number of times loop has ran: 58
# Number of times loop has ran: 59
# Number of times loop has ran: 60
# Number of times loop has ran: 61
# Number of times loop has ran: 62
# Number of times loop has ran: 63
# Number of times loop has ran: 64
# Number of times loop has ran: 65
# Number of times loop has ran: 66
# Number of times loop has ran: 67
# Number of times loop has ran: 68
# Number of times loop has ran: 69
# Number of times loop has ran: 70
# Number of times loop has ran: 71
# Number of times loop has ran: 72
# Number of times loop has ran: 73
# Number of times loop has ran: 74
# Number of times loop has ran: 75
# Number of times loop has ran: 76
# Number of times loop has ran: 77
# Number of times loop has ran: 78
# Number of times loop has ran: 79
# Number of times loop has ran: 80
# Number of times loop has ran: 81
# Number of times loop has ran: 82
# Number of times loop has ran: 83
# Number of times loop has ran: 84
# Number of times loop has ran: 85
# Number of times loop has ran: 86
# Number of times loop has ran: 87
# Number of times loop has ran: 88
# Number of times loop has ran: 89
# Number of times loop has ran: 90
# Number of times loop has ran: 91
# Number of times loop has ran: 92
# Number of times loop has ran: 93
# Number of times loop has ran: 94
# Number of times loop has ran: 95
# Number of times loop has ran: 96
# Number of times loop has ran: 97
# Number of times loop has ran: 98
# Number of times loop has ran: 99
# Number of times loop has ran: 100
# Number of times loop has ran: 101
# Number of times loop has ran: 102
# Number of times loop has ran: 103
# Number of times loop has ran: 104
# Number of times loop has ran: 105
# Number of times loop has ran: 106
# Number of times loop has ran: 107
