# %% [markdown]
# # Phase 2: Subject Creation
#
# **Description:**
#
# This notebook is to act as the resulting summary file for the creation and upload of subjects for the IceCube Zooniverse project currently called *Name that Neutrino!*. The project is currently being maintained by Elizabeth Warrick (as of March 2023). In this notebook, we take the i3 file and run it through several filters. [note: describe more later].
#
# > Nu Type: NuE
#
# > Run: 22076
#
# > SubRun: 000119
#
# ### Summary Stats:
#
# To be filled in after completing process. Also need to figure out global variables.
#
# **Subject Set Name:**

# %%
#Imports

#My functions: 
from uniformenergydist_filter import *

#General:
import numpy as np
import sys
import os
import subprocess
import argparse
import csv
from tables import *
import pandas as pd
from matplotlib import pyplot as plt
import h5py

#Zooniverse:
from panoptes_client import Panoptes, Project, SubjectSet, Subject
import magic
import glob

#IceCube:
from icecube.icetray import I3Units
import icecube.MuonGun
from icecube import dataio, dataclasses, icetray, MuonGun
from I3Tray import *
from icecube.hdfwriter import I3HDFWriter
from mc_labeler import MCLabeler #make sure that mc_labeler script is in current directory.

# %%
#Specify file paths:

#Initial I3 File:
nue = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst'

#Desired output directory. Note that creation of this directory is not yet coded and is done manually. 
phase1_dir = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/'

# %%
#Run Filter 1 to label MC truth.
filter1(nue,phase1_dir)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/mc_labeler.py:523: UserWarning: Couldn't find OMKey in MCPESeriesMap
#   warnings.warn("Couldn't find OMKey in MCPESeriesMap")

# %% [markdown]
# Note that the above cell might return an "exception" warning that the *MCPESeriesMap could not be found*. I am unsure why it does that because when I check the i3 file in dataio-shovel, I see the specified mc_pid_series_map (look at mc_labeler.py for exact name of specified key). The resulting file size should be around 400 MB.

# %%
#Path of hdf from above filter.
nue_hdf = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/\
Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst.hd5'

# %%
#Run uniformenergy_events function which requires hdf from filter 1, 
#number of bins, size of each random choice, and a random seed. 

uniformenergy_events(nue_hdf,25,15,12,subrun = True)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:177: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['binned_log10E'] = pd.cut(x = np.log10(df_filtered['energy']), bins = bins, labels = labels, include_lowest = True) #might throw an error?
# Number of Bins: 25
# Number of Events per Bin: 15
# Total Number of Events: 375
# Initial Number of Events: 2772
# Number of Events after filtering: 2698
# Please input subrun number:
# 000119

# %% [markdown]
# The above function throws another warning about pd.cut, currently that is not a problem but I don't know if a new version of pandas will allow this.

# %%
#Path to Random Events CSV
nue_csv = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/random_events_uniform_energy_distrib_22067_000119.csv'

# %%
#Run event_characterization_plots function whick makes some quick 
#plots to get an idea of what data you're dealing with.
#Note that I want to update the plot types, maybe make a 2D histogram as Mike K suggested. 
#For truth labels, check out enums.py or in the .py file that holds the functions.

event_characterization_plots(nue_csv)

# %% [markdown]
# Now that we have the events for this phase chosen, we run the second filter to pick out only those events.

# %%
#Path to i3 file from filter1 with MC truth labels. 
nue_filter1 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst'

# %%
#Run function to perform second filter which passes through only selected event IDs chosen from 
#the uniformenergy_events function. 
filter2(nue_filter1,phase1_dir,nue_csv)

# %%
#Path to i3 file from filter 2 that holds only specified events. 
nue_filter2 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst'

# %%
#Run function to perform third filter, which returns only the DAQ frames of the specified events.
#DAQ only file is then split up into many smaller i3 files since SteamShovel can't handle making videos of large
#i3 files at one time. Size limit is approx 2E6 MB (? unsure of units)
filter3(nue_filter2,22067_000119,phase1_dir)

# %%
#Path to NuMu Daq Only folder
nue_daq = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/'

# %%
get_steamshovel(nue_daq,22067000119)
# Out:
# List of files:
# ['/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/daq_only-0009_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/daq_only-0010_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst']
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/daq_only-0009_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000119/daq_only-0010_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000119.i3.zst

# %% [markdown]
# Ideas for Compression:
# - Use GUI to add files to queue and send to one compression folder.
# - Add a subprocess line in movie script to compress the video after making it and direct it to save in the compression folder.

# %%
compressed_path = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/'

# %% [markdown]
# Can't get manifest yet since some subjects are missing and lining it up won't work.

# %%
get_manifest(compressed_path, nue_csv)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:418: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   dict_manifest = s3.to_dict('dict')
# {'/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_7046_origidx_19_RF22.mp4': {'event': 7046,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3843529522418976,
#   'pred_cascade': 0.1014221161603927,
#   'pred_tgtrack': 0.3330444395542145,
#   'pred_starttrack': 0.106968268752098,
#   'pred_stoptrack': 0.0742122679948806,
#   'energy': 615.3148022158124,
#   'zenith': 2.8208720878641187,
#   'oneweight': 1204109923.1975265,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3843529522418976,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_7279_origidx_29_RF22.mp4': {'event': 7279,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9998377561569214,
#   'pred_cascade': 2.2522696951909893e-07,
#   'pred_tgtrack': 6.781576666980982e-05,
#   'pred_starttrack': 3.029586821412522e-07,
#   'pred_stoptrack': 9.385263547301292e-05,
#   'energy': 339034.52318198804,
#   'zenith': 1.7422430311703392,
#   'oneweight': 972369359824423.6,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9998377561569214,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_2306_origidx_9_RF22.mp4': {'event': 2306,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0199460349977016,
#   'pred_cascade': 0.0034097349271178,
#   'pred_tgtrack': 0.0010760265868157,
#   'pred_starttrack': 0.0119090806692838,
#   'pred_stoptrack': 0.9636591076850892,
#   'energy': 138.42237560286148,
#   'zenith': 1.6812494269379554,
#   'oneweight': 20240556.35120239,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9636591076850892,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_2576_origidx_24_RF22.mp4': {'event': 2576,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3111930191516876,
#   'pred_cascade': 0.002276056446135,
#   'pred_tgtrack': 0.5722616314888,
#   'pred_starttrack': 0.006080119870603,
#   'pred_stoptrack': 0.1081891059875488,
#   'energy': 830026.3728543916,
#   'zenith': 0.94422755274509,
#   'oneweight': 2.107350107961585e+16,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5722616314888,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_326_origidx_14_RF22.mp4': {'event': 326,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0006290698656812,
#   'pred_cascade': 0.8329666256904602,
#   'pred_tgtrack': 9.192674951918889e-06,
#   'pred_starttrack': 0.1663426160812378,
#   'pred_stoptrack': 5.256716394796968e-05,
#   'energy': 11066.105584258545,
#   'zenith': 1.6841811036345613,
#   'oneweight': 4504690571455.571,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8329666256904602,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_6521_origidx_30_RF22.mp4': {'event': 6521,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9997925162315368,
#   'pred_cascade': 1.9633914050132265e-08,
#   'pred_tgtrack': 2.8032825866830532e-05,
#   'pred_starttrack': 8.755397175264079e-06,
#   'pred_stoptrack': 0.0001707142218947,
#   'energy': 563212.7387176462,
#   'zenith': 2.6227378292507098,
#   'oneweight': 644134914198581.6,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9997925162315368,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_2835_origidx_34_RF22.mp4': {'event': 2835,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9948363304138184,
#   'pred_cascade': 1.9847534531436395e-06,
#   'pred_tgtrack': 0.0003896984853781,
#   'pred_starttrack': 1.609059950169467e-06,
#   'pred_stoptrack': 0.004770372994244,
#   'energy': 7305.586962968499,
#   'zenith': 2.2331644379649043,
#   'oneweight': 454552007644.60425,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9948363304138184,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_8839_origidx_6_RF22.mp4': {'event': 8839,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999407529830932,
#   'pred_cascade': 4.284871568671633e-09,
#   'pred_tgtrack': 1.4001836461829951e-05,
#   'pred_starttrack': 1.5305431588785723e-08,
#   'pred_stoptrack': 4.511833321885206e-05,
#   'energy': 875402.3043320873,
#   'zenith': 2.2027291139432825,
#   'oneweight': 122046551552244.48,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999407529830932,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_2305_origidx_8_RF22.mp4': {'event': 2305,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.7867993139807368e-06,
#   'pred_cascade': 0.6768198013305664,
#   'pred_tgtrack': 1.0658885912562257e-05,
#   'pred_starttrack': 0.3231573104858398,
#   'pred_stoptrack': 9.480264452577105e-06,
#   'energy': 4411.017605302485,
#   'zenith': 0.4299877269403339,
#   'oneweight': 111264041312.50227,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.6768198013305664,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_3125_origidx_4_RF22.mp4': {'event': 3125,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9934727549552916,
#   'pred_cascade': 1.188708483823575e-05,
#   'pred_tgtrack': 0.0048595191910862,
#   'pred_starttrack': 1.4269807252276225e-05,
#   'pred_stoptrack': 0.0016415350837633,
#   'energy': 8010.333860773598,
#   'zenith': 0.2711932096772266,
#   'oneweight': 397194576330.0719,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9934727549552916,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_6912_origidx_11_RF22.mp4': {'event': 6912,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 3.4197048080386594e-05,
#   'pred_cascade': 0.7766593098640442,
#   'pred_tgtrack': 1.1017449651262725e-05,
#   'pred_starttrack': 0.2232894599437713,
#   'pred_stoptrack': 5.975146905257134e-06,
#   'energy': 92042.25107570298,
#   'zenith': 2.529785681913731,
#   'oneweight': 8200236796788.999,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7766593098640442,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_487_origidx_20_RF22.mp4': {'event': 487,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0029333527199923,
#   'pred_cascade': 0.9853901863098145,
#   'pred_tgtrack': 1.0764409807961783e-06,
#   'pred_starttrack': 0.0116482088342309,
#   'pred_stoptrack': 2.7129464797326364e-05,
#   'energy': 7247.876263149391,
#   'zenith': 1.8615215661942504,
#   'oneweight': 339517784489.158,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9853901863098145,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_1709_origidx_9_RF22.mp4': {'event': 1709,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9984501600265504,
#   'pred_cascade': 2.8697008019662466e-05,
#   'pred_tgtrack': 0.0012642233632504,
#   'pred_starttrack': 3.645592732937075e-05,
#   'pred_stoptrack': 0.0002204679476562,
#   'energy': 573919.0475857224,
#   'zenith': 0.9538566797672596,
#   'oneweight': 2095779660368127.2,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9984501600265504,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_10053_origidx_13_RF22.mp4': {'event': 10053,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.6443408131599426,
#   'pred_cascade': 0.0072189765051007,
#   'pred_tgtrack': 0.2688538134098053,
#   'pred_starttrack': 0.0121766505762934,
#   'pred_stoptrack': 0.067409798502922,
#   'energy': 43067.06494297287,
#   'zenith': 1.3967086711433787,
#   'oneweight': 8716777830393.597,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6443408131599426,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_9652_origidx_11_RF22.mp4': {'event': 9652,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4293801784515381,
#   'pred_cascade': 0.0097197508439421,
#   'pred_tgtrack': 0.5443469882011414,
#   'pred_starttrack': 0.0115694412961602,
#   'pred_stoptrack': 0.0049836239777505,
#   'energy': 9127.540187684188,
#   'zenith': 2.140262593195221,
#   'oneweight': 3019944371374.3945,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5443469882011414,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_6944_origidx_14_RF22.mp4': {'event': 6944,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999035120010376,
#   'pred_cascade': 1.0101804946316406e-05,
#   'pred_tgtrack': 2.480931834725197e-05,
#   'pred_starttrack': 6.704146653646603e-05,
#   'pred_stoptrack': 0.0008629279909655,
#   'energy': 25223.668164432183,
#   'zenith': 2.5473977008688764,
#   'oneweight': 5750965390005.181,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999035120010376,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_2606_origidx_25_RF22.mp4': {'event': 2606,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 3.071389437536709e-05,
#   'pred_cascade': 0.6230389475822449,
#   'pred_tgtrack': 1.4889609701640438e-05,
#   'pred_starttrack': 0.3768671154975891,
#   'pred_stoptrack': 4.8258072638418525e-05,
#   'energy': 2206.747655664157,
#   'zenith': 1.150691266100692,
#   'oneweight': 20809632918.816395,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.6230389475822449,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_2442_origidx_16_RF22.mp4': {'event': 2442,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2723684012889862,
#   'pred_cascade': 0.0808494687080383,
#   'pred_tgtrack': 0.4790668487548828,
#   'pred_starttrack': 0.0834218338131904,
#   'pred_stoptrack': 0.0842934921383857,
#   'energy': 143.43316146251902,
#   'zenith': 2.8607925933948875,
#   'oneweight': 7657764.039174472,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4790668487548828,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_7210_origidx_26_RF22.mp4': {'event': 7210,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 4.137007272220217e-05,
#   'pred_cascade': 0.9811773300170898,
#   'pred_tgtrack': 3.766407098737545e-05,
#   'pred_starttrack': 0.0186862517148256,
#   'pred_stoptrack': 5.73021243326366e-05,
#   'energy': 7600.729392045441,
#   'zenith': 1.6601067909274403,
#   'oneweight': 314806426347.7543,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9811773300170898,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_6432_origidx_28_RF22.mp4': {'event': 6432,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.5196022391319275,
#   'pred_cascade': 0.3180480003356933,
#   'pred_tgtrack': 0.0108274901285767,
#   'pred_starttrack': 0.0975996404886245,
#   'pred_stoptrack': 0.0539226680994033,
#   'energy': 551.6785155115119,
#   'zenith': 1.0887025356843798,
#   'oneweight': 662477097.965765,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5196022391319275,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_5562_origidx_6_RF22.mp4': {'event': 5562,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.0010869392426684,
#   'pred_cascade': 0.909834921360016,
#   'pred_tgtrack': 0.0006805476732552,
#   'pred_starttrack': 0.085803635418415,
#   'pred_stoptrack': 0.0025939242914319,
#   'energy': 9949.947446622826,
#   'zenith': 1.2890198306392364,
#   'oneweight': 706325005828.3114,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.909834921360016,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_1823_origidx_17_RF22.mp4': {'event': 1823,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1470852941274643,
#   'pred_cascade': 0.0360006913542747,
#   'pred_tgtrack': 0.5270901918411255,
#   'pred_starttrack': 0.110909529030323,
#   'pred_stoptrack': 0.1789142936468124,
#   'energy': 251.74198825404815,
#   'zenith': 1.8780850627525008,
#   'oneweight': 91523458.25109586,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5270901918411255,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_6424_origidx_27_RF22.mp4': {'event': 6424,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1143733039498329,
#   'pred_cascade': 0.0318428874015808,
#   'pred_tgtrack': 0.6994130611419678,
#   'pred_starttrack': 0.027673102915287,
#   'pred_stoptrack': 0.1266976445913314,
#   'energy': 142.57258841446014,
#   'zenith': 1.7850485293068863,
#   'oneweight': 13580439.39276856,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6994130611419678,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_5793_origidx_14_RF22.mp4': {'event': 5793,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.809454083442688,
#   'pred_cascade': 0.1142880097031593,
#   'pred_tgtrack': 0.0017602113075554,
#   'pred_starttrack': 0.023666301742196,
#   'pred_stoptrack': 0.0508314594626426,
#   'energy': 1063.2970022995785,
#   'zenith': 1.259796667381449,
#   'oneweight': 6596867509.252371,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.809454083442688,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_9735_origidx_15_RF22.mp4': {'event': 9735,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0233440492302179,
#   'pred_cascade': 0.0056444844231009,
#   'pred_tgtrack': 0.8620258569717407,
#   'pred_starttrack': 0.0039525893516838,
#   'pred_stoptrack': 0.1050330698490142,
#   'energy': 792.0145982716268,
#   'zenith': 1.3127195783694412,
#   'oneweight': 1552234762.8209162,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8620258569717407,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_27_origidx_5_RF22.mp4': {'event': 27,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999122619628906,
#   'pred_cascade': 3.091911793262625e-08,
#   'pred_tgtrack': 7.934268069220707e-05,
#   'pred_starttrack': 2.7579366701502295e-07,
#   'pred_stoptrack': 8.076946869550738e-06,
#   'energy': 181389.0269177027,
#   'zenith': 1.558836463300846,
#   'oneweight': 260850799937308.75,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999122619628906,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_2418_origidx_15_RF22.mp4': {'event': 2418,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.2076669186353683,
#   'pred_cascade': 0.0599025003612041,
#   'pred_tgtrack': 0.0110382344573736,
#   'pred_starttrack': 0.0541402772068977,
#   'pred_stoptrack': 0.6672521233558655,
#   'energy': 1057.4755980932237,
#   'zenith': 1.623510808436044,
#   'oneweight': 2959140211.166676,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.6672521233558655,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_2803_origidx_31_RF22.mp4': {'event': 2803,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.3353685517358826e-06,
#   'pred_cascade': 0.859817385673523,
#   'pred_tgtrack': 6.345907195282052e-07,
#   'pred_starttrack': 0.1401803493499755,
#   'pred_stoptrack': 2.845512767635228e-07,
#   'energy': 414585.62486351706,
#   'zenith': 1.4386334535107013,
#   'oneweight': 1.3748986382674976e+16,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.859817385673523,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_4811_origidx_4_RF22.mp4': {'event': 4811,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.0006406981265172,
#   'pred_cascade': 0.9718172550201416,
#   'pred_tgtrack': 0.0002565314644016,
#   'pred_starttrack': 0.0256211142987012,
#   'pred_stoptrack': 0.001664433046244,
#   'energy': 14694.144181254447,
#   'zenith': 0.3336883807375375,
#   'oneweight': 1712674701285.5706,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9718172550201416,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_155_origidx_11_RF22.mp4': {'event': 155,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9979396462440492,
#   'pred_cascade': 1.0805420203041649e-07,
#   'pred_tgtrack': 0.0002067786699626,
#   'pred_starttrack': 1.0276794881747264e-07,
#   'pred_stoptrack': 0.0018533619586378,
#   'energy': 33577.8824123577,
#   'zenith': 0.5955073298656557,
#   'oneweight': 11520422584095.531,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9979396462440492,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_144_origidx_9_RF22.mp4': {'event': 144,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.672664231795352e-05,
#   'pred_cascade': 0.9973450303077698,
#   'pred_tgtrack': 2.486184200733988e-07,
#   'pred_starttrack': 0.0026268635410815,
#   'pred_stoptrack': 1.1611595027716248e-06,
#   'energy': 6998.63332905863,
#   'zenith': 1.7181871439785117,
#   'oneweight': 286924369070.6715,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9973450303077698,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_9596_origidx_7_RF22.mp4': {'event': 9596,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 5.584357131738216e-05,
#   'pred_cascade': 0.9069720506668092,
#   'pred_tgtrack': 9.68409949564375e-07,
#   'pred_starttrack': 0.0921922698616981,
#   'pred_stoptrack': 0.0007788673974573,
#   'energy': 117.841685200803,
#   'zenith': 1.9963188380836068,
#   'oneweight': 19077401.322679576,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9069720506668092,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_1904_origidx_20_RF22.mp4': {'event': 1904,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0895860940217971,
#   'pred_cascade': 0.0281826686114072,
#   'pred_tgtrack': 0.507161021232605,
#   'pred_starttrack': 0.0109901595860719,
#   'pred_stoptrack': 0.3640800714492798,
#   'energy': 9286.322740495782,
#   'zenith': 2.5047160790189884,
#   'oneweight': 538048204241.4229,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.507161021232605,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_6914_origidx_12_RF22.mp4': {'event': 6914,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9388831257820128,
#   'pred_cascade': 0.0344343297183513,
#   'pred_tgtrack': 0.0021042812149971,
#   'pred_starttrack': 0.0202339682728052,
#   'pred_stoptrack': 0.0043443064205348,
#   'energy': 11138.644065440149,
#   'zenith': 0.7823939939038365,
#   'oneweight': 1041369143557.6204,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9388831257820128,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_9525_origidx_4_RF22.mp4': {'event': 9525,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2725850045681,
#   'pred_cascade': 0.0754793882369995,
#   'pred_tgtrack': 0.4931181967258453,
#   'pred_starttrack': 0.0422025322914123,
#   'pred_stoptrack': 0.1166149452328682,
#   'energy': 1095.5422655378993,
#   'zenith': 1.3800285476064342,
#   'oneweight': 1707735099.4269807,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4931181967258453,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_9843_origidx_8_RF22.mp4': {'event': 9843,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0018122164765372,
#   'pred_cascade': 0.6986664533615112,
#   'pred_tgtrack': 3.290724635007791e-05,
#   'pred_starttrack': 0.2967753708362579,
#   'pred_stoptrack': 0.0027130220551043,
#   'energy': 523.5948800768307,
#   'zenith': 2.441859892721125,
#   'oneweight': 958531027.7944356,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.6986664533615112,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_9836_origidx_6_RF22.mp4': {'event': 9836,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0008131340146064,
#   'pred_cascade': 0.000428383675171,
#   'pred_tgtrack': 0.7097495794296265,
#   'pred_starttrack': 0.0001756135752657,
#   'pred_stoptrack': 0.2888332307338714,
#   'energy': 163.56596308247305,
#   'zenith': 1.4469468332421531,
#   'oneweight': 27595672.022003748,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7097495794296265,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_1774_origidx_15_RF22.mp4': {'event': 1774,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0020078963134437,
#   'pred_cascade': 0.0012354139471426,
#   'pred_tgtrack': 0.727988064289093,
#   'pred_starttrack': 0.0005170118529349,
#   'pred_stoptrack': 0.2682515680789947,
#   'energy': 142.5814381484868,
#   'zenith': 1.6296704210746518,
#   'oneweight': 14934330.246289724,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.727988064289093,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_2804_origidx_32_RF22.mp4': {'event': 2804,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9996088147163392,
#   'pred_cascade': 1.7404294894163286e-08,
#   'pred_tgtrack': 7.083611126290634e-05,
#   'pred_starttrack': 1.5973357392340406e-07,
#   'pred_stoptrack': 0.0003202031657565,
#   'energy': 270406.9503868359,
#   'zenith': 1.564989228751798,
#   'oneweight': 135829595971487.52,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9996088147163392,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_5972_origidx_16_RF22.mp4': {'event': 5972,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 6.957642199267866e-06,
#   'pred_cascade': 0.9902909398078918,
#   'pred_tgtrack': 3.358973685863021e-07,
#   'pred_starttrack': 0.0096957208588719,
#   'pred_stoptrack': 5.986592896078946e-06,
#   'energy': 11119.65169389026,
#   'zenith': 0.5775036604944452,
#   'oneweight': 1065625636572.4738,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9902909398078918,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_2215_origidx_4_RF22.mp4': {'event': 2215,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.751550555229187,
#   'pred_cascade': 0.2175246328115463,
#   'pred_tgtrack': 0.0025041447952389,
#   'pred_starttrack': 0.0191501937806606,
#   'pred_stoptrack': 0.0092705432325601,
#   'energy': 3283.8242781751787,
#   'zenith': 1.9382101619873355,
#   'oneweight': 178532779186.17773,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.751550555229187,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_9711_origidx_12_RF22.mp4': {'event': 9711,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0541245862841606,
#   'pred_cascade': 0.0087433122098445,
#   'pred_tgtrack': 0.1904315948486328,
#   'pred_starttrack': 0.0389675199985504,
#   'pred_stoptrack': 0.7077330350875854,
#   'energy': 103243.5405725244,
#   'zenith': 0.7617619608900343,
#   'oneweight': 52933568325140.92,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7077330350875854,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_2453_origidx_18_RF22.mp4': {'event': 2453,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.1235707029700279,
#   'pred_cascade': 0.5580098032951355,
#   'pred_tgtrack': 2.772623520286288e-05,
#   'pred_starttrack': 0.3176758885383606,
#   'pred_stoptrack': 0.0007158344960771,
#   'energy': 9146.00997184787,
#   'zenith': 2.077065081172049,
#   'oneweight': 597662615688.4297,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.5580098032951355,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_1744_origidx_12_RF22.mp4': {'event': 1744,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999990701675415,
#   'pred_cascade': 4.2551651091571336e-08,
#   'pred_tgtrack': 3.640551767603029e-06,
#   'pred_starttrack': 2.8415608994691866e-06,
#   'pred_stoptrack': 2.9111834010109305e-06,
#   'energy': 382481.90469730325,
#   'zenith': 1.463183621874186,
#   'oneweight': 1185110308025751.8,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999990701675415,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_7010_origidx_18_RF22.mp4': {'event': 7010,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.6622586846351624,
#   'pred_cascade': 0.2165739983320236,
#   'pred_tgtrack': 0.0148585392162203,
#   'pred_starttrack': 0.077040858566761,
#   'pred_stoptrack': 0.0292678978294134,
#   'energy': 1166.4659164162908,
#   'zenith': 0.2324778932064461,
#   'oneweight': 3473034884.236745,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6622586846351624,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_6743_origidx_6_RF22.mp4': {'event': 6743,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.0244069043546915,
#   'pred_cascade': 0.0049508158117532,
#   'pred_tgtrack': 0.2524343132972717,
#   'pred_starttrack': 0.0028812137898057,
#   'pred_stoptrack': 0.715326726436615,
#   'energy': 170.19690897470457,
#   'zenith': 2.2426073502656863,
#   'oneweight': 29960879.1164624,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.715326726436615,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_6469_origidx_29_RF22.mp4': {'event': 6469,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 3.3493332011858e-05,
#   'pred_cascade': 0.992492139339447,
#   'pred_tgtrack': 3.9788176309230046e-08,
#   'pred_starttrack': 0.0074741570279002,
#   'pred_stoptrack': 2.2253608733535657e-07,
#   'energy': 893733.5499730326,
#   'zenith': 0.4244371144053269,
#   'oneweight': 9631862336078112.0,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.992492139339447,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_657_origidx_22_RF22.mp4': {'event': 657,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9992765784263612,
#   'pred_cascade': 3.975784701459872e-10,
#   'pred_tgtrack': 0.0003102478513028,
#   'pred_starttrack': 5.224896959532543e-09,
#   'pred_stoptrack': 0.0004131789901293,
#   'energy': 631701.0206552212,
#   'zenith': 0.9350012185676784,
#   'oneweight': 4031328701365988.0,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9992765784263612,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_10061_origidx_14_RF22.mp4': {'event': 10061,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0022639189846813,
#   'pred_cascade': 0.3334377110004425,
#   'pred_tgtrack': 0.0072617819532752,
#   'pred_starttrack': 0.6558628082275391,
#   'pred_stoptrack': 0.0011737740132957,
#   'energy': 3148.28497277624,
#   'zenith': 0.8202226663095405,
#   'oneweight': 72746091148.4625,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.6558628082275391,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_6023_origidx_18_RF22.mp4': {'event': 6023,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 3.745726417037076e-06,
#   'pred_cascade': 0.8973941206932068,
#   'pred_tgtrack': 7.632719345451733e-09,
#   'pred_starttrack': 0.1025969833135604,
#   'pred_stoptrack': 5.143379894434474e-06,
#   'energy': 401.358412314663,
#   'zenith': 0.8787423301327975,
#   'oneweight': 460204810.0043018,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8973941206932068,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_663_origidx_23_RF22.mp4': {'event': 663,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2437560409307479,
#   'pred_cascade': 0.0816951170563697,
#   'pred_tgtrack': 0.5470272898674011,
#   'pred_starttrack': 0.0396994911134243,
#   'pred_stoptrack': 0.0878220200538635,
#   'energy': 27361.17782402193,
#   'zenith': 2.3957667298592478,
#   'oneweight': 51449050093271.66,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5470272898674011,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_6773_origidx_7_RF22.mp4': {'event': 6773,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1151519268751144,
#   'pred_cascade': 0.0377649739384651,
#   'pred_tgtrack': 0.7280787825584412,
#   'pred_starttrack': 0.0294826477766037,
#   'pred_stoptrack': 0.0895216986536979,
#   'energy': 456.1123122160324,
#   'zenith': 0.7834239258414593,
#   'oneweight': 350248778.2435509,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7280787825584412,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_6995_origidx_17_RF22.mp4': {'event': 6995,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9998718500137328,
#   'pred_cascade': 6.070085589726659e-08,
#   'pred_tgtrack': 4.136966526857577e-05,
#   'pred_starttrack': 7.039609073444808e-08,
#   'pred_stoptrack': 8.651072857901454e-05,
#   'energy': 101108.39180146685,
#   'zenith': 1.1029446117223975,
#   'oneweight': 84131034504544.69,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9998718500137328,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_6719_origidx_5_RF22.mp4': {'event': 6719,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9916278123855592,
#   'pred_cascade': 0.0072182370349764,
#   'pred_tgtrack': 4.6166365791577846e-05,
#   'pred_starttrack': 0.0010616725776344,
#   'pred_stoptrack': 4.610502946889028e-05,
#   'energy': 785727.52354536,
#   'zenith': 0.9845943794911084,
#   'oneweight': 1.5338964721634572e+16,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9916278123855592,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_7215_origidx_27_RF22.mp4': {'event': 7215,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 8.830551814753562e-05,
#   'pred_cascade': 0.9974143505096436,
#   'pred_tgtrack': 1.1584405434916787e-08,
#   'pred_starttrack': 0.0024968290235847,
#   'pred_stoptrack': 5.190149181544257e-07,
#   'energy': 15254.500278722042,
#   'zenith': 1.6650133686381523,
#   'oneweight': 1623883271981.5364,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9974143505096436,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_9940_origidx_10_RF22.mp4': {'event': 9940,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.124849647283554,
#   'pred_cascade': 0.0334413722157478,
#   'pred_tgtrack': 0.6761940121650696,
#   'pred_starttrack': 0.0113510182127356,
#   'pred_stoptrack': 0.1541639417409896,
#   'energy': 440159.6115716294,
#   'zenith': 2.625354480393427,
#   'oneweight': 372898770473324.56,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6761940121650696,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_1740_origidx_11_RF22.mp4': {'event': 1740,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0003077038563787,
#   'pred_cascade': 0.7191751599311829,
#   'pred_tgtrack': 3.3689608244458213e-05,
#   'pred_starttrack': 0.2800081670284271,
#   'pred_stoptrack': 0.0004753039684146,
#   'energy': 1233.8968407718596,
#   'zenith': 1.3376386431592604,
#   'oneweight': 4901263697.921867,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7191751599311829,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_208_origidx_12_RF22.mp4': {'event': 208,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 4.014315436506877e-06,
#   'pred_cascade': 0.9701508283615112,
#   'pred_tgtrack': 6.974363753187163e-09,
#   'pred_starttrack': 0.0298244673758745,
#   'pred_stoptrack': 2.065329681499861e-05,
#   'energy': 2117.239531501948,
#   'zenith': 1.9538710805593864,
#   'oneweight': 20180762330.54382,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9701508283615112,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_3002_origidx_40_RF22.mp4': {'event': 3002,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0003371151979081,
#   'pred_cascade': 0.9777897596359252,
#   'pred_tgtrack': 4.062003426952288e-06,
#   'pred_starttrack': 0.0218485556542873,
#   'pred_stoptrack': 2.0518837118288505e-05,
#   'energy': 12403.637445471197,
#   'zenith': 1.9745162746416187,
#   'oneweight': 1267708258015.0388,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9777897596359252,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_6886_origidx_10_RF22.mp4': {'event': 6886,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2149147987365722,
#   'pred_cascade': 0.076539821922779,
#   'pred_tgtrack': 0.5083921551704407,
#   'pred_starttrack': 0.0771751254796981,
#   'pred_stoptrack': 0.1229780986905098,
#   'energy': 160.9006124970839,
#   'zenith': 1.1682306197212913,
#   'oneweight': 15615345.479289472,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5083921551704407,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_1746_origidx_13_RF22.mp4': {'event': 1746,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.974201202392578,
#   'pred_cascade': 1.1814038771262858e-05,
#   'pred_tgtrack': 0.0106477094814181,
#   'pred_starttrack': 9.476900231675243e-06,
#   'pred_stoptrack': 0.0151298251003026,
#   'energy': 1560.7457240524834,
#   'zenith': 2.531939252638463,
#   'oneweight': 11099665796.710896,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.974201202392578,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_5882_origidx_15_RF22.mp4': {'event': 5882,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.085417129099369,
#   'pred_cascade': 0.0262492876499891,
#   'pred_tgtrack': 0.662997305393219,
#   'pred_starttrack': 0.0132370963692665,
#   'pred_stoptrack': 0.2120991647243499,
#   'energy': 174.1383088596289,
#   'zenith': 2.389987390679904,
#   'oneweight': 23963663.06192005,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.662997305393219,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_7241_origidx_28_RF22.mp4': {'event': 7241,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0766565650701522,
#   'pred_cascade': 0.2558543086051941,
#   'pred_tgtrack': 0.0144434003159403,
#   'pred_starttrack': 0.494870662689209,
#   'pred_stoptrack': 0.1581750214099884,
#   'energy': 1835.910209135954,
#   'zenith': 1.942277156440186,
#   'oneweight': 5117600603.335051,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.494870662689209,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_2568_origidx_23_RF22.mp4': {'event': 2568,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.99985933303833,
#   'pred_cascade': 8.596786216230613e-08,
#   'pred_tgtrack': 7.634900975972414e-05,
#   'pred_starttrack': 7.79823992047568e-08,
#   'pred_stoptrack': 6.418247357942164e-05,
#   'energy': 580185.5360070973,
#   'zenith': 1.5313393560513373,
#   'oneweight': 2434027981127347.5,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.99985933303833,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_10079_origidx_16_RF22.mp4': {'event': 10079,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9994284510612488,
#   'pred_cascade': 2.098959157592617e-05,
#   'pred_tgtrack': 3.229443245800212e-05,
#   'pred_starttrack': 6.307380681391805e-05,
#   'pred_stoptrack': 0.000455264293123,
#   'energy': 24028.822796626413,
#   'zenith': 0.4438580536761617,
#   'oneweight': 6144451402089.252,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9994284510612488,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_5709_origidx_10_RF22.mp4': {'event': 5709,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2003049850463867,
#   'pred_cascade': 0.0393118374049663,
#   'pred_tgtrack': 0.6606476306915283,
#   'pred_starttrack': 0.0370143949985504,
#   'pred_stoptrack': 0.0627211555838584,
#   'energy': 131.55190569919014,
#   'zenith': 2.7417035230194267,
#   'oneweight': 2621802.4266687334,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6606476306915283,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_110_origidx_8_RF22.mp4': {'event': 110,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.0169695087824948e-05,
#   'pred_cascade': 0.9977815747261048,
#   'pred_tgtrack': 1.265099598413144e-07,
#   'pred_starttrack': 0.0022078556939959,
#   'pred_stoptrack': 4.162776576777105e-07,
#   'energy': 24664.60231111227,
#   'zenith': 2.37982681060867,
#   'oneweight': 6639192464255.584,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9977815747261048,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_8798_origidx_4_RF22.mp4': {'event': 8798,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.986909568309784,
#   'pred_cascade': 0.0074612079188227,
#   'pred_tgtrack': 0.000307450274704,
#   'pred_starttrack': 0.0048478096723556,
#   'pred_stoptrack': 0.0004739747964777,
#   'energy': 535847.7790298596,
#   'zenith': 1.0639401026874955,
#   'oneweight': 5942690493149301.0,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.986909568309784,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_5670_origidx_8_RF22.mp4': {'event': 5670,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0337939523160457,
#   'pred_cascade': 0.0187329910695552,
#   'pred_tgtrack': 0.6578525304794312,
#   'pred_starttrack': 0.0103318700566887,
#   'pred_stoptrack': 0.2792887091636657,
#   'energy': 130.23087036327846,
#   'zenith': 2.1876649348934256,
#   'oneweight': 26785237.820222206,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6578525304794312,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_7080_origidx_21_RF22.mp4': {'event': 7080,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.6607757210731506,
#   'pred_cascade': 0.1779824346303939,
#   'pred_tgtrack': 0.0001868935651145,
#   'pred_starttrack': 0.1609821915626526,
#   'pred_stoptrack': 7.275710959220305e-05,
#   'energy': 171463.7976817684,
#   'zenith': 0.4919529871138939,
#   'oneweight': 488581809527006.1,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6607757210731506,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_2966_origidx_37_RF22.mp4': {'event': 2966,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999992609024048,
#   'pred_cascade': 1.3785982355685176e-09,
#   'pred_tgtrack': 8.756493343753391e-07,
#   'pred_starttrack': 6.25543279397789e-08,
#   'pred_stoptrack': 6.419705641746987e-06,
#   'energy': 174908.41643489784,
#   'zenith': 1.690114019390436,
#   'oneweight': 264157698325026.84,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999992609024048,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_2513_origidx_20_RF22.mp4': {'event': 2513,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.2200247645378112,
#   'pred_cascade': 0.047818623483181,
#   'pred_tgtrack': 0.0152376042678952,
#   'pred_starttrack': 0.2228610962629318,
#   'pred_stoptrack': 0.4940578937530517,
# ...
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9949782490730286,
#   'pred_cascade': 1.4585317842374934e-07,
#   'pred_tgtrack': 0.0009664784302003,
#   'pred_starttrack': 2.616063511595712e-06,
#   'pred_stoptrack': 0.0040525482036173,
#   'energy': 154059.75285604442,
#   'zenith': 1.1947538451426656,
#   'oneweight': 198754332681948.28,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9949782490730286,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_297_origidx_13_RF22.mp4': {'event': 297,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9978420734405518,
#   'pred_cascade': 0.0001696467079455,
#   'pred_tgtrack': 0.0003888981591444,
#   'pred_starttrack': 0.0002923108986578,
#   'pred_stoptrack': 0.0013070234563201,
#   'energy': 157388.95130463294,
#   'zenith': 2.244587366363473,
#   'oneweight': 43716881337711.96,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9978420734405518,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_2635_origidx_26_RF22.mp4': {'event': 2635,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.5398684740066528,
#   'pred_cascade': 0.0410619378089904,
#   'pred_tgtrack': 0.2585009634494781,
#   'pred_starttrack': 0.0965550765395164,
#   'pred_stoptrack': 0.0640135183930397,
#   'energy': 3173.4222807801275,
#   'zenith': 2.394976768307664,
#   'oneweight': 23697959617.69306,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5398684740066528,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_1690_origidx_8_RF22.mp4': {'event': 1690,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.1258232742547989,
#   'pred_cascade': 0.0312830731272697,
#   'pred_tgtrack': 0.7672349214553833,
#   'pred_starttrack': 0.0263221394270658,
#   'pred_stoptrack': 0.0493366047739982,
#   'energy': 2517.602103767622,
#   'zenith': 0.599182128407397,
#   'oneweight': 33250633905.18694,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7672349214553833,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_2221_origidx_5_RF22.mp4': {'event': 2221,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1883240789175033,
#   'pred_cascade': 0.0569785796105861,
#   'pred_tgtrack': 0.6229023337364197,
#   'pred_starttrack': 0.0827520191669464,
#   'pred_stoptrack': 0.0490430295467376,
#   'energy': 1823.626393104068,
#   'zenith': 0.395614646204426,
#   'oneweight': 12376243702.520905,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6229023337364197,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_6612_origidx_33_RF22.mp4': {'event': 6612,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 9.271627641282976e-05,
#   'pred_cascade': 0.8285598754882812,
#   'pred_tgtrack': 5.551936737901997e-06,
#   'pred_starttrack': 0.1713364720344543,
#   'pred_stoptrack': 5.363322543416871e-06,
#   'energy': 158052.30963520636,
#   'zenith': 1.8477749558215637,
#   'oneweight': 69550346325355.51,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8285598754882812,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_6943_origidx_13_RF22.mp4': {'event': 6943,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0106947617605328,
#   'pred_cascade': 0.003697226755321,
#   'pred_tgtrack': 0.8775798678398132,
#   'pred_starttrack': 0.0018622969510033,
#   'pred_stoptrack': 0.1061659008264541,
#   'energy': 168.45487246927664,
#   'zenith': 3.0052055455596856,
#   'oneweight': 23821226.08812296,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8775798678398132,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_2446_origidx_17_RF22.mp4': {'event': 2446,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1180755794048309,
#   'pred_cascade': 0.2354884892702102,
#   'pred_tgtrack': 0.1917797327041626,
#   'pred_starttrack': 0.4380819499492645,
#   'pred_stoptrack': 0.0165743064135313,
#   'energy': 266586.4392104854,
#   'zenith': 1.5974312307200764,
#   'oneweight': 639677895906207.2,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4380819499492645,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_5996_origidx_17_RF22.mp4': {'event': 5996,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.996658205986023,
#   'pred_cascade': 5.727201823901851e-09,
#   'pred_tgtrack': 0.0013429272221401,
#   'pred_starttrack': 1.0798977712056512e-07,
#   'pred_stoptrack': 0.0019987022969871,
#   'energy': 13862.400198571648,
#   'zenith': 1.437387430693512,
#   'oneweight': 1062575771840.3054,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.996658205986023,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_467_origidx_18_RF22.mp4': {'event': 467,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0626369193196296,
#   'pred_cascade': 0.0199714340269565,
#   'pred_tgtrack': 0.5766094923019409,
#   'pred_starttrack': 0.3295033276081085,
#   'pred_stoptrack': 0.0112787121906876,
#   'energy': 88342.3432094175,
#   'zenith': 1.1075988660319778,
#   'oneweight': 39526097175416.4,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5766094923019409,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_6064_origidx_19_RF22.mp4': {'event': 6064,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 6.301805842667818e-05,
#   'pred_cascade': 0.9591656923294068,
#   'pred_tgtrack': 4.216964953229763e-06,
#   'pred_starttrack': 0.0406797863543033,
#   'pred_stoptrack': 8.735492883715779e-05,
#   'energy': 6361.599627000148,
#   'zenith': 1.5301599390007898,
#   'oneweight': 212790992985.4876,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9591656923294068,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_5554_origidx_5_RF22.mp4': {'event': 5554,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2357914894819259,
#   'pred_cascade': 0.051878023892641,
#   'pred_tgtrack': 0.6181542873382568,
#   'pred_starttrack': 0.0394547320902347,
#   'pred_stoptrack': 0.054721463471651,
#   'energy': 2399.4299197611726,
#   'zenith': 0.9246353219330292,
#   'oneweight': 14808482754.476164,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6181542873382568,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_2752_origidx_28_RF22.mp4': {'event': 2752,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.606238220119849e-05,
#   'pred_cascade': 0.998674750328064,
#   'pred_tgtrack': 4.438637457582217e-09,
#   'pred_starttrack': 0.0013088647974655,
#   'pred_stoptrack': 3.5405429343882133e-07,
#   'energy': 25812.3099025302,
#   'zenith': 0.5030605438272828,
#   'oneweight': 7663575769684.336,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.998674750328064,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_667_origidx_24_RF22.mp4': {'event': 667,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 7.435824954882264e-05,
#   'pred_cascade': 0.9858697652816772,
#   'pred_tgtrack': 1.9497474568197506e-07,
#   'pred_starttrack': 0.0140554904937744,
#   'pred_stoptrack': 1.6575025085785458e-07,
#   'energy': 773377.1826695724,
#   'zenith': 0.7531355657911842,
#   'oneweight': 1.2275072634168204e+16,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9858697652816772,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_428_origidx_17_RF22.mp4': {'event': 428,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2195514440536499,
#   'pred_cascade': 0.0667573437094688,
#   'pred_tgtrack': 0.2717728316783905,
#   'pred_starttrack': 0.3757222592830658,
#   'pred_stoptrack': 0.0661961138248443,
#   'energy': 2046.104834750062,
#   'zenith': 0.9084145505150352,
#   'oneweight': 19270505748.32013,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3757222592830658,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_1864_origidx_18_RF22.mp4': {'event': 1864,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0013169252779334,
#   'pred_cascade': 0.0002337373880436,
#   'pred_tgtrack': 0.9897820949554444,
#   'pred_starttrack': 0.000393871043343,
#   'pred_stoptrack': 0.0082734720781445,
#   'energy': 53853.816693284505,
#   'zenith': 2.373817022585503,
#   'oneweight': 283723028079829.75,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9897820949554444,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_7123_origidx_22_RF22.mp4': {'event': 7123,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0130023499950766,
#   'pred_cascade': 0.7130722999572754,
#   'pred_tgtrack': 1.987464929698035e-05,
#   'pred_starttrack': 0.2523947656154632,
#   'pred_stoptrack': 0.021510723978281,
#   'energy': 206.94927475853697,
#   'zenith': 1.378071096912495,
#   'oneweight': 50269310.02388501,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7130722999572754,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_4915_origidx_5_RF22.mp4': {'event': 4915,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 6.828362984379055e-06,
#   'pred_cascade': 0.99879789352417,
#   'pred_tgtrack': 1.102619440196406e-09,
#   'pred_starttrack': 0.0011951428605243,
#   'pred_stoptrack': 1.3872428894501354e-07,
#   'energy': 8000.932601526668,
#   'zenith': 1.865102357861592,
#   'oneweight': 427006469141.8889,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.99879789352417,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_2491_origidx_19_RF22.mp4': {'event': 2491,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 3.7034340493846685e-05,
#   'pred_cascade': 0.989802062511444,
#   'pred_tgtrack': 5.371511679896912e-09,
#   'pred_starttrack': 0.010156369768083,
#   'pred_stoptrack': 4.4503231038106605e-06,
#   'energy': 880.3806818012289,
#   'zenith': 2.6273291309074125,
#   'oneweight': 2666120584.2866945,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.989802062511444,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_1870_origidx_19_RF22.mp4': {'event': 1870,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9997779726982116,
#   'pred_cascade': 9.73053101915866e-06,
#   'pred_tgtrack': 0.0001533575414214,
#   'pred_starttrack': 3.917791218555067e-06,
#   'pred_stoptrack': 5.498198879649863e-05,
#   'energy': 536125.4460402458,
#   'zenith': 2.009497286693444,
#   'oneweight': 3534799510118724.5,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9997779726982116,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_7160_origidx_24_RF22.mp4': {'event': 7160,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 3.180773637723178e-05,
#   'pred_cascade': 0.9865440726280212,
#   'pred_tgtrack': 1.3736703294853214e-06,
#   'pred_starttrack': 0.0134118050336837,
#   'pred_stoptrack': 1.096104460884817e-05,
#   'energy': 1219.8116941331346,
#   'zenith': 2.980805593887386,
#   'oneweight': 7871730023.716942,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9865440726280212,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_6299_origidx_23_RF22.mp4': {'event': 6299,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 3.901920354110189e-05,
#   'pred_cascade': 0.9033405184745787,
#   'pred_tgtrack': 9.000198588182684e-06,
#   'pred_starttrack': 0.0964986458420753,
#   'pred_stoptrack': 0.0001128072253777,
#   'energy': 1974.6613448257249,
#   'zenith': 1.158464755582913,
#   'oneweight': 23872680932.916893,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9033405184745787,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_6714_origidx_4_RF22.mp4': {'event': 6714,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 1.9647657154564517e-06,
#   'pred_cascade': 0.6506839990615845,
#   'pred_tgtrack': 2.697925538086565e-06,
#   'pred_starttrack': 0.3493013381958008,
#   'pred_stoptrack': 9.990653779823331e-06,
#   'energy': 2975.909079276632,
#   'zenith': 0.3154386915822809,
#   'oneweight': 41901323826.397,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.6506839990615845,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000119/compressed_run_22067_event_7057_origidx_20_RF22.mp4': {'event': 7057,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.164039745926857,
#   'pred_cascade': 0.0459116250276565,
#   'pred_tgtrack': 0.6782251596450806,
#   'pred_starttrack': 0.0355446226894855,
#   'pred_stoptrack': 0.0762788653373718,
#   'energy': 290.68453566631695,
#   'zenith': 2.54116424568036,
#   'oneweight': 154715910.81548592,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6782251596450806,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 3}}

# %%
make_subject_set('nue_run_22067_subrun_000119_phase2')
# Out:
# Subject Set Name: nue_run_22067_subrun_000119_phase2
# Subject Set ID: 112487
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112473>, <SubjectSet 112467>, <SubjectSet 112481>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>, <SubjectSet 112464>]

# %%
uploader(compressed_path,nue_csv,112487)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:469: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   dict_manifest = s3.to_dict('dict')
# Confirm if subject set 112487 is listed below.
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112473>, <SubjectSet 112467>, <SubjectSet 112481>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>, <SubjectSet 112464>]
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112473>, <SubjectSet 112467>, <SubjectSet 112481>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>, <SubjectSet 112464>]
# Number of times loop has ran: 1
# Number of times loop has ran: 2
# Number of times loop has ran: 3
# Number of times loop has ran: 4
# Number of times loop has ran: 5
# Number of times loop has ran: 6
# Number of times loop has ran: 7
# Number of times loop has ran: 8
# Number of times loop has ran: 9
# Number of times loop has ran: 10
# Number of times loop has ran: 11
# Number of times loop has ran: 12
# Number of times loop has ran: 13
# Number of times loop has ran: 14
# Number of times loop has ran: 15
# Number of times loop has ran: 16
# Number of times loop has ran: 17
# Number of times loop has ran: 18
# Number of times loop has ran: 19
# Number of times loop has ran: 20
# Number of times loop has ran: 21
# Number of times loop has ran: 22
# Number of times loop has ran: 23
# Number of times loop has ran: 24
# Number of times loop has ran: 25
# Number of times loop has ran: 26
# Number of times loop has ran: 27
# Number of times loop has ran: 28
# Number of times loop has ran: 29
# Number of times loop has ran: 30
# Number of times loop has ran: 31
# Number of times loop has ran: 32
# Number of times loop has ran: 33
# Number of times loop has ran: 34
# Number of times loop has ran: 35
# Number of times loop has ran: 36
# Number of times loop has ran: 37
# Number of times loop has ran: 38
# Number of times loop has ran: 39
# Number of times loop has ran: 40
# Number of times loop has ran: 41
# Number of times loop has ran: 42
# Number of times loop has ran: 43
# Number of times loop has ran: 44
# Number of times loop has ran: 45
# Number of times loop has ran: 46
# Number of times loop has ran: 47
# Number of times loop has ran: 48
# Number of times loop has ran: 49
# Number of times loop has ran: 50
# Number of times loop has ran: 51
# Number of times loop has ran: 52
# Number of times loop has ran: 53
# Number of times loop has ran: 54
# Number of times loop has ran: 55
# Number of times loop has ran: 56
# Number of times loop has ran: 57
# Number of times loop has ran: 58
# Number of times loop has ran: 59
# Number of times loop has ran: 60
# Number of times loop has ran: 61
# Number of times loop has ran: 62
# Number of times loop has ran: 63
# Number of times loop has ran: 64
# Number of times loop has ran: 65
# Number of times loop has ran: 66
# Number of times loop has ran: 67
# Number of times loop has ran: 68
# Number of times loop has ran: 69
# Number of times loop has ran: 70
# Number of times loop has ran: 71
# Number of times loop has ran: 72
# Number of times loop has ran: 73
# Number of times loop has ran: 74
# Number of times loop has ran: 75
# Number of times loop has ran: 76
# Number of times loop has ran: 77
# Number of times loop has ran: 78
# Number of times loop has ran: 79
# Number of times loop has ran: 80
# Number of times loop has ran: 81
# Number of times loop has ran: 82
# Number of times loop has ran: 83
# Number of times loop has ran: 84
# Number of times loop has ran: 85
# Number of times loop has ran: 86
# Number of times loop has ran: 87
# Number of times loop has ran: 88
# Number of times loop has ran: 89
# Number of times loop has ran: 90
# Number of times loop has ran: 91
# Number of times loop has ran: 92
# Number of times loop has ran: 93
# Number of times loop has ran: 94
# Number of times loop has ran: 95
# Number of times loop has ran: 96
# Number of times loop has ran: 97
# Number of times loop has ran: 98
# Number of times loop has ran: 99
# Number of times loop has ran: 100
# Number of times loop has ran: 101
# Number of times loop has ran: 102
# Number of times loop has ran: 103
# Number of times loop has ran: 104
# Number of times loop has ran: 105
# Number of times loop has ran: 106
# Number of times loop has ran: 107
# Number of times loop has ran: 108
# Number of times loop has ran: 109
# Number of times loop has ran: 110
# Number of times loop has ran: 111
# Number of times loop has ran: 112
# Number of times loop has ran: 113
# Number of times loop has ran: 114
# Number of times loop has ran: 115
# Number of times loop has ran: 116
# Number of times loop has ran: 117
# Number of times loop has ran: 118
# Number of times loop has ran: 119
# Number of times loop has ran: 120
# Number of times loop has ran: 121
# Number of times loop has ran: 122
# Number of times loop has ran: 123
# Number of times loop has ran: 124
# Number of times loop has ran: 125
# Number of times loop has ran: 126
# Number of times loop has ran: 127
# Number of times loop has ran: 128
# Number of times loop has ran: 129
# Number of times loop has ran: 130
# Number of times loop has ran: 131
# Number of times loop has ran: 132
# Number of times loop has ran: 133
# Number of times loop has ran: 134
# Number of times loop has ran: 135
# Number of times loop has ran: 136
# Number of times loop has ran: 137
# Number of times loop has ran: 138
# Number of times loop has ran: 139
# Number of times loop has ran: 140
# Number of times loop has ran: 141
# Number of times loop has ran: 142
# Number of times loop has ran: 143
# Number of times loop has ran: 144
# Number of times loop has ran: 145
# Number of times loop has ran: 146
# Number of times loop has ran: 147
# Number of times loop has ran: 148
# Number of times loop has ran: 149
# Number of times loop has ran: 150
# Number of times loop has ran: 151
# Number of times loop has ran: 152
# Number of times loop has ran: 153
# Number of times loop has ran: 154
# Number of times loop has ran: 155
# Number of times loop has ran: 156
# Number of times loop has ran: 157
# Number of times loop has ran: 158
# Number of times loop has ran: 159
# Number of times loop has ran: 160
# Number of times loop has ran: 161
# Number of times loop has ran: 162
# Number of times loop has ran: 163
# Number of times loop has ran: 164
# Number of times loop has ran: 165
# Number of times loop has ran: 166
