# %% [markdown]
# # Phase 2: Subject Creation
#
# **Description:**
#
# This notebook is to act as the resulting summary file for the creation and upload of subjects for the IceCube Zooniverse project currently called *Name that Neutrino!*. The project is currently being maintained by Elizabeth Warrick (as of March 2023). In this notebook, we take the i3 file and run it through several filters. [note: describe more later].
#
# > Nu Type: NuE
#
# > Run: 22076
#
# > SubRun: 000000
#
# ### Summary Stats:
#
# To be filled in after completing process. Also need to figure out global variables.
#
# **Subject Set Name:**

# %%
#Imports

#My functions: 
from uniformenergydist_filter import *

#General:
import numpy as np
import sys
import os
import subprocess
import argparse
import csv
from tables import *
import pandas as pd
from matplotlib import pyplot as plt
import h5py

#Zooniverse:
from panoptes_client import Panoptes, Project, SubjectSet, Subject
import magic
import glob

#IceCube:
from icecube.icetray import I3Units
import icecube.MuonGun
from icecube import dataio, dataclasses, icetray, MuonGun
from I3Tray import *
from icecube.hdfwriter import I3HDFWriter
from mc_labeler import MCLabeler #make sure that mc_labeler script is in current directory.

# %%
#Specify file paths:

#Initial I3 File:
nue = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst'

#Desired output directory. Note that creation of this directory is not yet coded and is done manually. 
phase1_dir = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/'

# %%
#Run Filter 1 to label MC truth.
filter1(nue,phase1_dir)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/mc_labeler.py:523: UserWarning: Couldn't find OMKey in MCPESeriesMap
#   warnings.warn("Couldn't find OMKey in MCPESeriesMap")

# %% [markdown]
# Note that the above cell might return an "exception" warning that the *MCPESeriesMap could not be found*. I am unsure why it does that because when I check the i3 file in dataio-shovel, I see the specified mc_pid_series_map (look at mc_labeler.py for exact name of specified key). The resulting file size should be around 400 MB.

# %%
#Path of hdf from above filter.
nue_hdf = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/\
Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst.hd5'

# %%
#Run uniformenergy_events function which requires hdf from filter 1, 
#number of bins, size of each random choice, and a random seed. 

uniformenergy_events(nue_hdf,25,15,12,subrun = True)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['binned_log10E'] = pd.cut(x = np.log10(df_filtered['energy']), bins = bins, labels = labels, include_lowest = True) #might throw an error?
# Number of Bins: 25
# Number of Events per Bin: 15
# Total Number of Events: 375
# Initial Number of Events: 2648
# Number of Events after filtering: 2581
# Please input subrun number:
# 000000

# %% [markdown]
# The above function throws another warning about pd.cut, currently that is not a problem but I don't know if a new version of pandas will allow this.

# %%
#Path to Random Events CSV
nue_csv = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/random_events_uniform_energy_distrib_22067_000000.csv'

# %%
#Run event_characterization_plots function whick makes some quick 
#plots to get an idea of what data you're dealing with.
#Note that I want to update the plot types, maybe make a 2D histogram as Mike K suggested. 
#For truth labels, check out enums.py or in the .py file that holds the functions.

event_characterization_plots(nue_csv)

# %% [markdown]
# Now that we have the events for this phase chosen, we run the second filter to pick out only those events.

# %%
#Path to i3 file from filter1 with MC truth labels. 
nue_filter1 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst'

# %%
#Run function to perform second filter which passes through only selected event IDs chosen from 
#the uniformenergy_events function. 
filter2(nue_filter1,phase1_dir,nue_csv)

# %%
#Path to i3 file from filter 2 that holds only specified events. 
nue_filter2 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst'

# %%
#Run function to perform third filter, which returns only the DAQ frames of the specified events.
#DAQ only file is then split up into many smaller i3 files since SteamShovel can't handle making videos of large
#i3 files at one time. Size limit is approx 2E6 MB (? unsure of units)
filter3(nue_filter2,22067_000000,phase1_dir)

# %%
#Path to NuMu Daq Only folder
nue_daq = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/'

# %%
get_steamshovel(nue_daq,22067000000)
# Out:
# List of files:
# ['/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/daq_only-0009_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/daq_only-0010_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst']
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/daq_only-0009_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000000/daq_only-0010_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000000.i3.zst

# %% [markdown]
# Ideas for Compression:
# - Use GUI to add files to queue and send to one compression folder.
# - Add a subprocess line in movie script to compress the video after making it and direct it to save in the compression folder.

# %%
compressed_path = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/'

# %% [markdown]
# Can't get manifest yet since some subjects are missing and lining it up won't work.

# %%
get_manifest(compressed_path, nue_csv)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:417: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   dict_manifest = s3.to_dict('dict')
# {'/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_2299_origidx_12_RF22.mp4': {'event': 2299,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9299907684326172,
#   'pred_cascade': 0.0027456346433609,
#   'pred_tgtrack': 0.0111693758517503,
#   'pred_starttrack': 0.0019036692101508,
#   'pred_stoptrack': 0.0541905798017978,
#   'energy': 1995.201123976012,
#   'zenith': 1.9402134161050808,
#   'oneweight': 16773586848.876598,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9299907684326172,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_2557_origidx_24_RF22.mp4': {'event': 2557,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0361383222043514,
#   'pred_cascade': 0.6487210988998413,
#   'pred_tgtrack': 0.0004978092620149,
#   'pred_starttrack': 0.3138977289199829,
#   'pred_stoptrack': 0.0007451435667462,
#   'energy': 25946.101517928862,
#   'zenith': 1.209113212234206,
#   'oneweight': 5512246988504.982,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.6487210988998413,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_9759_origidx_10_RF22.mp4': {'event': 9759,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1863581240177154,
#   'pred_cascade': 0.0492333583533763,
#   'pred_tgtrack': 0.5222975015640259,
#   'pred_starttrack': 0.0475567877292633,
#   'pred_stoptrack': 0.1945543140172958,
#   'energy': 30026.939796843715,
#   'zenith': 0.5758147993432556,
#   'oneweight': 5916772878856.603,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5222975015640259,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_5706_origidx_15_RF22.mp4': {'event': 5706,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9969738721847534,
#   'pred_cascade': 1.6643854072739826e-09,
#   'pred_tgtrack': 0.0017032917821779,
#   'pred_starttrack': 1.483942302371588e-09,
#   'pred_stoptrack': 0.0013228183379396,
#   'energy': 48215.70159388804,
#   'zenith': 2.2278575398877245,
#   'oneweight': 5667193209605.733,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9969738721847534,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_4504_origidx_7_RF22.mp4': {'event': 4504,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.513420440664049e-05,
#   'pred_cascade': 0.88896644115448,
#   'pred_tgtrack': 3.693611506605521e-05,
#   'pred_starttrack': 0.1108891516923904,
#   'pred_stoptrack': 8.23286100057885e-05,
#   'energy': 1359.8599258838528,
#   'zenith': 0.8357878376728569,
#   'oneweight': 7507584492.84369,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.88896644115448,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_4640_origidx_13_RF22.mp4': {'event': 4640,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0001106807030737,
#   'pred_cascade': 0.7418317794799805,
#   'pred_tgtrack': 0.0001519813231425,
#   'pred_starttrack': 0.2556560933589935,
#   'pred_stoptrack': 0.0022495137527585,
#   'energy': 104.21265133581352,
#   'zenith': 0.745561443581122,
#   'oneweight': 7781323.8531094575,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7418317794799805,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_9769_origidx_11_RF22.mp4': {'event': 9769,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.99945729970932,
#   'pred_cascade': 0.0001474813179811,
#   'pred_tgtrack': 0.0002516740642022,
#   'pred_starttrack': 0.0001067342527676,
#   'pred_stoptrack': 3.6827139410888776e-05,
#   'energy': 548534.6551363154,
#   'zenith': 1.324278397034618,
#   'oneweight': 1.5918688625956718e+16,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.99945729970932,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_2433_origidx_18_RF22.mp4': {'event': 2433,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2949461042881012,
#   'pred_cascade': 0.0934662222862243,
#   'pred_tgtrack': 0.1733389347791671,
#   'pred_starttrack': 0.1509827226400375,
#   'pred_stoptrack': 0.2872660458087921,
#   'energy': 824.9802226962515,
#   'zenith': 1.2332885368061208,
#   'oneweight': 1962029448.082909,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.2949461042881012,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_6289_origidx_36_RF22.mp4': {'event': 6289,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0006584246875718,
#   'pred_cascade': 0.9763346910476683,
#   'pred_tgtrack': 2.6925546237066555e-08,
#   'pred_starttrack': 0.0228743068873882,
#   'pred_stoptrack': 0.0001325827033724,
#   'energy': 3903.6909722065775,
#   'zenith': 2.853849930214956,
#   'oneweight': 252068340057.8399,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9763346910476683,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_2523_origidx_23_RF22.mp4': {'event': 2523,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.7054529786109924,
#   'pred_cascade': 0.0863345563411712,
#   'pred_tgtrack': 0.0443978980183601,
#   'pred_starttrack': 0.0158001948148012,
#   'pred_stoptrack': 0.1480143517255783,
#   'energy': 1765.528511080007,
#   'zenith': 1.653136698690123,
#   'oneweight': 9945852895.852468,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7054529786109924,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_2505_origidx_22_RF22.mp4': {'event': 2505,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 5.413089184003184e-06,
#   'pred_cascade': 0.8552395105361938,
#   'pred_tgtrack': 9.788181159819942e-06,
#   'pred_starttrack': 0.1447397917509079,
#   'pred_stoptrack': 5.5475961744377855e-06,
#   'energy': 4650.757936871664,
#   'zenith': 0.2381524382257331,
#   'oneweight': 104461950719.89912,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.8552395105361938,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_9800_origidx_12_RF22.mp4': {'event': 9800,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1341326534748077,
#   'pred_cascade': 0.0315192528069019,
#   'pred_tgtrack': 0.2405627220869064,
#   'pred_starttrack': 0.0130119938403368,
#   'pred_stoptrack': 0.5807733535766602,
#   'energy': 2279.060107454653,
#   'zenith': 1.9075238368408591,
#   'oneweight': 61531765811.96299,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5807733535766602,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_779_origidx_5_RF22.mp4': {'event': 779,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 4.818339948542416e-05,
#   'pred_cascade': 0.936316967010498,
#   'pred_tgtrack': 2.312916694791056e-05,
#   'pred_starttrack': 0.0636075809597969,
#   'pred_stoptrack': 4.179346888122382e-06,
#   'energy': 317452.72408722143,
#   'zenith': 0.8538889397011542,
#   'oneweight': 1640561870426861.0,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.936316967010498,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_6485_origidx_39_RF22.mp4': {'event': 6485,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 4.1431908925915206e-07,
#   'pred_cascade': 0.9924726486206056,
#   'pred_tgtrack': 4.747089388246195e-09,
#   'pred_starttrack': 0.0075268959626555,
#   'pred_stoptrack': 1.9490054015136596e-08,
#   'energy': 70903.5019108057,
#   'zenith': 0.906730250215774,
#   'oneweight': 65746747669531.14,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9924726486206056,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_4219_origidx_23_RF22.mp4': {'event': 4219,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0002230102254543,
#   'pred_cascade': 0.995252251625061,
#   'pred_tgtrack': 1.54068580116018e-08,
#   'pred_starttrack': 0.0045245573855936,
#   'pred_stoptrack': 1.1437994373864059e-07,
#   'energy': 409173.3620204509,
#   'zenith': 2.0515081715306773,
#   'oneweight': 1976766475249538.8,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.995252251625061,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_888_origidx_9_RF22.mp4': {'event': 888,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.5827544927597046,
#   'pred_cascade': 0.088252454996109,
#   'pred_tgtrack': 0.003687294665724,
#   'pred_starttrack': 0.2521055340766907,
#   'pred_stoptrack': 0.0732002928853035,
#   'energy': 289.0060709384764,
#   'zenith': 0.6630394898012014,
#   'oneweight': 173679394.8016924,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.5827544927597046,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_4489_origidx_6_RF22.mp4': {'event': 4489,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999790191650392,
#   'pred_cascade': 1.5206648440457826e-11,
#   'pred_tgtrack': 4.7358144001918845e-06,
#   'pred_starttrack': 4.3702841345805155e-09,
#   'pred_stoptrack': 1.615724431758281e-05,
#   'energy': 203762.6788250216,
#   'zenith': 1.1398100286583326,
#   'oneweight': 430253932887541.2,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999790191650392,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_8243_origidx_11_RF22.mp4': {'event': 8243,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999839067459106,
#   'pred_cascade': 1.029515986350482e-10,
#   'pred_tgtrack': 7.017122243269114e-07,
#   'pred_starttrack': 3.880083809804091e-08,
#   'pred_stoptrack': 1.5436255125678144e-05,
#   'energy': 654173.7389991082,
#   'zenith': 1.3346192347618084,
#   'oneweight': 4570017141178697.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999839067459106,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_4754_origidx_18_RF22.mp4': {'event': 4754,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.5326065421104431,
#   'pred_cascade': 0.0717699751257896,
#   'pred_tgtrack': 0.0273807868361473,
#   'pred_starttrack': 0.1006391644477844,
#   'pred_stoptrack': 0.2676035463809967,
#   'energy': 234439.93094115905,
#   'zenith': 1.6859138694876046,
#   'oneweight': 97475683947342.66,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5326065421104431,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_8095_origidx_5_RF22.mp4': {'event': 8095,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.5809311270713806,
#   'pred_cascade': 0.0733855366706848,
#   'pred_tgtrack': 0.0273998472839593,
#   'pred_starttrack': 0.0633432269096374,
#   'pred_stoptrack': 0.2549403309822082,
#   'energy': 734.9002736357579,
#   'zenith': 0.3808140571180776,
#   'oneweight': 1501391631.1604211,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5809311270713806,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_8152_origidx_8_RF22.mp4': {'event': 8152,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0059062805958092,
#   'pred_cascade': 0.0004889565170742,
#   'pred_tgtrack': 0.0002145373582607,
#   'pred_starttrack': 0.0006009096396155,
#   'pred_stoptrack': 0.9927893280982972,
#   'energy': 16830.251912382868,
#   'zenith': 1.1489655018450529,
#   'oneweight': 3295273512319.417,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9927893280982972,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_5557_origidx_10_RF22.mp4': {'event': 5557,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999935269355774,
#   'pred_cascade': 2.2844844806968467e-06,
#   'pred_tgtrack': 7.992149221536238e-06,
#   'pred_starttrack': 7.024668207122886e-07,
#   'pred_stoptrack': 5.374352986109443e-05,
#   'energy': 113107.60856291074,
#   'zenith': 1.0903348322040527,
#   'oneweight': 296089368082511.75,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999935269355774,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_3818_origidx_11_RF22.mp4': {'event': 3818,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.4037660548638088e-05,
#   'pred_cascade': 0.999359667301178,
#   'pred_tgtrack': 9.067980144550349e-09,
#   'pred_starttrack': 0.0006252863095141,
#   'pred_stoptrack': 9.91120032267645e-07,
#   'energy': 14949.633345446082,
#   'zenith': 1.279274015900861,
#   'oneweight': 1705623523474.306,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.999359667301178,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_8500_origidx_24_RF22.mp4': {'event': 8500,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 5.705089733964996e-06,
#   'pred_cascade': 0.997723400592804,
#   'pred_tgtrack': 1.496038315451642e-08,
#   'pred_starttrack': 0.0022686691954731,
#   'pred_stoptrack': 2.157290509785525e-06,
#   'energy': 13468.173137925764,
#   'zenith': 1.350120624200881,
#   'oneweight': 1289941925277.442,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.997723400592804,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_6014_origidx_29_RF22.mp4': {'event': 6014,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 7.882670615799725e-06,
#   'pred_cascade': 0.7402892708778381,
#   'pred_tgtrack': 5.224748747423291e-05,
#   'pred_starttrack': 0.2595877051353454,
#   'pred_stoptrack': 6.290180317591876e-05,
#   'energy': 391.8648584252532,
#   'zenith': 0.6597977489762317,
#   'oneweight': 344318384.0307587,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7402892708778381,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_8440_origidx_22_RF22.mp4': {'event': 8440,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0343489646911621,
#   'pred_cascade': 0.0102920969948172,
#   'pred_tgtrack': 0.7404555678367615,
#   'pred_starttrack': 0.0040921759791672,
#   'pred_stoptrack': 0.2108111530542373,
#   'energy': 602.0790319629818,
#   'zenith': 1.0377617521008868,
#   'oneweight': 531803037.8347495,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7404555678367615,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_4318_origidx_24_RF22.mp4': {'event': 4318,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9980054497718812,
#   'pred_cascade': 0.0002186083293054,
#   'pred_tgtrack': 0.0004591638862621,
#   'pred_starttrack': 0.0003524757921695,
#   'pred_stoptrack': 0.000964437611401,
#   'energy': 12574.969371703262,
#   'zenith': 1.3749412390736413,
#   'oneweight': 1131214091724.9138,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9980054497718812,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_4467_origidx_5_RF22.mp4': {'event': 4467,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 4.970002919435501e-06,
#   'pred_cascade': 0.8005635142326355,
#   'pred_tgtrack': 5.7312771417628034e-08,
#   'pred_starttrack': 0.1994161307811737,
#   'pred_stoptrack': 1.5326653738156892e-05,
#   'energy': 1379.9066086624598,
#   'zenith': 2.643245206295203,
#   'oneweight': 7867935829.319738,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.8005635142326355,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_5781_origidx_19_RF22.mp4': {'event': 5781,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0361571796238422,
#   'pred_cascade': 0.0087978690862655,
#   'pred_tgtrack': 0.9302594661712646,
#   'pred_starttrack': 0.0057364762760698,
#   'pred_stoptrack': 0.0190490037202835,
#   'energy': 13431.580276060638,
#   'zenith': 0.710243813386178,
#   'oneweight': 108886560168.15295,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9302594661712646,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_2247_origidx_8_RF22.mp4': {'event': 2247,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.6840811440488324e-05,
#   'pred_cascade': 0.9670059084892272,
#   'pred_tgtrack': 2.4186640530388104e-06,
#   'pred_starttrack': 0.0329338051378726,
#   'pred_stoptrack': 4.101849117432721e-05,
#   'energy': 863.2445330389339,
#   'zenith': 0.742554071218396,
#   'oneweight': 2734639853.045664,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9670059084892272,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_6910_origidx_10_RF22.mp4': {'event': 6910,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0182411894202232,
#   'pred_cascade': 0.0071242093108594,
#   'pred_tgtrack': 0.8276318907737732,
#   'pred_starttrack': 0.0127561744302511,
#   'pred_stoptrack': 0.1342466324567794,
#   'energy': 35384.362851062324,
#   'zenith': 1.979534749866674,
#   'oneweight': 94407818631787.12,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8276318907737732,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_2425_origidx_17_RF22.mp4': {'event': 2425,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999513626098632,
#   'pred_cascade': 3.096251033340991e-09,
#   'pred_tgtrack': 1.8004848243435845e-05,
#   'pred_starttrack': 1.1277759170980062e-08,
#   'pred_stoptrack': 3.058162837987766e-05,
#   'energy': 31337.361029285257,
#   'zenith': 0.8329987696191228,
#   'oneweight': 6729882355977.709,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999513626098632,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_2388_origidx_15_RF22.mp4': {'event': 2388,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.032684214413166,
#   'pred_cascade': 0.0652122497558593,
#   'pred_tgtrack': 0.0020220600999891,
#   'pred_starttrack': 0.8710027933120728,
#   'pred_stoptrack': 0.0290787182748317,
#   'energy': 110.28019541697968,
#   'zenith': 1.1549336022937449,
#   'oneweight': 8112344.863161612,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8710027933120728,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_4643_origidx_14_RF22.mp4': {'event': 4643,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.000384500977816,
#   'pred_cascade': 0.8682140111923218,
#   'pred_tgtrack': 0.0001626771409064,
#   'pred_starttrack': 0.1306310147047042,
#   'pred_stoptrack': 0.000607852532994,
#   'energy': 477.0951712158787,
#   'zenith': 1.519126615505057,
#   'oneweight': 525091303.0081114,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8682140111923218,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_6347_origidx_38_RF22.mp4': {'event': 6347,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 3.2037556252362265e-07,
#   'pred_cascade': 0.9933727979660034,
#   'pred_tgtrack': 2.6938517194707856e-08,
#   'pred_starttrack': 0.0066261333413422,
#   'pred_stoptrack': 6.646273504884448e-07,
#   'energy': 66853.7249288181,
#   'zenith': 1.7844771056898885,
#   'oneweight': 6763896385372.364,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9933727979660034,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_3944_origidx_16_RF22.mp4': {'event': 3944,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.2826739293814173e-05,
#   'pred_cascade': 0.9887450337409972,
#   'pred_tgtrack': 8.071751835814212e-06,
#   'pred_starttrack': 0.0111444639042019,
#   'pred_stoptrack': 8.956262172432616e-05,
#   'energy': 1820.0101516968732,
#   'zenith': 1.034194210505165,
#   'oneweight': 25243277741.664043,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9887450337409972,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_8902_origidx_11_RF22.mp4': {'event': 8902,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.978388010888011e-06,
#   'pred_cascade': 0.7738384008407593,
#   'pred_tgtrack': 6.0034147963961e-07,
#   'pred_starttrack': 0.2261561453342437,
#   'pred_stoptrack': 1.8819582692231047e-06,
#   'energy': 1874.2264484011569,
#   'zenith': 1.085106061560416,
#   'oneweight': 15610408074.110891,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7738384008407593,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_5307_origidx_38_RF22.mp4': {'event': 5307,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.0001707593037281,
#   'pred_cascade': 0.9898090362548828,
#   'pred_tgtrack': 2.3423558559443336e-06,
#   'pred_starttrack': 0.0099932700395584,
#   'pred_stoptrack': 2.45037426793715e-05,
#   'energy': 90599.3249265917,
#   'zenith': 0.4953246428572679,
#   'oneweight': 124817587208062.52,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9898090362548828,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_9876_origidx_14_RF22.mp4': {'event': 9876,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0387007072567939,
#   'pred_cascade': 0.7072021961212158,
#   'pred_tgtrack': 0.0018450686475262,
#   'pred_starttrack': 0.2162091135978698,
#   'pred_stoptrack': 0.0360428355634212,
#   'energy': 311.9996720169416,
#   'zenith': 1.428865344364716,
#   'oneweight': 135768441.7072313,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7072021961212158,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_5338_origidx_5_RF22.mp4': {'event': 5338,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2296493500471115,
#   'pred_cascade': 0.038252867758274,
#   'pred_tgtrack': 0.6787981390953064,
#   'pred_starttrack': 0.0172704048454761,
#   'pred_stoptrack': 0.03602921590209,
#   'energy': 610.0414692400265,
#   'zenith': 0.2312166000360494,
#   'oneweight': 175480051.21985766,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6787981390953064,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_6862_origidx_8_RF22.mp4': {'event': 6862,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0002909754985012,
#   'pred_cascade': 0.5545283555984497,
#   'pred_tgtrack': 0.0009070811793208,
#   'pred_starttrack': 0.4441818296909332,
#   'pred_stoptrack': 9.175407467409968e-05,
#   'energy': 418.7310884460374,
#   'zenith': 0.7989804729622689,
#   'oneweight': 351400153.6708462,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.5545283555984497,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_5317_origidx_4_RF22.mp4': {'event': 5317,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.5929837900330313e-05,
#   'pred_cascade': 0.9968920350074768,
#   'pred_tgtrack': 3.617924164700526e-07,
#   'pred_starttrack': 0.0030340084340423,
#   'pred_stoptrack': 5.765299283666536e-05,
#   'energy': 2202.4764075554986,
#   'zenith': 2.43141239564375,
#   'oneweight': 22654752930.046387,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9968920350074768,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_4081_origidx_19_RF22.mp4': {'event': 4081,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 8.360797801287845e-05,
#   'pred_cascade': 0.987473726272583,
#   'pred_tgtrack': 4.457686827663565e-06,
#   'pred_starttrack': 0.0124103482812643,
#   'pred_stoptrack': 2.787662197079044e-05,
#   'energy': 5460.271066608449,
#   'zenith': 0.4414068761591179,
#   'oneweight': 188355110888.73907,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.987473726272583,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_5858_origidx_22_RF22.mp4': {'event': 5858,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0912622585892677,
#   'pred_cascade': 0.0238921120762825,
#   'pred_tgtrack': 0.856960117816925,
#   'pred_starttrack': 0.0134114855900406,
#   'pred_stoptrack': 0.0144739998504519,
#   'energy': 124.0517022206475,
#   'zenith': 2.202823864546508,
#   'oneweight': 5145371.794597511,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.856960117816925,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_5839_origidx_21_RF22.mp4': {'event': 5839,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0002467868034727,
#   'pred_cascade': 0.486346572637558,
#   'pred_tgtrack': 0.0002000378299271,
#   'pred_starttrack': 0.4782010912895202,
#   'pred_stoptrack': 0.0350055433809757,
#   'energy': 117.819618781601,
#   'zenith': 0.6115906893126754,
#   'oneweight': 19926658.279838663,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.486346572637558,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_6023_origidx_30_RF22.mp4': {'event': 6023,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999923706054688,
#   'pred_cascade': 1.369289792663153e-09,
#   'pred_tgtrack': 4.952431140736735e-07,
#   'pred_starttrack': 8.902939718780091e-09,
#   'pred_stoptrack': 7.119720976334065e-06,
#   'energy': 34928.612578376815,
#   'zenith': 2.1411447375826653,
#   'oneweight': 10087963157353.389,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999923706054688,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_149_origidx_8_RF22.mp4': {'event': 149,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0175677947700023,
#   'pred_cascade': 0.0029599973931908,
#   'pred_tgtrack': 0.0124930832535028,
#   'pred_starttrack': 0.0034771680366247,
#   'pred_stoptrack': 0.9635019302368164,
#   'energy': 3083.299819437109,
#   'zenith': 1.1660039681545131,
#   'oneweight': 108664647241.67282,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9635019302368164,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_3866_origidx_13_RF22.mp4': {'event': 3866,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9994681477546692,
#   'pred_cascade': 2.994631529418257e-07,
#   'pred_tgtrack': 2.1610518160741776e-05,
#   'pred_starttrack': 2.640969114509062e-07,
#   'pred_stoptrack': 0.0005096083623357,
#   'energy': 7767.348779649282,
#   'zenith': 2.4644543605866605,
#   'oneweight': 370641665452.8964,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9994681477546692,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_9061_origidx_15_RF22.mp4': {'event': 9061,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.7088652132079005e-05,
#   'pred_cascade': 0.9271748661994934,
#   'pred_tgtrack': 5.570884695771383e-06,
#   'pred_starttrack': 0.0727690458297729,
#   'pred_stoptrack': 2.345754182897508e-05,
#   'energy': 501.19232861238686,
#   'zenith': 2.309662086375512,
#   'oneweight': 825224317.6003497,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9271748661994934,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_4128_origidx_22_RF22.mp4': {'event': 4128,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9989872574806212,
#   'pred_cascade': 6.985092682043614e-08,
#   'pred_tgtrack': 0.0001251513021998,
#   'pred_starttrack': 1.8015573743923602e-07,
#   'pred_stoptrack': 0.0008872889447957,
#   'energy': 8182.674039983477,
#   'zenith': 1.1612819682896718,
#   'oneweight': 376717388746.19977,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9989872574806212,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_9076_origidx_18_RF22.mp4': {'event': 9076,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1002094075083732,
#   'pred_cascade': 0.035484705120325,
#   'pred_tgtrack': 0.7748602628707886,
#   'pred_starttrack': 0.0331230945885181,
#   'pred_stoptrack': 0.0563225746154785,
#   'energy': 176.01407200378432,
#   'zenith': 1.1711476536872645,
#   'oneweight': 23514688.181417663,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7748602628707886,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_2300_origidx_13_RF22.mp4': {'event': 2300,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0792748555541038,
#   'pred_cascade': 0.0934479162096977,
#   'pred_tgtrack': 0.0364594087004661,
#   'pred_starttrack': 0.1213301122188568,
#   'pred_stoptrack': 0.6694877743721008,
#   'energy': 132.7944016005125,
#   'zenith': 1.9337272395021952,
#   'oneweight': 6947795.208852931,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6694877743721008,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_2187_origidx_6_RF22.mp4': {'event': 2187,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999997854232788,
#   'pred_cascade': 1.127673995848788e-11,
#   'pred_tgtrack': 1.3887664351841522e-07,
#   'pred_starttrack': 2.127104270499558e-09,
#   'pred_stoptrack': 2.0107368072785903e-06,
#   'energy': 665793.3118017606,
#   'zenith': 0.6209401324191949,
#   'oneweight': 3831715058119705.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999997854232788,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_5984_origidx_28_RF22.mp4': {'event': 5984,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 6.012087396811694e-05,
#   'pred_cascade': 0.9032410979270936,
#   'pred_tgtrack': 2.590585609141272e-06,
#   'pred_starttrack': 0.0938500463962555,
#   'pred_stoptrack': 0.0028461776673793,
#   'energy': 636.2148140231612,
#   'zenith': 1.6055916394653365,
#   'oneweight': 823534782.7801273,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9032410979270936,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_4877_origidx_20_RF22.mp4': {'event': 4877,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.2526595294475555,
#   'pred_cascade': 0.7254455089569092,
#   'pred_tgtrack': 1.570959466334898e-05,
#   'pred_starttrack': 0.0195860583335161,
#   'pred_stoptrack': 0.002293201861903,
#   'energy': 12844.47783492836,
#   'zenith': 1.9588260186507425,
#   'oneweight': 1205113141648.2986,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7254455089569092,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_4026_origidx_18_RF22.mp4': {'event': 4026,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9826416373252868,
#   'pred_cascade': 0.0134742576628923,
#   'pred_tgtrack': 0.0023208691272884,
#   'pred_starttrack': 0.0014277966693043,
#   'pred_stoptrack': 0.0001353942789137,
#   'energy': 106265.91757828707,
#   'zenith': 2.459770776736052,
#   'oneweight': 115946844135242.86,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9826416373252868,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_4626_origidx_12_RF22.mp4': {'event': 4626,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3227903842926025,
#   'pred_cascade': 0.0913188755512237,
#   'pred_tgtrack': 0.2748034000396728,
#   'pred_starttrack': 0.2053941637277603,
#   'pred_stoptrack': 0.1056932210922241,
#   'energy': 91203.482849803,
#   'zenith': 0.5056847602786312,
#   'oneweight': 102949367978572.4,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3227903842926025,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_4113_origidx_21_RF22.mp4': {'event': 4113,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0010942685185,
#   'pred_cascade': 0.9913314580917358,
#   'pred_tgtrack': 7.69040416344069e-05,
#   'pred_starttrack': 0.0072258650325238,
#   'pred_stoptrack': 0.0002714172587729,
#   'energy': 20497.580296667245,
#   'zenith': 0.6716597569729424,
#   'oneweight': 4907912336183.962,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9913314580917358,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_195_origidx_11_RF22.mp4': {'event': 195,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.0013641148107126,
#   'pred_cascade': 0.9283083081245422,
#   'pred_tgtrack': 0.0004254143859725,
#   'pred_starttrack': 0.0688800439238548,
#   'pred_stoptrack': 0.0010220281546935,
#   'energy': 6352.391905059361,
#   'zenith': 1.9646819087164893,
#   'oneweight': 271484086964.8669,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9283083081245422,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_9835_origidx_13_RF22.mp4': {'event': 9835,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9998723268508912,
#   'pred_cascade': 5.740793951325428e-10,
#   'pred_tgtrack': 3.996337909484282e-05,
#   'pred_starttrack': 2.01191892301722e-06,
#   'pred_stoptrack': 8.572464867029339e-05,
#   'energy': 924989.015572614,
#   'zenith': 1.8825773607398648,
#   'oneweight': 7124642933346005.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9998723268508912,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_8397_origidx_21_RF22.mp4': {'event': 8397,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999874711036682,
#   'pred_cascade': 8.385486580664292e-06,
#   'pred_tgtrack': 7.589959750475828e-06,
#   'pred_starttrack': 9.317980584455654e-05,
#   'pred_stoptrack': 1.621193950995803e-05,
#   'energy': 117519.71450069686,
#   'zenith': 1.7965187657259911,
#   'oneweight': 14652922795713.145,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999874711036682,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_6746_origidx_51_RF22.mp4': {'event': 6746,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 8.415676347794943e-06,
#   'pred_cascade': 0.990755021572113,
#   'pred_tgtrack': 1.8645341270939756e-08,
#   'pred_starttrack': 0.0092209260910749,
#   'pred_stoptrack': 1.5584702850901522e-05,
#   'energy': 1310.4094194297124,
#   'zenith': 2.0695243026664683,
#   'oneweight': 13075784710.854485,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.990755021572113,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_3692_origidx_4_RF22.mp4': {'event': 3692,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2630989253520965,
#   'pred_cascade': 0.0885003507137298,
#   'pred_tgtrack': 0.3965657949447632,
#   'pred_starttrack': 0.0373923256993293,
#   'pred_stoptrack': 0.214442566037178,
#   'energy': 307577.66198973934,
#   'zenith': 1.2471874565507186,
#   'oneweight': 4164966612257720.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3965657949447632,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_8447_origidx_23_RF22.mp4': {'event': 8447,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.7750459909439087,
#   'pred_cascade': 0.2036364525556564,
#   'pred_tgtrack': 0.0013368349755182,
#   'pred_starttrack': 0.0181303545832633,
#   'pred_stoptrack': 0.0018503684550523,
#   'energy': 60863.889078874505,
#   'zenith': 0.0646916580337792,
#   'oneweight': 28017825618732.453,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7750459909439087,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_2558_origidx_25_RF22.mp4': {'event': 2558,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9954049587249756,
#   'pred_cascade': 0.0013780976878479,
#   'pred_tgtrack': 0.0002482447598595,
#   'pred_starttrack': 0.0011012648465111,
#   'pred_stoptrack': 0.0018674043240025,
#   'energy': 7533.81155110735,
#   'zenith': 1.8712424977598583,
#   'oneweight': 1728019385260.779,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9954049587249756,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_9044_origidx_13_RF22.mp4': {'event': 9044,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.400286853313446,
#   'pred_cascade': 0.105024054646492,
#   'pred_tgtrack': 0.2683725357055664,
#   'pred_starttrack': 0.0423799492418766,
#   'pred_stoptrack': 0.1839365512132644,
#   'energy': 425.41398559133273,
#   'zenith': 2.1852048815111558,
#   'oneweight': 495568566.46077526,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.400286853313446,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_8342_origidx_17_RF22.mp4': {'event': 8342,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0725188180804252,
#   'pred_cascade': 0.2755008637905121,
#   'pred_tgtrack': 0.602446436882019,
#   'pred_starttrack': 0.0166629496961832,
#   'pred_stoptrack': 0.0328709445893764,
#   'energy': 12539.044846120803,
#   'zenith': 2.467692204172518,
#   'oneweight': 1278248208907.6868,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.602446436882019,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_5884_origidx_24_RF22.mp4': {'event': 5884,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.131098136305809,
#   'pred_cascade': 0.0386670306324958,
#   'pred_tgtrack': 0.0016665188595652,
#   'pred_starttrack': 0.031843326985836,
#   'pred_stoptrack': 0.7967249751091003,
#   'energy': 40925.12399447824,
#   'zenith': 0.5967806402494903,
#   'oneweight': 11042884448690.447,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7967249751091003,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_3777_origidx_7_RF22.mp4': {'event': 3777,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9962074756622314,
#   'pred_cascade': 0.00020900418167,
#   'pred_tgtrack': 0.000239372762735,
#   'pred_starttrack': 0.0002629043592605,
#   'pred_stoptrack': 0.0030813131015747,
#   'energy': 20355.107395464947,
#   'zenith': 2.5586410107742035,
#   'oneweight': 3943638950349.488,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9962074756622314,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_3797_origidx_10_RF22.mp4': {'event': 3797,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0567571073770523,
#   'pred_cascade': 0.0078817950561642,
#   'pred_tgtrack': 0.5507327914237976,
#   'pred_starttrack': 0.0123405186459422,
#   'pred_stoptrack': 0.372287780046463,
#   'energy': 155.16836305068168,
#   'zenith': 0.5838133911578213,
#   'oneweight': 13720413.66927467,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5507327914237976,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_5919_origidx_26_RF22.mp4': {'event': 5919,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0649413615465164,
#   'pred_cascade': 0.0117308534681797,
#   'pred_tgtrack': 0.9040680527687072,
#   'pred_starttrack': 0.0057835853658616,
#   'pred_stoptrack': 0.0134762153029441,
#   'energy': 217.46282694504723,
#   'zenith': 2.150696426937663,
#   'oneweight': 41598293.6800436,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9040680527687072,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_9987_origidx_18_RF22.mp4': {'event': 9987,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4003177881240845,
#   'pred_cascade': 0.0139682786539196,
#   'pred_tgtrack': 0.2189943939447403,
#   'pred_starttrack': 0.0329236574470996,
#   'pred_stoptrack': 0.3337958753108978,
#   'energy': 211.32505005047187,
#   'zenith': 2.365470217830542,
# ...
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_5627_origidx_14_RF22.mp4': {'event': 5627,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3300395905971527,
#   'pred_cascade': 0.1025371849536895,
#   'pred_tgtrack': 0.3200299143791199,
#   'pred_starttrack': 0.0512693747878074,
#   'pred_stoptrack': 0.1961239278316497,
#   'energy': 1070.4786047454872,
#   'zenith': 0.4368211945157217,
#   'oneweight': 2765269862.534552,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3300395905971527,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_9048_origidx_14_RF22.mp4': {'event': 9048,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 7.305508802346594e-07,
#   'pred_cascade': 0.9989572763442992,
#   'pred_tgtrack': 2.9285224245612085e-10,
#   'pred_starttrack': 0.0010420143371447,
#   'pred_stoptrack': 5.630932520261923e-08,
#   'energy': 189806.5908217117,
#   'zenith': 1.3668730637256574,
#   'oneweight': 341870695270820.3,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9989572763442992,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_6758_origidx_52_RF22.mp4': {'event': 6758,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 8.718880053493194e-06,
#   'pred_cascade': 0.9976442456245422,
#   'pred_tgtrack': 3.9748662694627507e-10,
#   'pred_starttrack': 0.0023452055174857,
#   'pred_stoptrack': 1.919273472594796e-06,
#   'energy': 10470.956860121983,
#   'zenith': 1.835376946030497,
#   'oneweight': 760400631145.1455,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9976442456245422,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_8803_origidx_8_RF22.mp4': {'event': 8803,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0002937305544037,
#   'pred_cascade': 0.8140708208084106,
#   'pred_tgtrack': 0.0003674902254715,
#   'pred_starttrack': 0.1841844767332077,
#   'pred_stoptrack': 0.0010834812419489,
#   'energy': 839.4530929066341,
#   'zenith': 2.272398453331993,
#   'oneweight': 3583505804.594775,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8140708208084106,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_9629_origidx_6_RF22.mp4': {'event': 9629,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.0927313809361294e-07,
#   'pred_cascade': 0.9980962872505188,
#   'pred_tgtrack': 4.36242153512012e-09,
#   'pred_starttrack': 0.0019034581491723,
#   'pred_stoptrack': 6.885529302280703e-08,
#   'energy': 80148.40783378012,
#   'zenith': 0.9451287690163944,
#   'oneweight': 75530262148120.72,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9980962872505188,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_2281_origidx_11_RF22.mp4': {'event': 2281,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999963879585266,
#   'pred_cascade': 2.0970912506523828e-11,
#   'pred_tgtrack': 6.045005648047663e-06,
#   'pred_starttrack': 3.6316702423100367e-10,
#   'pred_stoptrack': 3.0007382520125248e-05,
#   'energy': 495330.1401347786,
#   'zenith': 1.2213895099383685,
#   'oneweight': 2266682821424905.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999963879585266,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_8838_origidx_9_RF22.mp4': {'event': 8838,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.5582617521286011,
#   'pred_cascade': 0.2583772838115692,
#   'pred_tgtrack': 0.015637706965208,
#   'pred_starttrack': 0.0912815108895301,
#   'pred_stoptrack': 0.0764418020844459,
#   'energy': 515.1456604363426,
#   'zenith': 0.3245782227687613,
#   'oneweight': 493016183.4151868,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5582617521286011,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_3129_origidx_7_RF22.mp4': {'event': 3129,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9982245564460754,
#   'pred_cascade': 0.0001594698842382,
#   'pred_tgtrack': 0.0001441627537133,
#   'pred_starttrack': 0.0001910431019496,
#   'pred_stoptrack': 0.001280783326365,
#   'energy': 8069.102152881619,
#   'zenith': 2.0237969880632605,
#   'oneweight': 2249910886247.252,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9982245564460754,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_4446_origidx_4_RF22.mp4': {'event': 4446,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1472344845533371,
#   'pred_cascade': 0.0241980720311403,
#   'pred_tgtrack': 0.0072442791424691,
#   'pred_starttrack': 0.0398973487317562,
#   'pred_stoptrack': 0.7814258337020874,
#   'energy': 146369.7927142324,
#   'zenith': 1.1507833748045604,
#   'oneweight': 12156112813338.203,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7814258337020874,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_2248_origidx_9_RF22.mp4': {'event': 2248,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9996371269226074,
#   'pred_cascade': 2.2458762032329105e-06,
#   'pred_tgtrack': 0.0001753852266119,
#   'pred_starttrack': 2.6127523597097024e-05,
#   'pred_stoptrack': 0.0001591460895724,
#   'energy': 39784.09073757373,
#   'zenith': 2.4354821996133578,
#   'oneweight': 134034867227576.98,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9996371269226074,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_4532_origidx_11_RF22.mp4': {'event': 4532,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 4.296268889447674e-05,
#   'pred_cascade': 0.9756740927696228,
#   'pred_tgtrack': 2.97132999094174e-07,
#   'pred_starttrack': 0.0242783147841691,
#   'pred_stoptrack': 4.3499699131643865e-06,
#   'energy': 833506.6223207985,
#   'zenith': 0.153813198054318,
#   'oneweight': 6372724567082094.0,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9756740927696228,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_5923_origidx_27_RF22.mp4': {'event': 5923,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9945313930511476,
#   'pred_cascade': 0.000366953696357,
#   'pred_tgtrack': 0.000536089297384,
#   'pred_starttrack': 0.0010299123823642,
#   'pred_stoptrack': 0.0035356122534722,
#   'energy': 85515.0054766431,
#   'zenith': 2.459625172512726,
#   'oneweight': 507419033143.3861,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9945313930511476,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_8704_origidx_5_RF22.mp4': {'event': 8704,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9631407260894777,
#   'pred_cascade': 0.0100399898365139,
#   'pred_tgtrack': 0.0108604878187179,
#   'pred_starttrack': 0.0048656314611434,
#   'pred_stoptrack': 0.0110930632799863,
#   'energy': 449428.2912386899,
#   'zenith': 1.7775014465628527,
#   'oneweight': 2120563867411216.8,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9631407260894777,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_4990_origidx_23_RF22.mp4': {'event': 4990,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9995779395103456,
#   'pred_cascade': 1.7089485382371098e-08,
#   'pred_tgtrack': 0.0003887400089297,
#   'pred_starttrack': 3.6185392460197355e-09,
#   'pred_stoptrack': 3.332983033033088e-05,
#   'energy': 282602.2659137912,
#   'zenith': 0.8444280547260541,
#   'oneweight': 1101094444765694.8,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9995779395103456,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_5486_origidx_7_RF22.mp4': {'event': 5486,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0001244729646714,
#   'pred_cascade': 0.9600179195404052,
#   'pred_tgtrack': 0.0001634363434277,
#   'pred_starttrack': 0.0395194590091705,
#   'pred_stoptrack': 0.0001746270281728,
#   'energy': 3873.354629499843,
#   'zenith': 0.3827120514898662,
#   'oneweight': 83589946534.25977,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9600179195404052,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_9969_origidx_17_RF22.mp4': {'event': 9969,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1561102122068405,
#   'pred_cascade': 0.0299147143959999,
#   'pred_tgtrack': 0.7539963126182556,
#   'pred_starttrack': 0.0287579298019409,
#   'pred_stoptrack': 0.0312208365648984,
#   'energy': 385.67037298615,
#   'zenith': 1.2676239907700335,
#   'oneweight': 317322936.31280506,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7539963126182556,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_3849_origidx_12_RF22.mp4': {'event': 3849,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0453916601836681,
#   'pred_cascade': 0.0172393582761287,
#   'pred_tgtrack': 0.8669129610061646,
#   'pred_starttrack': 0.0080779204145073,
#   'pred_stoptrack': 0.0623780749738216,
#   'energy': 198799.22981805055,
#   'zenith': 1.1135216686934846,
#   'oneweight': 104736269416709.12,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8669129610061646,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_4097_origidx_20_RF22.mp4': {'event': 4097,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0504983067512512,
#   'pred_cascade': 0.0120396260172128,
#   'pred_tgtrack': 0.9017909169197084,
#   'pred_starttrack': 0.0255012325942516,
#   'pred_stoptrack': 0.0101698590442538,
#   'energy': 191.18549181948185,
#   'zenith': 2.132606408178508,
#   'oneweight': 35619951.58096309,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9017909169197084,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_8987_origidx_12_RF22.mp4': {'event': 8987,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.7382410078425892e-05,
#   'pred_cascade': 0.9587444067001344,
#   'pred_tgtrack': 2.9607310381152278e-08,
#   'pred_starttrack': 0.0412379056215286,
#   'pred_stoptrack': 3.060495998852275e-07,
#   'energy': 33875.809395323486,
#   'zenith': 1.54255842629387,
#   'oneweight': 8144193901396.454,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9587444067001344,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_6266_origidx_35_RF22.mp4': {'event': 6266,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.9195070965215564e-05,
#   'pred_cascade': 0.9760122895240784,
#   'pred_tgtrack': 2.8808121896872763e-06,
#   'pred_starttrack': 0.0239367261528968,
#   'pred_stoptrack': 1.8826382074621503e-05,
#   'energy': 1347.8204396879491,
#   'zenith': 1.004800824647841,
#   'oneweight': 7424223755.561053,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9760122895240784,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_5718_origidx_17_RF22.mp4': {'event': 5718,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2863425612449646,
#   'pred_cascade': 0.0747991353273391,
#   'pred_tgtrack': 0.3413125574588775,
#   'pred_starttrack': 0.0540312118828296,
#   'pred_stoptrack': 0.2435144931077957,
#   'energy': 409.31820084612406,
#   'zenith': 1.5067444416001488,
#   'oneweight': 313150296.0596438,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3413125574588775,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_5612_origidx_12_RF22.mp4': {'event': 5612,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 4.83760459246696e-06,
#   'pred_cascade': 0.9597702622413636,
#   'pred_tgtrack': 2.034873887168942e-06,
#   'pred_starttrack': 0.0402210876345634,
#   'pred_stoptrack': 1.7839663541963091e-06,
#   'energy': 113054.00542054953,
#   'zenith': 0.3929584421254179,
#   'oneweight': 143960561211573.03,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9597702622413636,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_5136_origidx_30_RF22.mp4': {'event': 5136,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9984976053237916,
#   'pred_cascade': 2.474513394190581e-07,
#   'pred_tgtrack': 4.544235343928449e-05,
#   'pred_starttrack': 2.280147100464092e-06,
#   'pred_stoptrack': 0.001454408513382,
#   'energy': 54179.48026407047,
#   'zenith': 0.8263204611203456,
#   'oneweight': 17709791599665.613,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9984976053237916,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000000/compressed_run_22067_event_5110_origidx_28_RF22.mp4': {'event': 5110,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0004519931098911,
#   'pred_cascade': 0.9802268743515016,
#   'pred_tgtrack': 3.9383594412356615e-06,
#   'pred_starttrack': 0.0182477235794067,
#   'pred_stoptrack': 0.00106955494266,
#   'energy': 388.6579106375522,
#   'zenith': 1.6463186890355288,
#   'oneweight': 240664839.34687057,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9802268743515016,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 4}}

# %%
make_subject_set('nue_run_22067_subrun_000000_phase2')
# Out:
# Subject Set Name: nue_run_22067_subrun_000000_phase2
# Subject Set ID: 112392
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>]

# %%
uploader(compressed_path,nue_csv,112392)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:468: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   dict_manifest = s3.to_dict('dict')
# Confirm if subject set 112392 is listed below.
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>]
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>]
# Number of times loop has ran: 1
# Number of times loop has ran: 2
# Number of times loop has ran: 3
# Number of times loop has ran: 4
# Number of times loop has ran: 5
# Number of times loop has ran: 6
# Number of times loop has ran: 7
# Number of times loop has ran: 8
# Number of times loop has ran: 9
# Number of times loop has ran: 10
# Number of times loop has ran: 11
# Number of times loop has ran: 12
# Number of times loop has ran: 13
# Number of times loop has ran: 14
# Number of times loop has ran: 15
# Number of times loop has ran: 16
# Number of times loop has ran: 17
# Number of times loop has ran: 18
# Number of times loop has ran: 19
# Number of times loop has ran: 20
# Number of times loop has ran: 21
# Number of times loop has ran: 22
# Number of times loop has ran: 23
# Number of times loop has ran: 24
# Number of times loop has ran: 25
# Number of times loop has ran: 26
# Number of times loop has ran: 27
# Number of times loop has ran: 28
# Number of times loop has ran: 29
# Number of times loop has ran: 30
# Number of times loop has ran: 31
# Number of times loop has ran: 32
# Number of times loop has ran: 33
# Number of times loop has ran: 34
# Number of times loop has ran: 35
# Number of times loop has ran: 36
# Number of times loop has ran: 37
# Number of times loop has ran: 38
# Number of times loop has ran: 39
# Number of times loop has ran: 40
# Number of times loop has ran: 41
# Number of times loop has ran: 42
# Number of times loop has ran: 43
# Number of times loop has ran: 44
# Number of times loop has ran: 45
# Number of times loop has ran: 46
# Number of times loop has ran: 47
# Number of times loop has ran: 48
# Number of times loop has ran: 49
# Number of times loop has ran: 50
# Number of times loop has ran: 51
# Number of times loop has ran: 52
# Number of times loop has ran: 53
# Number of times loop has ran: 54
# Number of times loop has ran: 55
# Number of times loop has ran: 56
# Number of times loop has ran: 57
# Number of times loop has ran: 58
# Number of times loop has ran: 59
# Number of times loop has ran: 60
# Number of times loop has ran: 61
# Number of times loop has ran: 62
# Number of times loop has ran: 63
# Number of times loop has ran: 64
# Number of times loop has ran: 65
# Number of times loop has ran: 66
# Number of times loop has ran: 67
# Number of times loop has ran: 68
# Number of times loop has ran: 69
# Number of times loop has ran: 70
# Number of times loop has ran: 71
# Number of times loop has ran: 72
# Number of times loop has ran: 73
# Number of times loop has ran: 74
# Number of times loop has ran: 75
# Number of times loop has ran: 76
# Number of times loop has ran: 77
# Number of times loop has ran: 78
# Number of times loop has ran: 79
# Number of times loop has ran: 80
# Number of times loop has ran: 81
# Number of times loop has ran: 82
# Number of times loop has ran: 83
# Number of times loop has ran: 84
# Number of times loop has ran: 85
# Number of times loop has ran: 86
# Number of times loop has ran: 87
# Number of times loop has ran: 88
# Number of times loop has ran: 89
# Number of times loop has ran: 90
# Number of times loop has ran: 91
# Number of times loop has ran: 92
# Number of times loop has ran: 93
# Number of times loop has ran: 94
# Number of times loop has ran: 95
# Number of times loop has ran: 96
# Number of times loop has ran: 97
# Number of times loop has ran: 98
# Number of times loop has ran: 99
# Number of times loop has ran: 100
# Number of times loop has ran: 101
# Number of times loop has ran: 102
# Number of times loop has ran: 103
# Number of times loop has ran: 104
# Number of times loop has ran: 105
# Number of times loop has ran: 106
# Number of times loop has ran: 107
# Number of times loop has ran: 108
# Number of times loop has ran: 109
# Number of times loop has ran: 110
# Number of times loop has ran: 111
# Number of times loop has ran: 112
# Number of times loop has ran: 113
# Number of times loop has ran: 114
# Number of times loop has ran: 115
# Number of times loop has ran: 116
# Number of times loop has ran: 117
# Number of times loop has ran: 118
# Number of times loop has ran: 119
# Number of times loop has ran: 120
# Number of times loop has ran: 121
# Number of times loop has ran: 122
# Number of times loop has ran: 123
# Number of times loop has ran: 124
# Number of times loop has ran: 125
# Number of times loop has ran: 126
# Number of times loop has ran: 127
# Number of times loop has ran: 128
# Number of times loop has ran: 129
# Number of times loop has ran: 130
# Number of times loop has ran: 131
# Number of times loop has ran: 132
# Number of times loop has ran: 133
# Number of times loop has ran: 134
# Number of times loop has ran: 135
# Number of times loop has ran: 136
# Number of times loop has ran: 137
# Number of times loop has ran: 138
# Number of times loop has ran: 139
# Number of times loop has ran: 140
# Number of times loop has ran: 141
# Number of times loop has ran: 142
# Number of times loop has ran: 143
# Number of times loop has ran: 144
# Number of times loop has ran: 145
# Number of times loop has ran: 146
# Number of times loop has ran: 147
# Number of times loop has ran: 148
# Number of times loop has ran: 149
# Number of times loop has ran: 150
# Number of times loop has ran: 151
# Number of times loop has ran: 152
# Number of times loop has ran: 153
# Number of times loop has ran: 154
# Number of times loop has ran: 155
# Number of times loop has ran: 156
# Number of times loop has ran: 157
# Number of times loop has ran: 158
# Number of times loop has ran: 159
# Number of times loop has ran: 160
# Number of times loop has ran: 161
# Number of times loop has ran: 162
# Number of times loop has ran: 163
# Number of times loop has ran: 164
# Number of times loop has ran: 165
# Number of times loop has ran: 166
# Number of times loop has ran: 167
# Number of times loop has ran: 168
# Number of times loop has ran: 169
# Number of times loop has ran: 170
# Number of times loop has ran: 171
# Number of times loop has ran: 172
# Number of times loop has ran: 173
# Number of times loop has ran: 174
# Number of times loop has ran: 175
# Number of times loop has ran: 176
# Number of times loop has ran: 177
# Number of times loop has ran: 178
# Number of times loop has ran: 179
# Number of times loop has ran: 180
# Number of times loop has ran: 181
# Number of times loop has ran: 182
# Number of times loop has ran: 183
# Number of times loop has ran: 184
# Number of times loop has ran: 185
# Number of times loop has ran: 186
# Number of times loop has ran: 187
# Number of times loop has ran: 188
# Number of times loop has ran: 189
# Number of times loop has ran: 190
# Number of times loop has ran: 191
# Number of times loop has ran: 192
# Number of times loop has ran: 193
# Number of times loop has ran: 194
# Number of times loop has ran: 195
# Number of times loop has ran: 196
# Number of times loop has ran: 197
# Number of times loop has ran: 198
# Number of times loop has ran: 199
# Number of times loop has ran: 200
# Number of times loop has ran: 201
# Number of times loop has ran: 202
# Number of times loop has ran: 203
# Number of times loop has ran: 204
# Number of times loop has ran: 205
# Number of times loop has ran: 206
# Number of times loop has ran: 207
# Number of times loop has ran: 208
# Number of times loop has ran: 209
# Number of times loop has ran: 210
# Number of times loop has ran: 211
# Number of times loop has ran: 212
