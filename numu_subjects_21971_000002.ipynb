# %% [markdown]
# # Phase 2: Subject Creation
#
# **Description:**
#
# This notebook is to act as the resulting summary file for the creation and upload of subjects for the IceCube Zooniverse project currently called *Name that Neutrino!*. The project is currently being maintained by Elizabeth Warrick (as of March 2023). In this notebook, we take the i3 file and run it through several filters. [note: describe more later].
#
# > Nu Type: NuMu
#
# > Run: 21971
#
# > SubRun: 000002
#
# ### Summary Stats:
#
# To be filled in after completing process. Also need to figure out global variables.
#
# **Subject Set Name:**

# %%
#Imports

#My functions: 
from uniformenergydist_filter import *

#General:
import numpy as np
import sys
import os
import subprocess
import argparse
import csv
from tables import *
import pandas as pd
from matplotlib import pyplot as plt
import h5py

#Zooniverse:
from panoptes_client import Panoptes, Project, SubjectSet, Subject
import magic
import glob

#IceCube:
from icecube.icetray import I3Units
import icecube.MuonGun
from icecube import dataio, dataclasses, icetray, MuonGun
from I3Tray import *
from icecube.hdfwriter import I3HDFWriter
from mc_labeler import MCLabeler #make sure that mc_labeler script is in current directory.

# %%
#Specify file paths:

#Initial I3 File:
numu = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst'

#Desired output directory. Note that creation of this directory is not yet coded and is done manually. 
phase1_dir = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/'

# %%
#Run Filter 1 to label MC truth.
filter1(numu,phase1_dir)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/mc_labeler.py:523: UserWarning: Couldn't find OMKey in MCPESeriesMap
#   warnings.warn("Couldn't find OMKey in MCPESeriesMap")

# %% [markdown]
# Note that the above cell might return an "exception" warning that the *MCPESeriesMap could not be found*. I am unsure why it does that because when I check the i3 file in dataio-shovel, I see the specified mc_pid_series_map (look at mc_labeler.py for exact name of specified key). The resulting file size should be around 400 MB.

# %%
#Path of hdf from above filter.
numu_hdf = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/\
Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst.hd5'

# %%
#Run uniformenergy_events function which requires hdf from filter 1, 
#number of bins, size of each random choice, and a random seed. 

uniformenergy_events(numu_hdf,25,40,12,subrun = True)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['binned_log10E'] = pd.cut(x = np.log10(df_filtered['energy']), bins = bins, labels = labels, include_lowest = True) #might throw an error?
# Number of Bins: 25
# Number of Events per Bin: 40
# Total Number of Events: 1000
# Initial Number of Events: 8759
# Number of Events after filtering: 8091
# Please input subrun number:
# 000002

# %% [markdown]
# The above function throws another warning about pd.cut, currently that is not a problem but I don't know if a new version of pandas will allow this.

# %%
#Path to Random Events CSV
numu_csv = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/random_events_uniform_energy_distrib_21971_000002.csv'

# %%
#Run event_characterization_plots function whick makes some quick 
#plots to get an idea of what data you're dealing with.
#Note that I want to update the plot types, maybe make a 2D histogram as Mike K suggested. 
#For truth labels, check out enums.py or in the .py file that holds the functions.

event_characterization_plots(numu_csv)

# %% [markdown]
# Now that we have the events for this phase chosen, we run the second filter to pick out only those events.

# %%
#Path to i3 file from filter1 with MC truth labels. 
numu_filter1 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst'

# %%
#Run function to perform second filter which passes through only selected event IDs chosen from 
#the uniformenergy_events function. 
filter2(numu_filter1,phase1_dir,numu_csv)

# %%
#Path to i3 file from filter 2 that holds only specified events. 
numu_filter2 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst'

# %%
#Run function to perform third filter, which returns only the DAQ frames of the specified events.
#DAQ only file is then split up into many smaller i3 files since SteamShovel can't handle making videos of large
#i3 files at one time. Size limit is approx 2E6 MB (? unsure of units)
filter3(numu_filter2,21971_000002,phase1_dir)

# %%
#Path to NuMu Daq Only folder
numu_daq = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/'

# %%
get_steamshovel(numu_daq,21971000002)
# Out:
# List of files:
# ['/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0009_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0010_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0011_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0012_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0013_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0014_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0015_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0016_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0017_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0018_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0019_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq ...
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0009_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0010_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0011_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0012_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0013_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0014_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0015_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0016_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0017_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0018_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0019_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0020_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0021_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0022_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0023_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000002/daq_only-0024_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000002.i3.zst

# %% [markdown]
# Ideas for Compression:
# - Use GUI to add files to queue and send to one compression folder.
# - Add a subprocess line in movie script to compress the video after making it and direct it to save in the compression folder.

# %%
compressed_path = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/'

# %% [markdown]
# Can't get manifest yet since some subjects are missing and lining it up won't work.

# %%
get_manifest(compressed_path, numu_csv)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:417: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   dict_manifest = s3.to_dict('dict')
# {'/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_5807_origidx_27_RF22.mp4': {'event': 5807,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0001278412964893,
#   'pred_cascade': 3.09819620269991e-06,
#   'pred_tgtrack': 0.7034744024276733,
#   'pred_starttrack': 0.0060670608654618,
#   'pred_stoptrack': 0.2903276085853576,
#   'energy': 917812.0590290908,
#   'zenith': 2.898957806719757,
#   'oneweight': 1259003516972213.8,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.7034744024276733,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_5276_origidx_7_RF22.mp4': {'event': 5276,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 8.403253204392058e-09,
#   'pred_cascade': 3.413538440626141e-13,
#   'pred_tgtrack': 0.999997615814209,
#   'pred_starttrack': 2.5956504146051884e-07,
#   'pred_stoptrack': 2.107878572132904e-06,
#   'energy': 701282.408885921,
#   'zenith': 2.513866404066982,
#   'oneweight': 2.4305709093668624e+16,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.999997615814209,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_1403_origidx_6_RF22.mp4': {'event': 1403,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.1944947838783264,
#   'pred_cascade': 0.0338047035038471,
#   'pred_tgtrack': 0.4374601542949676,
#   'pred_starttrack': 0.2836149036884308,
#   'pred_stoptrack': 0.0506255626678466,
#   'energy': 562.1481576650623,
#   'zenith': 2.306917774875702,
#   'oneweight': 1251546765.0412352,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.4374601542949676,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_3551_origidx_29_RF22.mp4': {'event': 3551,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0021716593764722,
#   'pred_cascade': 0.0001298899587709,
#   'pred_tgtrack': 0.9965204000473022,
#   'pred_starttrack': 0.0009271164308302,
#   'pred_stoptrack': 0.000251065212069,
#   'energy': 188611.466149487,
#   'zenith': 0.8275314953094851,
#   'oneweight': 941267046224388.0,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9965204000473022,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_20305_origidx_18_RF22.mp4': {'event': 20305,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.9811363816261292,
#   'pred_cascade': 0.0008150569046847,
#   'pred_tgtrack': 0.0175846740603446,
#   'pred_starttrack': 0.0002023402630584,
#   'pred_stoptrack': 0.0002615040866658,
#   'energy': 42749.87501555395,
#   'zenith': 0.60206470858687,
#   'oneweight': 33664610094037.68,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9811363816261292,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_2760_origidx_4_RF22.mp4': {'event': 2760,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 3.572211255686853e-07,
#   'pred_cascade': 3.463554207883135e-07,
#   'pred_tgtrack': 0.9576798677444458,
#   'pred_starttrack': 0.0422760769724845,
#   'pred_stoptrack': 4.3364099838072434e-05,
#   'energy': 290313.92074555514,
#   'zenith': 1.4176786391736198,
#   'oneweight': 5112330808406669.0,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9576798677444458,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_7238_origidx_21_RF22.mp4': {'event': 7238,
#   'run': 21971,
#   'truth_classification': 3,
#   'pred_skim': 7.240971171995625e-05,
#   'pred_cascade': 1.125319249695167e-05,
#   'pred_tgtrack': 6.413065420929343e-05,
#   'pred_starttrack': 0.0214577335864305,
#   'pred_stoptrack': 0.9783944487571716,
#   'energy': 608.0536182886493,
#   'zenith': 1.727221589520352,
#   'oneweight': 1142108682.328482,
#   'truth_classification_label': 'stopping_track',
#   'max_score_val': 0.9783944487571716,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_9555_origidx_7_RF22.mp4': {'event': 9555,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.0777981430292129,
#   'pred_cascade': 0.0318627133965492,
#   'pred_tgtrack': 0.5570635795593262,
#   'pred_starttrack': 0.2955707013607025,
#   'pred_stoptrack': 0.0377048999071121,
#   'energy': 432.8506331704464,
#   'zenith': 0.8714998425443385,
#   'oneweight': 437338369.4968019,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5570635795593262,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_22875_origidx_6_RF22.mp4': {'event': 22875,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0196819957345724,
#   'pred_cascade': 0.0870154574513435,
#   'pred_tgtrack': 0.0082474313676357,
#   'pred_starttrack': 0.0716036781668663,
#   'pred_stoptrack': 0.8134514093399048,
#   'energy': 5201.011972603789,
#   'zenith': 0.9742732073888078,
#   'oneweight': 298027241317.0494,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.8134514093399048,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_3384_origidx_21_RF22.mp4': {'event': 3384,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.3517700731754303,
#   'pred_cascade': 0.0386628918349742,
#   'pred_tgtrack': 0.3495648801326751,
#   'pred_starttrack': 0.0955706238746643,
#   'pred_stoptrack': 0.1644315123558044,
#   'energy': 214942.56404311644,
#   'zenith': 2.066275284743865,
#   'oneweight': 7372941090597634.0,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.3517700731754303,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_18493_origidx_11_RF22.mp4': {'event': 18493,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.299295425415039,
#   'pred_cascade': 0.1079943925142288,
#   'pred_tgtrack': 0.4127344489097595,
#   'pred_starttrack': 0.0478979647159576,
#   'pred_stoptrack': 0.1320777982473373,
#   'energy': 417.5646812244336,
#   'zenith': 1.4976578639757008,
#   'oneweight': 391707298.11586607,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4127344489097595,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_20537_origidx_21_RF22.mp4': {'event': 20537,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.1373757719993591,
#   'pred_cascade': 0.0013950396096333,
#   'pred_tgtrack': 0.8590030670166016,
#   'pred_starttrack': 0.0012080682208761,
#   'pred_stoptrack': 0.0010181149700656,
#   'energy': 20678.933847029293,
#   'zenith': 1.212221042095904,
#   'oneweight': 9287022888656.1,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.8590030670166016,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_20114_origidx_13_RF22.mp4': {'event': 20114,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0004134400805924,
#   'pred_cascade': 6.193412991706282e-05,
#   'pred_tgtrack': 0.7419447898864746,
#   'pred_starttrack': 0.0141049055382609,
#   'pred_stoptrack': 0.2434749752283096,
#   'energy': 745629.7665354094,
#   'zenith': 1.82373492703511,
#   'oneweight': 2.527373484130067e+16,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.7419447898864746,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_11699_origidx_22_RF22.mp4': {'event': 11699,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.9191753268241882,
#   'pred_cascade': 0.0010985659901052,
#   'pred_tgtrack': 0.0708404704928398,
#   'pred_starttrack': 0.0016445944784209,
#   'pred_stoptrack': 0.0072410069406032,
#   'energy': 65382.52985357645,
#   'zenith': 1.0169671410612209,
#   'oneweight': 70388799908646.55,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9191753268241882,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_4442_origidx_6_RF22.mp4': {'event': 4442,
#   'run': 21971,
#   'truth_classification': 3,
#   'pred_skim': 0.2250846922397613,
#   'pred_cascade': 0.0397528782486915,
#   'pred_tgtrack': 0.0222792997956275,
#   'pred_starttrack': 0.091871403157711,
#   'pred_stoptrack': 0.6210117340087891,
#   'energy': 209.40834495562143,
#   'zenith': 0.848811290586952,
#   'oneweight': 58629085.84702087,
#   'truth_classification_label': 'stopping_track',
#   'max_score_val': 0.6210117340087891,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_26362_origidx_8_RF22.mp4': {'event': 26362,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.1468884944915771,
#   'pred_cascade': 0.0624168962240219,
#   'pred_tgtrack': 0.6675481796264648,
#   'pred_starttrack': 0.042863879352808,
#   'pred_stoptrack': 0.080282524228096,
#   'energy': 159.8107091201745,
#   'zenith': 0.6144945010160462,
#   'oneweight': 23432220.262270983,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.6675481796264648,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_23998_origidx_6_RF22.mp4': {'event': 23998,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 1.4792108231631572e-05,
#   'pred_cascade': 1.82885707999958e-06,
#   'pred_tgtrack': 0.9973487854003906,
#   'pred_starttrack': 0.0020849278662353,
#   'pred_stoptrack': 0.0005496765952557,
#   'energy': 227918.6429348057,
#   'zenith': 1.469892207718503,
#   'oneweight': 5051888268714100.0,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9973487854003906,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_30672_origidx_4_RF22.mp4': {'event': 30672,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0019296708051115,
#   'pred_cascade': 3.142242576359422e-06,
#   'pred_tgtrack': 0.5798198580741882,
#   'pred_starttrack': 0.4182288348674774,
#   'pred_stoptrack': 1.8492077288101427e-05,
#   'energy': 49852.29185870172,
#   'zenith': 1.1067945137244468,
#   'oneweight': 77498488869882.52,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.5798198580741882,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_12113_origidx_34_RF22.mp4': {'event': 12113,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.9999918937683104,
#   'pred_cascade': 5.031998639992708e-08,
#   'pred_tgtrack': 3.014695266756462e-06,
#   'pred_starttrack': 1.556962729409861e-06,
#   'pred_stoptrack': 3.58593683813524e-06,
#   'energy': 270679.3843069231,
#   'zenith': 0.1719517750131875,
#   'oneweight': 909000607960310.2,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9999918937683104,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_22958_origidx_12_RF22.mp4': {'event': 22958,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.988344669342041,
#   'pred_cascade': 0.0005433231708593,
#   'pred_tgtrack': 0.0078066331334412,
#   'pred_starttrack': 0.0006434338865801,
#   'pred_stoptrack': 0.002662060316652,
#   'energy': 115073.18814436089,
#   'zenith': 0.592534547091334,
#   'oneweight': 266177905021144.88,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.988344669342041,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_18687_origidx_20_RF22.mp4': {'event': 18687,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.3685446083545685,
#   'pred_cascade': 0.1148433610796928,
#   'pred_tgtrack': 0.1755197644233703,
#   'pred_starttrack': 0.1458544582128524,
#   'pred_stoptrack': 0.1952378004789352,
#   'energy': 268.8110651438185,
#   'zenith': 2.025500122979012,
#   'oneweight': 66706181.26142672,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.3685446083545685,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_28678_origidx_8_RF22.mp4': {'event': 28678,
#   'run': 21971,
#   'truth_classification': 3,
#   'pred_skim': 0.1331928968429565,
#   'pred_cascade': 0.0286340303719043,
#   'pred_tgtrack': 0.0168910827487707,
#   'pred_starttrack': 0.0190853215754032,
#   'pred_stoptrack': 0.802196741104126,
#   'energy': 913.9370643865966,
#   'zenith': 2.094294867920226,
#   'oneweight': 4507727660.005342,
#   'truth_classification_label': 'stopping_track',
#   'max_score_val': 0.802196741104126,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_5852_origidx_30_RF22.mp4': {'event': 5852,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0106262238696217,
#   'pred_cascade': 0.0025084679946303,
#   'pred_tgtrack': 0.907034397125244,
#   'pred_starttrack': 0.0112424315884709,
#   'pred_stoptrack': 0.0685885250568389,
#   'energy': 841.4429148952621,
#   'zenith': 1.3922318371274325,
#   'oneweight': 5260051858.427831,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.907034397125244,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_11910_origidx_29_RF22.mp4': {'event': 11910,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 1.0807372063936782e-06,
#   'pred_cascade': 4.295740438919893e-07,
#   'pred_tgtrack': 0.702430784702301,
#   'pred_starttrack': 0.0006185285164974,
#   'pred_stoptrack': 0.2969491183757782,
#   'energy': 1721.5456305578368,
#   'zenith': 2.955927737347542,
#   'oneweight': 22028993251.254696,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.702430784702301,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_15766_origidx_13_RF22.mp4': {'event': 15766,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0009802421554923,
#   'pred_cascade': 0.0001824404898798,
#   'pred_tgtrack': 0.9971702694892884,
#   'pred_starttrack': 3.6435107176657766e-05,
#   'pred_stoptrack': 0.001630563987419,
#   'energy': 360894.0764490978,
#   'zenith': 0.6544523207852736,
#   'oneweight': 2902105375258266.5,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9971702694892884,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_30723_origidx_6_RF22.mp4': {'event': 30723,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.1638786494731903,
#   'pred_cascade': 0.055240161716938,
#   'pred_tgtrack': 0.5122345685958862,
#   'pred_starttrack': 0.235400766134262,
#   'pred_stoptrack': 0.0332459025084972,
#   'energy': 128982.87913142746,
#   'zenith': 2.334392171573386,
#   'oneweight': 473659513244312.5,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.5122345685958862,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_9543_origidx_5_RF22.mp4': {'event': 9543,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.1164551302790641,
#   'pred_cascade': 0.0330606438219547,
#   'pred_tgtrack': 0.3624088764190674,
#   'pred_starttrack': 0.4434051811695099,
#   'pred_stoptrack': 0.0446701645851135,
#   'energy': 152.57109207246222,
#   'zenith': 1.9837795988139089,
#   'oneweight': 8393632.269146118,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4434051811695099,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_8388_origidx_6_RF22.mp4': {'event': 8388,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.2056358903646469,
#   'pred_cascade': 0.0298315621912479,
#   'pred_tgtrack': 0.6220115423202515,
#   'pred_starttrack': 0.0096301371231675,
#   'pred_stoptrack': 0.1328908503055572,
#   'energy': 4468.427230237403,
#   'zenith': 1.520742867539071,
#   'oneweight': 353454422577.7242,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.6220115423202515,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_5924_origidx_31_RF22.mp4': {'event': 5924,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.2301722019910812,
#   'pred_cascade': 0.0506547279655933,
#   'pred_tgtrack': 0.030423866584897,
#   'pred_starttrack': 0.0293789394199848,
#   'pred_stoptrack': 0.6593703031539917,
#   'energy': 25022.89070070068,
#   'zenith': 1.5610850576003217,
#   'oneweight': 45744021568795.63,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6593703031539917,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_7196_origidx_18_RF22.mp4': {'event': 7196,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.2039331197738647,
#   'pred_cascade': 0.0322040878236293,
#   'pred_tgtrack': 0.0058804950676858,
#   'pred_starttrack': 0.1975433677434921,
#   'pred_stoptrack': 0.560438871383667,
#   'energy': 206.10213934413412,
#   'zenith': 2.203574693855461,
#   'oneweight': 45311843.923184365,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.560438871383667,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_15611_origidx_8_RF22.mp4': {'event': 15611,
#   'run': 21971,
#   'truth_classification': 3,
#   'pred_skim': 7.429110701195896e-05,
#   'pred_cascade': 2.199312802986242e-05,
#   'pred_tgtrack': 0.0002545731840655,
#   'pred_starttrack': 0.0244574323296546,
#   'pred_stoptrack': 0.9751917123794556,
#   'energy': 401.6459968867708,
#   'zenith': 2.3003061161680214,
#   'oneweight': 725211157.0438421,
#   'truth_classification_label': 'stopping_track',
#   'max_score_val': 0.9751917123794556,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_5794_origidx_26_RF22.mp4': {'event': 5794,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 7.23361495147401e-07,
#   'pred_cascade': 0.0008168196654878,
#   'pred_tgtrack': 2.929920628957916e-05,
#   'pred_starttrack': 0.999103844165802,
#   'pred_stoptrack': 4.925766188534908e-05,
#   'energy': 472.9570851160145,
#   'zenith': 1.7772644830183046,
#   'oneweight': 533260133.41506034,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.999103844165802,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_9720_origidx_10_RF22.mp4': {'event': 9720,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0186512116342782,
#   'pred_cascade': 0.0063921865075826,
#   'pred_tgtrack': 0.8893193602561951,
#   'pred_starttrack': 0.003225038293749,
#   'pred_stoptrack': 0.0824121758341789,
#   'energy': 13021.613007819393,
#   'zenith': 0.4067453951267567,
#   'oneweight': 1421354574289.1958,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.8893193602561951,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_21501_origidx_28_RF22.mp4': {'event': 21501,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 8.169733689555869e-08,
#   'pred_cascade': 1.990511009353213e-05,
#   'pred_tgtrack': 0.001921962480992,
#   'pred_starttrack': 0.9980558156967164,
#   'pred_stoptrack': 2.3025625068839872e-06,
#   'energy': 546.0724362094687,
#   'zenith': 1.945139717499628,
#   'oneweight': 904814307.0168709,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.9980558156967164,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_20768_origidx_6_RF22.mp4': {'event': 20768,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.9977396726608276,
#   'pred_cascade': 2.5975677999667823e-06,
#   'pred_tgtrack': 0.0001900508214021,
#   'pred_starttrack': 5.855415292899124e-05,
#   'pred_stoptrack': 0.0020091813057661,
#   'energy': 9839.83126880528,
#   'zenith': 0.3041563124297161,
#   'oneweight': 664317508457.7559,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9977396726608276,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_7153_origidx_16_RF22.mp4': {'event': 7153,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.3932311534881592,
#   'pred_cascade': 0.0755185335874557,
#   'pred_tgtrack': 0.1035482510924339,
#   'pred_starttrack': 0.0701739713549614,
#   'pred_stoptrack': 0.3575280904769897,
#   'energy': 116.18454095170388,
#   'zenith': 1.3169467272388102,
#   'oneweight': 10659628.374563904,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.3932311534881592,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_23237_origidx_26_RF22.mp4': {'event': 23237,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.9841227531433104,
#   'pred_cascade': 0.0050949086435139,
#   'pred_tgtrack': 0.0012803256977349,
#   'pred_starttrack': 0.0041166502051055,
#   'pred_stoptrack': 0.0053853266872465,
#   'energy': 2846.9236945832936,
#   'zenith': 1.7058282971227063,
#   'oneweight': 165186649228.51663,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9841227531433104,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_15570_origidx_6_RF22.mp4': {'event': 15570,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 3.601482239901088e-05,
#   'pred_cascade': 3.4238000807818025e-05,
#   'pred_tgtrack': 0.9716290235519408,
#   'pred_starttrack': 0.0277627129107713,
#   'pred_stoptrack': 0.0005378791829571,
#   'energy': 878225.2664568706,
#   'zenith': 0.9869832271055832,
#   'oneweight': 1.839059395768786e+16,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9716290235519408,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_4914_origidx_13_RF22.mp4': {'event': 4914,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 4.177363788215871e-09,
#   'pred_cascade': 6.510891543791419e-13,
#   'pred_tgtrack': 0.999398708343506,
#   'pred_starttrack': 0.0005176523700356,
#   'pred_stoptrack': 8.366835390916094e-05,
#   'energy': 488764.986284534,
#   'zenith': 2.5351641084404077,
#   'oneweight': 1.2132874597578556e+16,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.999398708343506,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_21539_origidx_31_RF22.mp4': {'event': 21539,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 0.0035825653467327,
#   'pred_cascade': 0.0012308740988373,
#   'pred_tgtrack': 0.5926389098167419,
#   'pred_starttrack': 0.3986734449863434,
#   'pred_stoptrack': 0.0038742143660783,
#   'energy': 6196.919764762131,
#   'zenith': 0.2158846516963992,
#   'oneweight': 311689054463.8801,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.5926389098167419,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_9926_origidx_15_RF22.mp4': {'event': 9926,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0507148578763008,
#   'pred_cascade': 0.0112739289179444,
#   'pred_tgtrack': 0.893327534198761,
#   'pred_starttrack': 0.0142993256449699,
#   'pred_stoptrack': 0.0303843654692173,
#   'energy': 27870.367204772152,
#   'zenith': 1.0394229314454555,
#   'oneweight': 20277507347954.707,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.893327534198761,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_3197_origidx_17_RF22.mp4': {'event': 3197,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0001142986657214,
#   'pred_cascade': 0.0002580042637418,
#   'pred_tgtrack': 0.9303305149078368,
#   'pred_starttrack': 0.0637327879667282,
#   'pred_stoptrack': 0.0055643343366682,
#   'energy': 2048.1717100195774,
#   'zenith': 2.1640802076981007,
#   'oneweight': 77354000452.94669,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9303305149078368,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_15830_origidx_15_RF22.mp4': {'event': 15830,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0001058866037055,
#   'pred_cascade': 7.008107786532491e-05,
#   'pred_tgtrack': 0.9992727637290956,
#   'pred_starttrack': 0.000251593068242,
#   'pred_stoptrack': 0.0002997021947521,
#   'energy': 822400.4554470216,
#   'zenith': 0.8445920289551124,
#   'oneweight': 1.7610215820062906e+16,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9992727637290956,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_11651_origidx_18_RF22.mp4': {'event': 11651,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.1762822121381759,
#   'pred_cascade': 0.0499036759138107,
#   'pred_tgtrack': 0.7022853493690491,
#   'pred_starttrack': 0.0215854495763778,
#   'pred_stoptrack': 0.049943346530199,
#   'energy': 2583.3840889447933,
#   'zenith': 0.9715236624928072,
#   'oneweight': 88502165152.56812,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.7022853493690491,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_21427_origidx_25_RF22.mp4': {'event': 21427,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0945926159620285,
#   'pred_cascade': 0.011287210509181,
#   'pred_tgtrack': 0.7412436008453369,
#   'pred_starttrack': 0.0674836561083793,
#   'pred_stoptrack': 0.0853929445147514,
#   'energy': 4215.897041611869,
#   'zenith': 0.6614828756296335,
#   'oneweight': 197419243643.84293,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.7412436008453369,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_9541_origidx_4_RF22.mp4': {'event': 9541,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 3.546142761479132e-05,
#   'pred_cascade': 4.196735608275048e-05,
#   'pred_tgtrack': 0.0341925285756588,
#   'pred_starttrack': 0.9524615406990052,
#   'pred_stoptrack': 0.0132684195414185,
#   'energy': 568.8688649675124,
#   'zenith': 1.6120152692704124,
#   'oneweight': 1540099745.6605408,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.9524615406990052,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_6750_origidx_7_RF22.mp4': {'event': 6750,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0021049086935818,
#   'pred_cascade': 9.581339691067114e-05,
#   'pred_tgtrack': 0.9970850348472596,
#   'pred_starttrack': 9.429961210116744e-05,
#   'pred_stoptrack': 0.0006199859199114,
#   'energy': 147405.6970888916,
#   'zenith': 1.2132786332748933,
#   'oneweight': 746150589224140.2,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9970850348472596,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_28942_origidx_19_RF22.mp4': {'event': 28942,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.3565694391727447,
#   'pred_cascade': 0.0972349792718887,
#   'pred_tgtrack': 0.4376930594444275,
#   'pred_starttrack': 0.043268796056509,
#   'pred_stoptrack': 0.0652337819337844,
#   'energy': 112741.15341857278,
#   'zenith': 0.8690929350041282,
#   'oneweight': 260520364273663.03,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.4376930594444275,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_3158_origidx_15_RF22.mp4': {'event': 3158,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.3806589543819427,
#   'pred_cascade': 0.1145521476864814,
#   'pred_tgtrack': 0.2791202366352081,
#   'pred_starttrack': 0.0706671997904777,
#   'pred_stoptrack': 0.1550014764070511,
#   'energy': 213.8707896387948,
#   'zenith': 1.4318399988477766,
#   'oneweight': 28337138.31774631,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.3806589543819427,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_3631_origidx_30_RF22.mp4': {'event': 3631,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 4.476283720578067e-05,
#   'pred_cascade': 9.348632011096925e-05,
#   'pred_tgtrack': 0.9434282183647156,
#   'pred_starttrack': 0.0515952855348587,
#   'pred_stoptrack': 0.0048382310196757,
#   'energy': 69854.39439763768,
#   'zenith': 1.6347788292922607,
#   'oneweight': 554819126845109.1,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9434282183647156,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_20214_origidx_16_RF22.mp4': {'event': 20214,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 2.528264531065361e-08,
#   'pred_cascade': 1.5021179933683015e-05,
#   'pred_tgtrack': 1.4882318737363676e-06,
#   'pred_starttrack': 0.9999802112579346,
#   'pred_stoptrack': 3.386236130609177e-06,
#   'energy': 1513.9396476964362,
#   'zenith': 1.5571585480582364,
#   'oneweight': 26164060467.841194,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.9999802112579346,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_23416_origidx_28_RF22.mp4': {'event': 23416,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0382381901144981,
#   'pred_cascade': 0.0138063039630651,
#   'pred_tgtrack': 0.076717235147953,
#   'pred_starttrack': 0.0083940476179122,
#   'pred_stoptrack': 0.8628442287445068,
#   'energy': 9093.219142184447,
#   'zenith': 0.2589960930145009,
#   'oneweight': 528317904389.9484,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.8628442287445068,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_11275_origidx_10_RF22.mp4': {'event': 11275,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0001877211761893,
#   'pred_cascade': 1.6671834600856528e-05,
#   'pred_tgtrack': 0.9392932057380676,
#   'pred_starttrack': 0.053162083029747,
#   'pred_stoptrack': 0.0073403380811214,
#   'energy': 2730.4649724745027,
#   'zenith': 1.5635649863575098,
#   'oneweight': 139742141097.87726,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9392932057380676,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_27237_origidx_4_RF22.mp4': {'event': 27237,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.4319263696670532,
#   'pred_cascade': 0.0483042299747467,
#   'pred_tgtrack': 0.3544075787067413,
#   'pred_starttrack': 0.0313057005405426,
#   'pred_stoptrack': 0.1340561211109161,
#   'energy': 8427.745817593535,
#   'zenith': 1.2099783261009682,
#   'oneweight': 944982670241.6238,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.4319263696670532,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_4724_origidx_11_RF22.mp4': {'event': 4724,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0016114870086312,
#   'pred_cascade': 0.0008554633823223,
#   'pred_tgtrack': 0.9316499829292296,
#   'pred_starttrack': 0.0471635647118091,
#   'pred_stoptrack': 0.018719533458352,
#   'energy': 34618.00948883448,
#   'zenith': 1.3886110556325446,
#   'oneweight': 49514477389464.92,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9316499829292296,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_11755_origidx_24_RF22.mp4': {'event': 11755,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.1365271061658859,
#   'pred_cascade': 0.005335219670087,
#   'pred_tgtrack': 0.8303576111793518,
#   'pred_starttrack': 0.0058770421892404,
#   'pred_stoptrack': 0.0219031013548374,
#   'energy': 8753.290315110155,
#   'zenith': 0.797708965998991,
#   'oneweight': 831911170909.7202,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.8303576111793518,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_27535_origidx_11_RF22.mp4': {'event': 27535,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0002001753600779,
#   'pred_cascade': 5.509029870154336e-05,
#   'pred_tgtrack': 0.9854082465171814,
#   'pred_starttrack': 0.0106031885370612,
#   'pred_stoptrack': 0.0037333024665713,
#   'energy': 69658.6268800972,
#   'zenith': 1.4853760418368394,
#   'oneweight': 456224303057289.94,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9854082465171814,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_20456_origidx_20_RF22.mp4': {'event': 20456,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 0.0593086518347263,
#   'pred_cascade': 0.403297871351242,
#   'pred_tgtrack': 0.0006115293363109,
#   'pred_starttrack': 0.4703995585441589,
#   'pred_stoptrack': 0.0663823932409286,
#   'energy': 148.04497036647393,
#   'zenith': 0.7335628119944605,
#   'oneweight': 44617411.48161674,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.4703995585441589,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_23199_origidx_23_RF22.mp4': {'event': 23199,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 2.9769953169278546e-10,
#   'pred_cascade': 9.666364348959178e-07,
#   'pred_tgtrack': 6.464478701673215e-06,
#   'pred_starttrack': 0.9999924898147584,
#   'pred_stoptrack': 7.73595729697263e-08,
#   'energy': 2428.380646792074,
#   'zenith': 1.5469532366273195,
#   'oneweight': 61276930656.3175,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.9999924898147584,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_16089_origidx_22_RF22.mp4': {'event': 16089,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0017372855218127,
#   'pred_cascade': 0.0002953106595668,
#   'pred_tgtrack': 0.9938417673110962,
#   'pred_starttrack': 0.0020126674789935,
#   'pred_stoptrack': 0.0021129802335053,
#   'energy': 186674.6296138068,
#   'zenith': 1.0263289739770562,
#   'oneweight': 1060414913830187.6,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9938417673110962,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_3476_origidx_24_RF22.mp4': {'event': 3476,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0389747098088264,
#   'pred_cascade': 0.011766217648983,
#   'pred_tgtrack': 0.9262012243270874,
#   'pred_starttrack': 0.0139241153374314,
#   'pred_stoptrack': 0.0091336658224463,
#   'energy': 3633.49223169342,
#   'zenith': 1.0874853086849128,
#   'oneweight': 99680276486.40388,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9262012243270874,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_23542_origidx_35_RF22.mp4': {'event': 23542,
#   'run': 21971,
#   'truth_classification': 7,
#   'pred_skim': 0.5695101022720337,
#   'pred_cascade': 0.2387070953845977,
#   'pred_tgtrack': 0.0584997236728668,
#   'pred_starttrack': 0.1263390779495239,
#   'pred_stoptrack': 0.0069440463557839,
#   'energy': 68747.01356164021,
#   'zenith': 0.5017342426552803,
#   'oneweight': 67996113075678.3,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.5695101022720337,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_28593_origidx_5_RF22.mp4': {'event': 28593,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 0.0762768760323524,
#   'pred_cascade': 0.0020492251496762,
#   'pred_tgtrack': 0.0079050408676266,
#   'pred_starttrack': 0.8940568566322327,
#   'pred_stoptrack': 0.0197120830416679,
#   'energy': 495.4789477934475,
#   'zenith': 0.6865837748078684,
#   'oneweight': 1123077721.6739614,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.8940568566322327,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_29990_origidx_8_RF22.mp4': {'event': 29990,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.9981648325920104,
#   'pred_cascade': 1.1192503279744417e-06,
#   'pred_tgtrack': 0.0004116571799386,
#   'pred_starttrack': 1.0383374501543584e-05,
#   'pred_stoptrack': 0.001412006909959,
#   'energy': 51805.44281453166,
#   'zenith': 0.7583517536937999,
#   'oneweight': 56418767691892.44,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9981648325920104,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_9906_origidx_14_RF22.mp4': {'event': 9906,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.1087723597884178,
#   'pred_cascade': 0.0284390337765216,
#   'pred_tgtrack': 0.7796837687492371,
#   'pred_starttrack': 0.0101083973422646,
#   'pred_stoptrack': 0.0729964971542358,
#   'energy': 285989.9897710611,
#   'zenith': 2.3409636310281345,
#   'oneweight': 1302136444850008.2,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7796837687492371,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_18342_origidx_8_RF22.mp4': {'event': 18342,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 2.792594204947818e-05,
#   'pred_cascade': 3.026941044481646e-07,
#   'pred_tgtrack': 0.9999492168426514,
#   'pred_starttrack': 5.709014203603147e-07,
#   'pred_stoptrack': 2.188525650126394e-05,
#   'energy': 167357.85320952482,
#   'zenith': 0.70710003941896,
#   'oneweight': 645578428466142.0,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9999492168426514,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_21008_origidx_11_RF22.mp4': {'event': 21008,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.0309428665786981,
#   'pred_cascade': 0.0062652477063238,
#   'pred_tgtrack': 0.9480721950531006,
#   'pred_starttrack': 0.0061148595996201,
#   'pred_stoptrack': 0.0086048264056444,
#   'energy': 109.8056514588498,
#   'zenith': 1.588350576437152,
#   'oneweight': 7360745.258332799,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9480721950531006,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_3538_origidx_28_RF22.mp4': {'event': 3538,
#   'run': 21971,
#   'truth_classification': 7,
#   'pred_skim': 0.1161692216992378,
#   'pred_cascade': 0.0090392436832189,
#   'pred_tgtrack': 0.3582302927970886,
#   'pred_starttrack': 0.008292811922729,
#   'pred_stoptrack': 0.508268415927887,
#   'energy': 143.407899619904,
#   'zenith': 0.5393738692370038,
#   'oneweight': 21721199.46385117,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.508268415927887,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_18924_origidx_27_RF22.mp4': {'event': 18924,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.44462850689888,
#   'pred_cascade': 0.2132256031036377,
#   'pred_tgtrack': 0.0007126474520191,
#   'pred_starttrack': 0.2292517274618148,
#   'pred_stoptrack': 0.1121815219521522,
#   'energy': 165.27186358081136,
#   'zenith': 1.2638400763648008,
#   'oneweight': 27994193.25169073,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.44462850689888,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_11801_origidx_26_RF22.mp4': {'event': 11801,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.005269200541079,
#   'pred_cascade': 0.0032133399508893,
#   'pred_tgtrack': 0.8704943060874939,
#   'pred_starttrack': 0.0019435553112998,
#   'pred_stoptrack': 0.1190795749425888,
#   'energy': 662999.9649659735,
#   'zenith': 1.0009190760870252,
#   'oneweight': 6947423734556628.0,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.8704943060874939,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_8985_origidx_23_RF22.mp4': {'event': 8985,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 1.4109510226845146e-09,
#   'pred_cascade': 4.374606926704772e-11,
#   'pred_tgtrack': 0.999988317489624,
#   'pred_starttrack': 1.8965809545079537e-07,
#   'pred_stoptrack': 1.1482970876386387e-05,
#   'energy': 245250.50297225863,
#   'zenith': 1.696186421647499,
#   'oneweight': 8672084853989778.0,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.999988317489624,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_5042_origidx_19_RF22.mp4': {'event': 5042,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 1.0778175237646792e-05,
#   'pred_cascade': 4.285444674678729e-07,
#   'pred_tgtrack': 0.9449768662452698,
#   'pred_starttrack': 0.0001181054249173,
#   'pred_stoptrack': 0.054893858730793,
#   'energy': 11083.119680973625,
#   'zenith': 2.647701925776526,
#   'oneweight': 1469922659182.4812,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9449768662452698,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 13},
# ...
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_28597_origidx_6_RF22.mp4': {'event': 28597,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.1000623926520347,
#   'pred_cascade': 0.0003324772405903,
#   'pred_tgtrack': 0.8868386149406433,
#   'pred_starttrack': 0.0088820168748497,
#   'pred_stoptrack': 0.0038845755625516,
#   'energy': 87682.87751949906,
#   'zenith': 0.9002322503504772,
#   'oneweight': 212531443905234.38,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.8868386149406433,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_18582_origidx_14_RF22.mp4': {'event': 18582,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.3039384484291076,
#   'pred_cascade': 0.09016914665699,
#   'pred_tgtrack': 0.2494321167469024,
#   'pred_starttrack': 0.03280496224761,
#   'pred_stoptrack': 0.3236553370952606,
#   'energy': 108.00800227061865,
#   'zenith': 1.987909205817174,
#   'oneweight': 15366435.358745327,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.3236553370952606,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_8749_origidx_14_RF22.mp4': {'event': 8749,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 0.0323229469358921,
#   'pred_cascade': 0.0072197192348539,
#   'pred_tgtrack': 0.1772901564836502,
#   'pred_starttrack': 0.7203124761581421,
#   'pred_stoptrack': 0.0628546476364135,
#   'energy': 399.4333171275024,
#   'zenith': 2.168831882820012,
#   'oneweight': 413124342.745714,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.7203124761581421,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_8278_origidx_5_RF22.mp4': {'event': 8278,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0016304291784763,
#   'pred_cascade': 0.0004299151769373,
#   'pred_tgtrack': 0.986174702644348,
#   'pred_starttrack': 0.0082193296402692,
#   'pred_stoptrack': 0.0035456335172057,
#   'energy': 12154.273320396576,
#   'zenith': 0.6662420263251465,
#   'oneweight': 1562839059655.656,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.986174702644348,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_28855_origidx_15_RF22.mp4': {'event': 28855,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.2311452329158783,
#   'pred_cascade': 0.0644031316041946,
#   'pred_tgtrack': 0.5678281188011169,
#   'pred_starttrack': 0.0480009354650974,
#   'pred_stoptrack': 0.0886226147413253,
#   'energy': 476298.7521974908,
#   'zenith': 1.2749059828751226,
#   'oneweight': 5183425240666802.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5678281188011169,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_20887_origidx_9_RF22.mp4': {'event': 20887,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.7118877172470093,
#   'pred_cascade': 2.18074035274185e-07,
#   'pred_tgtrack': 0.2879108786582947,
#   'pred_starttrack': 3.114558467132156e-06,
#   'pred_stoptrack': 0.0001980290981009,
#   'energy': 558409.922197388,
#   'zenith': 0.9401750392231302,
#   'oneweight': 7405407643567707.0,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.7118877172470093,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_22879_origidx_7_RF22.mp4': {'event': 22879,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 0.0001955411134986,
#   'pred_cascade': 0.6769331097602844,
#   'pred_tgtrack': 4.7560784878442064e-05,
#   'pred_starttrack': 0.3215826153755188,
#   'pred_stoptrack': 0.0012411386705935,
#   'energy': 208.4856746112358,
#   'zenith': 0.2707016880149293,
#   'oneweight': 47338544.599988185,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.6769331097602844,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_11899_origidx_28_RF22.mp4': {'event': 11899,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0128792952746152,
#   'pred_cascade': 0.0047065690159797,
#   'pred_tgtrack': 0.9733853936195374,
#   'pred_starttrack': 0.0046169264242053,
#   'pred_stoptrack': 0.0044118277728557,
#   'energy': 14694.065463276738,
#   'zenith': 1.0087825901979273,
#   'oneweight': 5263766033278.936,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9733853936195374,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_5720_origidx_20_RF22.mp4': {'event': 5720,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.9998759031295776,
#   'pred_cascade': 5.933272095859365e-09,
#   'pred_tgtrack': 1.495141623308882e-05,
#   'pred_starttrack': 5.985580919798394e-09,
#   'pred_stoptrack': 0.0001091974772862,
#   'energy': 115447.58144078322,
#   'zenith': 0.6288088266646136,
#   'oneweight': 277862055413381.03,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9998759031295776,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_8881_origidx_20_RF22.mp4': {'event': 8881,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.1104328408837318,
#   'pred_cascade': 0.0325959920883178,
#   'pred_tgtrack': 0.5916889309883118,
#   'pred_starttrack': 0.020522279664874,
#   'pred_stoptrack': 0.2447599619626999,
#   'energy': 1490.3795946036855,
#   'zenith': 2.537029268207828,
#   'oneweight': 32638328827.23628,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5916889309883118,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_26370_origidx_9_RF22.mp4': {'event': 26370,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.1195222437381744,
#   'pred_cascade': 0.0487645231187343,
#   'pred_tgtrack': 0.5780633687973022,
#   'pred_starttrack': 0.0435587167739868,
#   'pred_stoptrack': 0.2100911736488342,
#   'energy': 307130.8953159612,
#   'zenith': 1.7912629025734512,
#   'oneweight': 1.6597698982444656e+16,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.5780633687973022,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_20835_origidx_8_RF22.mp4': {'event': 20835,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.001017641974613,
#   'pred_cascade': 2.158468305424321e-06,
#   'pred_tgtrack': 0.7151445150375366,
#   'pred_starttrack': 0.0005400474765338,
#   'pred_stoptrack': 0.2832956314086914,
#   'energy': 4907.406033870839,
#   'zenith': 1.785844887776151,
#   'oneweight': 808020716972.6638,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.7151445150375366,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_7200_origidx_19_RF22.mp4': {'event': 7200,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.617678701877594,
#   'pred_cascade': 0.0488826371729373,
#   'pred_tgtrack': 0.3024522662162781,
#   'pred_starttrack': 0.0291337687522172,
#   'pred_stoptrack': 0.0018526437925174,
#   'energy': 12190.69692117553,
#   'zenith': 0.8874336288595689,
#   'oneweight': 2935474201932.664,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.617678701877594,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_16025_origidx_21_RF22.mp4': {'event': 16025,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 2.552627220708814e-09,
#   'pred_cascade': 9.743766557490652e-12,
#   'pred_tgtrack': 0.9999481439590454,
#   'pred_starttrack': 1.93460382433841e-05,
#   'pred_stoptrack': 3.25727196468506e-05,
#   'energy': 83960.70403162365,
#   'zenith': 2.6190777570473163,
#   'oneweight': 971468211221876.0,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9999481439590454,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_19761_origidx_4_RF22.mp4': {'event': 19761,
#   'run': 21971,
#   'truth_classification': 7,
#   'pred_skim': 2.6467148927622475e-05,
#   'pred_cascade': 0.9206808805465698,
#   'pred_tgtrack': 0.000110443761514,
#   'pred_starttrack': 0.0786767452955246,
#   'pred_stoptrack': 0.0005055488436482,
#   'energy': 920.1299875934346,
#   'zenith': 1.7775985319600094,
#   'oneweight': 6870845836.049307,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9206808805465698,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_21538_origidx_30_RF22.mp4': {'event': 21538,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 1.6315878781369977e-07,
#   'pred_cascade': 1.6894245724596854e-10,
#   'pred_tgtrack': 0.9995290040969848,
#   'pred_starttrack': 0.0002760161587502,
#   'pred_stoptrack': 0.0001948957069544,
#   'energy': 150847.71471065373,
#   'zenith': 2.5762036783102604,
#   'oneweight': 108090658034166.9,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9995290040969848,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_18893_origidx_25_RF22.mp4': {'event': 18893,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.0134255876764655,
#   'pred_cascade': 0.0018509614747017,
#   'pred_tgtrack': 0.9805312752723694,
#   'pred_starttrack': 0.0015481888549402,
#   'pred_stoptrack': 0.0026440646033734,
#   'energy': 540.7992440703524,
#   'zenith': 0.5604966480439018,
#   'oneweight': 1232714573.992211,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9805312752723694,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_29988_origidx_7_RF22.mp4': {'event': 29988,
#   'run': 21971,
#   'truth_classification': 3,
#   'pred_skim': 3.36824705300387e-05,
#   'pred_cascade': 8.516875823261216e-05,
#   'pred_tgtrack': 0.1666634380817413,
#   'pred_starttrack': 0.7122777700424194,
#   'pred_stoptrack': 0.1209398657083511,
#   'energy': 758.777583543254,
#   'zenith': 1.7416301523077091,
#   'oneweight': 3885493360.524218,
#   'truth_classification_label': 'stopping_track',
#   'max_score_val': 0.7122777700424194,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_30730_origidx_8_RF22.mp4': {'event': 30730,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 7.864396320655942e-05,
#   'pred_cascade': 1.3655640941578897e-05,
#   'pred_tgtrack': 0.0005899183452129,
#   'pred_starttrack': 0.9993088245391846,
#   'pred_stoptrack': 8.97008430911228e-06,
#   'energy': 3998.518938838648,
#   'zenith': 0.9353312990822912,
#   'oneweight': 155409128965.8253,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.9993088245391846,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_11353_origidx_12_RF22.mp4': {'event': 11353,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.043271355330944,
#   'pred_cascade': 0.0227869469672441,
#   'pred_tgtrack': 0.2665154039859772,
#   'pred_starttrack': 0.6156126260757446,
#   'pred_stoptrack': 0.0518136844038963,
#   'energy': 8147.993379925518,
#   'zenith': 0.824687675923011,
#   'oneweight': 579340455400.9928,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.6156126260757446,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_4969_origidx_14_RF22.mp4': {'event': 4969,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0847478359937667,
#   'pred_cascade': 0.0253005642443895,
#   'pred_tgtrack': 0.7524827718734741,
#   'pred_starttrack': 0.0977562963962555,
#   'pred_stoptrack': 0.0397125743329525,
#   'energy': 15446.707798239047,
#   'zenith': 1.2518560921095787,
#   'oneweight': 4464292131633.499,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.7524827718734741,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_28862_origidx_17_RF22.mp4': {'event': 28862,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.2142803370952606,
#   'pred_cascade': 0.0346891917288303,
#   'pred_tgtrack': 0.6615740656852722,
#   'pred_starttrack': 0.0207767225801944,
#   'pred_stoptrack': 0.0686797425150871,
#   'energy': 1719.63841362353,
#   'zenith': 0.8259554602268536,
#   'oneweight': 21045677599.622364,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.6615740656852722,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_30727_origidx_7_RF22.mp4': {'event': 30727,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 1.5006250464466578e-07,
#   'pred_cascade': 1.0409583195425396e-09,
#   'pred_tgtrack': 0.9997792840003968,
#   'pred_starttrack': 2.1208625184954144e-06,
#   'pred_stoptrack': 0.0002185174525948,
#   'energy': 35595.19983741107,
#   'zenith': 2.278911473644545,
#   'oneweight': 107919393759089.05,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9997792840003968,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000002/compressed_run_21971_event_11040_origidx_5_RF22.mp4': {'event': 11040,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.9999727010726928,
#   'pred_cascade': 4.534124897759284e-08,
#   'pred_tgtrack': 7.795347300998401e-06,
#   'pred_starttrack': 1.0531886800890788e-05,
#   'pred_stoptrack': 8.92665957508143e-06,
#   'energy': 459555.2753058612,
#   'zenith': 1.0853524705573865,
#   'oneweight': 7571253566276563.0,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9999727010726928,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23}}

# %%
make_subject_set('numu_run_21971_subrun_000002_phase2')
# Out:
# Subject Set Name: numu_run_21971_subrun_000002_phase2
# Subject Set ID: 112425
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>]

# %%
uploader(compressed_path,numu_csv,112425)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:468: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   dict_manifest = s3.to_dict('dict')
# Confirm if subject set 112425 is listed below.
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>]
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>]
# Number of times loop has ran: 1
# Number of times loop has ran: 2
# Number of times loop has ran: 3
# Number of times loop has ran: 4
# Number of times loop has ran: 5
# Number of times loop has ran: 6
# Number of times loop has ran: 7
# Number of times loop has ran: 8
# Number of times loop has ran: 9
# Number of times loop has ran: 10
# Number of times loop has ran: 11
# Number of times loop has ran: 12
# Number of times loop has ran: 13
# Number of times loop has ran: 14
# Number of times loop has ran: 15
# Number of times loop has ran: 16
# Number of times loop has ran: 17
# Number of times loop has ran: 18
# Number of times loop has ran: 19
# Number of times loop has ran: 20
# Number of times loop has ran: 21
# Number of times loop has ran: 22
# Number of times loop has ran: 23
# Number of times loop has ran: 24
# Number of times loop has ran: 25
# Number of times loop has ran: 26
# Number of times loop has ran: 27
# Number of times loop has ran: 28
# Number of times loop has ran: 29
# Number of times loop has ran: 30
# Number of times loop has ran: 31
# Number of times loop has ran: 32
# Number of times loop has ran: 33
# Number of times loop has ran: 34
# Number of times loop has ran: 35
# Number of times loop has ran: 36
# Number of times loop has ran: 37
# Number of times loop has ran: 38
# Number of times loop has ran: 39
# Number of times loop has ran: 40
# Number of times loop has ran: 41
# Number of times loop has ran: 42
# Number of times loop has ran: 43
# Number of times loop has ran: 44
# Number of times loop has ran: 45
# Number of times loop has ran: 46
# Number of times loop has ran: 47
# Number of times loop has ran: 48
# Number of times loop has ran: 49
# Number of times loop has ran: 50
# Number of times loop has ran: 51
# Number of times loop has ran: 52
# Number of times loop has ran: 53
# Number of times loop has ran: 54
# Number of times loop has ran: 55
# Number of times loop has ran: 56
# Number of times loop has ran: 57
# Number of times loop has ran: 58
# Number of times loop has ran: 59
# Number of times loop has ran: 60
# Number of times loop has ran: 61
# Number of times loop has ran: 62
# Number of times loop has ran: 63
# Number of times loop has ran: 64
# Number of times loop has ran: 65
# Number of times loop has ran: 66
# Number of times loop has ran: 67
# Number of times loop has ran: 68
# Number of times loop has ran: 69
# Number of times loop has ran: 70
# Number of times loop has ran: 71
# Number of times loop has ran: 72
# Number of times loop has ran: 73
# Number of times loop has ran: 74
# Number of times loop has ran: 75
# Number of times loop has ran: 76
# Number of times loop has ran: 77
# Number of times loop has ran: 78
# Number of times loop has ran: 79
# Number of times loop has ran: 80
# Number of times loop has ran: 81
# Number of times loop has ran: 82
# Number of times loop has ran: 83
# Number of times loop has ran: 84
# Number of times loop has ran: 85
# Number of times loop has ran: 86
# Number of times loop has ran: 87
# Number of times loop has ran: 88
# Number of times loop has ran: 89
# Number of times loop has ran: 90
# Number of times loop has ran: 91
# Number of times loop has ran: 92
# Number of times loop has ran: 93
# Number of times loop has ran: 94
# Number of times loop has ran: 95
# Number of times loop has ran: 96
# Number of times loop has ran: 97
# Number of times loop has ran: 98
# Number of times loop has ran: 99
# Number of times loop has ran: 100
# Number of times loop has ran: 101
# Number of times loop has ran: 102
# Number of times loop has ran: 103
# Number of times loop has ran: 104
# Number of times loop has ran: 105
# Number of times loop has ran: 106
# Number of times loop has ran: 107
# Number of times loop has ran: 108
# Number of times loop has ran: 109
# Number of times loop has ran: 110
# Number of times loop has ran: 111
# Number of times loop has ran: 112
# Number of times loop has ran: 113
# Number of times loop has ran: 114
# Number of times loop has ran: 115
# Number of times loop has ran: 116
# Number of times loop has ran: 117
# Number of times loop has ran: 118
# Number of times loop has ran: 119
# Number of times loop has ran: 120
# Number of times loop has ran: 121
# Number of times loop has ran: 122
# Number of times loop has ran: 123
# Number of times loop has ran: 124
# Number of times loop has ran: 125
# Number of times loop has ran: 126
# Number of times loop has ran: 127
# Number of times loop has ran: 128
# Number of times loop has ran: 129
# Number of times loop has ran: 130
# Number of times loop has ran: 131
# Number of times loop has ran: 132
# Number of times loop has ran: 133
# Number of times loop has ran: 134
# Number of times loop has ran: 135
# Number of times loop has ran: 136
# Number of times loop has ran: 137
# Number of times loop has ran: 138
# Number of times loop has ran: 139
# Number of times loop has ran: 140
# Number of times loop has ran: 141
# Number of times loop has ran: 142
# Number of times loop has ran: 143
# Number of times loop has ran: 144
# Number of times loop has ran: 145
# Number of times loop has ran: 146
# Number of times loop has ran: 147
# Number of times loop has ran: 148
# Number of times loop has ran: 149
# Number of times loop has ran: 150
# Number of times loop has ran: 151
# Number of times loop has ran: 152
# Number of times loop has ran: 153
# Number of times loop has ran: 154
# Number of times loop has ran: 155
# Number of times loop has ran: 156
# Number of times loop has ran: 157
# Number of times loop has ran: 158
# Number of times loop has ran: 159
# Number of times loop has ran: 160
# Number of times loop has ran: 161
# Number of times loop has ran: 162
# Number of times loop has ran: 163
# Number of times loop has ran: 164
# Number of times loop has ran: 165
# Number of times loop has ran: 166
# Number of times loop has ran: 167
# Number of times loop has ran: 168
# Number of times loop has ran: 169
# Number of times loop has ran: 170
# Number of times loop has ran: 171
# Number of times loop has ran: 172
# Number of times loop has ran: 173
# Number of times loop has ran: 174
# Number of times loop has ran: 175
# Number of times loop has ran: 176
# Number of times loop has ran: 177
# Number of times loop has ran: 178
# Number of times loop has ran: 179
# Number of times loop has ran: 180
# Number of times loop has ran: 181
# Number of times loop has ran: 182
# Number of times loop has ran: 183
# Number of times loop has ran: 184
# Number of times loop has ran: 185
# Number of times loop has ran: 186
# Number of times loop has ran: 187
# Number of times loop has ran: 188
# Number of times loop has ran: 189
# Number of times loop has ran: 190
# Number of times loop has ran: 191
# Number of times loop has ran: 192
# Number of times loop has ran: 193
# Number of times loop has ran: 194
# Number of times loop has ran: 195
# Number of times loop has ran: 196
# Number of times loop has ran: 197
# Number of times loop has ran: 198
# Number of times loop has ran: 199
# Number of times loop has ran: 200
# Number of times loop has ran: 201
# Number of times loop has ran: 202
# Number of times loop has ran: 203
# Number of times loop has ran: 204
# Number of times loop has ran: 205
# Number of times loop has ran: 206
# Number of times loop has ran: 207
# Number of times loop has ran: 208
# Number of times loop has ran: 209
# Number of times loop has ran: 210
# Number of times loop has ran: 211
# Number of times loop has ran: 212
# Number of times loop has ran: 213
# Number of times loop has ran: 214
# Number of times loop has ran: 215
# Number of times loop has ran: 216
# Number of times loop has ran: 217
# Number of times loop has ran: 218
# Number of times loop has ran: 219
# Number of times loop has ran: 220
# Number of times loop has ran: 221
# Number of times loop has ran: 222
# Number of times loop has ran: 223
# Number of times loop has ran: 224
# Number of times loop has ran: 225
# Number of times loop has ran: 226
# Number of times loop has ran: 227
# Number of times loop has ran: 228
# Number of times loop has ran: 229
# Number of times loop has ran: 230
# Number of times loop has ran: 231
# Number of times loop has ran: 232
# Number of times loop has ran: 233
# Number of times loop has ran: 234
# Number of times loop has ran: 235
# Number of times loop has ran: 236
# Number of times loop has ran: 237
# Number of times loop has ran: 238
# Number of times loop has ran: 239
# Number of times loop has ran: 240
# Number of times loop has ran: 241
# Number of times loop has ran: 242
# Number of times loop has ran: 243
# Number of times loop has ran: 244
# Number of times loop has ran: 245
# Number of times loop has ran: 246
# Number of times loop has ran: 247
# Number of times loop has ran: 248
# Number of times loop has ran: 249
# Number of times loop has ran: 250
# Number of times loop has ran: 251
# Number of times loop has ran: 252
# Number of times loop has ran: 253
# Number of times loop has ran: 254
# Number of times loop has ran: 255
# Number of times loop has ran: 256
# Number of times loop has ran: 257
# Number of times loop has ran: 258
# Number of times loop has ran: 259
# Number of times loop has ran: 260
# Number of times loop has ran: 261
# Number of times loop has ran: 262
# Number of times loop has ran: 263
# Number of times loop has ran: 264
# Number of times loop has ran: 265
# Number of times loop has ran: 266
# Number of times loop has ran: 267
# Number of times loop has ran: 268
# Number of times loop has ran: 269
# Number of times loop has ran: 270
# Number of times loop has ran: 271
# Number of times loop has ran: 272
# Number of times loop has ran: 273
# Number of times loop has ran: 274
# Number of times loop has ran: 275
# Number of times loop has ran: 276
# Number of times loop has ran: 277
# Number of times loop has ran: 278
# Number of times loop has ran: 279
# Number of times loop has ran: 280
# Number of times loop has ran: 281
# Number of times loop has ran: 282
# Number of times loop has ran: 283
# Number of times loop has ran: 284
# Number of times loop has ran: 285
# Number of times loop has ran: 286
# Number of times loop has ran: 287
# Number of times loop has ran: 288
# Number of times loop has ran: 289
# Number of times loop has ran: 290
# Number of times loop has ran: 291
# Number of times loop has ran: 292
# Number of times loop has ran: 293
# Number of times loop has ran: 294
# Number of times loop has ran: 295
# Number of times loop has ran: 296
# Number of times loop has ran: 297
# Number of times loop has ran: 298
# Number of times loop has ran: 299
# Number of times loop has ran: 300
# Number of times loop has ran: 301
# Number of times loop has ran: 302
# Number of times loop has ran: 303
# Number of times loop has ran: 304
# Number of times loop has ran: 305
# Number of times loop has ran: 306
# Number of times loop has ran: 307
# Number of times loop has ran: 308
# Number of times loop has ran: 309
# Number of times loop has ran: 310
# Number of times loop has ran: 311
# Number of times loop has ran: 312
# Number of times loop has ran: 313
# Number of times loop has ran: 314
# Number of times loop has ran: 315
# Number of times loop has ran: 316
# Number of times loop has ran: 317
# Number of times loop has ran: 318
# Number of times loop has ran: 319
# Number of times loop has ran: 320
# Number of times loop has ran: 321
# Number of times loop has ran: 322
# Number of times loop has ran: 323
# Number of times loop has ran: 324
# Number of times loop has ran: 325
# Number of times loop has ran: 326
# Number of times loop has ran: 327
# Number of times loop has ran: 328
# Number of times loop has ran: 329
# Number of times loop has ran: 330
# Number of times loop has ran: 331
# Number of times loop has ran: 332
# Number of times loop has ran: 333
# Number of times loop has ran: 334
# Number of times loop has ran: 335
# Number of times loop has ran: 336
# Number of times loop has ran: 337
# Number of times loop has ran: 338
# Number of times loop has ran: 339
# Number of times loop has ran: 340
# Number of times loop has ran: 341
# Number of times loop has ran: 342
# Number of times loop has ran: 343
# Number of times loop has ran: 344
# Number of times loop has ran: 345
# Number of times loop has ran: 346
# Number of times loop has ran: 347
# Number of times loop has ran: 348
# Number of times loop has ran: 349
# Number of times loop has ran: 350
# Number of times loop has ran: 351
# Number of times loop has ran: 352
# Number of times loop has ran: 353
# Number of times loop has ran: 354
# Number of times loop has ran: 355
# Number of times loop has ran: 356
# Number of times loop has ran: 357
# Number of times loop has ran: 358
# Number of times loop has ran: 359
# Number of times loop has ran: 360
# Number of times loop has ran: 361
# Number of times loop has ran: 362
# Number of times loop has ran: 363
# Number of times loop has ran: 364
# Number of times loop has ran: 365
# Number of times loop has ran: 366
# Number of times loop has ran: 367
# Number of times loop has ran: 368
