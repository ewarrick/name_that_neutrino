# %% [markdown]
# # Phase 2: Subject Creation
#
# **Description:**
#
# This notebook is to act as the resulting summary file for the creation and upload of subjects for the IceCube Zooniverse project currently called *Name that Neutrino!*. The project is currently being maintained by Elizabeth Warrick (as of March 2023). In this notebook, we take the i3 file and run it through several filters. [note: describe more later].
#
# > Nu Type: NuE
#
# > Run: 22076
#
# > SubRun: 000873
#
# ### Summary Stats:
#
# To be filled in after completing process. Also need to figure out global variables.
#
# **Subject Set Name:**

# %%
#Imports

#My functions: 
from uniformenergydist_filter import *

#General:
import numpy as np
import sys
import os
import subprocess
import argparse
import csv
from tables import *
import pandas as pd
from matplotlib import pyplot as plt
import h5py

#Zooniverse:
from panoptes_client import Panoptes, Project, SubjectSet, Subject
import magic
import glob

#IceCube:
from icecube.icetray import I3Units
import icecube.MuonGun
from icecube import dataio, dataclasses, icetray, MuonGun
from I3Tray import *
from icecube.hdfwriter import I3HDFWriter
from mc_labeler import MCLabeler #make sure that mc_labeler script is in current directory.

# %%
#Specify file paths:

#Initial I3 File:
nue = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst'

#Desired output directory. Note that creation of this directory is not yet coded and is done manually. 
phase1_dir = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/'

# %%
#Run Filter 1 to label MC truth.
filter1(nue,phase1_dir)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/mc_labeler.py:523: UserWarning: Couldn't find OMKey in MCPESeriesMap
#   warnings.warn("Couldn't find OMKey in MCPESeriesMap")

# %% [markdown]
# Note that the above cell might return an "exception" warning that the *MCPESeriesMap could not be found*. I am unsure why it does that because when I check the i3 file in dataio-shovel, I see the specified mc_pid_series_map (look at mc_labeler.py for exact name of specified key). The resulting file size should be around 400 MB.

# %%
#Path of hdf from above filter.
nue_hdf = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/\
Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst.hd5'

# %%
#Run uniformenergy_events function which requires hdf from filter 1, 
#number of bins, size of each random choice, and a random seed. 

uniformenergy_events(nue_hdf,25,15,12,subrun = True)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:177: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['binned_log10E'] = pd.cut(x = np.log10(df_filtered['energy']), bins = bins, labels = labels, include_lowest = True) #might throw an error?
# Number of Bins: 25
# Number of Events per Bin: 15
# Total Number of Events: 375
# Initial Number of Events: 2521
# Number of Events after filtering: 2457
# Please input subrun number:
# 000873

# %% [markdown]
# The above function throws another warning about pd.cut, currently that is not a problem but I don't know if a new version of pandas will allow this.

# %%
#Path to Random Events CSV
nue_csv = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/random_events_uniform_energy_distrib_22067_000873.csv'

# %%
#Run event_characterization_plots function whick makes some quick 
#plots to get an idea of what data you're dealing with.
#Note that I want to update the plot types, maybe make a 2D histogram as Mike K suggested. 
#For truth labels, check out enums.py or in the .py file that holds the functions.

event_characterization_plots(nue_csv)

# %% [markdown]
# Now that we have the events for this phase chosen, we run the second filter to pick out only those events.

# %%
#Path to i3 file from filter1 with MC truth labels. 
nue_filter1 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst'

# %%
#Run function to perform second filter which passes through only selected event IDs chosen from 
#the uniformenergy_events function. 
filter2(nue_filter1,phase1_dir,nue_csv)

# %%
#Path to i3 file from filter 2 that holds only specified events. 
nue_filter2 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst'

# %%
#Run function to perform third filter, which returns only the DAQ frames of the specified events.
#DAQ only file is then split up into many smaller i3 files since SteamShovel can't handle making videos of large
#i3 files at one time. Size limit is approx 2E6 MB (? unsure of units)
filter3(nue_filter2,22067_000873,phase1_dir)

# %%
#Path to NuMu Daq Only folder
nue_daq = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000873/'

# %%
get_steamshovel(nue_daq,22067000873)
# Out:
# List of files:
# ['/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000873/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000873/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000873/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000873/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000873/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000873/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000873/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000873/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000873/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000873/daq_only-0009_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst']
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000873/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000873/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000873/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000873/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000873/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000873/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000873/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000873/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000873/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000873/daq_only-0009_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000873.i3.zst

# %% [markdown]
# Ideas for Compression:
# - Use GUI to add files to queue and send to one compression folder.
# - Add a subprocess line in movie script to compress the video after making it and direct it to save in the compression folder.

# %%
compressed_path = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/'

# %% [markdown]
# Can't get manifest yet since some subjects are missing and lining it up won't work.

# %%
get_manifest(compressed_path, nue_csv)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:418: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   dict_manifest = s3.to_dict('dict')
# {'/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_4849_origidx_19_RF22.mp4': {'event': 4849,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999995231628418,
#   'pred_cascade': 4.564133959661376e-09,
#   'pred_tgtrack': 1.9601577605499187e-06,
#   'pred_starttrack': 3.385174238701439e-07,
#   'pred_stoptrack': 2.465505758664221e-06,
#   'energy': 166807.94866072098,
#   'zenith': 0.9560591856202048,
#   'oneweight': 204996705296513.44,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999995231628418,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_4672_origidx_12_RF22.mp4': {'event': 4672,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0001285729958908,
#   'pred_cascade': 0.9807398319244384,
#   'pred_tgtrack': 8.846579476085026e-06,
#   'pred_starttrack': 0.0191152207553386,
#   'pred_stoptrack': 7.506504971388495e-06,
#   'energy': 1873.021292949234,
#   'zenith': 1.406568715286204,
#   'oneweight': 32283647880.121014,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9807398319244384,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_2056_origidx_25_RF22.mp4': {'event': 2056,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999995231628418,
#   'pred_cascade': 1.3744043880423162e-12,
#   'pred_tgtrack': 1.770679318724433e-06,
#   'pred_starttrack': 1.294547524732792e-10,
#   'pred_stoptrack': 2.9654147510882467e-06,
#   'energy': 747277.1653658526,
#   'zenith': 1.5616248883381676,
#   'oneweight': 4330430707068825.5,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999995231628418,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_2840_origidx_11_RF22.mp4': {'event': 2840,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0002359390055062,
#   'pred_cascade': 0.8939902186393738,
#   'pred_tgtrack': 0.0118220839649438,
#   'pred_starttrack': 0.093658410012722,
#   'pred_stoptrack': 0.0002932650968432,
#   'energy': 6955.604641983886,
#   'zenith': 1.869058466128155,
#   'oneweight': 1394044557835.5498,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8939902186393738,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_1737_origidx_14_RF22.mp4': {'event': 1737,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9998921155929564,
#   'pred_cascade': 2.3488178158004303e-06,
#   'pred_tgtrack': 3.750594487428316e-06,
#   'pred_starttrack': 7.400577032967703e-06,
#   'pred_stoptrack': 9.434107050765306e-05,
#   'energy': 125810.12312280187,
#   'zenith': 1.6408853863904125,
#   'oneweight': 106069569670097.77,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9998921155929564,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_2069_origidx_26_RF22.mp4': {'event': 2069,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4145147204399109,
#   'pred_cascade': 0.0490061789751052,
#   'pred_tgtrack': 0.2612481117248535,
#   'pred_starttrack': 0.1721910387277603,
#   'pred_stoptrack': 0.1030400022864341,
#   'energy': 264570.22892602603,
#   'zenith': 1.9500679763162083,
#   'oneweight': 75258498095055.17,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4145147204399109,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_1928_origidx_20_RF22.mp4': {'event': 1928,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9982759952545166,
#   'pred_cascade': 9.012746318148857e-07,
#   'pred_tgtrack': 0.0016259304247796,
#   'pred_starttrack': 4.5082234123583486e-07,
#   'pred_stoptrack': 9.660859359428288e-05,
#   'energy': 80024.31728469951,
#   'zenith': 1.3470205676756526,
#   'oneweight': 50275965944484.5,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9982759952545166,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_4515_origidx_8_RF22.mp4': {'event': 4515,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0001681826397543,
#   'pred_cascade': 0.9772703051567078,
#   'pred_tgtrack': 2.8651803152257566e-10,
#   'pred_starttrack': 0.0225611180067062,
#   'pred_stoptrack': 3.597326099225029e-07,
#   'energy': 75579.91551421653,
#   'zenith': 1.625983265768377,
#   'oneweight': 47751264479877.695,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9772703051567078,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_3249_origidx_4_RF22.mp4': {'event': 3249,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9374924898147584,
#   'pred_cascade': 0.0277739707380533,
#   'pred_tgtrack': 0.0004798086592927,
#   'pred_starttrack': 0.0339311137795448,
#   'pred_stoptrack': 0.0003226291155442,
#   'energy': 6052.888020914766,
#   'zenith': 1.756269485642932,
#   'oneweight': 209708062596.0429,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9374924898147584,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_1432_origidx_6_RF22.mp4': {'event': 1432,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.0002919961698353,
#   'pred_cascade': 0.6893973350524902,
#   'pred_tgtrack': 6.700864469166845e-05,
#   'pred_starttrack': 0.3099028468132019,
#   'pred_stoptrack': 0.0003407891781534,
#   'energy': 1150.5607465059463,
#   'zenith': 0.4524414845401138,
#   'oneweight': 4592049107.700659,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.6893973350524902,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_67_origidx_7_RF22.mp4': {'event': 67,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2344380915164947,
#   'pred_cascade': 0.0210718568414449,
#   'pred_tgtrack': 0.039041057229042,
#   'pred_starttrack': 0.2692473530769348,
#   'pred_stoptrack': 0.4362016022205353,
#   'energy': 14909.265056042635,
#   'zenith': 0.4820962006818353,
#   'oneweight': 2115402939750.1904,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4362016022205353,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_918_origidx_6_RF22.mp4': {'event': 918,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1383263617753982,
#   'pred_cascade': 0.0385551489889621,
#   'pred_tgtrack': 0.0033163903281092,
#   'pred_starttrack': 0.1646226942539215,
#   'pred_stoptrack': 0.6551794409751892,
#   'energy': 59021.48461376708,
#   'zenith': 0.8138471359155749,
#   'oneweight': 41542914443667.74,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6551794409751892,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_8602_origidx_6_RF22.mp4': {'event': 8602,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0005296518793329,
#   'pred_cascade': 0.8746364712715149,
#   'pred_tgtrack': 3.3156320569105446e-05,
#   'pred_starttrack': 0.1231553852558136,
#   'pred_stoptrack': 0.0016452592099085,
#   'energy': 745.5339283064004,
#   'zenith': 2.0509213018034256,
#   'oneweight': 1683440613.076385,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8746364712715149,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_5996_origidx_9_RF22.mp4': {'event': 5996,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 1.0144711268367246e-05,
#   'pred_cascade': 0.9776188135147096,
#   'pred_tgtrack': 1.952030856955389e-07,
#   'pred_starttrack': 0.0223558228462934,
#   'pred_stoptrack': 1.5005513887444977e-05,
#   'energy': 39958.73098752533,
#   'zenith': 1.0586882044804595,
#   'oneweight': 16197446707762.88,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9776188135147096,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_165_origidx_10_RF22.mp4': {'event': 165,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.5843526721000671,
#   'pred_cascade': 0.4000265002250671,
#   'pred_tgtrack': 2.9367924980761018e-06,
#   'pred_starttrack': 0.0037459642626345,
#   'pred_stoptrack': 0.0118718920275568,
#   'energy': 1979.417031291652,
#   'zenith': 2.1320133441159426,
#   'oneweight': 44156052327.06768,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.5843526721000671,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_1758_origidx_16_RF22.mp4': {'event': 1758,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.7491177916526794,
#   'pred_cascade': 0.1491700261831283,
#   'pred_tgtrack': 0.0322842821478843,
#   'pred_starttrack': 0.0287016760557889,
#   'pred_stoptrack': 0.0407261438667774,
#   'energy': 1640.9089418402525,
#   'zenith': 1.487601107202882,
#   'oneweight': 20793474873.76693,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7491177916526794,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_3142_origidx_16_RF22.mp4': {'event': 3142,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1695501208305359,
#   'pred_cascade': 0.0017872275784611,
#   'pred_tgtrack': 0.6630449891090393,
#   'pred_starttrack': 0.0028962159994989,
#   'pred_stoptrack': 0.1627213656902313,
#   'energy': 4111.816258469868,
#   'zenith': 1.5877795910221637,
#   'oneweight': 75267185116.30933,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6630449891090393,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_4984_origidx_21_RF22.mp4': {'event': 4984,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2291779071092605,
#   'pred_cascade': 0.0039121019653975,
#   'pred_tgtrack': 0.6842917203903198,
#   'pred_starttrack': 0.0630835220217704,
#   'pred_stoptrack': 0.0195348020642995,
#   'energy': 22424.412178760653,
#   'zenith': 2.4502698356250003,
#   'oneweight': 32681166596163.152,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6842917203903198,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_3404_origidx_5_RF22.mp4': {'event': 3404,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.995912492275238,
#   'pred_cascade': 0.0006353789940476,
#   'pred_tgtrack': 0.0008053570054471,
#   'pred_starttrack': 0.0009336319053545,
#   'pred_stoptrack': 0.0017130833584815,
#   'energy': 18496.38766330836,
#   'zenith': 1.4518056430948412,
#   'oneweight': 2397752985463.462,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.995912492275238,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_6170_origidx_18_RF22.mp4': {'event': 6170,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.000181516923476,
#   'pred_cascade': 0.995470643043518,
#   'pred_tgtrack': 3.744009546835514e-09,
#   'pred_starttrack': 0.0043474580161273,
#   'pred_stoptrack': 3.5967181588603125e-07,
#   'energy': 151434.9477145243,
#   'zenith': 2.666348794873007,
#   'oneweight': 3944219797302.5854,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.995470643043518,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_6028_origidx_10_RF22.mp4': {'event': 6028,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.4943609833717346,
#   'pred_cascade': 0.4824185967445373,
#   'pred_tgtrack': 0.000158959213877,
#   'pred_starttrack': 0.0225595664232969,
#   'pred_stoptrack': 0.0005019197706133,
#   'energy': 606908.3725386009,
#   'zenith': 2.05358902456533,
#   'oneweight': 944480752333758.4,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.4943609833717346,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_1509_origidx_8_RF22.mp4': {'event': 1509,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999750316143036,
#   'pred_cascade': 2.9240811993958e-09,
#   'pred_tgtrack': 7.737503619864583e-05,
#   'pred_starttrack': 4.608480708157003e-09,
#   'pred_stoptrack': 0.0001722750894259,
#   'energy': 45794.88947424484,
#   'zenith': 2.2855154448861805,
#   'oneweight': 22223957338107.133,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999750316143036,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_1704_origidx_13_RF22.mp4': {'event': 1704,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 5.199405222811038e-06,
#   'pred_cascade': 0.9846327304840088,
#   'pred_tgtrack': 2.689754410312162e-07,
#   'pred_starttrack': 0.0153581397607922,
#   'pred_stoptrack': 3.78178606297297e-06,
#   'energy': 13328.78699468908,
#   'zenith': 0.9123639515627764,
#   'oneweight': 1335987939962.323,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9846327304840088,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_3128_origidx_15_RF22.mp4': {'event': 3128,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0001789294619811,
#   'pred_cascade': 0.9176762700080872,
#   'pred_tgtrack': 1.7046828304501105e-07,
#   'pred_starttrack': 0.0821421816945076,
#   'pred_stoptrack': 2.4438222681055777e-06,
#   'energy': 430584.55435753736,
#   'zenith': 1.9706562867230808,
#   'oneweight': 2044379241215826.5,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9176762700080872,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_8525_origidx_5_RF22.mp4': {'event': 8525,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9342751502990724,
#   'pred_cascade': 0.0285637509077787,
#   'pred_tgtrack': 0.0011220044689252,
#   'pred_starttrack': 0.008510023355484,
#   'pred_stoptrack': 0.0275291427969932,
#   'energy': 549.8796514742929,
#   'zenith': 1.8763371034040508,
#   'oneweight': 658090223.0901834,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9342751502990724,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_2783_origidx_7_RF22.mp4': {'event': 2783,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9965267777442932,
#   'pred_cascade': 6.4012173339733636e-09,
#   'pred_tgtrack': 0.0005332474247552,
#   'pred_starttrack': 1.0559098484463902e-08,
#   'pred_stoptrack': 0.0029399602208286,
#   'energy': 11126.580514525493,
#   'zenith': 1.780418623975297,
#   'oneweight': 672109530174.7374,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9965267777442932,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_2073_origidx_27_RF22.mp4': {'event': 2073,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9973596930503844,
#   'pred_cascade': 0.0001020995769067,
#   'pred_tgtrack': 0.0001753598626237,
#   'pred_starttrack': 0.000123231249745,
#   'pred_stoptrack': 0.0022395642008632,
#   'energy': 160886.75019503332,
#   'zenith': 2.7026782773077294,
#   'oneweight': 9543945348461.717,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9973596930503844,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_5873_origidx_5_RF22.mp4': {'event': 5873,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 4.011353667010553e-06,
#   'pred_cascade': 0.9977712631225586,
#   'pred_tgtrack': 3.0918849347472133e-07,
#   'pred_starttrack': 0.0022234893403947,
#   'pred_stoptrack': 9.470620057072664e-07,
#   'energy': 34952.83953246419,
#   'zenith': 0.9925323645911098,
#   'oneweight': 13537651146292.55,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9977712631225586,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_5958_origidx_7_RF22.mp4': {'event': 5958,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0001254135859198,
#   'pred_cascade': 0.9822454452514648,
#   'pred_tgtrack': 7.184813739513629e-07,
#   'pred_starttrack': 0.0176260899752378,
#   'pred_stoptrack': 2.3978291210369207e-06,
#   'energy': 49030.197015265134,
#   'zenith': 1.653396268784797,
#   'oneweight': 2950463609622.032,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9822454452514648,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_950_origidx_8_RF22.mp4': {'event': 950,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0004631823976524,
#   'pred_cascade': 0.785429060459137,
#   'pred_tgtrack': 0.001848739106208,
#   'pred_starttrack': 0.2116300761699676,
#   'pred_stoptrack': 0.0006289381999522,
#   'energy': 1316.334747599772,
#   'zenith': 1.0482586437914574,
#   'oneweight': 6111005315.24098,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.785429060459137,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_2828_origidx_9_RF22.mp4': {'event': 2828,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9997420907020568,
#   'pred_cascade': 1.1419321044314754e-09,
#   'pred_tgtrack': 8.983029692899436e-05,
#   'pred_starttrack': 5.420883297801993e-09,
#   'pred_stoptrack': 0.0001680307032074,
#   'energy': 409279.9452303508,
#   'zenith': 2.981080365680839,
#   'oneweight': 49593999707663.94,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9997420907020568,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_6151_origidx_16_RF22.mp4': {'event': 6151,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999817430973053,
#   'pred_cascade': 6.013263373461086e-06,
#   'pred_tgtrack': 7.722247391939163e-05,
#   'pred_starttrack': 8.005276322364807e-05,
#   'pred_stoptrack': 1.93630166904768e-05,
#   'energy': 83077.05066193167,
#   'zenith': 1.2345966465293834,
#   'oneweight': 65471925020861.69,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999817430973053,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_5042_origidx_24_RF22.mp4': {'event': 5042,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1232163161039352,
#   'pred_cascade': 0.0069981194101274,
#   'pred_tgtrack': 0.0028781972359865,
#   'pred_starttrack': 0.0148653462529182,
#   'pred_stoptrack': 0.8520419597625732,
#   'energy': 178.7793648775839,
#   'zenith': 1.0121576697115504,
#   'oneweight': 34928568.77560804,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8520419597625732,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_1800_origidx_17_RF22.mp4': {'event': 1800,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1521594077348709,
#   'pred_cascade': 0.0476474985480308,
#   'pred_tgtrack': 0.705625057220459,
#   'pred_starttrack': 0.0305918026715517,
#   'pred_stoptrack': 0.0639763548970222,
#   'energy': 164486.929934872,
#   'zenith': 1.5993430675088778,
#   'oneweight': 195223764101326.53,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.705625057220459,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_4804_origidx_18_RF22.mp4': {'event': 4804,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 5.613966095552314e-06,
#   'pred_cascade': 0.9974491000175476,
#   'pred_tgtrack': 5.0431172127218815e-08,
#   'pred_starttrack': 0.0025451048277318,
#   'pred_stoptrack': 1.596758636424056e-07,
#   'energy': 83445.67874511571,
#   'zenith': 0.7196777759292347,
#   'oneweight': 115293790803064.8,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9974491000175476,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_3227_origidx_19_RF22.mp4': {'event': 3227,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 3.070241234581772e-07,
#   'pred_cascade': 0.8231067061424255,
#   'pred_tgtrack': 1.7703985122352608e-07,
#   'pred_starttrack': 0.1768926531076431,
#   'pred_stoptrack': 2.060965726968789e-07,
#   'energy': 658601.8554597514,
#   'zenith': 0.2213413246615059,
#   'oneweight': 4287770392256369.5,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.8231067061424255,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_4747_origidx_15_RF22.mp4': {'event': 4747,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1954687237739563,
#   'pred_cascade': 0.0396925322711467,
#   'pred_tgtrack': 0.0020213953685015,
#   'pred_starttrack': 0.0255704838782548,
#   'pred_stoptrack': 0.7372468113899231,
#   'energy': 101.58133064595803,
#   'zenith': 2.008678955084217,
#   'oneweight': 406306.3654998172,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7372468113899231,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_6109_origidx_14_RF22.mp4': {'event': 6109,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.0001588918821653,
#   'pred_cascade': 0.7984810471534729,
#   'pred_tgtrack': 9.03975490018638e-07,
#   'pred_starttrack': 0.1999917477369308,
#   'pred_stoptrack': 0.0013674483634531,
#   'energy': 12406.617845581071,
#   'zenith': 2.7298295338848795,
#   'oneweight': 1263274059307.986,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.7984810471534729,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_5918_origidx_6_RF22.mp4': {'event': 5918,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999961256980896,
#   'pred_cascade': 3.7669021679676014e-08,
#   'pred_tgtrack': 1.3673884495801758e-06,
#   'pred_starttrack': 8.250631111650365e-08,
#   'pred_stoptrack': 3.729717718670145e-05,
#   'energy': 212427.6122836536,
#   'zenith': 2.4511846082168707,
#   'oneweight': 509105175995456.94,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999961256980896,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_6214_origidx_22_RF22.mp4': {'event': 6214,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.995969295501709,
#   'pred_cascade': 0.0004238651308696,
#   'pred_tgtrack': 0.0002345663961023,
#   'pred_starttrack': 0.000560738844797,
#   'pred_stoptrack': 0.0028114900924265,
#   'energy': 11211.95981670418,
#   'zenith': 1.7677660896691785,
#   'oneweight': 738878672185.9297,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.995969295501709,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_4402_origidx_5_RF22.mp4': {'event': 4402,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2123442143201828,
#   'pred_cascade': 0.5190209150314331,
#   'pred_tgtrack': 0.1476222276687622,
#   'pred_starttrack': 0.1101859360933303,
#   'pred_stoptrack': 0.0108266901224851,
#   'energy': 2068.400038312981,
#   'zenith': 1.963070815026518,
#   'oneweight': 15637153985.712507,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5190209150314331,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_4442_origidx_6_RF22.mp4': {'event': 4442,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 7.082455795170972e-06,
#   'pred_cascade': 0.2552394270896911,
#   'pred_tgtrack': 4.200800958642503e-06,
#   'pred_starttrack': 0.7447419762611389,
#   'pred_stoptrack': 7.385548542515607e-06,
#   'energy': 14528.25224267248,
#   'zenith': 1.48537660174051,
#   'oneweight': 1425256551521.62,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7447419762611389,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_937_origidx_7_RF22.mp4': {'event': 937,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4073929190635681,
#   'pred_cascade': 0.0720163509249687,
#   'pred_tgtrack': 0.1600059270858764,
#   'pred_starttrack': 0.0792336910963058,
#   'pred_stoptrack': 0.2813511490821838,
#   'energy': 112.86989586564528,
#   'zenith': 1.667221334152191,
#   'oneweight': 11898496.96462993,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4073929190635681,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_2759_origidx_6_RF22.mp4': {'event': 2759,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0066191051155328,
#   'pred_cascade': 0.5736044645309448,
#   'pred_tgtrack': 0.0446739569306373,
#   'pred_starttrack': 0.3659822642803192,
#   'pred_stoptrack': 0.0091202026233077,
#   'energy': 1675.1004703104068,
#   'zenith': 1.6050183620043132,
#   'oneweight': 21250620315.200996,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.5736044645309448,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_1521_origidx_9_RF22.mp4': {'event': 1521,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2526161670684814,
#   'pred_cascade': 0.0710348337888717,
#   'pred_tgtrack': 0.4900284111499786,
#   'pred_starttrack': 0.0703187957406044,
#   'pred_stoptrack': 0.1160018369555473,
#   'energy': 734.0514319917781,
#   'zenith': 2.035844786928045,
#   'oneweight': 1813299316.492205,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4900284111499786,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_4448_origidx_7_RF22.mp4': {'event': 4448,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2990582585334778,
#   'pred_cascade': 0.1580807566642761,
#   'pred_tgtrack': 0.2120155096054077,
#   'pred_starttrack': 0.228341057896614,
#   'pred_stoptrack': 0.1025044023990631,
#   'energy': 114937.37593147726,
#   'zenith': 1.582303578732396,
#   'oneweight': 1399718912418416.5,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.2990582585334778,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_1823_origidx_18_RF22.mp4': {'event': 1823,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 3.916112746082945e-06,
#   'pred_cascade': 0.9346444606781006,
#   'pred_tgtrack': 5.909164997319749e-07,
#   'pred_starttrack': 0.0653413906693458,
#   'pred_stoptrack': 9.728811164677609e-06,
#   'energy': 1147.507961893236,
#   'zenith': 1.30475459567325,
#   'oneweight': 4116113161.6944175,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9346444606781006,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_4699_origidx_14_RF22.mp4': {'event': 4699,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0581207349896431,
#   'pred_cascade': 0.0075475615449249,
#   'pred_tgtrack': 0.0710377097129821,
#   'pred_starttrack': 0.0061231204308569,
#   'pred_stoptrack': 0.8571709394454956,
#   'energy': 1488.1284290625465,
#   'zenith': 1.9699409496990727,
#   'oneweight': 13463063836.483171,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8571709394454956,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_1962_origidx_21_RF22.mp4': {'event': 1962,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0301309172064065,
#   'pred_cascade': 0.0051594702526926,
#   'pred_tgtrack': 0.9564275741577148,
#   'pred_starttrack': 0.0028609104920178,
#   'pred_stoptrack': 0.0054211691021919,
#   'energy': 1127.9563332130306,
#   'zenith': 1.7850224230869114,
#   'oneweight': 3064312503.809261,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9564275741577148,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_4697_origidx_13_RF22.mp4': {'event': 4697,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.0002284378424519,
#   'pred_cascade': 0.9863538146018982,
#   'pred_tgtrack': 5.471671449264193e-10,
#   'pred_starttrack': 0.0133837554603815,
#   'pred_stoptrack': 3.401680805836804e-05,
#   'energy': 8538.847615480172,
#   'zenith': 2.75986579644326,
#   'oneweight': 526705525933.43616,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9863538146018982,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_2837_origidx_10_RF22.mp4': {'event': 2837,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0329623594880104,
#   'pred_cascade': 0.0114646526053547,
#   'pred_tgtrack': 0.8282618522644043,
#   'pred_starttrack': 0.0072660096921026,
#   'pred_stoptrack': 0.1200451329350471,
#   'energy': 442.18407539486446,
#   'zenith': 1.519792270537273,
#   'oneweight': 675974860.942659,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8282618522644043,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_5167_origidx_5_RF22.mp4': {'event': 5167,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0006831914070062,
#   'pred_cascade': 0.9974411725997924,
#   'pred_tgtrack': 8.511734428395812e-09,
#   'pred_starttrack': 0.0018751249881461,
#   'pred_stoptrack': 4.91916239298007e-07,
#   'energy': 273677.1514129727,
#   'zenith': 2.509302111006791,
#   'oneweight': 173304476459535.8,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9974411725997924,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_2203_origidx_30_RF22.mp4': {'event': 2203,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.1636937856674194,
#   'pred_cascade': 0.717695415019989,
#   'pred_tgtrack': 0.0020942823030054,
#   'pred_starttrack': 0.0854770317673683,
#   'pred_stoptrack': 0.0310394205152988,
#   'energy': 3988.973874081141,
#   'zenith': 2.9023734046241305,
#   'oneweight': 77514956034.20844,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.717695415019989,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_6033_origidx_12_RF22.mp4': {'event': 6033,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9995439648628236,
#   'pred_cascade': 8.544019935996515e-10,
#   'pred_tgtrack': 0.0004113743489142,
#   'pred_starttrack': 5.174360495630026e-09,
#   'pred_stoptrack': 4.469853229238652e-05,
#   'energy': 470335.1082760745,
#   'zenith': 1.5673830690318065,
#   'oneweight': 1957424930430098.0,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9995439648628236,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_6044_origidx_13_RF22.mp4': {'event': 6044,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.7191570401191711,
#   'pred_cascade': 0.0039764964021742,
#   'pred_tgtrack': 0.2275078296661377,
#   'pred_starttrack': 0.0022725411690771,
#   'pred_stoptrack': 0.0470860786736011,
#   'energy': 412.1639021772446,
#   'zenith': 1.2323929025463245,
#   'oneweight': 384507130.2397893,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7191570401191711,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_4796_origidx_17_RF22.mp4': {'event': 4796,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.369982898235321,
#   'pred_cascade': 0.0861529856920242,
#   'pred_tgtrack': 0.2415789812803268,
#   'pred_starttrack': 0.1240140050649643,
#   'pred_stoptrack': 0.1782711148262024,
#   'energy': 474.8213101162735,
#   'zenith': 2.677939847736936,
#   'oneweight': 629473328.4976009,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.369982898235321,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_2110_origidx_28_RF22.mp4': {'event': 2110,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0176197607070207,
#   'pred_cascade': 0.0062626381404697,
#   'pred_tgtrack': 0.2079830318689346,
#   'pred_starttrack': 0.0030264188535511,
#   'pred_stoptrack': 0.7651081085205078,
#   'energy': 3827.4130600736994,
#   'zenith': 2.6239296682393345,
#   'oneweight': 92739506335.80128,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7651081085205078,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_8_origidx_5_RF22.mp4': {'event': 8,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0704093053936958,
#   'pred_cascade': 0.0221209321171045,
#   'pred_tgtrack': 0.8717374205589294,
#   'pred_starttrack': 0.0126130599528551,
#   'pred_stoptrack': 0.0231192279607057,
#   'energy': 2824.1071597595087,
#   'zenith': 1.4372617728960408,
#   'oneweight': 86285295915.50449,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8717374205589294,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_2119_origidx_29_RF22.mp4': {'event': 2119,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.99843567609787,
#   'pred_cascade': 1.7446775018470362e-05,
#   'pred_tgtrack': 0.000969000684563,
#   'pred_starttrack': 1.7553587895235978e-05,
#   'pred_stoptrack': 0.0005601854645647,
#   'energy': 8869.992053896898,
#   'zenith': 0.3255787737264883,
#   'oneweight': 536445634410.8445,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.99843567609787,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_6173_origidx_19_RF22.mp4': {'event': 6173,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999887943267822,
#   'pred_cascade': 1.765843293810576e-08,
#   'pred_tgtrack': 8.7081167521319e-07,
#   'pred_starttrack': 5.690350803888578e-07,
#   'pred_stoptrack': 9.75257898971904e-06,
#   'energy': 25095.29409608986,
#   'zenith': 1.6567897667218672,
#   'oneweight': 4749255837152.603,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999887943267822,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_8510_origidx_4_RF22.mp4': {'event': 8510,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9983347058296204,
#   'pred_cascade': 1.621081935354596e-07,
#   'pred_tgtrack': 0.0004874985606875,
#   'pred_starttrack': 5.208687170465964e-08,
#   'pred_stoptrack': 0.0011776462197303,
#   'energy': 39782.67140391708,
#   'zenith': 1.2328469296059312,
#   'oneweight': 15571618110046.766,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9983347058296204,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_2217_origidx_31_RF22.mp4': {'event': 2217,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.7882824977277778e-05,
#   'pred_cascade': 0.1251881569623947,
#   'pred_tgtrack': 0.0001309864164795,
#   'pred_starttrack': 0.8736951947212219,
#   'pred_stoptrack': 0.0009677344351075,
#   'energy': 197.17835113163108,
#   'zenith': 2.1668403278887998,
#   'oneweight': 67603286.34424184,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8736951947212219,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_2004_origidx_22_RF22.mp4': {'event': 2004,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1865132749080658,
#   'pred_cascade': 0.0440652817487716,
#   'pred_tgtrack': 0.51400226354599,
#   'pred_starttrack': 0.0180259365588426,
#   'pred_stoptrack': 0.2373932749032974,
#   'energy': 224.743009304864,
#   'zenith': 2.3317752140425454,
#   'oneweight': 41742412.90167257,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.51400226354599,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_3148_origidx_17_RF22.mp4': {'event': 3148,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9614534378051758,
#   'pred_cascade': 0.003067452693358,
#   'pred_tgtrack': 0.0001107327043428,
#   'pred_starttrack': 0.0071018412709236,
#   'pred_stoptrack': 0.0282666105777025,
#   'energy': 540.3141582928797,
#   'zenith': 0.3008124119180608,
#   'oneweight': 650328730.6695387,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9614534378051758,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_4598_origidx_10_RF22.mp4': {'event': 4598,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1691183745861053,
#   'pred_cascade': 0.0356111712753772,
#   'pred_tgtrack': 0.0077470317482948,
#   'pred_starttrack': 0.050391212105751,
#   'pred_stoptrack': 0.7371322512626648,
#   'energy': 6468.303270425483,
#   'zenith': 0.5250289591430506,
#   'oneweight': 306189019562.67206,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7371322512626648,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_6208_origidx_21_RF22.mp4': {'event': 6208,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0014879027148708,
#   'pred_cascade': 0.0006148334941826,
#   'pred_tgtrack': 0.7754873037338257,
#   'pred_starttrack': 0.0005790333379991,
#   'pred_stoptrack': 0.2218309044837951,
#   'energy': 106.38231239115704,
#   'zenith': 1.787896171396018,
#   'oneweight': 6650920.432803656,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7754873037338257,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_5866_origidx_4_RF22.mp4': {'event': 5866,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.6824764315970242e-05,
#   'pred_cascade': 0.9179237484931946,
#   'pred_tgtrack': 3.676121195894666e-05,
#   'pred_starttrack': 0.0820200145244598,
#   'pred_stoptrack': 2.613178367028013e-06,
#   'energy': 543878.172152604,
#   'zenith': 0.601252830348563,
#   'oneweight': 2503221308376803.5,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9179237484931946,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_4394_origidx_4_RF22.mp4': {'event': 4394,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999668598175048,
#   'pred_cascade': 5.402082670080688e-10,
#   'pred_tgtrack': 1.7477790379416549e-06,
#   'pred_starttrack': 2.7526290136137277e-09,
#   'pred_stoptrack': 3.135804217890836e-05,
#   'energy': 55473.30761044628,
#   'zenith': 1.536870891151486,
#   'oneweight': 25526714089194.887,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999668598175048,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_5027_origidx_22_RF22.mp4': {'event': 5027,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.1112322136759758,
#   'pred_cascade': 0.7700505256652832,
#   'pred_tgtrack': 4.806716970051639e-05,
#   'pred_starttrack': 0.1183139905333519,
#   'pred_stoptrack': 0.0003551357949618,
#   'energy': 12734.69253836798,
#   'zenith': 0.9461316006674118,
#   'oneweight': 1327768851874.994,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7700505256652832,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_6158_origidx_17_RF22.mp4': {'event': 6158,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0040423483587801,
#   'pred_cascade': 0.0014404864050447,
#   'pred_tgtrack': 0.9788975715637208,
#   'pred_starttrack': 0.0005473140045069,
#   'pred_stoptrack': 0.0150722377002239,
#   'energy': 3219.6124701175645,
#   'zenith': 1.2924395141726206,
#   'oneweight': 41529362693.24577,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9788975715637208,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_2798_origidx_8_RF22.mp4': {'event': 2798,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0073443907313048,
#   'pred_cascade': 0.0021995182614773,
#   'pred_tgtrack': 0.8150264620780945,
#   'pred_starttrack': 0.0013101390795782,
#   'pred_stoptrack': 0.1741194725036621,
#   'energy': 107.30748460068872,
#   'zenith': 2.2813762810722222,
#   'oneweight': 10149596.23264875,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8150264620780945,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_5033_origidx_23_RF22.mp4': {'event': 5033,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 4.701485067926114e-06,
#   'pred_cascade': 0.9965882301330566,
#   'pred_tgtrack': 6.023561649470821e-09,
#   'pred_starttrack': 0.003406937001273,
#   'pred_stoptrack': 6.436913935203847e-08,
#   'energy': 607525.4893996991,
#   'zenith': 1.975898238253761,
# ...
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_129_origidx_9_RF22.mp4': {'event': 129,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0806627348065376,
#   'pred_cascade': 0.0141150215640664,
#   'pred_tgtrack': 0.8787098526954651,
#   'pred_starttrack': 0.0161931738257408,
#   'pred_stoptrack': 0.0103193093091249,
#   'energy': 10834.937233544317,
#   'zenith': 2.461121238046029,
#   'oneweight': 625235897560.856,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8787098526954651,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_84_origidx_8_RF22.mp4': {'event': 84,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 3.932701019948581e-06,
#   'pred_cascade': 0.9234105944633484,
#   'pred_tgtrack': 1.2689849882008275e-06,
#   'pred_starttrack': 0.0765756592154502,
#   'pred_stoptrack': 8.446270840067882e-06,
#   'energy': 1311.8425042962765,
#   'zenith': 0.8376620832450914,
#   'oneweight': 8609594803.160765,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9234105944633484,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_1747_origidx_15_RF22.mp4': {'event': 1747,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.007069599814713,
#   'pred_cascade': 0.9302186965942384,
#   'pred_tgtrack': 0.000438029092038,
#   'pred_starttrack': 0.0603747442364692,
#   'pred_stoptrack': 0.0018988453084602,
#   'energy': 2305.513687586121,
#   'zenith': 0.5344196755867638,
#   'oneweight': 28195591531.98099,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9302186965942384,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_1906_origidx_19_RF22.mp4': {'event': 1906,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0367137789726257,
#   'pred_cascade': 0.0062638386152684,
#   'pred_tgtrack': 0.9286782145500184,
#   'pred_starttrack': 0.02215470187366,
#   'pred_stoptrack': 0.0061895344406366,
#   'energy': 793.5692656235188,
#   'zenith': 1.2735166534551488,
#   'oneweight': 2662176682.3777795,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9286782145500184,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_6032_origidx_11_RF22.mp4': {'event': 6032,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0005168925854377,
#   'pred_cascade': 0.0001817343581933,
#   'pred_tgtrack': 0.9492149353027344,
#   'pred_starttrack': 0.0002138853888027,
#   'pred_stoptrack': 0.0498726367950439,
#   'energy': 440907.6284991125,
#   'zenith': 0.8117126781288045,
#   'oneweight': 952908340093662.0,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9492149353027344,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_2026_origidx_24_RF22.mp4': {'event': 2026,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.5854700207710266,
#   'pred_cascade': 0.0997457131743431,
#   'pred_tgtrack': 0.0104230213910341,
#   'pred_starttrack': 0.1310756653547287,
#   'pred_stoptrack': 0.173285499215126,
#   'energy': 299.0078200388415,
#   'zenith': 1.3001210670985608,
#   'oneweight': 129405485.2462848,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5854700207710266,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_1413_origidx_5_RF22.mp4': {'event': 1413,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.195358857512474,
#   'pred_cascade': 0.0733372494578361,
#   'pred_tgtrack': 0.0484222583472728,
#   'pred_starttrack': 0.0746398121118545,
#   'pred_stoptrack': 0.6082417964935303,
#   'energy': 205.29399927062516,
#   'zenith': 0.8643283212169618,
#   'oneweight': 1671576.088276788,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6082417964935303,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_1550_origidx_10_RF22.mp4': {'event': 1550,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999512791633606,
#   'pred_cascade': 2.7829359169118103e-05,
#   'pred_tgtrack': 9.71683839452453e-05,
#   'pred_starttrack': 9.29621164686978e-05,
#   'pred_stoptrack': 0.0002691959962248,
#   'energy': 60154.05968626639,
#   'zenith': 1.5385452426919553,
#   'oneweight': 24913665963359.99,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999512791633606,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_3161_origidx_18_RF22.mp4': {'event': 3161,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9788091778755188,
#   'pred_cascade': 0.0009297226788476,
#   'pred_tgtrack': 0.0093273110687732,
#   'pred_starttrack': 0.0015395325608551,
#   'pred_stoptrack': 0.0093942284584045,
#   'energy': 7637.227928084706,
#   'zenith': 1.5944373035145722,
#   'oneweight': 246442364975.9888,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9788091778755188,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_2930_origidx_13_RF22.mp4': {'event': 2930,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 8.349075869773515e-06,
#   'pred_cascade': 0.9990074038505554,
#   'pred_tgtrack': 8.093015146926064e-09,
#   'pred_starttrack': 0.0009838150581344,
#   'pred_stoptrack': 4.782818336934724e-07,
#   'energy': 28633.48448544676,
#   'zenith': 1.5384300007642635,
#   'oneweight': 6031534333165.194,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9990074038505554,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_2618_origidx_4_RF22.mp4': {'event': 2618,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.1108936632808764e-05,
#   'pred_cascade': 0.997190535068512,
#   'pred_tgtrack': 5.874357000834607e-09,
#   'pred_starttrack': 0.0027978129219263,
#   'pred_stoptrack': 5.989270448480966e-07,
#   'energy': 116440.8610093212,
#   'zenith': 1.3835846745121196,
#   'oneweight': 134557555614104.98,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.997190535068512,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_5158_origidx_4_RF22.mp4': {'event': 5158,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 1.8456958059687167e-05,
#   'pred_cascade': 0.9476492404937744,
#   'pred_tgtrack': 3.918699803762138e-06,
#   'pred_starttrack': 0.0522757470607757,
#   'pred_stoptrack': 5.260115358396433e-05,
#   'energy': 8314.586606437002,
#   'zenith': 1.0309773350234015,
#   'oneweight': 610066414009.4213,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9476492404937744,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_917_origidx_5_RF22.mp4': {'event': 917,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999934434890748,
#   'pred_cascade': 5.360723420722025e-08,
#   'pred_tgtrack': 1.649677528803295e-06,
#   'pred_starttrack': 2.094758855264445e-07,
#   'pred_stoptrack': 4.6985569497337565e-06,
#   'energy': 942275.2549521975,
#   'zenith': 1.1611936222846024,
#   'oneweight': 8365392712688448.0,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999934434890748,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_4658_origidx_11_RF22.mp4': {'event': 4658,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999444484710692,
#   'pred_cascade': 3.2580629749645595e-08,
#   'pred_tgtrack': 7.944946446514223e-06,
#   'pred_starttrack': 3.0807163398094417e-07,
#   'pred_stoptrack': 4.736348637379706e-05,
#   'energy': 354831.09942892124,
#   'zenith': 2.5309965750919656,
#   'oneweight': 143755431700209.75,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999444484710692,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_6121_origidx_15_RF22.mp4': {'event': 6121,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3462581932544708,
#   'pred_cascade': 0.0888260379433631,
#   'pred_tgtrack': 0.3046876490116119,
#   'pred_starttrack': 0.0366925224661827,
#   'pred_stoptrack': 0.2235355675220489,
#   'energy': 4177.757526025108,
#   'zenith': 2.572191186524284,
#   'oneweight': 7135428087.604105,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3462581932544708,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_5168_origidx_6_RF22.mp4': {'event': 5168,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0886773392558097,
#   'pred_cascade': 0.0243782568722963,
#   'pred_tgtrack': 0.1416259706020355,
#   'pred_starttrack': 0.0132627198472619,
#   'pred_stoptrack': 0.7320557236671448,
#   'energy': 76791.90723405719,
#   'zenith': 2.010119191076848,
#   'oneweight': 651419092656286.6,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7320557236671448,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_5148_origidx_25_RF22.mp4': {'event': 5148,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9998974800109864,
#   'pred_cascade': 1.499515711600452e-08,
#   'pred_tgtrack': 6.851280340924859e-05,
#   'pred_starttrack': 3.1723381255233114e-08,
#   'pred_stoptrack': 3.394771192688495e-05,
#   'energy': 526619.5775807521,
#   'zenith': 2.0463648790480216,
#   'oneweight': 871474398558495.0,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9998974800109864,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_2742_origidx_5_RF22.mp4': {'event': 2742,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1658529192209243,
#   'pred_cascade': 0.0269023049622774,
#   'pred_tgtrack': 0.017857726663351,
#   'pred_starttrack': 0.0257450249046087,
#   'pred_stoptrack': 0.7636420726776123,
#   'energy': 4043.326056673869,
#   'zenith': 1.1295657290060277,
#   'oneweight': 96948696519.36205,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7636420726776123,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_43_origidx_6_RF22.mp4': {'event': 43,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.995384156703949,
#   'pred_cascade': 5.185690952203004e-06,
#   'pred_tgtrack': 0.0033387837465852,
#   'pred_starttrack': 7.489740255550714e-06,
#   'pred_stoptrack': 0.0012642706278711,
#   'energy': 331591.9013102,
#   'zenith': 1.5789453577320542,
#   'oneweight': 938513948274064.8,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.995384156703949,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_913_origidx_4_RF22.mp4': {'event': 913,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3193010091781616,
#   'pred_cascade': 0.0996596962213516,
#   'pred_tgtrack': 0.1932615488767624,
#   'pred_starttrack': 0.0443356744945049,
#   'pred_stoptrack': 0.3434421122074127,
#   'energy': 12537.564873214134,
#   'zenith': 1.1974675532208665,
#   'oneweight': 932694644038.7772,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3434421122074127,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_4873_origidx_20_RF22.mp4': {'event': 4873,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 3.4239703381899744e-05,
#   'pred_cascade': 0.9805712103843688,
#   'pred_tgtrack': 1.3119225741320406e-06,
#   'pred_starttrack': 0.0193415898829698,
#   'pred_stoptrack': 5.164694448467344e-05,
#   'energy': 1199.3154133349592,
#   'zenith': 1.2115674079953458,
#   'oneweight': 4449435606.51464,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9805712103843688,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_6206_origidx_20_RF22.mp4': {'event': 6206,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.933495332195889e-05,
#   'pred_cascade': 0.9482337832450868,
#   'pred_tgtrack': 3.384584715604433e-06,
#   'pred_starttrack': 0.0517171658575534,
#   'pred_stoptrack': 2.633556687214877e-05,
#   'energy': 2130.519079633094,
#   'zenith': 2.237539909947995,
#   'oneweight': 26338669520.90533,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9482337832450868,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_4792_origidx_16_RF22.mp4': {'event': 4792,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999943971633912,
#   'pred_cascade': 1.7821627854019972e-11,
#   'pred_tgtrack': 4.984987754141912e-06,
#   'pred_starttrack': 2.874083859794041e-09,
#   'pred_stoptrack': 5.749195679527475e-07,
#   'energy': 498989.8074613983,
#   'zenith': 2.223938581765041,
#   'oneweight': 3661671578694250.5,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999943971633912,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000873/compressed_run_22067_event_3126_origidx_14_RF22.mp4': {'event': 3126,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.5853816270828247,
#   'pred_cascade': 0.3835992217063904,
#   'pred_tgtrack': 0.0023556707892566,
#   'pred_starttrack': 0.0224373489618301,
#   'pred_stoptrack': 0.0062261181883513,
#   'energy': 2253.4294452045456,
#   'zenith': 1.2588795473729604,
#   'oneweight': 18758168000.65608,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5853816270828247,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 9}}

# %%
make_subject_set('nue_run_22067_subrun_000873_phase2')
# Out:
# Subject Set Name: nue_run_22067_subrun_000873_phase2
# Subject Set ID: 112501
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112498>, <SubjectSet 112473>, <SubjectSet 112487>, <SubjectSet 112492>, <SubjectSet 112467>, <SubjectSet 112481>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>, <SubjectSet 112464>]

# %%
uploader(compressed_path,nue_csv,112501)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:469: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   dict_manifest = s3.to_dict('dict')
# Confirm if subject set 112501 is listed below.
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112498>, <SubjectSet 112473>, <SubjectSet 112487>, <SubjectSet 112492>, <SubjectSet 112467>, <SubjectSet 112481>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>, <SubjectSet 112464>]
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112498>, <SubjectSet 112473>, <SubjectSet 112487>, <SubjectSet 112492>, <SubjectSet 112467>, <SubjectSet 112481>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>, <SubjectSet 112464>]
# Number of times loop has ran: 1
# Number of times loop has ran: 2
# Number of times loop has ran: 3
# Number of times loop has ran: 4
# Number of times loop has ran: 5
# Number of times loop has ran: 6
# Number of times loop has ran: 7
# Number of times loop has ran: 8
# Number of times loop has ran: 9
# Number of times loop has ran: 10
# Number of times loop has ran: 11
# Number of times loop has ran: 12
# Number of times loop has ran: 13
# Number of times loop has ran: 14
# Number of times loop has ran: 15
# Number of times loop has ran: 16
# Number of times loop has ran: 17
# Number of times loop has ran: 18
# Number of times loop has ran: 19
# Number of times loop has ran: 20
# Number of times loop has ran: 21
# Number of times loop has ran: 22
# Number of times loop has ran: 23
# Number of times loop has ran: 24
# Number of times loop has ran: 25
# Number of times loop has ran: 26
# Number of times loop has ran: 27
# Number of times loop has ran: 28
# Number of times loop has ran: 29
# Number of times loop has ran: 30
# Number of times loop has ran: 31
# Number of times loop has ran: 32
# Number of times loop has ran: 33
# Number of times loop has ran: 34
# Number of times loop has ran: 35
# Number of times loop has ran: 36
# Number of times loop has ran: 37
# Number of times loop has ran: 38
# Number of times loop has ran: 39
# Number of times loop has ran: 40
# Number of times loop has ran: 41
# Number of times loop has ran: 42
# Number of times loop has ran: 43
# Number of times loop has ran: 44
# Number of times loop has ran: 45
# Number of times loop has ran: 46
# Number of times loop has ran: 47
# Number of times loop has ran: 48
# Number of times loop has ran: 49
# Number of times loop has ran: 50
# Number of times loop has ran: 51
# Number of times loop has ran: 52
# Number of times loop has ran: 53
# Number of times loop has ran: 54
# Number of times loop has ran: 55
# Number of times loop has ran: 56
# Number of times loop has ran: 57
# Number of times loop has ran: 58
# Number of times loop has ran: 59
# Number of times loop has ran: 60
# Number of times loop has ran: 61
# Number of times loop has ran: 62
# Number of times loop has ran: 63
# Number of times loop has ran: 64
# Number of times loop has ran: 65
# Number of times loop has ran: 66
# Number of times loop has ran: 67
# Number of times loop has ran: 68
# Number of times loop has ran: 69
# Number of times loop has ran: 70
# Number of times loop has ran: 71
# Number of times loop has ran: 72
# Number of times loop has ran: 73
# Number of times loop has ran: 74
# Number of times loop has ran: 75
# Number of times loop has ran: 76
# Number of times loop has ran: 77
# Number of times loop has ran: 78
# Number of times loop has ran: 79
# Number of times loop has ran: 80
# Number of times loop has ran: 81
# Number of times loop has ran: 82
# Number of times loop has ran: 83
# Number of times loop has ran: 84
# Number of times loop has ran: 85
# Number of times loop has ran: 86
# Number of times loop has ran: 87
# Number of times loop has ran: 88
# Number of times loop has ran: 89
# Number of times loop has ran: 90
# Number of times loop has ran: 91
# Number of times loop has ran: 92
# Number of times loop has ran: 93
# Number of times loop has ran: 94
# Number of times loop has ran: 95
# Number of times loop has ran: 96
# Number of times loop has ran: 97
# Number of times loop has ran: 98
# Number of times loop has ran: 99
# Number of times loop has ran: 100
# Number of times loop has ran: 101
# Number of times loop has ran: 102
# Number of times loop has ran: 103
# Number of times loop has ran: 104
