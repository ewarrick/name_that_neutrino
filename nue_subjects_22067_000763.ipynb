# %% [markdown]
# # Phase 2: Subject Creation
#
# **Description:**
#
# This notebook is to act as the resulting summary file for the creation and upload of subjects for the IceCube Zooniverse project currently called *Name that Neutrino!*. The project is currently being maintained by Elizabeth Warrick (as of March 2023). In this notebook, we take the i3 file and run it through several filters. [note: describe more later].
#
# > Nu Type: NuE
#
# > Run: 22076
#
# > SubRun: 000763
#
# ### Summary Stats:
#
# To be filled in after completing process. Also need to figure out global variables.
#
# **Subject Set Name:**

# %%
#Imports

#My functions: 
from uniformenergydist_filter import *

#General:
import numpy as np
import sys
import os
import subprocess
import argparse
import csv
from tables import *
import pandas as pd
from matplotlib import pyplot as plt
import h5py

#Zooniverse:
from panoptes_client import Panoptes, Project, SubjectSet, Subject
import magic
import glob

#IceCube:
from icecube.icetray import I3Units
import icecube.MuonGun
from icecube import dataio, dataclasses, icetray, MuonGun
from I3Tray import *
from icecube.hdfwriter import I3HDFWriter
from mc_labeler import MCLabeler #make sure that mc_labeler script is in current directory.

# %%
#Specify file paths:

#Initial I3 File:
nue = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/classifier_rehyd_DST_IC86.2020_NuE.022067.000763.i3.zst'

#Desired output directory. Note that creation of this directory is not yet coded and is done manually. 
phase1_dir = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/'

# %%
#Run Filter 1 to label MC truth.
filter1(nue,phase1_dir)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/mc_labeler.py:523: UserWarning: Couldn't find OMKey in MCPESeriesMap
#   warnings.warn("Couldn't find OMKey in MCPESeriesMap")

# %% [markdown]
# Note that the above cell might return an "exception" warning that the *MCPESeriesMap could not be found*. I am unsure why it does that because when I check the i3 file in dataio-shovel, I see the specified mc_pid_series_map (look at mc_labeler.py for exact name of specified key). The resulting file size should be around 400 MB.

# %%
#Path of hdf from above filter.
nue_hdf = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/\
Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000763.i3.zst.hd5'

# %%
#Run uniformenergy_events function which requires hdf from filter 1, 
#number of bins, size of each random choice, and a random seed. 

uniformenergy_events(nue_hdf,25,10,12,subrun = True)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:177: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['binned_log10E'] = pd.cut(x = np.log10(df_filtered['energy']), bins = bins, labels = labels, include_lowest = True) #might throw an error?
# Number of Bins: 25
# Number of Events per Bin: 10
# Total Number of Events: 250
# Initial Number of Events: 2743
# Number of Events after filtering: 2670
# Please input subrun number:
# 000763

# %% [markdown]
# The above function throws another warning about pd.cut, currently that is not a problem but I don't know if a new version of pandas will allow this.

# %%
#Path to Random Events CSV
nue_csv = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/random_events_uniform_energy_distrib_22067_000763.csv'

# %%
#Run event_characterization_plots function whick makes some quick 
#plots to get an idea of what data you're dealing with.
#Note that I want to update the plot types, maybe make a 2D histogram as Mike K suggested. 
#For truth labels, check out enums.py or in the .py file that holds the functions.

event_characterization_plots(nue_csv)

# %% [markdown]
# Now that we have the events for this phase chosen, we run the second filter to pick out only those events.

# %%
#Path to i3 file from filter1 with MC truth labels. 
nue_filter1 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000763.i3.zst'

# %%
#Run function to perform second filter which passes through only selected event IDs chosen from 
#the uniformenergy_events function. 
filter2(nue_filter1,phase1_dir,nue_csv)

# %%
#Path to i3 file from filter 2 that holds only specified events. 
nue_filter2 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000763.i3.zst'

# %%
#Run function to perform third filter, which returns only the DAQ frames of the specified events.
#DAQ only file is then split up into many smaller i3 files since SteamShovel can't handle making videos of large
#i3 files at one time. Size limit is approx 2E6 MB (? unsure of units)
filter3(nue_filter2,22067_000763,phase1_dir)

# %%
#Path to NuMu Daq Only folder
nue_daq = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000763/'

# %%
get_steamshovel(nue_daq,22067000763)
# Out:
# List of files:
# ['/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000763/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000763.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000763/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000763.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000763/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000763.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000763/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000763.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000763/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000763.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000763/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000763.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000763/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000763.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000763/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000763.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000763/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000763.i3.zst']
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000763/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000763.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000763/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000763.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000763/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000763.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000763/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000763.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000763/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000763.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000763/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000763.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000763/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000763.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000763/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000763.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000763/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000763.i3.zst

# %% [markdown]
# Ideas for Compression:
# - Use GUI to add files to queue and send to one compression folder.
# - Add a subprocess line in movie script to compress the video after making it and direct it to save in the compression folder.

# %%
compressed_path = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/'

# %% [markdown]
# Can't get manifest yet since some subjects are missing and lining it up won't work.

# %%
get_manifest(compressed_path, nue_csv)
# Out:
# {'/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_5815_origidx_5_RF22.mp4': {'event': 5815,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.4937906598788686e-05,
#   'pred_cascade': 0.9755093455314636,
#   'pred_tgtrack': 1.5729850701973191e-06,
#   'pred_starttrack': 0.0244601387530565,
#   'pred_stoptrack': 1.4089615433476864e-05,
#   'energy': 5566.386606719101,
#   'zenith': 0.7554397620013693,
#   'oneweight': 198345902275.8189,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9755093455314636,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_8370_origidx_15_RF22.mp4': {'event': 8370,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 5.88698239880614e-05,
#   'pred_cascade': 0.9821258783340454,
#   'pred_tgtrack': 1.389120569683655e-07,
#   'pred_starttrack': 0.0178093239665031,
#   'pred_stoptrack': 5.711306130251614e-06,
#   'energy': 54247.26041567803,
#   'zenith': 2.7739227401307542,
#   'oneweight': 7739409346576.596,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9821258783340454,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_8024_origidx_7_RF22.mp4': {'event': 8024,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.2015372365713119,
#   'pred_cascade': 0.0534779131412506,
#   'pred_tgtrack': 0.575899064540863,
#   'pred_starttrack': 0.1006738096475601,
#   'pred_stoptrack': 0.0684119760990142,
#   'energy': 314.3252287190923,
#   'zenith': 2.2739129645700054,
#   'oneweight': 201109524.1291328,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.575899064540863,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_8161_origidx_9_RF22.mp4': {'event': 8161,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.466509073972702,
#   'pred_cascade': 0.4844515025615692,
#   'pred_tgtrack': 0.0068572787567973,
#   'pred_starttrack': 0.0417822934687137,
#   'pred_stoptrack': 0.0003998472820967,
#   'energy': 168185.51724968443,
#   'zenith': 1.365003079373999,
#   'oneweight': 286783878738018.7,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.4844515025615692,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_8325_origidx_14_RF22.mp4': {'event': 8325,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.99904066324234,
#   'pred_cascade': 2.753748958639335e-05,
#   'pred_tgtrack': 0.0002777869231067,
#   'pred_starttrack': 2.260355722683016e-05,
#   'pred_stoptrack': 0.0006313826888799,
#   'energy': 9961.411703418968,
#   'zenith': 1.9519328103120568,
#   'oneweight': 577609808116.7351,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.99904066324234,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_3761_origidx_9_RF22.mp4': {'event': 3761,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.5112081170082092,
#   'pred_cascade': 0.1025280877947807,
#   'pred_tgtrack': 0.0289320554584264,
#   'pred_starttrack': 0.0303419828414917,
#   'pred_stoptrack': 0.3269897699356079,
#   'energy': 966226.7934317024,
#   'zenith': 2.52515020786601,
#   'oneweight': 6.08197650800072e+16,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5112081170082092,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_1447_origidx_37_RF22.mp4': {'event': 1447,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4217802286148071,
#   'pred_cascade': 0.0586542300879955,
#   'pred_tgtrack': 0.2129507660865783,
#   'pred_starttrack': 0.1107604429125785,
#   'pred_stoptrack': 0.1958543211221695,
#   'energy': 306856.91461002995,
#   'zenith': 1.4796241481907089,
#   'oneweight': 810768217127207.8,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4217802286148071,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_801_origidx_18_RF22.mp4': {'event': 801,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.973341679535224e-06,
#   'pred_cascade': 0.9678046107292176,
#   'pred_tgtrack': 1.367122877127258e-07,
#   'pred_starttrack': 0.0321884416043758,
#   'pred_stoptrack': 3.8117163967399392e-06,
#   'energy': 2525.218027718159,
#   'zenith': 1.0111081042565877,
#   'oneweight': 46560240372.42205,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9678046107292176,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_905_origidx_20_RF22.mp4': {'event': 905,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9998352527618408,
#   'pred_cascade': 6.651888497799519e-07,
#   'pred_tgtrack': 5.181366577744484e-05,
#   'pred_starttrack': 1.3833600860380102e-06,
#   'pred_stoptrack': 0.0001108647702494,
#   'energy': 7528.794501353327,
#   'zenith': 2.1191121099782992,
#   'oneweight': 378766431067.6979,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9998352527618408,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_9121_origidx_4_RF22.mp4': {'event': 9121,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2139357328414917,
#   'pred_cascade': 0.0386333428323268,
#   'pred_tgtrack': 0.0073423744179308,
#   'pred_starttrack': 0.0306335613131523,
#   'pred_stoptrack': 0.7094549536705017,
#   'energy': 1377.5372740895682,
#   'zenith': 1.6361635202142135,
#   'oneweight': 12309827456.160276,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7094549536705017,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_74_origidx_7_RF22.mp4': {'event': 74,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.294075459241867,
#   'pred_cascade': 0.0037352663930505,
#   'pred_tgtrack': 0.6121903657913208,
#   'pred_starttrack': 0.0350779704749584,
#   'pred_stoptrack': 0.0549208931624889,
#   'energy': 158.26875102611615,
#   'zenith': 1.1809155064397665,
#   'oneweight': 29896487.04816001,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6121903657913208,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_4145_origidx_18_RF22.mp4': {'event': 4145,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9998579025268556,
#   'pred_cascade': 4.801921447278312e-12,
#   'pred_tgtrack': 8.755698945606127e-05,
#   'pred_starttrack': 1.5599200750560094e-11,
#   'pred_stoptrack': 5.445960778160952e-05,
#   'energy': 231282.89837863293,
#   'zenith': 2.1499667467748145,
#   'oneweight': 722110703819637.0,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9998579025268556,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_1078_origidx_24_RF22.mp4': {'event': 1078,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.948650598526001,
#   'pred_cascade': 0.0225776694715023,
#   'pred_tgtrack': 0.0216389074921607,
#   'pred_starttrack': 0.0059527601115405,
#   'pred_stoptrack': 0.0011800406500697,
#   'energy': 31111.3649927482,
#   'zenith': 3.0747360682007177,
#   'oneweight': 1559740611462.4158,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.948650598526001,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_9193_origidx_5_RF22.mp4': {'event': 9193,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0428443178534507,
#   'pred_cascade': 0.0136455800384283,
#   'pred_tgtrack': 0.8194999694824219,
#   'pred_starttrack': 0.020367082208395,
#   'pred_stoptrack': 0.1036430150270462,
#   'energy': 977.8467492803538,
#   'zenith': 2.3421816108090345,
#   'oneweight': 4110351472.5179534,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8194999694824219,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_7300_origidx_43_RF22.mp4': {'event': 7300,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.5732558369636536,
#   'pred_cascade': 0.305655837059021,
#   'pred_tgtrack': 0.0004488735867198,
#   'pred_starttrack': 0.0260320454835891,
#   'pred_stoptrack': 0.0946075096726417,
#   'energy': 1589.451028602848,
#   'zenith': 2.70333752478554,
#   'oneweight': 10410762344.525564,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5732558369636536,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_2101_origidx_54_RF22.mp4': {'event': 2101,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0008642000029794,
#   'pred_cascade': 0.957301914691925,
#   'pred_tgtrack': 0.000230937890592,
#   'pred_starttrack': 0.0409302450716495,
#   'pred_stoptrack': 0.0006726649589836,
#   'energy': 3086.122523953003,
#   'zenith': 0.3764426809489306,
#   'oneweight': 44114070577.74297,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.957301914691925,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_9747_origidx_19_RF22.mp4': {'event': 9747,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2133625149726867,
#   'pred_cascade': 0.0215205997228622,
#   'pred_tgtrack': 0.0074576847255229,
#   'pred_starttrack': 0.0554189831018447,
#   'pred_stoptrack': 0.7022402286529541,
#   'energy': 1907.9901423514,
#   'zenith': 0.5780594747722365,
#   'oneweight': 10690930612.599665,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7022402286529541,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_351_origidx_5_RF22.mp4': {'event': 351,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0454317405819892,
#   'pred_cascade': 0.0030300421640276,
#   'pred_tgtrack': 0.1799846291542053,
#   'pred_starttrack': 0.7220590114593506,
#   'pred_stoptrack': 0.0494945459067821,
#   'energy': 27431.77291952464,
#   'zenith': 1.7267833640407175,
#   'oneweight': 47957868351639.5,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7220590114593506,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_8593_origidx_19_RF22.mp4': {'event': 8593,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 5.042559132562019e-05,
#   'pred_cascade': 0.986786425113678,
#   'pred_tgtrack': 6.374908139150648e-07,
#   'pred_starttrack': 0.0131474984809756,
#   'pred_stoptrack': 1.510419497208204e-05,
#   'energy': 125576.04033973534,
#   'zenith': 0.9235868338134232,
#   'oneweight': 199046286134968.62,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.986786425113678,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_5878_origidx_7_RF22.mp4': {'event': 5878,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.3629445135593414,
#   'pred_cascade': 0.4746955335140228,
#   'pred_tgtrack': 8.481818076688796e-05,
#   'pred_starttrack': 0.1583361774682998,
#   'pred_stoptrack': 0.0039388821460306,
#   'energy': 2915.418989404223,
#   'zenith': 1.727344888907706,
#   'oneweight': 36091407688.620026,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.4746955335140228,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_816_origidx_19_RF22.mp4': {'event': 816,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999275207519532,
#   'pred_cascade': 2.153218403577739e-08,
#   'pred_tgtrack': 4.12442532251589e-05,
#   'pred_starttrack': 1.2113783753875396e-08,
#   'pred_stoptrack': 3.118753375019878e-05,
#   'energy': 430430.5495114753,
#   'zenith': 2.118469663244309,
#   'oneweight': 163594221322707.84,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999275207519532,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_8766_origidx_21_RF22.mp4': {'event': 8766,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9996229410171508,
#   'pred_cascade': 1.1524375898019912e-10,
#   'pred_tgtrack': 0.000298559811199,
#   'pred_starttrack': 2.4571153445229754e-10,
#   'pred_stoptrack': 7.848255336284637e-05,
#   'energy': 58406.84206225514,
#   'zenith': 2.567285000887861,
#   'oneweight': 344535090361636.5,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9996229410171508,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_569_origidx_11_RF22.mp4': {'event': 569,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9982404708862304,
#   'pred_cascade': 2.9727138439739065e-07,
#   'pred_tgtrack': 0.0005187678616493,
#   'pred_starttrack': 3.7482988091142033e-07,
#   'pred_stoptrack': 0.0012401166604831,
#   'energy': 9592.102521439409,
#   'zenith': 0.7388726086828326,
#   'oneweight': 818719236476.8536,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9982404708862304,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_7012_origidx_35_RF22.mp4': {'event': 7012,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3061538636684418,
#   'pred_cascade': 0.1010979861021041,
#   'pred_tgtrack': 0.2085691392421722,
#   'pred_starttrack': 0.229990929365158,
#   'pred_stoptrack': 0.1541880965232849,
#   'energy': 218.66454642390883,
#   'zenith': 1.2061840343976635,
#   'oneweight': 73552531.5425238,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3061538636684418,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_2074_origidx_53_RF22.mp4': {'event': 2074,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999918818473816,
#   'pred_cascade': 1.2443903685266378e-08,
#   'pred_tgtrack': 1.972551217477303e-06,
#   'pred_starttrack': 7.944819117255975e-06,
#   'pred_stoptrack': 7.124009425751865e-05,
#   'energy': 630912.7618811877,
#   'zenith': 2.766860307729901,
#   'oneweight': 760359388761474.2,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999918818473816,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_2422_origidx_7_RF22.mp4': {'event': 2422,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9997009038925172,
#   'pred_cascade': 2.07322834455681e-08,
#   'pred_tgtrack': 0.0001622731651877,
#   'pred_starttrack': 1.3857096803349125e-07,
#   'pred_stoptrack': 0.0001367307559121,
#   'energy': 26360.041988406123,
#   'zenith': 0.2115213418305683,
#   'oneweight': 5492435618509.1045,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9997009038925172,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_2459_origidx_8_RF22.mp4': {'event': 2459,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.5118417143821716,
#   'pred_cascade': 0.4254370927810669,
#   'pred_tgtrack': 0.0110133113339543,
#   'pred_starttrack': 0.0512237586081028,
#   'pred_stoptrack': 0.000484171177959,
#   'energy': 651819.715480053,
#   'zenith': 0.7289958875671819,
#   'oneweight': 4746501514738611.0,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5118417143821716,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_8021_origidx_6_RF22.mp4': {'event': 8021,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0622533112764358,
#   'pred_cascade': 0.0193146895617246,
#   'pred_tgtrack': 0.8707377910614014,
#   'pred_starttrack': 0.0119551941752433,
#   'pred_stoptrack': 0.0357389412820339,
#   'energy': 2011.7360851086576,
#   'zenith': 2.145941436711779,
#   'oneweight': 36097916319.861694,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8707377910614014,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_5979_origidx_11_RF22.mp4': {'event': 5979,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9998137354850768,
#   'pred_cascade': 1.059377446877008e-10,
#   'pred_tgtrack': 5.4990458011161536e-05,
#   'pred_starttrack': 1.6496143340205551e-09,
#   'pred_stoptrack': 0.000131308886921,
#   'energy': 232093.49562456584,
#   'zenith': 1.616821506333685,
#   'oneweight': 346790128757409.75,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9998137354850768,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_4125_origidx_16_RF22.mp4': {'event': 4125,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1666141748428344,
#   'pred_cascade': 0.0350808836519718,
#   'pred_tgtrack': 0.6758049726486206,
#   'pred_starttrack': 0.0423568040132522,
#   'pred_stoptrack': 0.0801432281732559,
#   'energy': 554.15158449757,
#   'zenith': 2.208644795670262,
#   'oneweight': 942711830.6213216,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6758049726486206,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_642_origidx_13_RF22.mp4': {'event': 642,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.951507031917572,
#   'pred_cascade': 0.0004855548613704,
#   'pred_tgtrack': 6.304004637058824e-05,
#   'pred_starttrack': 0.0014029202284291,
#   'pred_stoptrack': 0.0465414188802242,
#   'energy': 1215.2720883542638,
#   'zenith': 2.3639444969043946,
#   'oneweight': 5495492519.024674,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.951507031917572,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_6907_origidx_29_RF22.mp4': {'event': 6907,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.8334519267082214,
#   'pred_cascade': 0.0482232384383678,
#   'pred_tgtrack': 0.0004318219143897,
#   'pred_starttrack': 0.0604754276573658,
#   'pred_stoptrack': 0.0574175976216793,
#   'energy': 12830.563693000811,
#   'zenith': 0.917196961100616,
#   'oneweight': 2376090645061.1343,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8334519267082214,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_7155_origidx_41_RF22.mp4': {'event': 7155,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.3211477380536962e-05,
#   'pred_cascade': 0.4001063704490661,
#   'pred_tgtrack': 6.677578494418412e-05,
#   'pred_starttrack': 0.5997880101203918,
#   'pred_stoptrack': 2.564325586718041e-05,
#   'energy': 744.6330888301504,
#   'zenith': 1.1010911834935218,
#   'oneweight': 1823886107.0123527,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.5997880101203918,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_616_origidx_12_RF22.mp4': {'event': 616,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0217379592359066,
#   'pred_cascade': 0.0031367579940706,
#   'pred_tgtrack': 0.0125190522521734,
#   'pred_starttrack': 0.0029142580460757,
#   'pred_stoptrack': 0.9596919417381288,
#   'energy': 388.5839840458416,
#   'zenith': 1.5638235489805254,
#   'oneweight': 233577353.83576724,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9596919417381288,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_6903_origidx_28_RF22.mp4': {'event': 6903,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0014056204818189,
#   'pred_cascade': 0.9192913174629213,
#   'pred_tgtrack': 0.000942560553085,
#   'pred_starttrack': 0.0756353214383125,
#   'pred_stoptrack': 0.0027252081781625,
#   'energy': 899.9157171652993,
#   'zenith': 0.7471848458529312,
#   'oneweight': 2561380390.235745,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9192913174629213,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_2286_origidx_57_RF22.mp4': {'event': 2286,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0025832636747509,
#   'pred_cascade': 0.0765010192990303,
#   'pred_tgtrack': 0.0007616170332767,
#   'pred_starttrack': 0.9161889553070068,
#   'pred_stoptrack': 0.0039651938714087,
#   'energy': 2293.2746618154288,
#   'zenith': 1.2086921594112665,
#   'oneweight': 21582466608.92345,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9161889553070068,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_8975_origidx_25_RF22.mp4': {'event': 8975,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.5688299299654318e-06,
#   'pred_cascade': 0.9950194358825684,
#   'pred_tgtrack': 1.1644340602856572e-08,
#   'pred_starttrack': 0.0049788942560553,
#   'pred_stoptrack': 1.6563470239816525e-07,
#   'energy': 74713.51036723472,
#   'zenith': 0.20380630012419,
#   'oneweight': 61347787675672.39,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9950194358825684,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_1173_origidx_30_RF22.mp4': {'event': 1173,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9992948770523072,
#   'pred_cascade': 3.830109199043363e-05,
#   'pred_tgtrack': 0.0003856098337564,
#   'pred_starttrack': 4.896640530205332e-05,
#   'pred_stoptrack': 0.0002321626961929,
#   'energy': 13735.815241969847,
#   'zenith': 0.578911316247209,
#   'oneweight': 1922958838702.0295,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9992948770523072,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_6919_origidx_31_RF22.mp4': {'event': 6919,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.203274016210344e-05,
#   'pred_cascade': 0.997581958770752,
#   'pred_tgtrack': 2.438890200906485e-09,
#   'pred_starttrack': 0.0023948929738253,
#   'pred_stoptrack': 1.0945567510134424e-06,
#   'energy': 16313.997726508607,
#   'zenith': 1.783796039301961,
#   'oneweight': 2043000413384.5127,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.997581958770752,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_9034_origidx_28_RF22.mp4': {'event': 9034,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 3.7757919926662e-05,
#   'pred_cascade': 0.9934237003326416,
#   'pred_tgtrack': 6.731700068485225e-07,
#   'pred_starttrack': 0.0065375585108995,
#   'pred_stoptrack': 1.820522896878174e-07,
#   'energy': 743209.9496408526,
#   'zenith': 1.5619583600445388,
#   'oneweight': 9.702025647057587e+16,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9934237003326416,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_6924_origidx_32_RF22.mp4': {'event': 6924,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1073528081178665,
#   'pred_cascade': 0.0302455481141805,
#   'pred_tgtrack': 0.5071592926979065,
#   'pred_starttrack': 0.0127352261915802,
#   'pred_stoptrack': 0.3425070941448211,
#   'energy': 221.2964001286664,
#   'zenith': 0.2134699496431491,
#   'oneweight': 30859788.19808424,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5071592926979065,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_1760_origidx_46_RF22.mp4': {'event': 1760,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999017596244812,
#   'pred_cascade': 2.161588054150343e-05,
#   'pred_tgtrack': 0.0007870000554248,
#   'pred_starttrack': 4.510153667069972e-05,
#   'pred_stoptrack': 0.0001286333572352,
#   'energy': 636301.6737953688,
#   'zenith': 0.6106448141846932,
#   'oneweight': 5777730356592529.0,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999017596244812,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_6281_origidx_20_RF22.mp4': {'event': 6281,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2708528935909271,
#   'pred_cascade': 0.0572490394115448,
#   'pred_tgtrack': 0.2125975489616394,
#   'pred_starttrack': 0.2236003428697586,
#   'pred_stoptrack': 0.23570017516613,
#   'energy': 102.07484977697816,
#   'zenith': 1.6066814109193914,
#   'oneweight': 6540531.990496964,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.2708528935909271,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_3700_origidx_7_RF22.mp4': {'event': 3700,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0453769713640213,
#   'pred_cascade': 0.914588451385498,
#   'pred_tgtrack': 9.825931920204312e-05,
#   'pred_starttrack': 0.0386121980845928,
#   'pred_stoptrack': 0.0013240867992863,
#   'energy': 7622.674114278626,
#   'zenith': 2.3533665645017607,
#   'oneweight': 360570538021.8765,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.914588451385498,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_9574_origidx_13_RF22.mp4': {'event': 9574,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.8309049606323242,
#   'pred_cascade': 6.334255886031315e-05,
#   'pred_tgtrack': 0.16547392308712,
#   'pred_starttrack': 0.000390934117604,
#   'pred_stoptrack': 0.0031668304000049,
#   'energy': 286.18783870396527,
#   'zenith': 1.3227241840812565,
#   'oneweight': 102601500.8349948,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8309049606323242,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_2302_origidx_58_RF22.mp4': {'event': 2302,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999527096748352,
#   'pred_cascade': 4.582372675754343e-11,
#   'pred_tgtrack': 0.0003255852498114,
#   'pred_starttrack': 4.72646422000622e-10,
#   'pred_stoptrack': 0.0001472715084673,
#   'energy': 379787.057701635,
#   'zenith': 1.904211893889765,
#   'oneweight': 93164090810521.56,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999527096748352,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_6755_origidx_26_RF22.mp4': {'event': 6755,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1130159646272659,
#   'pred_cascade': 0.0180572737008333,
#   'pred_tgtrack': 0.1359771788120269,
#   'pred_starttrack': 0.0193516686558723,
#   'pred_stoptrack': 0.7135979533195496,
#   'energy': 2388.823549445405,
#   'zenith': 2.732419132206148,
#   'oneweight': 10022853626.719349,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7135979533195496,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_6050_origidx_13_RF22.mp4': {'event': 6050,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999738931655884,
#   'pred_cascade': 7.76081088282865e-10,
#   'pred_tgtrack': 2.80363724414201e-06,
#   'pred_starttrack': 3.098708845072906e-08,
#   'pred_stoptrack': 2.329952985746786e-05,
#   'energy': 82986.6434649929,
#   'zenith': 1.370973759501458,
#   'oneweight': 41076369890386.734,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999738931655884,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_3933_origidx_13_RF22.mp4': {'event': 3933,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0028840005397796,
#   'pred_cascade': 0.0008603135938756,
#   'pred_tgtrack': 0.962128758430481,
#   'pred_starttrack': 0.0006938347942195,
#   'pred_stoptrack': 0.0334331206977367,
#   'energy': 4880.145277088562,
#   'zenith': 1.440416504932762,
#   'oneweight': 457119426018.6472,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.962128758430481,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_5931_origidx_10_RF22.mp4': {'event': 5931,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 1.0598506378300954e-05,
#   'pred_cascade': 0.9841906428337096,
#   'pred_tgtrack': 4.735223058105476e-08,
#   'pred_starttrack': 0.0157976951450109,
#   'pred_stoptrack': 1.107639377551095e-06,
#   'energy': 65841.49003624977,
#   'zenith': 1.408054248634634,
#   'oneweight': 35441622267101.445,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9841906428337096,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_1339_origidx_35_RF22.mp4': {'event': 1339,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.0002813074388541,
#   'pred_cascade': 0.9628682136535645,
#   'pred_tgtrack': 5.52038409296074e-06,
#   'pred_starttrack': 0.0368277244269847,
#   'pred_stoptrack': 1.7192822269862518e-05,
#   'energy': 32549.23015840808,
#   'zenith': 2.272950787911016,
#   'oneweight': 12866683475861.326,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9628682136535645,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_7031_origidx_37_RF22.mp4': {'event': 7031,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 5.984722884022631e-05,
#   'pred_cascade': 0.9440639019012452,
#   'pred_tgtrack': 1.5422179785673507e-05,
#   'pred_starttrack': 0.0552331916987896,
#   'pred_stoptrack': 0.0006276022759266,
#   'energy': 493.66589062743657,
#   'zenith': 1.5869486687713088,
#   'oneweight': 547766182.4650295,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9440639019012452,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_6184_origidx_16_RF22.mp4': {'event': 6184,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 5.811135997646488e-05,
#   'pred_cascade': 0.9967092275619508,
#   'pred_tgtrack': 4.3663415105754674e-09,
#   'pred_starttrack': 0.003230556147173,
#   'pred_stoptrack': 2.0968757326045302e-06,
#   'energy': 8937.905373237389,
#   'zenith': 1.7858195444101064,
#   'oneweight': 529493717989.537,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9967092275619508,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_467_origidx_8_RF22.mp4': {'event': 467,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0841641351580619,
#   'pred_cascade': 0.0331417508423328,
#   'pred_tgtrack': 0.0313063785433769,
#   'pred_starttrack': 0.0196447167545557,
#   'pred_stoptrack': 0.831743061542511,
#   'energy': 126.4763799469078,
#   'zenith': 1.2867954681396054,
#   'oneweight': 9396920.590556294,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.831743061542511,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_9804_origidx_22_RF22.mp4': {'event': 9804,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 3.3900212201842805e-06,
#   'pred_cascade': 0.999339997768402,
#   'pred_tgtrack': 5.362064126046562e-09,
#   'pred_starttrack': 0.0006566998199559,
#   'pred_stoptrack': 9.708516657269683e-09,
#   'energy': 250323.45987218217,
#   'zenith': 0.824015425555168,
#   'oneweight': 1370808591262853.8,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.999339997768402,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_5782_origidx_4_RF22.mp4': {'event': 5782,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 9.118140951613896e-06,
#   'pred_cascade': 0.6694878339767456,
#   'pred_tgtrack': 2.6406365577713583e-05,
#   'pred_starttrack': 0.3304271697998047,
#   'pred_stoptrack': 4.953248571837321e-05,
#   'energy': 215.17801281073216,
#   'zenith': 0.2325176952117243,
#   'oneweight': 61818382.62049386,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.6694878339767456,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_1822_origidx_48_RF22.mp4': {'event': 1822,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.662769079208374,
#   'pred_cascade': 0.1016995459794998,
#   'pred_tgtrack': 0.0157176256179809,
#   'pred_starttrack': 0.1021749079227447,
#   'pred_stoptrack': 0.1176388412714004,
#   'energy': 163989.93497017337,
#   'zenith': 1.3813490533807231,
#   'oneweight': 352508986196959.5,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.662769079208374,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_9724_origidx_18_RF22.mp4': {'event': 9724,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0213909912854433,
#   'pred_cascade': 0.0084077296778559,
#   'pred_tgtrack': 0.6743087768554688,
#   'pred_starttrack': 0.0041313837282359,
#   'pred_stoptrack': 0.2917611002922058,
#   'energy': 114.47971955586038,
#   'zenith': 2.62157877728548,
#   'oneweight': 6916118.191041142,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6743087768554688,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_981_origidx_23_RF22.mp4': {'event': 981,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9590920805931092,
#   'pred_cascade': 0.0023912254255264,
#   'pred_tgtrack': 0.0142779238522052,
#   'pred_starttrack': 0.0066673108376562,
#   'pred_stoptrack': 0.0175714436918497,
#   'energy': 1711.8147251204678,
#   'zenith': 1.2283540082162432,
#   'oneweight': 11682054348.96502,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9590920805931092,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_1338_origidx_34_RF22.mp4': {'event': 1338,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4857967495918274,
#   'pred_cascade': 0.0786132588982582,
#   'pred_tgtrack': 0.3478488326072693,
#   'pred_starttrack': 0.0399179682135582,
#   'pred_stoptrack': 0.0478231832385063,
#   'energy': 26688.867916174226,
#   'zenith': 2.1230679196919877,
#   'oneweight': 7691736394370.537,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4857967495918274,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_8387_origidx_16_RF22.mp4': {'event': 8387,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9998308420181274,
#   'pred_cascade': 4.391048150864663e-06,
#   'pred_tgtrack': 5.498185782926157e-05,
#   'pred_starttrack': 2.6179481210419908e-05,
#   'pred_stoptrack': 8.349247218575329e-05,
#   'energy': 19372.4193647746,
#   'zenith': 1.247007149012053,
#   'oneweight': 6611126343671.311,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9998308420181274,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_6698_origidx_24_RF22.mp4': {'event': 6698,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1055211052298545,
#   'pred_cascade': 0.0227487720549106,
#   'pred_tgtrack': 0.0429033115506172,
#   'pred_starttrack': 0.0355371013283729,
#   'pred_stoptrack': 0.7932896614074707,
#   'energy': 32474.16918172508,
#   'zenith': 2.512012420887625,
#   'oneweight': 9111662767631.035,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7932896614074707,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_9630_origidx_16_RF22.mp4': {'event': 9630,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 6.023348305461695e-06,
#   'pred_cascade': 0.9610778093338012,
#   'pred_tgtrack': 1.8788832676364109e-06,
#   'pred_starttrack': 0.0388935059309005,
#   'pred_stoptrack': 2.0722494809888303e-05,
#   'energy': 1041.5986470290557,
#   'zenith': 0.9855819602352406,
#   'oneweight': 4007640547.737694,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9610778093338012,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_7105_origidx_38_RF22.mp4': {'event': 7105,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.0002462866250425,
#   'pred_cascade': 0.8657866716384888,
#   'pred_tgtrack': 8.907681149139535e-06,
#   'pred_starttrack': 0.1338819414377212,
#   'pred_stoptrack': 7.627013110322878e-05,
#   'energy': 10626.245723091555,
#   'zenith': 2.29002320565921,
#   'oneweight': 1004343239727.2336,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.8657866716384888,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_6973_origidx_34_RF22.mp4': {'event': 6973,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0847079381346702,
#   'pred_cascade': 0.0172137729823589,
#   'pred_tgtrack': 0.0043880105949938,
#   'pred_starttrack': 0.022538486868143,
#   'pred_stoptrack': 0.8711518049240112,
#   'energy': 1072.1408953422824,
#   'zenith': 1.789105564926494,
#   'oneweight': 2485860581.477548,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8711518049240112,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_6047_origidx_12_RF22.mp4': {'event': 6047,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.944773882518348e-07,
#   'pred_cascade': 0.9976580142974854,
#   'pred_tgtrack': 6.283336517753925e-08,
#   'pred_starttrack': 0.0023377826437354,
#   'pred_stoptrack': 3.951397502532927e-06,
#   'energy': 21599.67730320623,
#   'zenith': 1.092023044666715,
#   'oneweight': 4970098124604.361,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9976580142974854,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_1831_origidx_49_RF22.mp4': {'event': 1831,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.0153448963537812,
#   'pred_cascade': 0.0057623675093054,
#   'pred_tgtrack': 0.9283260107040404,
#   'pred_starttrack': 0.0029685229528695,
#   'pred_stoptrack': 0.0475982353091239,
#   'energy': 120.40005131269486,
#   'zenith': 1.034163871972231,
#   'oneweight': 17961356.72430875,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9283260107040404,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_1755_origidx_45_RF22.mp4': {'event': 1755,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0097482902929186,
#   'pred_cascade': 0.0048442757688462,
#   'pred_tgtrack': 0.9750977754592896,
#   'pred_starttrack': 0.0041601033881306,
#   'pred_stoptrack': 0.0061495504342019,
#   'energy': 249.59938241468885,
#   'zenith': 1.4472603888640794,
#   'oneweight': 70795489.09752741,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9750977754592896,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_2350_origidx_4_RF22.mp4': {'event': 2350,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0651725232601165,
#   'pred_cascade': 0.0166450701653957,
#   'pred_tgtrack': 0.8463816046714783,
#   'pred_starttrack': 0.031742375344038,
#   'pred_stoptrack': 0.0400584787130355,
#   'energy': 3052.5078127067723,
#   'zenith': 1.9504306012770571,
#   'oneweight': 46130812749.092926,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8463816046714783,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_1616_origidx_41_RF22.mp4': {'event': 1616,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0121797313913702,
#   'pred_cascade': 0.9827074408531188,
#   'pred_tgtrack': 9.27850942389341e-06,
#   'pred_starttrack': 0.0048500071279704,
#   'pred_stoptrack': 0.000253520294791,
#   'energy': 19152.460355463245,
#   'zenith': 1.4630797558836448,
#   'oneweight': 2268006504102.8896,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9827074408531188,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_9378_origidx_9_RF22.mp4': {'event': 9378,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9342973232269288,
#   'pred_cascade': 0.0075886906124651,
#   'pred_tgtrack': 0.0090589011088013,
#   'pred_starttrack': 0.0215653609484434,
#   'pred_stoptrack': 0.027489686384797,
#   'energy': 1367.3813464651798,
#   'zenith': 1.25340275268477,
#   'oneweight': 6679499676.593035,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9342973232269288,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_7942_origidx_5_RF22.mp4': {'event': 7942,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.1885247826576233,
#   'pred_cascade': 0.7917948365211487,
#   'pred_tgtrack': 1.536255695100408e-05,
#   'pred_starttrack': 0.0196522269397974,
#   'pred_stoptrack': 1.2729135050904006e-05,
#   'energy': 831904.834083303,
#   'zenith': 1.5854259132318265,
#   'oneweight': 6082688819690243.0,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7917948365211487,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 25},
# ...
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_1902_origidx_50_RF22.mp4': {'event': 1902,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 3.3665432965790387e-06,
#   'pred_cascade': 0.9976932406425476,
#   'pred_tgtrack': 1.992692122421147e-10,
#   'pred_starttrack': 0.0023033414036035,
#   'pred_stoptrack': 3.321684616253151e-08,
#   'energy': 132547.1484500054,
#   'zenith': 0.4282676435120934,
#   'oneweight': 206702870336048.62,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9976932406425476,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_6778_origidx_27_RF22.mp4': {'event': 6778,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0843636766076088,
#   'pred_cascade': 0.0242147650569677,
#   'pred_tgtrack': 0.8492224812507629,
#   'pred_starttrack': 0.0127936350181698,
#   'pred_stoptrack': 0.0294054690748453,
#   'energy': 4910.083280831512,
#   'zenith': 1.2481786926074852,
#   'oneweight': 110112747951.11124,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8492224812507629,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_1365_origidx_36_RF22.mp4': {'event': 1365,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 6.806901365052909e-05,
#   'pred_cascade': 0.9409654140472412,
#   'pred_tgtrack': 3.9760379877407104e-05,
#   'pred_starttrack': 0.0588940903544425,
#   'pred_stoptrack': 3.2673982786946e-05,
#   'energy': 33598.65289830925,
#   'zenith': 2.915078625292829,
#   'oneweight': 73095160820249.45,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9409654140472412,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_6199_origidx_17_RF22.mp4': {'event': 6199,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.7887911200523376,
#   'pred_cascade': 0.0867003500461578,
#   'pred_tgtrack': 0.0002530494239181,
#   'pred_starttrack': 0.0255920123308897,
#   'pred_stoptrack': 0.0986634641885757,
#   'energy': 561.9151588421566,
#   'zenith': 1.8681386451297437,
#   'oneweight': 809307246.6382831,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7887911200523376,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_1253_origidx_33_RF22.mp4': {'event': 1253,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.5123616456985474,
#   'pred_cascade': 0.1205736994743347,
#   'pred_tgtrack': 0.0008216335554607,
#   'pred_starttrack': 0.0951418429613113,
#   'pred_stoptrack': 0.2711011469364166,
#   'energy': 555.9141256612513,
#   'zenith': 0.9190438242287452,
#   'oneweight': 881949064.4960437,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.5123616456985474,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_9388_origidx_10_RF22.mp4': {'event': 9388,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.994884192943573,
#   'pred_cascade': 0.0012854636879637,
#   'pred_tgtrack': 0.0006602258654311,
#   'pred_starttrack': 0.0004789027734659,
#   'pred_stoptrack': 0.0026911154855042,
#   'energy': 9719.626334040646,
#   'zenith': 1.1926531384025196,
#   'oneweight': 740040641520.1411,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.994884192943573,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_9338_origidx_7_RF22.mp4': {'event': 9338,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0845955535769462,
#   'pred_cascade': 0.0170633755624294,
#   'pred_tgtrack': 0.199297085404396,
#   'pred_starttrack': 0.008243397809565,
#   'pred_stoptrack': 0.6908005475997925,
#   'energy': 779.1046298374307,
#   'zenith': 0.9924144378854872,
#   'oneweight': 2490145985.5084567,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6908005475997925,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_8137_origidx_8_RF22.mp4': {'event': 8137,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.173971801996231,
#   'pred_cascade': 0.0502429641783237,
#   'pred_tgtrack': 0.437593400478363,
#   'pred_starttrack': 0.0190866850316524,
#   'pred_stoptrack': 0.3191052377223968,
#   'energy': 3208.471175000053,
#   'zenith': 2.133443804649436,
#   'oneweight': 140474783765.53784,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.437593400478363,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_3932_origidx_12_RF22.mp4': {'event': 3932,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 6.034152829670347e-05,
#   'pred_cascade': 0.9931649565696716,
#   'pred_tgtrack': 8.937673356967936e-08,
#   'pred_starttrack': 0.0067715952172875,
#   'pred_stoptrack': 2.922530484283925e-06,
#   'energy': 12427.87760509853,
#   'zenith': 1.481794482157648,
#   'oneweight': 1008085839751.7556,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9931649565696716,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_1168_origidx_28_RF22.mp4': {'event': 1168,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 4.7158641791611444e-07,
#   'pred_cascade': 0.9983324408531188,
#   'pred_tgtrack': 1.501017088401113e-08,
#   'pred_starttrack': 0.0016665505245327,
#   'pred_stoptrack': 4.313140209433186e-07,
#   'energy': 87329.56026642631,
#   'zenith': 0.7879950659098514,
#   'oneweight': 102636240203180.36,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9983324408531188,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_6248_origidx_19_RF22.mp4': {'event': 6248,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1939644068479538,
#   'pred_cascade': 0.0249592438340187,
#   'pred_tgtrack': 0.0162230469286441,
#   'pred_starttrack': 0.0373799838125705,
#   'pred_stoptrack': 0.7274733185768127,
#   'energy': 130.91752083269498,
#   'zenith': 2.5431318866853245,
#   'oneweight': 9897648.06365442,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7274733185768127,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_5889_origidx_8_RF22.mp4': {'event': 5889,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.980847179889679,
#   'pred_cascade': 0.0100286211818456,
#   'pred_tgtrack': 0.0061049619689583,
#   'pred_starttrack': 0.0007906128885224,
#   'pred_stoptrack': 0.0022285729646682,
#   'energy': 550674.1512916284,
#   'zenith': 2.7466489129489675,
#   'oneweight': 31295170278952.965,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.980847179889679,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_668_origidx_14_RF22.mp4': {'event': 668,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9639376997947692,
#   'pred_cascade': 0.0006287533324211,
#   'pred_tgtrack': 0.0332653224468231,
#   'pred_starttrack': 0.0007329982472583,
#   'pred_stoptrack': 0.0014352406142279,
#   'energy': 6549.922098210425,
#   'zenith': 1.3238927507083111,
#   'oneweight': 232824631190.41272,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9639376997947692,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_3608_origidx_5_RF22.mp4': {'event': 3608,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0134627213701605,
#   'pred_cascade': 0.0025530522689223,
#   'pred_tgtrack': 0.9541520476341248,
#   'pred_starttrack': 0.0032525085844099,
#   'pred_stoptrack': 0.0265796277672052,
#   'energy': 164.59234535143838,
#   'zenith': 1.2629404124010648,
#   'oneweight': 32908113.809725232,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9541520476341248,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_9371_origidx_8_RF22.mp4': {'event': 9371,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2235182374715805,
#   'pred_cascade': 0.0486232005059719,
#   'pred_tgtrack': 0.6158333420753479,
#   'pred_starttrack': 0.0236111283302307,
#   'pred_stoptrack': 0.0884141102433204,
#   'energy': 263.0936867305944,
#   'zenith': 2.181645618465549,
#   'oneweight': 29388862.33057373,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6158333420753479,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_3781_origidx_10_RF22.mp4': {'event': 3781,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.1382734775543213,
#   'pred_cascade': 0.026444423943758,
#   'pred_tgtrack': 0.7014604806900024,
#   'pred_starttrack': 0.0118687842041254,
#   'pred_stoptrack': 0.1219529062509536,
#   'energy': 37743.20382484527,
#   'zenith': 2.2600733462405307,
#   'oneweight': 15780319077135.416,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7014604806900024,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_9457_origidx_12_RF22.mp4': {'event': 9457,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.8812482953071594,
#   'pred_cascade': 0.0139836082234978,
#   'pred_tgtrack': 0.0004763414617627,
#   'pred_starttrack': 0.0651879236102104,
#   'pred_stoptrack': 0.0391038134694099,
#   'energy': 9927.895396953703,
#   'zenith': 0.9992400193456432,
#   'oneweight': 738619120584.2191,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8812482953071594,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_9722_origidx_17_RF22.mp4': {'event': 9722,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.0049484660848975,
#   'pred_cascade': 0.8604695200920105,
#   'pred_tgtrack': 3.663614961624262e-06,
#   'pred_starttrack': 0.1341980844736099,
#   'pred_stoptrack': 0.0003802780120167,
#   'energy': 26266.55766180242,
#   'zenith': 1.4126719239424328,
#   'oneweight': 5573654139400.155,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.8604695200920105,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_4574_origidx_26_RF22.mp4': {'event': 4574,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0056449524126946,
#   'pred_cascade': 0.6319535970687866,
#   'pred_tgtrack': 1.7614713215152733e-05,
#   'pred_starttrack': 0.3623801171779632,
#   'pred_stoptrack': 3.642167030193377e-06,
#   'energy': 110112.00793817909,
#   'zenith': 1.219962107109642,
#   'oneweight': 133099748451325.92,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.6319535970687866,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_750_origidx_16_RF22.mp4': {'event': 750,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999767243862152,
#   'pred_cascade': 1.966144758114297e-08,
#   'pred_tgtrack': 0.0001529832516098,
#   'pred_starttrack': 1.0203109468420737e-07,
#   'pred_stoptrack': 7.971081504365429e-05,
#   'energy': 299923.2899412782,
#   'zenith': 0.825664153742693,
#   'oneweight': 1343204658226409.5,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999767243862152,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_6135_origidx_14_RF22.mp4': {'event': 6135,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0602699257433414,
#   'pred_cascade': 0.0206719748675823,
#   'pred_tgtrack': 0.8500100374221802,
#   'pred_starttrack': 0.0277489870786666,
#   'pred_stoptrack': 0.0412990562617778,
#   'energy': 811614.721549503,
#   'zenith': 1.207079085126506,
#   'oneweight': 1.3571934879720016e+16,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8500100374221802,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_7026_origidx_36_RF22.mp4': {'event': 7026,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 9.791730917640962e-06,
#   'pred_cascade': 0.7564130425453186,
#   'pred_tgtrack': 1.7432730601285584e-06,
#   'pred_starttrack': 0.2434761226177215,
#   'pred_stoptrack': 9.927719656843692e-05,
#   'energy': 427.6528573216425,
#   'zenith': 1.4914954466555983,
#   'oneweight': 324564317.659594,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.7564130425453186,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_8164_origidx_10_RF22.mp4': {'event': 8164,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0572386793792247,
#   'pred_cascade': 0.0186174511909484,
#   'pred_tgtrack': 0.7897105813026428,
#   'pred_starttrack': 0.1114695966243743,
#   'pred_stoptrack': 0.0229637008160352,
#   'energy': 910128.346576796,
#   'zenith': 0.3842084963173283,
#   'oneweight': 1.4040546070688736e+16,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7897105813026428,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000763/compressed_run_22067_event_8296_origidx_13_RF22.mp4': {'event': 8296,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2454056292772293,
#   'pred_cascade': 0.0809132903814315,
#   'pred_tgtrack': 0.3390073776245117,
#   'pred_starttrack': 0.1527496129274368,
#   'pred_stoptrack': 0.1819240897893905,
#   'energy': 785.596171268661,
#   'zenith': 0.2823919017496548,
#   'oneweight': 1358113410.6742644,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3390073776245117,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 6}}

# %%
make_subject_set('nue_run_22067_subrun_000763_phase2')
# Out:
# Subject Set Name: nue_run_22067_subrun_000763_phase2
# Subject Set ID: 112481
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112473>, <SubjectSet 112467>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>, <SubjectSet 112464>]

# %%
uploader(compressed_path,nue_csv,112481)
# Out:
# Confirm if subject set 112481 is listed below.
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112473>, <SubjectSet 112467>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>, <SubjectSet 112464>]
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112473>, <SubjectSet 112467>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>, <SubjectSet 112464>]
# Number of times loop has ran: 1
# Number of times loop has ran: 2
# Number of times loop has ran: 3
# Number of times loop has ran: 4
# Number of times loop has ran: 5
# Number of times loop has ran: 6
# Number of times loop has ran: 7
# Number of times loop has ran: 8
# Number of times loop has ran: 9
# Number of times loop has ran: 10
# Number of times loop has ran: 11
# Number of times loop has ran: 12
# Number of times loop has ran: 13
# Number of times loop has ran: 14
# Number of times loop has ran: 15
# Number of times loop has ran: 16
# Number of times loop has ran: 17
# Number of times loop has ran: 18
# Number of times loop has ran: 19
# Number of times loop has ran: 20
# Number of times loop has ran: 21
# Number of times loop has ran: 22
# Number of times loop has ran: 23
# Number of times loop has ran: 24
# Number of times loop has ran: 25
# Number of times loop has ran: 26
# Number of times loop has ran: 27
# Number of times loop has ran: 28
# Number of times loop has ran: 29
# Number of times loop has ran: 30
# Number of times loop has ran: 31
# Number of times loop has ran: 32
# Number of times loop has ran: 33
# Number of times loop has ran: 34
# Number of times loop has ran: 35
# Number of times loop has ran: 36
# Number of times loop has ran: 37
# Number of times loop has ran: 38
# Number of times loop has ran: 39
# Number of times loop has ran: 40
# Number of times loop has ran: 41
# Number of times loop has ran: 42
# Number of times loop has ran: 43
# Number of times loop has ran: 44
# Number of times loop has ran: 45
# Number of times loop has ran: 46
# Number of times loop has ran: 47
# Number of times loop has ran: 48
# Number of times loop has ran: 49
# Number of times loop has ran: 50
# Number of times loop has ran: 51
# Number of times loop has ran: 52
# Number of times loop has ran: 53
# Number of times loop has ran: 54
# Number of times loop has ran: 55
# Number of times loop has ran: 56
# Number of times loop has ran: 57
# Number of times loop has ran: 58
# Number of times loop has ran: 59
# Number of times loop has ran: 60
# Number of times loop has ran: 61
# Number of times loop has ran: 62
# Number of times loop has ran: 63
# Number of times loop has ran: 64
# Number of times loop has ran: 65
# Number of times loop has ran: 66
# Number of times loop has ran: 67
# Number of times loop has ran: 68
# Number of times loop has ran: 69
# Number of times loop has ran: 70
# Number of times loop has ran: 71
# Number of times loop has ran: 72
# Number of times loop has ran: 73
# Number of times loop has ran: 74
# Number of times loop has ran: 75
# Number of times loop has ran: 76
# Number of times loop has ran: 77
# Number of times loop has ran: 78
# Number of times loop has ran: 79
# Number of times loop has ran: 80
# Number of times loop has ran: 81
# Number of times loop has ran: 82
# Number of times loop has ran: 83
# Number of times loop has ran: 84
# Number of times loop has ran: 85
# Number of times loop has ran: 86
# Number of times loop has ran: 87
# Number of times loop has ran: 88
# Number of times loop has ran: 89
# Number of times loop has ran: 90
# Number of times loop has ran: 91
# Number of times loop has ran: 92
# Number of times loop has ran: 93
# Number of times loop has ran: 94
# Number of times loop has ran: 95
# Number of times loop has ran: 96
# Number of times loop has ran: 97
# Number of times loop has ran: 98
# Number of times loop has ran: 99
# Number of times loop has ran: 100
# Number of times loop has ran: 101
# Number of times loop has ran: 102
# Number of times loop has ran: 103
# Number of times loop has ran: 104
# Number of times loop has ran: 105
# Number of times loop has ran: 106
# Number of times loop has ran: 107
# Number of times loop has ran: 108
# Number of times loop has ran: 109
# Number of times loop has ran: 110
# Number of times loop has ran: 111
# Number of times loop has ran: 112
# Number of times loop has ran: 113
# Number of times loop has ran: 114
# Number of times loop has ran: 115
# Number of times loop has ran: 116
# Number of times loop has ran: 117
# Number of times loop has ran: 118
# Number of times loop has ran: 119
# Number of times loop has ran: 120
# Number of times loop has ran: 121
# Number of times loop has ran: 122
# Number of times loop has ran: 123
# Number of times loop has ran: 124
# Number of times loop has ran: 125
# Number of times loop has ran: 126
# Number of times loop has ran: 127
# Number of times loop has ran: 128
# Number of times loop has ran: 129
# Number of times loop has ran: 130
# Number of times loop has ran: 131
# Number of times loop has ran: 132
# Number of times loop has ran: 133
# Number of times loop has ran: 134
# Number of times loop has ran: 135
# Number of times loop has ran: 136
# Number of times loop has ran: 137
# Number of times loop has ran: 138
# Number of times loop has ran: 139
# Number of times loop has ran: 140
# Number of times loop has ran: 141
# Number of times loop has ran: 142
# Number of times loop has ran: 143
# Number of times loop has ran: 144
# Number of times loop has ran: 145
# Number of times loop has ran: 146
# Number of times loop has ran: 147
# Number of times loop has ran: 148
# Number of times loop has ran: 149
# Number of times loop has ran: 150
# Number of times loop has ran: 151
# Number of times loop has ran: 152
# Number of times loop has ran: 153
# Number of times loop has ran: 154
# Number of times loop has ran: 155
# Number of times loop has ran: 156
# Number of times loop has ran: 157
# Number of times loop has ran: 158
# Number of times loop has ran: 159
# Number of times loop has ran: 160
# Number of times loop has ran: 161
# Number of times loop has ran: 162
# Number of times loop has ran: 163
# Number of times loop has ran: 164
# Number of times loop has ran: 165
# Number of times loop has ran: 166
# Number of times loop has ran: 167
# Number of times loop has ran: 168
# Number of times loop has ran: 169
# Number of times loop has ran: 170
# Number of times loop has ran: 171
# Number of times loop has ran: 172
# Number of times loop has ran: 173
# Number of times loop has ran: 174
# Number of times loop has ran: 175
# Number of times loop has ran: 176
# Number of times loop has ran: 177
