# %% [markdown]
# # Phase 2: Subject Creation
#
# **Description:**
#
# This notebook is to act as the resulting summary file for the creation and upload of subjects for the IceCube Zooniverse project currently called *Name that Neutrino!*. The project is currently being maintained by Elizabeth Warrick (as of March 2023). In this notebook, we take the i3 file and run it through several filters. [note: describe more later].
#
# > Nu Type: NuE
#
# > Run: 22076
#
# > SubRun: 000032
#
# ### Summary Stats:
#
# To be filled in after completing process. Also need to figure out global variables.
#
# **Subject Set Name:**

# %%
#Imports

#My functions: 
from uniformenergydist_filter import *

#General:
import numpy as np
import sys
import os
import subprocess
import argparse
import csv
from tables import *
import pandas as pd
from matplotlib import pyplot as plt
import h5py

#Zooniverse:
from panoptes_client import Panoptes, Project, SubjectSet, Subject
import magic
import glob

#IceCube:
from icecube.icetray import I3Units
import icecube.MuonGun
from icecube import dataio, dataclasses, icetray, MuonGun
from I3Tray import *
from icecube.hdfwriter import I3HDFWriter
from mc_labeler import MCLabeler #make sure that mc_labeler script is in current directory.

# %%
#Specify file paths:

#Initial I3 File:
nue = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/classifier_rehyd_DST_IC86.2020_NuE.022067.000032.i3.zst'

#Desired output directory. Note that creation of this directory is not yet coded and is done manually. 
phase1_dir = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/'

# %%
#Run Filter 1 to label MC truth.
filter1(nue,phase1_dir)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/mc_labeler.py:523: UserWarning: Couldn't find OMKey in MCPESeriesMap
#   warnings.warn("Couldn't find OMKey in MCPESeriesMap")

# %% [markdown]
# Note that the above cell might return an "exception" warning that the *MCPESeriesMap could not be found*. I am unsure why it does that because when I check the i3 file in dataio-shovel, I see the specified mc_pid_series_map (look at mc_labeler.py for exact name of specified key). The resulting file size should be around 400 MB.

# %%
#Path of hdf from above filter.
nue_hdf = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/\
Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000032.i3.zst.hd5'

# %%
#Run uniformenergy_events function which requires hdf from filter 1, 
#number of bins, size of each random choice, and a random seed. 

uniformenergy_events(nue_hdf,25,8,12,subrun = True)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:177: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['binned_log10E'] = pd.cut(x = np.log10(df_filtered['energy']), bins = bins, labels = labels, include_lowest = True) #might throw an error?
# Number of Bins: 25
# Number of Events per Bin: 8
# Total Number of Events: 200
# Initial Number of Events: 2678
# Number of Events after filtering: 2593
# Please input subrun number:
# 000032

# %% [markdown]
# The above function throws another warning about pd.cut, currently that is not a problem but I don't know if a new version of pandas will allow this.

# %%
#Path to Random Events CSV
nue_csv = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/random_events_uniform_energy_distrib_22067_000032.csv'

# %%
#Run event_characterization_plots function whick makes some quick 
#plots to get an idea of what data you're dealing with.
#Note that I want to update the plot types, maybe make a 2D histogram as Mike K suggested. 
#For truth labels, check out enums.py or in the .py file that holds the functions.

event_characterization_plots(nue_csv)

# %% [markdown]
# Now that we have the events for this phase chosen, we run the second filter to pick out only those events.

# %%
#Path to i3 file from filter1 with MC truth labels. 
nue_filter1 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000032.i3.zst'

# %%
#Run function to perform second filter which passes through only selected event IDs chosen from 
#the uniformenergy_events function. 
filter2(nue_filter1,phase1_dir,nue_csv)

# %%
#Path to i3 file from filter 2 that holds only specified events. 
nue_filter2 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000032.i3.zst'

# %%
#Run function to perform third filter, which returns only the DAQ frames of the specified events.
#DAQ only file is then split up into many smaller i3 files since SteamShovel can't handle making videos of large
#i3 files at one time. Size limit is approx 2E6 MB (? unsure of units)
filter3(nue_filter2,22067_000032,phase1_dir)

# %%
#Path to NuMu Daq Only folder
nue_daq = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000032/'

# %%
get_steamshovel(nue_daq,22067000032)
# Out:
# List of files:
# ['/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000032/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000032.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000032/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000032.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000032/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000032.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000032/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000032.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000032/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000032.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000032/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000032.i3.zst']
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000032/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000032.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000032/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000032.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000032/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000032.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000032/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000032.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000032/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000032.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000032/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000032.i3.zst

# %% [markdown]
# Ideas for Compression:
# - Use GUI to add files to queue and send to one compression folder.
# - Add a subprocess line in movie script to compress the video after making it and direct it to save in the compression folder.

# %%
compressed_path = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/'

# %% [markdown]
# Can't get manifest yet since some subjects are missing and lining it up won't work.

# %%
get_manifest(compressed_path, nue_csv)
# Out:
# {'/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_2163_origidx_41_RF22.mp4': {'event': 2163,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0644321590662002,
#   'pred_cascade': 0.0091189695522189,
#   'pred_tgtrack': 0.0030923939775675,
#   'pred_starttrack': 0.0067738164216279,
#   'pred_stoptrack': 0.9165825843811036,
#   'energy': 119.16964926971492,
#   'zenith': 2.187907649504185,
#   'oneweight': 16038531.534472002,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9165825843811036,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_1066_origidx_17_RF22.mp4': {'event': 1066,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0060244584456086,
#   'pred_cascade': 0.0044892719015479,
#   'pred_tgtrack': 0.984321117401123,
#   'pred_starttrack': 0.0012023100862279,
#   'pred_stoptrack': 0.0039628758095204,
#   'energy': 3162.528009191445,
#   'zenith': 0.830663422903596,
#   'oneweight': 27720416991.93731,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.984321117401123,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_9900_origidx_7_RF22.mp4': {'event': 9900,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 5.5735094974807e-06,
#   'pred_cascade': 0.9745635986328124,
#   'pred_tgtrack': 1.1745047459044144e-06,
#   'pred_starttrack': 0.0254160650074481,
#   'pred_stoptrack': 1.3554024008044507e-05,
#   'energy': 931.217624248814,
#   'zenith': 2.3813013512627283,
#   'oneweight': 5340094863.717869,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9745635986328124,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_1062_origidx_15_RF22.mp4': {'event': 1062,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3922275006771087,
#   'pred_cascade': 4.394758434500545e-05,
#   'pred_tgtrack': 0.6038755774497986,
#   'pred_starttrack': 0.0011648110812529,
#   'pred_stoptrack': 0.0026881550438702,
#   'energy': 51208.47600500559,
#   'zenith': 1.0454766393304884,
#   'oneweight': 21874892960106.074,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6038755774497986,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_1063_origidx_16_RF22.mp4': {'event': 1063,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9994519352912904,
#   'pred_cascade': 2.502548568372731e-08,
#   'pred_tgtrack': 2.451514956192113e-05,
#   'pred_starttrack': 1.7437322696878257e-07,
#   'pred_stoptrack': 0.0005233971751295,
#   'energy': 495477.6529304,
#   'zenith': 2.7816956942785085,
#   'oneweight': 7131580309337.022,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9994519352912904,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_1880_origidx_31_RF22.mp4': {'event': 1880,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1281504929065704,
#   'pred_cascade': 0.0305967219173908,
#   'pred_tgtrack': 0.6361900568008423,
#   'pred_starttrack': 0.1023431420326232,
#   'pred_stoptrack': 0.1027196049690246,
#   'energy': 102268.6198855708,
#   'zenith': 1.3816886772181574,
#   'oneweight': 573555215531574.0,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6361900568008423,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_675_origidx_5_RF22.mp4': {'event': 675,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999960660934448,
#   'pred_cascade': 6.251726913930611e-10,
#   'pred_tgtrack': 9.764519290911269e-07,
#   'pred_starttrack': 7.0397554452483754e-09,
#   'pred_stoptrack': 2.932753432105528e-06,
#   'energy': 269131.3212868982,
#   'zenith': 0.8535411470186868,
#   'oneweight': 859278948684189.5,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999960660934448,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_2011_origidx_36_RF22.mp4': {'event': 2011,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.2209305465221405,
#   'pred_cascade': 0.0639959424734115,
#   'pred_tgtrack': 0.5709976553916931,
#   'pred_starttrack': 0.0403036065399646,
#   'pred_stoptrack': 0.1037721633911132,
#   'energy': 131.6526092096857,
#   'zenith': 0.6779807149106937,
#   'oneweight': 28137845.83600069,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.5709976553916931,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_2008_origidx_35_RF22.mp4': {'event': 2008,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9982230067253112,
#   'pred_cascade': 2.165310434065759e-06,
#   'pred_tgtrack': 8.246212382800877e-05,
#   'pred_starttrack': 1.3487850992532913e-05,
#   'pred_stoptrack': 0.0016789728542789,
#   'energy': 873734.6444456644,
#   'zenith': 2.2393568096320773,
#   'oneweight': 201086424980633.3,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9982230067253112,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_1598_origidx_27_RF22.mp4': {'event': 1598,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3227624297142029,
#   'pred_cascade': 0.0938607975840568,
#   'pred_tgtrack': 0.072104275226593,
#   'pred_starttrack': 0.1429703384637832,
#   'pred_stoptrack': 0.3683021664619446,
#   'energy': 241210.07349069623,
#   'zenith': 2.8226587985614318,
#   'oneweight': 1836010423601.821,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3683021664619446,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_1544_origidx_26_RF22.mp4': {'event': 1544,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0264637451618909,
#   'pred_cascade': 0.0097208656370639,
#   'pred_tgtrack': 0.2205018699169159,
#   'pred_starttrack': 0.0095899645239114,
#   'pred_stoptrack': 0.7337235808372498,
#   'energy': 16431.701932939486,
#   'zenith': 0.7810476741758591,
#   'oneweight': 2262640340422.6694,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7337235808372498,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_2480_origidx_47_RF22.mp4': {'event': 2480,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0153263928368687,
#   'pred_cascade': 0.0052393744699656,
#   'pred_tgtrack': 0.7743910551071167,
#   'pred_starttrack': 0.0131888734176754,
#   'pred_stoptrack': 0.1918542683124542,
#   'energy': 112.4461716283781,
#   'zenith': 0.0884676299563834,
#   'oneweight': 3710727.591014448,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7743910551071167,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_707_origidx_6_RF22.mp4': {'event': 707,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999963879585266,
#   'pred_cascade': 4.495353742028918e-11,
#   'pred_tgtrack': 1.9996126866317358e-05,
#   'pred_starttrack': 1.2435772411834023e-09,
#   'pred_stoptrack': 1.608081402082462e-05,
#   'energy': 474763.1550875945,
#   'zenith': 1.2879715353434456,
#   'oneweight': 2994516001258279.5,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999963879585266,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_9823_origidx_5_RF22.mp4': {'event': 9823,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.115008920431137,
#   'pred_cascade': 0.0172051526606082,
#   'pred_tgtrack': 0.0031245062127709,
#   'pred_starttrack': 0.0938244462013244,
#   'pred_stoptrack': 0.7708370089530945,
#   'energy': 4434.324860597742,
#   'zenith': 1.6066074522463076,
#   'oneweight': 67363367171.18898,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7708370089530945,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_2664_origidx_4_RF22.mp4': {'event': 2664,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 8.3906206782558e-06,
#   'pred_cascade': 0.892387330532074,
#   'pred_tgtrack': 2.400200855845469e-06,
#   'pred_starttrack': 0.1075783222913742,
#   'pred_stoptrack': 2.351628427277319e-05,
#   'energy': 226.00621401812023,
#   'zenith': 1.5444318155553518,
#   'oneweight': 64114566.92780791,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.892387330532074,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_2673_origidx_5_RF22.mp4': {'event': 2673,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 9.1121306468267e-05,
#   'pred_cascade': 0.9856717586517334,
#   'pred_tgtrack': 1.2638933810649178e-07,
#   'pred_starttrack': 0.0142354797571897,
#   'pred_stoptrack': 1.566272999298235e-06,
#   'energy': 27537.983684753635,
#   'zenith': 1.6444051399900668,
#   'oneweight': 5383693126808.93,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9856717586517334,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_2146_origidx_40_RF22.mp4': {'event': 2146,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 3.1160598155111074e-05,
#   'pred_cascade': 0.9789435267448424,
#   'pred_tgtrack': 4.4231466489463855e-08,
#   'pred_starttrack': 0.0210166126489639,
#   'pred_stoptrack': 8.59719148138538e-06,
#   'energy': 1607.8699090810362,
#   'zenith': 1.3788046843174862,
#   'oneweight': 9040037062.078465,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9789435267448424,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_1729_origidx_28_RF22.mp4': {'event': 1729,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.7000313401222229,
#   'pred_cascade': 0.2521966397762298,
#   'pred_tgtrack': 0.000118530158943,
#   'pred_starttrack': 0.0237997379153966,
#   'pred_stoptrack': 0.0238537304103374,
#   'energy': 561.7633169130746,
#   'zenith': 1.4407059487601517,
#   'oneweight': 902857472.845374,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7000313401222229,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_2130_origidx_39_RF22.mp4': {'event': 2130,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.1489386260509491,
#   'pred_cascade': 0.0185481887310743,
#   'pred_tgtrack': 0.0211915355175733,
#   'pred_starttrack': 0.0181453302502632,
#   'pred_stoptrack': 0.7931762933731079,
#   'energy': 753.3892706227575,
#   'zenith': 2.424743658877999,
#   'oneweight': 1416257569.8646977,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7931762933731079,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_3218_origidx_11_RF22.mp4': {'event': 3218,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1450971215963363,
#   'pred_cascade': 0.0918088555335998,
#   'pred_tgtrack': 0.5671406388282776,
#   'pred_starttrack': 0.0798786208033561,
#   'pred_stoptrack': 0.1160747930407524,
#   'energy': 208.14105650182756,
#   'zenith': 2.1001154434955693,
#   'oneweight': 52305021.45215165,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5671406388282776,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_1405_origidx_22_RF22.mp4': {'event': 1405,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9990358352661132,
#   'pred_cascade': 9.141824557445943e-05,
#   'pred_tgtrack': 0.0002061409468296,
#   'pred_starttrack': 6.651585863437504e-05,
#   'pred_stoptrack': 0.0006000906578265,
#   'energy': 901356.9914800428,
#   'zenith': 1.4700910308895494,
#   'oneweight': 6066139554068071.0,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9990358352661132,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_10007_origidx_8_RF22.mp4': {'event': 10007,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.6843585146707483e-05,
#   'pred_cascade': 0.9362820982933044,
#   'pred_tgtrack': 1.7002400909404969e-06,
#   'pred_starttrack': 0.0636446848511695,
#   'pred_stoptrack': 4.4699321733787656e-05,
#   'energy': 463.7647358429337,
#   'zenith': 0.9157455918033652,
#   'oneweight': 588976848.7707745,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9362820982933044,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_965_origidx_12_RF22.mp4': {'event': 965,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.95045268535614,
#   'pred_cascade': 0.0288269035518169,
#   'pred_tgtrack': 0.0001338551810476,
#   'pred_starttrack': 0.0201849192380905,
#   'pred_stoptrack': 0.0004015996237285,
#   'energy': 18764.61006357463,
#   'zenith': 1.4432861668038413,
#   'oneweight': 17188251835436.06,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.95045268535614,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_1855_origidx_29_RF22.mp4': {'event': 1855,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.463055104977684e-05,
#   'pred_cascade': 0.9949145317077636,
#   'pred_tgtrack': 2.4021664657425393e-08,
#   'pred_starttrack': 0.0050706584006547,
#   'pred_stoptrack': 2.729041170823621e-07,
#   'energy': 20864.501437668736,
#   'zenith': 1.1011380497681895,
#   'oneweight': 4230860654499.819,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9949145317077636,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_1313_origidx_19_RF22.mp4': {'event': 1313,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4548524022102356,
#   'pred_cascade': 0.5244015455245972,
#   'pred_tgtrack': 0.0001034550150507,
#   'pred_starttrack': 0.0201679021120071,
#   'pred_stoptrack': 0.0004747095517814,
#   'energy': 37975.0230645836,
#   'zenith': 0.6755771603493234,
#   'oneweight': 17653404237164.477,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5244015455245972,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_1879_origidx_30_RF22.mp4': {'event': 1879,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.98861163854599,
#   'pred_cascade': 1.1676211215672083e-05,
#   'pred_tgtrack': 0.0007122362148948,
#   'pred_starttrack': 0.0089852912351489,
#   'pred_stoptrack': 0.001679127337411,
#   'energy': 171315.26744415206,
#   'zenith': 0.9280667631221856,
#   'oneweight': 388804310545003.1,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.98861163854599,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_2634_origidx_49_RF22.mp4': {'event': 2634,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 7.534752057836158e-06,
#   'pred_cascade': 0.9740671515464784,
#   'pred_tgtrack': 3.2082272838351855e-08,
#   'pred_starttrack': 0.0259223375469446,
#   'pred_stoptrack': 2.887419668695657e-06,
#   'energy': 118054.5041258364,
#   'zenith': 1.158841042646779,
#   'oneweight': 160499759938598.22,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9740671515464784,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_7361_origidx_4_RF22.mp4': {'event': 7361,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4046060442924499,
#   'pred_cascade': 0.1011149361729621,
#   'pred_tgtrack': 0.3375430703163147,
#   'pred_starttrack': 0.0654268413782119,
#   'pred_stoptrack': 0.0913091003894805,
#   'energy': 450.4157346342657,
#   'zenith': 2.740118845602743,
#   'oneweight': 375462682.3377099,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4046060442924499,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_2460_origidx_46_RF22.mp4': {'event': 2460,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999941110610962,
#   'pred_cascade': 2.2172739022607857e-07,
#   'pred_tgtrack': 4.454981899471022e-05,
#   'pred_starttrack': 3.423527630275203e-07,
#   'pred_stoptrack': 1.36647240651655e-05,
#   'energy': 101279.96411683103,
#   'zenith': 1.3270811127596354,
#   'oneweight': 342178333438208.6,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999941110610962,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_1380_origidx_21_RF22.mp4': {'event': 1380,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.1572240509849507e-05,
#   'pred_cascade': 0.9860646724700928,
#   'pred_tgtrack': 4.4087465767006506e-07,
#   'pred_starttrack': 0.0138713689520955,
#   'pred_stoptrack': 5.193698234506883e-05,
#   'energy': 1604.72315948834,
#   'zenith': 2.4734129989516003,
#   'oneweight': 11068893151.837923,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9860646724700928,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_1515_origidx_25_RF22.mp4': {'event': 1515,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9992656111717224,
#   'pred_cascade': 3.8575260987272486e-05,
#   'pred_tgtrack': 0.0001256519317394,
#   'pred_starttrack': 0.0003142939240206,
#   'pred_stoptrack': 0.0002558958658482,
#   'energy': 47485.01802964098,
#   'zenith': 0.4232860772262448,
#   'oneweight': 18286978465716.902,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9992656111717224,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_2998_origidx_9_RF22.mp4': {'event': 2998,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4047017693519592,
#   'pred_cascade': 0.0662257969379425,
#   'pred_tgtrack': 0.0143454326316714,
#   'pred_starttrack': 0.1521466225385666,
#   'pred_stoptrack': 0.3625804185867309,
#   'energy': 28194.66792322609,
#   'zenith': 2.1639875983190056,
#   'oneweight': 2170900609224.5183,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4047017693519592,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_4981_origidx_7_RF22.mp4': {'event': 4981,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.998629093170166,
#   'pred_cascade': 9.260604201699609e-06,
#   'pred_tgtrack': 0.0002575027756392,
#   'pred_starttrack': 4.96111751999706e-05,
#   'pred_stoptrack': 0.0010545662371441,
#   'energy': 1979.135256864458,
#   'zenith': 1.7576980051502151,
#   'oneweight': 12502748762.941404,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.998629093170166,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_10039_origidx_9_RF22.mp4': {'event': 10039,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9993696808815002,
#   'pred_cascade': 1.418207773440372e-07,
#   'pred_tgtrack': 0.0003915952693205,
#   'pred_starttrack': 7.05494116459704e-08,
#   'pred_stoptrack': 0.0002385289553785,
#   'energy': 14555.231807904973,
#   'zenith': 1.5530396245003193,
#   'oneweight': 1381318141531.5508,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9993696808815002,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_4830_origidx_4_RF22.mp4': {'event': 4830,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2075877040624618,
#   'pred_cascade': 0.0486148819327354,
#   'pred_tgtrack': 0.4878198206424713,
#   'pred_starttrack': 0.0445102304220199,
#   'pred_stoptrack': 0.2114673107862472,
#   'energy': 277.8501718364185,
#   'zenith': 2.6076677528565426,
#   'oneweight': 157383807.40028575,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4878198206424713,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_2611_origidx_48_RF22.mp4': {'event': 2611,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9993632435798644,
#   'pred_cascade': 1.8617652131069923e-07,
#   'pred_tgtrack': 0.0002465694269631,
#   'pred_starttrack': 4.646800846330734e-07,
#   'pred_stoptrack': 0.000389470194932,
#   'energy': 709340.2739577459,
#   'zenith': 1.7615273472599906,
#   'oneweight': 513716918697771.6,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9993632435798644,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_9812_origidx_4_RF22.mp4': {'event': 9812,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0627211779356002,
#   'pred_cascade': 0.1752883493900299,
#   'pred_tgtrack': 0.4787333905696869,
#   'pred_starttrack': 0.1793956011533737,
#   'pred_stoptrack': 0.1038615182042121,
#   'energy': 108.18993116685822,
#   'zenith': 0.7896886208421438,
#   'oneweight': 9875244.228444118,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4787333905696869,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_1926_origidx_33_RF22.mp4': {'event': 1926,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 1.770924313859723e-06,
#   'pred_cascade': 0.980757474899292,
#   'pred_tgtrack': 1.2413154593104994e-07,
#   'pred_starttrack': 0.0192371737211942,
#   'pred_stoptrack': 3.463861276031821e-06,
#   'energy': 37662.59495164028,
#   'zenith': 0.4654903884617747,
#   'oneweight': 15300197975436.434,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.980757474899292,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_1087_origidx_18_RF22.mp4': {'event': 1087,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 2.3527960365754552e-05,
#   'pred_cascade': 0.9028751254081726,
#   'pred_tgtrack': 2.548274278524332e-05,
#   'pred_starttrack': 0.0970230549573898,
#   'pred_stoptrack': 5.284978760755621e-05,
#   'energy': 826.5324657938418,
#   'zenith': 1.1689089767730438,
#   'oneweight': 1844090433.243514,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9028751254081726,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_9878_origidx_6_RF22.mp4': {'event': 9878,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.998242735862732,
#   'pred_cascade': 0.0001602238626219,
#   'pred_tgtrack': 0.0005471199401654,
#   'pred_starttrack': 0.0003452047239989,
#   'pred_stoptrack': 0.0007047464023344,
#   'energy': 118338.25842309718,
#   'zenith': 1.271468819765211,
#   'oneweight': 145340059804570.84,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.998242735862732,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_1990_origidx_34_RF22.mp4': {'event': 1990,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0929759517312049,
#   'pred_cascade': 0.0892087072134018,
#   'pred_tgtrack': 0.0691107809543609,
#   'pred_starttrack': 0.0608559511601924,
#   'pred_stoptrack': 0.6878485679626465,
#   'energy': 108.66139797718346,
#   'zenith': 0.9004899465344012,
#   'oneweight': 9091830.560353843,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6878485679626465,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_673_origidx_4_RF22.mp4': {'event': 673,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.0026725048664957,
#   'pred_cascade': 0.9754431247711182,
#   'pred_tgtrack': 0.000157817165018,
#   'pred_starttrack': 0.0208557620644569,
#   'pred_stoptrack': 0.0008708048844709,
#   'energy': 229541.55449052583,
#   'zenith': 1.8538163456859325,
#   'oneweight': 562550313382834.8,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9754431247711182,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_4894_origidx_5_RF22.mp4': {'event': 4894,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0157456547021865,
#   'pred_cascade': 0.006162853911519,
#   'pred_tgtrack': 0.687568187713623,
#   'pred_starttrack': 0.0122632943093776,
#   'pred_stoptrack': 0.2782599925994873,
#   'energy': 637.7505678056013,
#   'zenith': 2.429343700302532,
#   'oneweight': 1343029419.9849546,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.687568187713623,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_4927_origidx_6_RF22.mp4': {'event': 4927,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1145486235618591,
#   'pred_cascade': 0.0758413150906562,
#   'pred_tgtrack': 0.6632758975028992,
#   'pred_starttrack': 0.0339021533727645,
#   'pred_stoptrack': 0.112431950867176,
#   'energy': 255.71863841210796,
#   'zenith': 1.810021000585902,
#   'oneweight': 86356254.67064777,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6632758975028992,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_7527_origidx_5_RF22.mp4': {'event': 7527,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.8535028696060181,
#   'pred_cascade': 0.0054953540675342,
#   'pred_tgtrack': 0.1068107038736343,
#   'pred_starttrack': 0.0068300385028123,
#   'pred_stoptrack': 0.0273609422147274,
#   'energy': 26804.304319874336,
#   'zenith': 1.1063797702932618,
#   'oneweight': 7237858568021.406,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8535028696060181,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_2786_origidx_7_RF22.mp4': {'event': 2786,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2153354585170745,
#   'pred_cascade': 0.0297013260424137,
#   'pred_tgtrack': 0.6928814053535461,
#   'pred_starttrack': 0.0145213603973388,
#   'pred_stoptrack': 0.0475604124367237,
#   'energy': 775.5914172147477,
#   'zenith': 0.6929484925470843,
#   'oneweight': 1534456188.9036975,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6928814053535461,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_741_origidx_7_RF22.mp4': {'event': 741,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.991137683391571,
#   'pred_cascade': 0.0009624431258998,
#   'pred_tgtrack': 0.0006873412057757,
#   'pred_starttrack': 0.0003904381010215,
#   'pred_stoptrack': 0.0068220039829611,
#   'energy': 18253.63319518674,
#   'zenith': 0.4814850672814522,
#   'oneweight': 3386144446734.164,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.991137683391571,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_2212_origidx_42_RF22.mp4': {'event': 2212,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0001956358319148,
#   'pred_cascade': 0.5013135075569153,
#   'pred_tgtrack': 3.165811358485371e-05,
#   'pred_starttrack': 0.4983391463756561,
#   'pred_stoptrack': 0.0001200310653075,
#   'energy': 199.21542822502647,
#   'zenith': 0.5375555637942806,
#   'oneweight': 68553590.46236324,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.5013135075569153,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_1889_origidx_32_RF22.mp4': {'event': 1889,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0295739471912384,
#   'pred_cascade': 0.0103601301088929,
#   'pred_tgtrack': 0.0102908462285995,
#   'pred_starttrack': 0.0216926019638776,
#   'pred_stoptrack': 0.9280824661254884,
#   'energy': 4917.315994621942,
#   'zenith': 2.138948767782224,
#   'oneweight': 494994270423.3659,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9280824661254884,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_985_origidx_14_RF22.mp4': {'event': 985,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.7039664044204985e-06,
#   'pred_cascade': 0.9985750913619996,
#   'pred_tgtrack': 7.762511466946619e-11,
#   'pred_starttrack': 0.0014232888352125,
#   'pred_stoptrack': 1.6268339564362577e-08,
#   'energy': 9881.156623914569,
#   'zenith': 0.8742656528546284,
#   'oneweight': 934317949715.827,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9985750913619996,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_3075_origidx_10_RF22.mp4': {'event': 3075,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9600151777267456,
#   'pred_cascade': 0.0011426373384892,
#   'pred_tgtrack': 0.0147618995979428,
#   'pred_starttrack': 0.0011132881045341,
#   'pred_stoptrack': 0.0229670349508523,
#   'energy': 7527.068005254278,
#   'zenith': 2.9643071769385543,
#   'oneweight': 59003211422.46046,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9600151777267456,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_967_origidx_13_RF22.mp4': {'event': 967,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0779015570878982,
#   'pred_cascade': 0.0161861274391412,
#   'pred_tgtrack': 0.8325737118721008,
#   'pred_starttrack': 0.05708809196949,
#   'pred_stoptrack': 0.0162505228072404,
#   'energy': 8346.840863284964,
#   'zenith': 1.9863205044122636,
#   'oneweight': 2190455026209.0076,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8325737118721008,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_865_origidx_9_RF22.mp4': {'event': 865,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 7.207758699223632e-06,
#   'pred_cascade': 0.8921610713005066,
#   'pred_tgtrack': 1.4682667881515954e-07,
#   'pred_starttrack': 0.1078281551599502,
#   'pred_stoptrack': 3.385958962098812e-06,
#   'energy': 3478.943564181326,
#   'zenith': 1.4095845497609178,
#   'oneweight': 189179772188.59445,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8921610713005066,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_2232_origidx_43_RF22.mp4': {'event': 2232,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9884584546089172,
#   'pred_cascade': 4.841850750381127e-05,
#   'pred_tgtrack': 0.0003958753368351,
#   'pred_starttrack': 7.864685176173225e-05,
#   'pred_stoptrack': 0.0110185462981462,
#   'energy': 37927.51925579812,
#   'zenith': 0.3194236893990948,
#   'oneweight': 13461059355355.23,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9884584546089172,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_948_origidx_11_RF22.mp4': {'event': 948,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0013156965142115,
#   'pred_cascade': 0.0001611355692148,
#   'pred_tgtrack': 0.0004492945445235,
#   'pred_starttrack': 0.0010131208691745,
#   'pred_stoptrack': 0.9970607161521912,
#   'energy': 1203.7905736617986,
#   'zenith': 1.2087754738826813,
#   'oneweight': 8323288302.813095,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9970607161521912,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_831_origidx_8_RF22.mp4': {'event': 831,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999605417251588,
#   'pred_cascade': 1.4487402943963446e-10,
#   'pred_tgtrack': 3.258242713854997e-06,
#   'pred_starttrack': 3.7352798631928863e-10,
#   'pred_stoptrack': 3.626420584623702e-05,
#   'energy': 24994.210210475405,
#   'zenith': 0.2711384387471395,
#   'oneweight': 5661137647609.106,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999605417251588,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_2440_origidx_45_RF22.mp4': {'event': 2440,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0337281376123428,
#   'pred_cascade': 0.008719015866518,
#   'pred_tgtrack': 0.1944483816623687,
#   'pred_starttrack': 0.0036043797153979,
#   'pred_stoptrack': 0.7595000267028809,
#   'energy': 259.68574798097507,
#   'zenith': 1.615094106100038,
#   'oneweight': 67166160.8607166,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7595000267028809,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_2718_origidx_6_RF22.mp4': {'event': 2718,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0007623499259352,
#   'pred_cascade': 9.34791169129312e-05,
#   'pred_tgtrack': 0.000105079547211,
#   'pred_starttrack': 0.0001291377993766,
#   'pred_stoptrack': 0.9989099502563475,
#   'energy': 510579.2305250948,
#   'zenith': 2.833927236346818,
#   'oneweight': 259271925501.3572,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9989099502563475,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_2260_origidx_44_RF22.mp4': {'event': 2260,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0024477664846926,
#   'pred_cascade': 0.6202309131622314,
#   'pred_tgtrack': 1.2457407137844712e-05,
#   'pred_starttrack': 0.3772868514060974,
#   'pred_stoptrack': 2.202045106969308e-05,
#   'energy': 64933.06080645873,
#   'zenith': 1.4402965142491004,
#   'oneweight': 36415837330113.78,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.6202309131622314,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_3252_origidx_12_RF22.mp4': {'event': 3252,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 9.52534392126836e-05,
#   'pred_cascade': 0.970580756664276,
#   'pred_tgtrack': 7.485245441785082e-05,
#   'pred_starttrack': 0.0292359367012977,
#   'pred_stoptrack': 1.3352020687307233e-05,
#   'energy': 159212.29484064458,
#   'zenith': 0.2098349410154422,
#   'oneweight': 241766614149987.0,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.970580756664276,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_1439_origidx_23_RF22.mp4': {'event': 1439,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.000109838998469,
#   'pred_cascade': 0.9946187734603882,
#   'pred_tgtrack': 1.080140989984102e-07,
#   'pred_starttrack': 0.0052699670195579,
#   'pred_stoptrack': 1.2656443004743778e-06,
#   'energy': 7800.677588331869,
#   'zenith': 1.4737356755556787,
#   'oneweight': 354722254025.91504,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9946187734603882,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_2028_origidx_37_RF22.mp4': {'event': 2028,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9997099041938782,
#   'pred_cascade': 1.1499412977400425e-08,
#   'pred_tgtrack': 0.0001075158797902,
#   'pred_starttrack': 1.0223913449181057e-07,
#   'pred_stoptrack': 0.0001824682112783,
#   'energy': 940916.3094446546,
#   'zenith': 0.9328389900094548,
#   'oneweight': 1.117319123862573e+16,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9997099041938782,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_1348_origidx_20_RF22.mp4': {'event': 1348,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9698336124420166,
#   'pred_cascade': 0.0007731497753411,
#   'pred_tgtrack': 0.0207756888121366,
#   'pred_starttrack': 0.0011034035123884,
#   'pred_stoptrack': 0.0075141238048672,
#   'energy': 255246.5876140496,
#   'zenith': 1.4495905236574873,
#   'oneweight': 637988886427419.4,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9698336124420166,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_1481_origidx_24_RF22.mp4': {'event': 1481,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0190133955329656,
#   'pred_cascade': 0.9006715416908264,
#   'pred_tgtrack': 6.263724208110943e-05,
#   'pred_starttrack': 0.0799889042973518,
#   'pred_stoptrack': 0.0002635208074934,
#   'energy': 410104.4956571924,
#   'zenith': 1.289312722515391,
#   'oneweight': 1846688419095905.2,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9006715416908264,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_2085_origidx_38_RF22.mp4': {'event': 2085,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0289029125124216,
#   'pred_cascade': 0.0100175030529499,
#   'pred_tgtrack': 0.338173508644104,
#   'pred_starttrack': 0.0081220706924796,
#   'pred_stoptrack': 0.6147840023040771,
#   'energy': 510048.3566606098,
#   'zenith': 1.0066522805547216,
#   'oneweight': 3099003653589155.5,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6147840023040771,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_928_origidx_10_RF22.mp4': {'event': 928,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9994248151779176,
#   'pred_cascade': 3.282938223492238e-07,
#   'pred_tgtrack': 1.1342880497977603e-05,
#   'pred_starttrack': 1.0922015007963637e-06,
#   'pred_stoptrack': 0.0005624968325719,
#   'energy': 8659.6879508157,
#   'zenith': 1.5281844845385464,
#   'oneweight': 328571872385.1016,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9994248151779176,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000032/compressed_run_22067_event_2945_origidx_8_RF22.mp4': {'event': 2945,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1187773495912551,
#   'pred_cascade': 0.0324749276041984,
#   'pred_tgtrack': 0.2500670254230499,
#   'pred_starttrack': 0.0115284966304898,
#   'pred_stoptrack': 0.5871521830558777,
#   'energy': 211.20409524552088,
#   'zenith': 2.3432461930042323,
#   'oneweight': 52950218.467143625,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5871521830558777,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 3}}

# %%
make_subject_set('nue_run_22067_subrun_000032_phase2')
# Out:
# Subject Set Name: nue_run_22067_subrun_000032_phase2
# Subject Set ID: 112498
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112473>, <SubjectSet 112487>, <SubjectSet 112492>, <SubjectSet 112467>, <SubjectSet 112481>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>, <SubjectSet 112464>]

# %%
uploader(compressed_path,nue_csv,112498)
# Out:
# Confirm if subject set 112498 is listed below.
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112473>, <SubjectSet 112487>, <SubjectSet 112492>, <SubjectSet 112467>, <SubjectSet 112481>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>, <SubjectSet 112464>]
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112473>, <SubjectSet 112487>, <SubjectSet 112492>, <SubjectSet 112467>, <SubjectSet 112481>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>, <SubjectSet 112464>]
# Number of times loop has ran: 1
# Number of times loop has ran: 2
# Number of times loop has ran: 3
# Number of times loop has ran: 4
# Number of times loop has ran: 5
# Number of times loop has ran: 6
# Number of times loop has ran: 7
# Number of times loop has ran: 8
# Number of times loop has ran: 9
# Number of times loop has ran: 10
# Number of times loop has ran: 11
# Number of times loop has ran: 12
# Number of times loop has ran: 13
# Number of times loop has ran: 14
# Number of times loop has ran: 15
# Number of times loop has ran: 16
# Number of times loop has ran: 17
# Number of times loop has ran: 18
# Number of times loop has ran: 19
# Number of times loop has ran: 20
# Number of times loop has ran: 21
# Number of times loop has ran: 22
# Number of times loop has ran: 23
# Number of times loop has ran: 24
# Number of times loop has ran: 25
# Number of times loop has ran: 26
# Number of times loop has ran: 27
# Number of times loop has ran: 28
# Number of times loop has ran: 29
# Number of times loop has ran: 30
# Number of times loop has ran: 31
# Number of times loop has ran: 32
# Number of times loop has ran: 33
# Number of times loop has ran: 34
# Number of times loop has ran: 35
# Number of times loop has ran: 36
# Number of times loop has ran: 37
# Number of times loop has ran: 38
# Number of times loop has ran: 39
# Number of times loop has ran: 40
# Number of times loop has ran: 41
# Number of times loop has ran: 42
# Number of times loop has ran: 43
# Number of times loop has ran: 44
# Number of times loop has ran: 45
# Number of times loop has ran: 46
# Number of times loop has ran: 47
# Number of times loop has ran: 48
# Number of times loop has ran: 49
# Number of times loop has ran: 50
# Number of times loop has ran: 51
# Number of times loop has ran: 52
# Number of times loop has ran: 53
# Number of times loop has ran: 54
# Number of times loop has ran: 55
# Number of times loop has ran: 56
# Number of times loop has ran: 57
# Number of times loop has ran: 58
# Number of times loop has ran: 59
# Number of times loop has ran: 60
# Number of times loop has ran: 61
# Number of times loop has ran: 62
# Number of times loop has ran: 63
# Number of times loop has ran: 64
# Number of times loop has ran: 65
# Number of times loop has ran: 66
# Number of times loop has ran: 67
