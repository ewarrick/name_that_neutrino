# %% [markdown]
# # Phase 2: Subject Creation
#
# **Description:**
#
# This notebook is to act as the resulting summary file for the creation and upload of subjects for the IceCube Zooniverse project currently called *Name that Neutrino!*. The project is currently being maintained by Elizabeth Warrick (as of March 2023). In this notebook, we take the i3 file and run it through several filters. [note: describe more later].
#
# > Nu Type: NuE
#
# > Run: 22076
#
# > SubRun: 000003
#
# ### Summary Stats:
#
# To be filled in after completing process. Also need to figure out global variables.
#
# **Subject Set Name:**

# %%
#Imports

#My functions: 
from uniformenergydist_filter import *

#General:
import numpy as np
import sys
import os
import subprocess
import argparse
import csv
from tables import *
import pandas as pd
from matplotlib import pyplot as plt
import h5py

#Zooniverse:
from panoptes_client import Panoptes, Project, SubjectSet, Subject
import magic
import glob

#IceCube:
from icecube.icetray import I3Units
import icecube.MuonGun
from icecube import dataio, dataclasses, icetray, MuonGun
from I3Tray import *
from icecube.hdfwriter import I3HDFWriter
from mc_labeler import MCLabeler #make sure that mc_labeler script is in current directory.

# %%
#Specify file paths:

#Initial I3 File:
nue = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst'

#Desired output directory. Note that creation of this directory is not yet coded and is done manually. 
phase1_dir = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/'

# %%
#Run Filter 1 to label MC truth.
filter1(nue,phase1_dir)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/mc_labeler.py:523: UserWarning: Couldn't find OMKey in MCPESeriesMap
#   warnings.warn("Couldn't find OMKey in MCPESeriesMap")

# %% [markdown]
# Note that the above cell might return an "exception" warning that the *MCPESeriesMap could not be found*. I am unsure why it does that because when I check the i3 file in dataio-shovel, I see the specified mc_pid_series_map (look at mc_labeler.py for exact name of specified key). The resulting file size should be around 400 MB.

# %%
#Path of hdf from above filter.
nue_hdf = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/\
Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst.hd5'

# %%
#Run uniformenergy_events function which requires hdf from filter 1, 
#number of bins, size of each random choice, and a random seed. 

uniformenergy_events(nue_hdf,25,17,12,subrun = True)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['binned_log10E'] = pd.cut(x = np.log10(df_filtered['energy']), bins = bins, labels = labels, include_lowest = True) #might throw an error?
# Number of Bins: 25
# Number of Events per Bin: 17
# Total Number of Events: 425
# Initial Number of Events: 2676
# Number of Events after filtering: 2615
# Please input subrun number:
# 000003

# %% [markdown]
# The above function throws another warning about pd.cut, currently that is not a problem but I don't know if a new version of pandas will allow this.

# %%
#Path to Random Events CSV
nue_csv = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/random_events_uniform_energy_distrib_22067_000003.csv'

# %%
#Run event_characterization_plots function whick makes some quick 
#plots to get an idea of what data you're dealing with.
#Note that I want to update the plot types, maybe make a 2D histogram as Mike K suggested. 
#For truth labels, check out enums.py or in the .py file that holds the functions.

event_characterization_plots(nue_csv)

# %% [markdown]
# Now that we have the events for this phase chosen, we run the second filter to pick out only those events.

# %%
#Path to i3 file from filter1 with MC truth labels. 
nue_filter1 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst'

# %%
#Run function to perform second filter which passes through only selected event IDs chosen from 
#the uniformenergy_events function. 
filter2(nue_filter1,phase1_dir,nue_csv)

# %%
#Path to i3 file from filter 2 that holds only specified events. 
nue_filter2 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst'

# %%
#Run function to perform third filter, which returns only the DAQ frames of the specified events.
#DAQ only file is then split up into many smaller i3 files since SteamShovel can't handle making videos of large
#i3 files at one time. Size limit is approx 2E6 MB (? unsure of units)
filter3(nue_filter2,22067_000003,phase1_dir)

# %%
#Path to NuMu Daq Only folder
nue_daq = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/'

# %%
get_steamshovel(nue_daq,22067000003)
# Out:
# List of files:
# ['/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0009_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0010_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0011_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0012_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst']
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0009_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0010_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0011_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000003/daq_only-0012_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000003.i3.zst

# %% [markdown]
# Ideas for Compression:
# - Use GUI to add files to queue and send to one compression folder.
# - Add a subprocess line in movie script to compress the video after making it and direct it to save in the compression folder.

# %%
compressed_path = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/'

# %% [markdown]
# Can't get manifest yet since some subjects are missing and lining it up won't work.

# %%
get_manifest(compressed_path, nue_csv)
# Out:
# {'/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_9535_origidx_29_RF22.mp4': {'event': 9535,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0200608912855386,
#   'pred_cascade': 0.003020669799298,
#   'pred_tgtrack': 0.8589375019073486,
#   'pred_starttrack': 0.0019978161435574,
#   'pred_stoptrack': 0.1159831136465072,
#   'energy': 104.14474346612413,
#   'zenith': 2.588147206312206,
#   'oneweight': 5270090.9830001965,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8589375019073486,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_1984_origidx_23_RF22.mp4': {'event': 1984,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9974426031112672,
#   'pred_cascade': 0.0003647176199592,
#   'pred_tgtrack': 0.0002333630691282,
#   'pred_starttrack': 0.0002759790222626,
#   'pred_stoptrack': 0.0016833432018756,
#   'energy': 15113.661948507335,
#   'zenith': 0.7231762428837367,
#   'oneweight': 2377037375463.0234,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9974426031112672,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_7707_origidx_5_RF22.mp4': {'event': 7707,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.6319465041160583,
#   'pred_cascade': 0.2739009261131286,
#   'pred_tgtrack': 0.0703002139925956,
#   'pred_starttrack': 0.0232746042311191,
#   'pred_stoptrack': 0.0005777945625595,
#   'energy': 295346.56333490054,
#   'zenith': 0.3212015208234833,
#   'oneweight': 951484787223622.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6319465041160583,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_7343_origidx_18_RF22.mp4': {'event': 7343,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.8829436302185059,
#   'pred_cascade': 0.0072516137734055,
#   'pred_tgtrack': 0.026402685791254,
#   'pred_starttrack': 0.0288537070155143,
#   'pred_stoptrack': 0.0545482896268367,
#   'energy': 3608.639514593131,
#   'zenith': 1.850406808178929,
#   'oneweight': 68188042080.12047,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8829436302185059,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_8972_origidx_7_RF22.mp4': {'event': 8972,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1951996684074401,
#   'pred_cascade': 0.0281602777540683,
#   'pred_tgtrack': 0.6846731901168823,
#   'pred_starttrack': 0.0542326234281063,
#   'pred_stoptrack': 0.0377343259751796,
#   'energy': 131842.63109749844,
#   'zenith': 0.8960461607537684,
#   'oneweight': 70611590832843.19,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6846731901168823,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_1776_origidx_10_RF22.mp4': {'event': 1776,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 9.03834279597504e-06,
#   'pred_cascade': 0.990031599998474,
#   'pred_tgtrack': 9.829421543372518e-08,
#   'pred_starttrack': 0.0099550057202577,
#   'pred_stoptrack': 4.230356353218667e-06,
#   'energy': 1767.3304184914025,
#   'zenith': 1.1258201150870837,
#   'oneweight': 23750189764.82418,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.990031599998474,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_71_origidx_8_RF22.mp4': {'event': 71,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0232260469347238,
#   'pred_cascade': 0.0035785238724201,
#   'pred_tgtrack': 0.9509462714195251,
#   'pred_starttrack': 0.0102218901738524,
#   'pred_stoptrack': 0.0120271993800997,
#   'energy': 4054.9310817243336,
#   'zenith': 2.449637888655221,
#   'oneweight': 42681254788.74826,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9509462714195251,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_7490_origidx_24_RF22.mp4': {'event': 7490,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0261317454278469,
#   'pred_cascade': 0.0077435369603335,
#   'pred_tgtrack': 0.9492928981781006,
#   'pred_starttrack': 0.0074381702579557,
#   'pred_stoptrack': 0.0093936398625373,
#   'energy': 496.3060112201362,
#   'zenith': 2.5325648115042467,
#   'oneweight': 413688475.2793906,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9492928981781006,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_8976_origidx_8_RF22.mp4': {'event': 8976,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9998248219490052,
#   'pred_cascade': 6.9801858737506e-11,
#   'pred_tgtrack': 2.4364140699617565e-05,
#   'pred_starttrack': 5.412734704890454e-09,
#   'pred_stoptrack': 0.0001508946006651,
#   'energy': 215743.55268635863,
#   'zenith': 1.2329825507721497,
#   'oneweight': 607144154341395.4,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9998248219490052,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_9517_origidx_26_RF22.mp4': {'event': 9517,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0001932890008902,
#   'pred_cascade': 0.9268936514854432,
#   'pred_tgtrack': 1.5405455997097306e-05,
#   'pred_starttrack': 0.0728393122553825,
#   'pred_stoptrack': 5.835562114953064e-05,
#   'energy': 1471.0842946334203,
#   'zenith': 1.3932993039253798,
#   'oneweight': 6576981420.95607,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9268936514854432,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_5819_origidx_21_RF22.mp4': {'event': 5819,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9983927607536316,
#   'pred_cascade': 3.384006959095132e-07,
#   'pred_tgtrack': 0.0001577695657033,
#   'pred_starttrack': 6.685257858407567e-07,
#   'pred_stoptrack': 0.00144841207657,
#   'energy': 16405.179472065603,
#   'zenith': 2.890928616443745,
#   'oneweight': 11957137330202.434,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9983927607536316,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_10308_origidx_12_RF22.mp4': {'event': 10308,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0444451197981834,
#   'pred_cascade': 0.0135329309850931,
#   'pred_tgtrack': 0.9128807187080384,
#   'pred_starttrack': 0.0146468011662364,
#   'pred_stoptrack': 0.0144943799823522,
#   'energy': 194.35948097638396,
#   'zenith': 0.4270204149806144,
#   'oneweight': 12729768.809494331,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9128807187080384,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_3299_origidx_8_RF22.mp4': {'event': 3299,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0278878509998321,
#   'pred_cascade': 0.0135211776942014,
#   'pred_tgtrack': 0.7121373414993286,
#   'pred_starttrack': 0.0080416239798069,
#   'pred_stoptrack': 0.2384120523929596,
#   'energy': 260019.3519671274,
#   'zenith': 1.9821736074436709,
#   'oneweight': 1.122426236786169e+16,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7121373414993286,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_7111_origidx_4_RF22.mp4': {'event': 7111,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999966025352478,
#   'pred_cascade': 1.4004051251959028e-08,
#   'pred_tgtrack': 2.500027676433092e-06,
#   'pred_starttrack': 9.891422791952209e-08,
#   'pred_stoptrack': 3.140015542157926e-05,
#   'energy': 47735.83779398262,
#   'zenith': 2.102289795216929,
#   'oneweight': 16089107487222.896,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999966025352478,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_2272_origidx_6_RF22.mp4': {'event': 2272,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0060072806663811,
#   'pred_cascade': 0.0007314064423553,
#   'pred_tgtrack': 0.9895201921463012,
#   'pred_starttrack': 0.0013547566486522,
#   'pred_stoptrack': 0.0023863175883889,
#   'energy': 375.3863821096922,
#   'zenith': 1.6969994427289383,
#   'oneweight': 194226319.99608645,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9895201921463012,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_381_origidx_21_RF22.mp4': {'event': 381,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2206294685602188,
#   'pred_cascade': 0.0402030311524868,
#   'pred_tgtrack': 0.6717348694801331,
#   'pred_starttrack': 0.0475551187992095,
#   'pred_stoptrack': 0.019877491518855,
#   'energy': 5861.852244939643,
#   'zenith': 0.6605204481660576,
#   'oneweight': 198488825809.8612,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6717348694801331,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_5787_origidx_18_RF22.mp4': {'event': 5787,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.914744800364133e-05,
#   'pred_cascade': 0.9976535439491272,
#   'pred_tgtrack': 2.3890440736806795e-09,
#   'pred_starttrack': 0.0023170590866357,
#   'pred_stoptrack': 1.907396978140241e-07,
#   'energy': 60768.55903915728,
#   'zenith': 2.052086079980962,
#   'oneweight': 41291698291550.83,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9976535439491272,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_5463_origidx_5_RF22.mp4': {'event': 5463,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.99804025888443,
#   'pred_cascade': 9.88313217931136e-08,
#   'pred_tgtrack': 0.0002012323820963,
#   'pred_starttrack': 8.227013950090623e-07,
#   'pred_stoptrack': 0.0017576869577169,
#   'energy': 33250.06201150994,
#   'zenith': 0.6278109190678482,
#   'oneweight': 8888863970353.05,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.99804025888443,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_9147_origidx_13_RF22.mp4': {'event': 9147,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 4.928478119836655e-06,
#   'pred_cascade': 0.0770477205514907,
#   'pred_tgtrack': 1.960227200470399e-05,
#   'pred_starttrack': 0.9229233264923096,
#   'pred_stoptrack': 4.407267169881379e-06,
#   'energy': 2090.206932108545,
#   'zenith': 1.502362994553302,
#   'oneweight': 15635634109.7457,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9229233264923096,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_1700_origidx_7_RF22.mp4': {'event': 1700,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1683292984962463,
#   'pred_cascade': 0.1783751100301742,
#   'pred_tgtrack': 0.2702636420726776,
#   'pred_starttrack': 0.2453324198722839,
#   'pred_stoptrack': 0.1376995295286178,
#   'energy': 1901.8788975572395,
#   'zenith': 1.039645499464753,
#   'oneweight': 19847550188.50691,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.2702636420726776,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_7351_origidx_19_RF22.mp4': {'event': 7351,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9550604224205016,
#   'pred_cascade': 0.01536750420928,
#   'pred_tgtrack': 0.0042005046270787,
#   'pred_starttrack': 0.0149886487051844,
#   'pred_stoptrack': 0.0103828785941004,
#   'energy': 4432.859014908311,
#   'zenith': 1.4874491167648018,
#   'oneweight': 93339486668.68411,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9550604224205016,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_6573_origidx_7_RF22.mp4': {'event': 6573,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9997900128364564,
#   'pred_cascade': 2.022373379872988e-10,
#   'pred_tgtrack': 0.0001112599929911,
#   'pred_starttrack': 2.212247940391876e-09,
#   'pred_stoptrack': 9.864095773082228e-05,
#   'energy': 220959.05174229364,
#   'zenith': 1.475326773160014,
#   'oneweight': 417916746999870.6,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9997900128364564,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_9274_origidx_16_RF22.mp4': {'event': 9274,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9998672008514404,
#   'pred_cascade': 3.7499432892218473e-06,
#   'pred_tgtrack': 3.508692316245288e-05,
#   'pred_starttrack': 1.6667914678691886e-05,
#   'pred_stoptrack': 7.736076804576442e-05,
#   'energy': 197226.756424984,
#   'zenith': 0.7862351078101909,
#   'oneweight': 887152829315433.2,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9998672008514404,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_9521_origidx_27_RF22.mp4': {'event': 9521,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.1104434430599212,
#   'pred_cascade': 0.7307871580123901,
#   'pred_tgtrack': 0.0026630891952663,
#   'pred_starttrack': 0.1510775536298751,
#   'pred_stoptrack': 0.0050287037156522,
#   'energy': 2195.798233297406,
#   'zenith': 0.5291861787379429,
#   'oneweight': 19696124610.27342,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7307871580123901,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_2061_origidx_26_RF22.mp4': {'event': 2061,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.818409484461881e-06,
#   'pred_cascade': 0.995528757572174,
#   'pred_tgtrack': 5.972533045905949e-08,
#   'pred_starttrack': 0.0044655022211372,
#   'pred_stoptrack': 2.891024678319809e-06,
#   'energy': 6704.984099525944,
#   'zenith': 1.3865174968548155,
#   'oneweight': 266834756913.2176,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.995528757572174,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_3378_origidx_13_RF22.mp4': {'event': 3378,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 8.55512644193368e-06,
#   'pred_cascade': 0.9803186058998108,
#   'pred_tgtrack': 3.5172924981452525e-05,
#   'pred_starttrack': 0.0195956900715827,
#   'pred_stoptrack': 4.1945200791815296e-05,
#   'energy': 60214.35377442694,
#   'zenith': 1.744587331661549,
#   'oneweight': 32323393795194.24,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9803186058998108,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_1982_origidx_22_RF22.mp4': {'event': 1982,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 4.811202597920783e-05,
#   'pred_cascade': 0.9236775040626526,
#   'pred_tgtrack': 1.8147413356928155e-05,
#   'pred_starttrack': 0.0761340633034706,
#   'pred_stoptrack': 0.0001222333521582,
#   'energy': 1344.9788506358775,
#   'zenith': 0.1739086426187946,
#   'oneweight': 4650690195.69215,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9236775040626526,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_9169_origidx_14_RF22.mp4': {'event': 9169,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0692980587482452,
#   'pred_cascade': 0.0115947648882865,
#   'pred_tgtrack': 0.9000152945518494,
#   'pred_starttrack': 0.0084549663588404,
#   'pred_stoptrack': 0.0106368800625205,
#   'energy': 146.77416728170118,
#   'zenith': 1.6588109590325664,
#   'oneweight': 33004822.86209307,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9000152945518494,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_9885_origidx_47_RF22.mp4': {'event': 9885,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0036206687800586,
#   'pred_cascade': 0.0017649233341217,
#   'pred_tgtrack': 0.990480363368988,
#   'pred_starttrack': 0.0010126521810889,
#   'pred_stoptrack': 0.0031214735936373,
#   'energy': 189.19688496692103,
#   'zenith': 1.0796611253290385,
#   'oneweight': 41062825.52390599,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.990480363368988,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_9666_origidx_38_RF22.mp4': {'event': 9666,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0401236377656459,
#   'pred_cascade': 0.0138112427666783,
#   'pred_tgtrack': 0.7309085130691528,
#   'pred_starttrack': 0.0073721776716411,
#   'pred_stoptrack': 0.2077844440937042,
#   'energy': 363.34548753235055,
#   'zenith': 1.863656037220948,
#   'oneweight': 26992316.04430524,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7309085130691528,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_1759_origidx_8_RF22.mp4': {'event': 1759,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.998258411884308,
#   'pred_cascade': 0.0001072940649464,
#   'pred_tgtrack': 0.0001353929401375,
#   'pred_starttrack': 0.0001457081380067,
#   'pred_stoptrack': 0.0013532161246985,
#   'energy': 30877.89793089258,
#   'zenith': 1.6163387751520937,
#   'oneweight': 7374108398999.592,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.998258411884308,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_6655_origidx_9_RF22.mp4': {'event': 6655,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.026200845837593,
#   'pred_cascade': 0.7495760321617126,
#   'pred_tgtrack': 0.0031285663135349,
#   'pred_starttrack': 0.1745099872350692,
#   'pred_stoptrack': 0.0465845949947834,
#   'energy': 1425.186933641481,
#   'zenith': 0.6883331960529272,
#   'oneweight': 8973201629.758503,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7495760321617126,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_5574_origidx_9_RF22.mp4': {'event': 5574,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1664153486490249,
#   'pred_cascade': 0.0451061800122261,
#   'pred_tgtrack': 0.7392719984054565,
#   'pred_starttrack': 0.040295336395502,
#   'pred_stoptrack': 0.0089111160486936,
#   'energy': 84081.50119201027,
#   'zenith': 1.2241288556500916,
#   'oneweight': 123896881656201.02,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7392719984054565,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_9714_origidx_41_RF22.mp4': {'event': 9714,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0009781301487237,
#   'pred_cascade': 0.3559278547763824,
#   'pred_tgtrack': 0.0001356648281216,
#   'pred_starttrack': 0.6407877206802368,
#   'pred_stoptrack': 0.0021705287508666,
#   'energy': 159.34303872918338,
#   'zenith': 1.7650801096184083,
#   'oneweight': 23867389.74118852,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.6407877206802368,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_357_origidx_20_RF22.mp4': {'event': 357,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 7.999669469427317e-05,
#   'pred_cascade': 0.9893717765808104,
#   'pred_tgtrack': 2.6195092761582824e-09,
#   'pred_starttrack': 0.0105347353965044,
#   'pred_stoptrack': 1.3542870874516666e-05,
#   'energy': 7521.483584516528,
#   'zenith': 2.427132402919422,
#   'oneweight': 518064296534.42944,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9893717765808104,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_5623_origidx_11_RF22.mp4': {'event': 5623,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2443824708461761,
#   'pred_cascade': 0.0963088274002075,
#   'pred_tgtrack': 0.1338200718164444,
#   'pred_starttrack': 0.4684197008609772,
#   'pred_stoptrack': 0.0570689514279365,
#   'energy': 2815.6353801557098,
#   'zenith': 1.7908054496306438,
#   'oneweight': 24449220217.463696,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4684197008609772,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_4821_origidx_6_RF22.mp4': {'event': 4821,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9473881125450134,
#   'pred_cascade': 5.649983722832985e-05,
#   'pred_tgtrack': 0.0475544854998588,
#   'pred_starttrack': 5.085967495688237e-05,
#   'pred_stoptrack': 0.0049500055611133,
#   'energy': 4271.340631361001,
#   'zenith': 2.482739823897063,
#   'oneweight': 77231866417.02472,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9473881125450134,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_3219_origidx_6_RF22.mp4': {'event': 3219,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.112388290464878,
#   'pred_cascade': 0.0311843156814575,
#   'pred_tgtrack': 0.5672982335090637,
#   'pred_starttrack': 0.2560125589370727,
#   'pred_stoptrack': 0.033116590231657,
#   'energy': 1179.7195658264493,
#   'zenith': 2.692425390847712,
#   'oneweight': 1634126676.2101326,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5672982335090637,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_9552_origidx_31_RF22.mp4': {'event': 9552,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.5042037963867188,
#   'pred_cascade': 0.0671891793608665,
#   'pred_tgtrack': 0.0693476870656013,
#   'pred_starttrack': 0.1269622594118118,
#   'pred_stoptrack': 0.2322970181703567,
#   'energy': 17276.693421022883,
#   'zenith': 1.2689542291020088,
#   'oneweight': 2891551223553.748,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5042037963867188,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_5462_origidx_4_RF22.mp4': {'event': 5462,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.806431282602716e-05,
#   'pred_cascade': 0.98662006855011,
#   'pred_tgtrack': 3.708477606778615e-06,
#   'pred_starttrack': 0.013052468188107,
#   'pred_stoptrack': 0.0003056501154787,
#   'energy': 867.2509995775578,
#   'zenith': 2.192844156489342,
#   'oneweight': 3872881099.15252,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.98662006855011,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_10237_origidx_8_RF22.mp4': {'event': 10237,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.528470940887928e-05,
#   'pred_cascade': 0.9502764344215392,
#   'pred_tgtrack': 1.104593411582755e-05,
#   'pred_starttrack': 0.0496775284409523,
#   'pred_stoptrack': 9.745511306391563e-06,
#   'energy': 91370.93757780666,
#   'zenith': 1.9388095362986335,
#   'oneweight': 92356971840437.2,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9502764344215392,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_5556_origidx_8_RF22.mp4': {'event': 5556,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1334472000598907,
#   'pred_cascade': 0.0458673648536205,
#   'pred_tgtrack': 0.7333564758300781,
#   'pred_starttrack': 0.019478028640151,
#   'pred_stoptrack': 0.0678509995341301,
#   'energy': 1066.834873130903,
#   'zenith': 1.181582032417581,
#   'oneweight': 3563597254.576233,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7333564758300781,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_1796_origidx_12_RF22.mp4': {'event': 1796,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 8.625876034784596e-06,
#   'pred_cascade': 0.8679559826850891,
#   'pred_tgtrack': 2.666202590262401e-06,
#   'pred_starttrack': 0.131973996758461,
#   'pred_stoptrack': 5.878122465219349e-05,
#   'energy': 651.1052985848868,
#   'zenith': 2.602001133130213,
#   'oneweight': 1298286449.4076436,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8679559826850891,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_5797_origidx_19_RF22.mp4': {'event': 5797,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2248966842889785,
#   'pred_cascade': 0.0522834546864032,
#   'pred_tgtrack': 0.5559892654418945,
#   'pred_starttrack': 0.0257700700312852,
#   'pred_stoptrack': 0.1410605311393737,
#   'energy': 282.6133853338731,
#   'zenith': 2.713760717481374,
#   'oneweight': 6398033.45221696,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5559892654418945,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_4840_origidx_7_RF22.mp4': {'event': 4840,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 4.536197764082317e-07,
#   'pred_cascade': 0.9980621933937072,
#   'pred_tgtrack': 2.5144236692753447e-10,
#   'pred_starttrack': 0.0019372043898329,
#   'pred_stoptrack': 1.027335372327798e-07,
#   'energy': 198901.5136154012,
#   'zenith': 0.9624887499485344,
#   'oneweight': 512700164347203.4,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9980621933937072,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_3356_origidx_9_RF22.mp4': {'event': 3356,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.6331310272216797,
#   'pred_cascade': 0.0748108774423599,
#   'pred_tgtrack': 0.0503277406096458,
#   'pred_starttrack': 0.0663242563605308,
#   'pred_stoptrack': 0.1754060983657837,
#   'energy': 215.7116149972112,
#   'zenith': 2.856264050300558,
#   'oneweight': 29917266.79496925,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6331310272216797,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_9608_origidx_35_RF22.mp4': {'event': 9608,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9927162528038024,
#   'pred_cascade': 0.0002015530044445,
#   'pred_tgtrack': 0.0032818920444697,
#   'pred_starttrack': 0.0002119275159202,
#   'pred_stoptrack': 0.0035884380340576,
#   'energy': 3635.246507699624,
#   'zenith': 2.1203307130375366,
#   'oneweight': 80009524878.50069,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9927162528038024,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_7634_origidx_34_RF22.mp4': {'event': 7634,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.8722093702526763e-05,
#   'pred_cascade': 0.8645682334899902,
#   'pred_tgtrack': 5.04799209011253e-06,
#   'pred_starttrack': 0.1353090405464172,
#   'pred_stoptrack': 8.892011101124808e-05,
#   'energy': 594.8894872436417,
#   'zenith': 1.5125073958282946,
#   'oneweight': 994713930.4507008,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8645682334899902,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_1835_origidx_15_RF22.mp4': {'event': 1835,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.861283635662403e-05,
#   'pred_cascade': 0.9882013201713562,
#   'pred_tgtrack': 5.8401340652380895e-08,
#   'pred_starttrack': 0.0117386737838387,
#   'pred_stoptrack': 4.134529081056826e-05,
#   'energy': 4629.842518367552,
#   'zenith': 1.3304908770696129,
#   'oneweight': 117762423729.2646,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9882013201713562,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_2180_origidx_33_RF22.mp4': {'event': 2180,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999319314956664,
#   'pred_cascade': 2.1116211001981355e-08,
#   'pred_tgtrack': 1.2245411198819056e-05,
#   'pred_starttrack': 2.953207101086264e-08,
#   'pred_stoptrack': 5.577339106821455e-05,
#   'energy': 6997.933723559388,
#   'zenith': 0.3007040275273533,
#   'oneweight': 297599025934.04474,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999319314956664,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_7577_origidx_29_RF22.mp4': {'event': 7577,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9921877384185792,
#   'pred_cascade': 2.5507426471449435e-05,
#   'pred_tgtrack': 0.0030465240124613,
#   'pred_starttrack': 3.4846503695007414e-05,
#   'pred_stoptrack': 0.004705308470875,
#   'energy': 35978.34598220623,
#   'zenith': 1.2132605370293867,
#   'oneweight': 10768794103573.607,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9921877384185792,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_2096_origidx_27_RF22.mp4': {'event': 2096,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.7966833710670471,
#   'pred_cascade': 0.0121195148676633,
#   'pred_tgtrack': 0.1530402451753616,
#   'pred_starttrack': 0.0040903696790337,
#   'pred_stoptrack': 0.0340665727853775,
#   'energy': 1884.58803453912,
#   'zenith': 2.033518991110443,
#   'oneweight': 13838909623.042006,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7966833710670471,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_10127_origidx_5_RF22.mp4': {'event': 10127,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3172578513622284,
#   'pred_cascade': 0.1352755725383758,
#   'pred_tgtrack': 0.2392814457416534,
#   'pred_starttrack': 0.197991594672203,
#   'pred_stoptrack': 0.110193595290184,
#   'energy': 121213.22441777083,
#   'zenith': 0.7849350229431918,
#   'oneweight': 314580835464866.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3172578513622284,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_9977_origidx_49_RF22.mp4': {'event': 9977,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999504089355468,
#   'pred_cascade': 4.877291903682135e-09,
#   'pred_tgtrack': 2.917785604950041e-05,
#   'pred_starttrack': 1.8472996998752933e-07,
#   'pred_stoptrack': 2.0321906049503013e-05,
#   'energy': 952502.2960201992,
#   'zenith': 1.2289380016710092,
#   'oneweight': 8788662395521446.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999504089355468,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_5727_origidx_15_RF22.mp4': {'event': 5727,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999397993087769,
#   'pred_cascade': 3.716218088811729e-08,
#   'pred_tgtrack': 2.6735884603112936e-05,
#   'pred_starttrack': 2.4618543648102782e-06,
#   'pred_stoptrack': 3.102617847616784e-05,
#   'energy': 76001.03572915353,
#   'zenith': 0.3862118540986374,
#   'oneweight': 62625844503992.08,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999397993087769,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_32_origidx_6_RF22.mp4': {'event': 32,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9978681802749634,
#   'pred_cascade': 3.2762919488504856e-08,
#   'pred_tgtrack': 0.0006523401243612,
#   'pred_starttrack': 3.1522219501312065e-08,
#   'pred_stoptrack': 0.0014794620219618,
#   'energy': 139818.1269412031,
#   'zenith': 1.4857505562559363,
#   'oneweight': 126172285238643.69,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9978681802749634,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_263_origidx_15_RF22.mp4': {'event': 263,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3269927203655243,
#   'pred_cascade': 0.0833600461483001,
#   'pred_tgtrack': 0.415325254201889,
#   'pred_starttrack': 0.049966737627983,
#   'pred_stoptrack': 0.1243552342057228,
#   'energy': 4738.110059789628,
#   'zenith': 1.6614180663342997,
#   'oneweight': 16512263419.50741,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.415325254201889,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_206_origidx_12_RF22.mp4': {'event': 206,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0028384067118167,
#   'pred_cascade': 0.0007384441560134,
#   'pred_tgtrack': 0.0067920116707682,
#   'pred_starttrack': 0.0006477772258222,
#   'pred_stoptrack': 0.9889833331108092,
#   'energy': 352490.92960777105,
#   'zenith': 1.0877572074577209,
#   'oneweight': 3988155658956181.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9889833331108092,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_2009_origidx_24_RF22.mp4': {'event': 2009,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0775939226150512,
#   'pred_cascade': 0.0214294772595167,
#   'pred_tgtrack': 0.853455662727356,
#   'pred_starttrack': 0.0256346240639686,
#   'pred_stoptrack': 0.0218863822519779,
#   'energy': 227705.4729411524,
#   'zenith': 2.957260018211219,
#   'oneweight': 1012141390218084.4,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.853455662727356,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_7520_origidx_26_RF22.mp4': {'event': 7520,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 9.56024905462982e-06,
#   'pred_cascade': 0.9980190992355348,
#   'pred_tgtrack': 2.521936132149349e-11,
#   'pred_starttrack': 0.0019712150096893,
#   'pred_stoptrack': 1.31236220113351e-07,
#   'energy': 343422.6061763052,
#   'zenith': 1.4479742769380586,
#   'oneweight': 1163693588677168.5,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9980190992355348,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_5663_origidx_12_RF22.mp4': {'event': 5663,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.3750321865081787,
#   'pred_cascade': 0.5582588911056519,
#   'pred_tgtrack': 0.0001580366370035,
#   'pred_starttrack': 0.0246603619307279,
#   'pred_stoptrack': 0.0418905280530452,
#   'energy': 1038.4463836337982,
#   'zenith': 1.550137772981025,
#   'oneweight': 2672507823.1370635,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.5582588911056519,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_10114_origidx_4_RF22.mp4': {'event': 10114,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.1877660602331161,
#   'pred_cascade': 0.7372827529907227,
#   'pred_tgtrack': 8.539311966160312e-05,
#   'pred_starttrack': 0.0585721023380756,
#   'pred_stoptrack': 0.0162937715649604,
#   'energy': 3256.4440825420925,
#   'zenith': 1.751162830348295,
#   'oneweight': 47824724543.51722,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7372827529907227,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_6662_origidx_10_RF22.mp4': {'event': 6662,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999934196472168,
#   'pred_cascade': 1.0079270396090578e-07,
#   'pred_tgtrack': 1.811509537219536e-05,
#   'pred_starttrack': 1.920015165524092e-06,
#   'pred_stoptrack': 4.561075547826477e-05,
#   'energy': 5697.550589346911,
#   'zenith': 2.315942602222865,
#   'oneweight': 147814264090.67093,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999934196472168,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_3715_origidx_6_RF22.mp4': {'event': 3715,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9947040677070618,
#   'pred_cascade': 0.0004012870194856,
#   'pred_tgtrack': 0.0018573532579466,
#   'pred_starttrack': 0.0009456259431317,
#   'pred_stoptrack': 0.0020916608627885,
#   'energy': 4307.558149482501,
#   'zenith': 1.2762608081162623,
#   'oneweight': 98001433988.11444,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9947040677070618,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_391_origidx_22_RF22.mp4': {'event': 391,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.4984415176732e-06,
#   'pred_cascade': 0.8435052037239075,
#   'pred_tgtrack': 5.385520012168854e-07,
#   'pred_starttrack': 0.1564911752939224,
#   'pred_stoptrack': 4.98270651405619e-07,
#   'energy': 134375.11874183462,
#   'zenith': 1.6854648353146993,
#   'oneweight': 152949590011484.56,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8435052037239075,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_9996_origidx_50_RF22.mp4': {'event': 9996,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999938011169434,
#   'pred_cascade': 7.496812770568796e-08,
#   'pred_tgtrack': 2.518628150482982e-07,
#   'pred_starttrack': 5.343047746464435e-07,
#   'pred_stoptrack': 5.291010438668309e-06,
#   'energy': 107620.39528832686,
#   'zenith': 0.3891674139236641,
#   'oneweight': 163311989474082.3,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999938011169434,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_1820_origidx_13_RF22.mp4': {'event': 1820,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0182675644755363,
#   'pred_cascade': 0.005546894390136,
#   'pred_tgtrack': 0.7188059091567993,
#   'pred_starttrack': 0.0030215634033083,
#   'pred_stoptrack': 0.2543581128120422,
#   'energy': 9579.433099274822,
#   'zenith': 2.2852279655815493,
#   'oneweight': 717968055943.3179,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7188059091567993,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_2129_origidx_30_RF22.mp4': {'event': 2129,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.774694439722225e-05,
#   'pred_cascade': 0.9938648343086244,
#   'pred_tgtrack': 1.7944883268228298e-07,
#   'pred_starttrack': 0.0061022965237498,
#   'pred_stoptrack': 4.973633167537628e-06,
#   'energy': 13387.368207790554,
#   'zenith': 0.3174915065586467,
#   'oneweight': 1401204502942.7292,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9938648343086244,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_10076_origidx_53_RF22.mp4': {'event': 10076,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.8641988635063171,
#   'pred_cascade': 0.0228467248380184,
#   'pred_tgtrack': 0.0006669185822829,
#   'pred_starttrack': 0.014035815373063,
#   'pred_stoptrack': 0.0982516556978225,
#   'energy': 744.2287551965527,
#   'zenith': 2.31077454797564,
#   'oneweight': 1774376186.0082865,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8641988635063171,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_85_origidx_9_RF22.mp4': {'event': 85,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9565556049346924,
#   'pred_cascade': 0.0261613503098487,
#   'pred_tgtrack': 0.0015214239247143,
#   'pred_starttrack': 0.0078321760520339,
#   'pred_stoptrack': 0.0079294247552752,
#   'energy': 6221.024705344059,
#   'zenith': 1.334693600365616,
#   'oneweight': 670397654693.5298,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9565556049346924,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_8899_origidx_5_RF22.mp4': {'event': 8899,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 4.1044722820515744e-06,
#   'pred_cascade': 0.9982540011405944,
#   'pred_tgtrack': 6.86686803419434e-07,
#   'pred_starttrack': 0.0017408496933057,
#   'pred_stoptrack': 4.122296388686664e-07,
#   'energy': 151713.94813477652,
#   'zenith': 0.3726128743115742,
#   'oneweight': 335161852062316.5,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9982540011405944,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_9685_origidx_40_RF22.mp4': {'event': 9685,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9992475509643556,
#   'pred_cascade': 1.840727348323412e-09,
#   'pred_tgtrack': 0.0002006635331781,
#   'pred_starttrack': 2.205841287405974e-09,
#   'pred_stoptrack': 0.0005517650279216,
#   'energy': 64513.34456677916,
#   'zenith': 2.7454443069175407,
#   'oneweight': 44168593557638.95,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9992475509643556,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
# ...
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_7436_origidx_23_RF22.mp4': {'event': 7436,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.6664684414863586,
#   'pred_cascade': 0.2149785012006759,
#   'pred_tgtrack': 0.0066095720976591,
#   'pred_starttrack': 0.0604526922106742,
#   'pred_stoptrack': 0.0514907054603099,
#   'energy': 773.624798750622,
#   'zenith': 3.042684351096593,
#   'oneweight': 1267186288.9638078,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6664684414863586,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_1855_origidx_17_RF22.mp4': {'event': 1855,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 4.047304901177995e-05,
#   'pred_cascade': 0.7669486403465271,
#   'pred_tgtrack': 6.897184357512742e-05,
#   'pred_starttrack': 0.2324817031621933,
#   'pred_stoptrack': 0.0004601419204846,
#   'energy': 146.86883139173074,
#   'zenith': 0.8665411555051329,
#   'oneweight': 32381248.267101053,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7669486403465271,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_10210_origidx_7_RF22.mp4': {'event': 10210,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999680995941162,
#   'pred_cascade': 2.9139681778644903e-09,
#   'pred_tgtrack': 0.0001802828192012,
#   'pred_starttrack': 2.6420936549698126e-09,
#   'pred_stoptrack': 0.0001386643998557,
#   'energy': 299687.6730566095,
#   'zenith': 1.1981553763968715,
#   'oneweight': 954037119643155.6,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999680995941162,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_9534_origidx_28_RF22.mp4': {'event': 9534,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9703916907310486,
#   'pred_cascade': 0.0030329453293234,
#   'pred_tgtrack': 0.0252823326736688,
#   'pred_starttrack': 0.0009246044210158,
#   'pred_stoptrack': 0.0003685492556542,
#   'energy': 41226.115200899614,
#   'zenith': 0.2501142195688745,
#   'oneweight': 15004105953122.238,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9703916907310486,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_9860_origidx_46_RF22.mp4': {'event': 9860,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.994424045085907,
#   'pred_cascade': 8.238106238422915e-05,
#   'pred_tgtrack': 0.0005248371162451,
#   'pred_starttrack': 6.154500442789868e-05,
#   'pred_stoptrack': 0.004907198715955,
#   'energy': 5704.254446098595,
#   'zenith': 1.7391842872204262,
#   'oneweight': 152259396102.25113,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.994424045085907,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_535_origidx_24_RF22.mp4': {'event': 535,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.997147023677826,
#   'pred_cascade': 0.0004853585269302,
#   'pred_tgtrack': 0.0001128713556681,
#   'pred_starttrack': 0.0003255287883803,
#   'pred_stoptrack': 0.001929273828864,
#   'energy': 159228.3137366832,
#   'zenith': 2.675601193241087,
#   'oneweight': 14944615747032.271,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.997147023677826,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_5731_origidx_16_RF22.mp4': {'event': 5731,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4341348111629486,
#   'pred_cascade': 0.0771017894148826,
#   'pred_tgtrack': 0.3983347713947296,
#   'pred_starttrack': 0.0536110326647758,
#   'pred_stoptrack': 0.0368176512420177,
#   'energy': 2645.4228270505746,
#   'zenith': 1.9955956078698451,
#   'oneweight': 35251276077.62172,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4341348111629486,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_5750_origidx_17_RF22.mp4': {'event': 5750,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999933242797852,
#   'pred_cascade': 1.927756457069385e-13,
#   'pred_tgtrack': 3.641082457761513e-06,
#   'pred_starttrack': 4.9694574844050265e-11,
#   'pred_stoptrack': 2.931794597316184e-06,
#   'energy': 487436.62318408827,
#   'zenith': 0.3277458190299991,
#   'oneweight': 1946746738781815.5,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999933242797852,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_7167_origidx_10_RF22.mp4': {'event': 7167,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0059208609163761,
#   'pred_cascade': 0.0022254604846239,
#   'pred_tgtrack': 0.3438659608364105,
#   'pred_starttrack': 0.0008585272007621,
#   'pred_stoptrack': 0.647129237651825,
#   'energy': 4542.649710276784,
#   'zenith': 2.42428259494346,
#   'oneweight': 442968382310.1809,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.647129237651825,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_5802_origidx_20_RF22.mp4': {'event': 5802,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.6424576640129089,
#   'pred_cascade': 0.2842448651790619,
#   'pred_tgtrack': 0.0120467655360698,
#   'pred_starttrack': 0.0464106798171997,
#   'pred_stoptrack': 0.0148400338366627,
#   'energy': 445.0246703254093,
#   'zenith': 2.2660418584296163,
#   'oneweight': 404910577.4011232,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.6424576640129089,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_7694_origidx_4_RF22.mp4': {'event': 7694,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0002080284175463,
#   'pred_cascade': 0.9942856431007384,
#   'pred_tgtrack': 2.355040384927065e-09,
#   'pred_starttrack': 0.0055063259787857,
#   'pred_stoptrack': 3.92644139424192e-08,
#   'energy': 706072.474794682,
#   'zenith': 1.6067284558071857,
#   'oneweight': 4563083420445606.0,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9942856431007384,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_9232_origidx_15_RF22.mp4': {'event': 9232,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0851816460490226,
#   'pred_cascade': 0.0316318981349468,
#   'pred_tgtrack': 0.7948160767555237,
#   'pred_starttrack': 0.0486414730548858,
#   'pred_stoptrack': 0.03972889482975,
#   'energy': 8198.015257989504,
#   'zenith': 1.758337948620626,
#   'oneweight': 2096637572069.8057,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7948160767555237,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_7522_origidx_27_RF22.mp4': {'event': 7522,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999881982803344,
#   'pred_cascade': 1.5212262872987825e-12,
#   'pred_tgtrack': 1.8040823306364475e-06,
#   'pred_starttrack': 1.1264593424709089e-11,
#   'pred_stoptrack': 1.007223272608826e-05,
#   'energy': 267422.2799340925,
#   'zenith': 1.5948769304933652,
#   'oneweight': 639058829546566.6,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999881982803344,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_7186_origidx_11_RF22.mp4': {'event': 7186,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.998713493347168,
#   'pred_cascade': 8.01195164967794e-06,
#   'pred_tgtrack': 3.400450077606365e-05,
#   'pred_starttrack': 4.692778020398691e-05,
#   'pred_stoptrack': 0.0011976140085607,
#   'energy': 14205.703956577172,
#   'zenith': 1.1578914000195637,
#   'oneweight': 1734801185485.337,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.998713493347168,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_418_origidx_23_RF22.mp4': {'event': 418,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4508348703384399,
#   'pred_cascade': 0.3560900092124939,
#   'pred_tgtrack': 0.0479211509227752,
#   'pred_starttrack': 0.1246526166796684,
#   'pred_stoptrack': 0.0205013956874609,
#   'energy': 619880.7286192083,
#   'zenith': 1.269743078558709,
#   'oneweight': 1.2018336998272008e+16,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4508348703384399,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_213_origidx_13_RF22.mp4': {'event': 213,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1393175721168518,
#   'pred_cascade': 0.0413623638451099,
#   'pred_tgtrack': 0.4816060364246368,
#   'pred_starttrack': 0.3181090652942657,
#   'pred_stoptrack': 0.0196050573140382,
#   'energy': 117043.46955886007,
#   'zenith': 1.659976258348437,
#   'oneweight': 76923180182628.72,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4816060364246368,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_1832_origidx_14_RF22.mp4': {'event': 1832,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.1959378868341446,
#   'pred_cascade': 0.5592274069786072,
#   'pred_tgtrack': 7.958428795973305e-06,
#   'pred_starttrack': 0.2446775734424591,
#   'pred_stoptrack': 0.0001491876028012,
#   'energy': 891668.4745307063,
#   'zenith': 2.180815503342413,
#   'oneweight': 2497998392030722.0,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.5592274069786072,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_348_origidx_18_RF22.mp4': {'event': 348,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0613336227834224,
#   'pred_cascade': 0.277631551027298,
#   'pred_tgtrack': 0.4471224844455719,
#   'pred_starttrack': 0.1183729767799377,
#   'pred_stoptrack': 0.095539316534996,
#   'energy': 1340.9069523334892,
#   'zenith': 1.220176090340037,
#   'oneweight': 11886962186.64101,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4471224844455719,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_1873_origidx_19_RF22.mp4': {'event': 1873,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.870042979135178e-05,
#   'pred_cascade': 0.9791824221611024,
#   'pred_tgtrack': 3.2705872854421614e-06,
#   'pred_starttrack': 0.0207463782280683,
#   'pred_stoptrack': 4.92719846079126e-05,
#   'energy': 1901.5982784528528,
#   'zenith': 0.7388207718706465,
#   'oneweight': 15503722769.771498,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9791824221611024,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_7238_origidx_14_RF22.mp4': {'event': 7238,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9997676014900208,
#   'pred_cascade': 8.947467072806248e-11,
#   'pred_tgtrack': 4.80316266475711e-05,
#   'pred_starttrack': 2.374864083165562e-09,
#   'pred_stoptrack': 0.0001844101207097,
#   'energy': 253303.48529814245,
#   'zenith': 1.3431214948620005,
#   'oneweight': 494354866891727.3,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9997676014900208,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_3294_origidx_7_RF22.mp4': {'event': 3294,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0001149410600191,
#   'pred_cascade': 0.9873308539390564,
#   'pred_tgtrack': 2.663151121851115e-07,
#   'pred_starttrack': 0.0125481821596622,
#   'pred_stoptrack': 5.704205250367522e-06,
#   'energy': 5017.299524331986,
#   'zenith': 1.1710426938201133,
#   'oneweight': 158236131358.9295,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9873308539390564,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_10081_origidx_54_RF22.mp4': {'event': 10081,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4250141084194183,
#   'pred_cascade': 0.0912586599588394,
#   'pred_tgtrack': 0.0112088853493332,
#   'pred_starttrack': 0.1559527665376663,
#   'pred_stoptrack': 0.3165655732154846,
#   'energy': 2832.454336185142,
#   'zenith': 1.7336469289258063,
#   'oneweight': 34769775579.8854,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4250141084194183,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_9355_origidx_21_RF22.mp4': {'event': 9355,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.8576597571372986,
#   'pred_cascade': 0.0278701577335596,
#   'pred_tgtrack': 0.0005188534851185,
#   'pred_starttrack': 0.0120457299053668,
#   'pred_stoptrack': 0.1019055023789405,
#   'energy': 368.90894134230206,
#   'zenith': 2.5019951670145586,
#   'oneweight': 269338709.8225076,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8576597571372986,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000003/compressed_run_22067_event_6635_origidx_8_RF22.mp4': {'event': 6635,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9992635846138,
#   'pred_cascade': 8.713369581414554e-09,
#   'pred_tgtrack': 0.0002950679336208,
#   'pred_starttrack': 3.658318235011393e-07,
#   'pred_stoptrack': 0.0004409768735058,
#   'energy': 138067.35245271248,
#   'zenith': 1.912722965775655,
#   'oneweight': 212757139953965.38,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9992635846138,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20}}

# %%
make_subject_set('nue_run_22067_subrun_000003_phase2')
# Out:
# Subject Set Name: nue_run_22067_subrun_000003_phase2
# Subject Set ID: 112418
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>]

# %%
uploader(compressed_path,nue_csv,112418)
# Out:
# Confirm if subject set 112418 is listed below.
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>]
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>]
# Number of times loop has ran: 1
# Number of times loop has ran: 2
# Number of times loop has ran: 3
# Number of times loop has ran: 4
# Number of times loop has ran: 5
# Number of times loop has ran: 6
# Number of times loop has ran: 7
# Number of times loop has ran: 8
# Number of times loop has ran: 9
# Number of times loop has ran: 10
# Number of times loop has ran: 11
# Number of times loop has ran: 12
# Number of times loop has ran: 13
# Number of times loop has ran: 14
# Number of times loop has ran: 15
# Number of times loop has ran: 16
# Number of times loop has ran: 17
# Number of times loop has ran: 18
# Number of times loop has ran: 19
# Number of times loop has ran: 20
# Number of times loop has ran: 21
# Number of times loop has ran: 22
# Number of times loop has ran: 23
# Number of times loop has ran: 24
# Number of times loop has ran: 25
# Number of times loop has ran: 26
# Number of times loop has ran: 27
# Number of times loop has ran: 28
# Number of times loop has ran: 29
# Number of times loop has ran: 30
# Number of times loop has ran: 31
# Number of times loop has ran: 32
# Number of times loop has ran: 33
# Number of times loop has ran: 34
# Number of times loop has ran: 35
# Number of times loop has ran: 36
# Number of times loop has ran: 37
# Number of times loop has ran: 38
# Number of times loop has ran: 39
# Number of times loop has ran: 40
# Number of times loop has ran: 41
# Number of times loop has ran: 42
# Number of times loop has ran: 43
# Number of times loop has ran: 44
# Number of times loop has ran: 45
# Number of times loop has ran: 46
# Number of times loop has ran: 47
# Number of times loop has ran: 48
# Number of times loop has ran: 49
# Number of times loop has ran: 50
# Number of times loop has ran: 51
# Number of times loop has ran: 52
# Number of times loop has ran: 53
# Number of times loop has ran: 54
# Number of times loop has ran: 55
# Number of times loop has ran: 56
# Number of times loop has ran: 57
# Number of times loop has ran: 58
# Number of times loop has ran: 59
# Number of times loop has ran: 60
# Number of times loop has ran: 61
# Number of times loop has ran: 62
# Number of times loop has ran: 63
# Number of times loop has ran: 64
# Number of times loop has ran: 65
# Number of times loop has ran: 66
# Number of times loop has ran: 67
# Number of times loop has ran: 68
# Number of times loop has ran: 69
# Number of times loop has ran: 70
# Number of times loop has ran: 71
# Number of times loop has ran: 72
# Number of times loop has ran: 73
# Number of times loop has ran: 74
# Number of times loop has ran: 75
# Number of times loop has ran: 76
# Number of times loop has ran: 77
# Number of times loop has ran: 78
# Number of times loop has ran: 79
# Number of times loop has ran: 80
# Number of times loop has ran: 81
# Number of times loop has ran: 82
# Number of times loop has ran: 83
# Number of times loop has ran: 84
# Number of times loop has ran: 85
# Number of times loop has ran: 86
# Number of times loop has ran: 87
# Number of times loop has ran: 88
# Number of times loop has ran: 89
# Number of times loop has ran: 90
# Number of times loop has ran: 91
# Number of times loop has ran: 92
# Number of times loop has ran: 93
# Number of times loop has ran: 94
# Number of times loop has ran: 95
# Number of times loop has ran: 96
# Number of times loop has ran: 97
# Number of times loop has ran: 98
# Number of times loop has ran: 99
# Number of times loop has ran: 100
# Number of times loop has ran: 101
# Number of times loop has ran: 102
# Number of times loop has ran: 103
# Number of times loop has ran: 104
# Number of times loop has ran: 105
# Number of times loop has ran: 106
# Number of times loop has ran: 107
# Number of times loop has ran: 108
# Number of times loop has ran: 109
# Number of times loop has ran: 110
# Number of times loop has ran: 111
# Number of times loop has ran: 112
# Number of times loop has ran: 113
# Number of times loop has ran: 114
# Number of times loop has ran: 115
# Number of times loop has ran: 116
# Number of times loop has ran: 117
# Number of times loop has ran: 118
# Number of times loop has ran: 119
# Number of times loop has ran: 120
# Number of times loop has ran: 121
# Number of times loop has ran: 122
# Number of times loop has ran: 123
# Number of times loop has ran: 124
# Number of times loop has ran: 125
# Number of times loop has ran: 126
# Number of times loop has ran: 127
# Number of times loop has ran: 128
# Number of times loop has ran: 129
# Number of times loop has ran: 130
# Number of times loop has ran: 131
# Number of times loop has ran: 132
# Number of times loop has ran: 133
# Number of times loop has ran: 134
# Number of times loop has ran: 135
# Number of times loop has ran: 136
# Number of times loop has ran: 137
# Number of times loop has ran: 138
# Number of times loop has ran: 139
# Number of times loop has ran: 140
# Number of times loop has ran: 141
# Number of times loop has ran: 142
# Number of times loop has ran: 143
# Number of times loop has ran: 144
# Number of times loop has ran: 145
# Number of times loop has ran: 146
# Number of times loop has ran: 147
# Number of times loop has ran: 148
# Number of times loop has ran: 149
# Number of times loop has ran: 150
# Number of times loop has ran: 151
# Number of times loop has ran: 152
# Number of times loop has ran: 153
# Number of times loop has ran: 154
# Number of times loop has ran: 155
# Number of times loop has ran: 156
# Number of times loop has ran: 157
# Number of times loop has ran: 158
# Number of times loop has ran: 159
# Number of times loop has ran: 160
# Number of times loop has ran: 161
# Number of times loop has ran: 162
# Number of times loop has ran: 163
# Number of times loop has ran: 164
# Number of times loop has ran: 165
# Number of times loop has ran: 166
# Number of times loop has ran: 167
# Number of times loop has ran: 168
# Number of times loop has ran: 169
# Number of times loop has ran: 170
# Number of times loop has ran: 171
# Number of times loop has ran: 172
# Number of times loop has ran: 173
# Number of times loop has ran: 174
# Number of times loop has ran: 175
# Number of times loop has ran: 176
# Number of times loop has ran: 177
# Number of times loop has ran: 178
# Number of times loop has ran: 179
# Number of times loop has ran: 180
# Number of times loop has ran: 181
# Number of times loop has ran: 182
# Number of times loop has ran: 183
# Number of times loop has ran: 184
# Number of times loop has ran: 185
# Number of times loop has ran: 186
# Number of times loop has ran: 187
# Number of times loop has ran: 188
# Number of times loop has ran: 189
# Number of times loop has ran: 190
# Number of times loop has ran: 191
# Number of times loop has ran: 192
# Number of times loop has ran: 193
