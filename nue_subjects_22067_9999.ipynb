# %% [markdown]
# # Phase 1: Subject Creation
#
# **Description:**
#
# This notebook is to act as the resulting summary file for the creation and upload of subjects for the IceCube Zooniverse project currently called *Name that Neutrino!*. The project is currently being maintained by Elizabeth Warrick (as of March 2023). In this notebook, we take the i3 file and run it through several filters. [note: describe more later].
#
# > Nu Type: NuE
#
# > Run: 22076
#
# > SubRun: 009999
#
# ### Summary Stats:
#
# To be filled in after completing process. Also need to figure out global variables.
#
# **Subject Set Name:**

# %%
#Imports

#My functions: 
from uniformenergydist_filter import *

#General:
import numpy as np
import sys
import os
import subprocess
import argparse
import csv
from tables import *
import pandas as pd
from matplotlib import pyplot as plt
import h5py

#Zooniverse:
from panoptes_client import Panoptes, Project, SubjectSet, Subject
import magic
import glob

#IceCube:
from icecube.icetray import I3Units
import icecube.MuonGun
from icecube import dataio, dataclasses, icetray, MuonGun
from I3Tray import *
from icecube.hdfwriter import I3HDFWriter
from mc_labeler import MCLabeler #make sure that mc_labeler script is in current directory.

# %%
#Specify file paths:

#Initial I3 File:
nue = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/classifier_rehyd_DST_IC86.2020_NuE.022067.009999.i3.zst'

#Desired output directory. Note that creation of this directory is not yet coded and is done manually. 
phase1_dir = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/'

# %%
#Run Filter 1 to label MC truth.
filter1(nue,phase1_dir)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/mc_labeler.py:523: UserWarning: Couldn't find OMKey in MCPESeriesMap
#   warnings.warn("Couldn't find OMKey in MCPESeriesMap")

# %% [markdown]
# Note that the above cell might return an "exception" warning that the *MCPESeriesMap could not be found*. I am unsure why it does that because when I check the i3 file in dataio-shovel, I see the specified mc_pid_series_map (look at mc_labeler.py for exact name of specified key). The resulting file size should be around 400 MB.

# %%
#Path of hdf from above filter.
nue_hdf = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/\
Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.009999.i3.zst.hd5'

# %%
#Run uniformenergy_events function which requires hdf from filter 1, 
#number of bins, size of each random choice, and a random seed. 

uniformenergy_events(nue_hdf,25,12,12,subrun = True)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['binned_log10E'] = pd.cut(x = np.log10(df_filtered['energy']), bins = bins, labels = labels, include_lowest = True) #might throw an error?
# Number of Bins: 25
# Number of Events per Bin: 12
# Total Number of Events: 300
# Initial Number of Events: 2881
# Number of Events after filtering: 2787
# Please input subrun number:
# 9999

# %% [markdown]
# The above function throws another warning about pd.cut, currently that is not a problem but I don't know if a new version of pandas will allow this.

# %%
#Path to Random Events CSV
nue_csv = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/random_events_uniform_energy_distrib_22067_9999.csv'

# %%
#Run event_characterization_plots function whick makes some quick 
#plots to get an idea of what data you're dealing with.
#Note that I want to update the plot types, maybe make a 2D histogram as Mike K suggested. 
#For truth labels, check out enums.py or in the .py file that holds the functions.

event_characterization_plots(nue_csv)

# %% [markdown]
# Now that we have the events for this phase chosen, we run the second filter to pick out only those events.

# %%
#Path to i3 file from filter1 with MC truth labels. 
nue_filter1 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.009999.i3.zst'

# %%
#Run function to perform second filter which passes through only selected event IDs chosen from 
#the uniformenergy_events function. 
filter2(nue_filter1,phase1_dir,nue_csv)

# %%
#Path to i3 file from filter 2 that holds only specified events. 
nue_filter2 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.009999.i3.zst'

# %%
#Run function to perform third filter, which returns only the DAQ frames of the specified events.
#DAQ only file is then split up into many smaller i3 files since SteamShovel can't handle making videos of large
#i3 files at one time. Size limit is approx 2E6 MB (? unsure of units)
filter3(nue_filter2,22067_9999,phase1_dir)

# %%
#Path to NuMu Daq Only folder
nue_daq = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220679999/'

# %%
get_steamshovel(nue_daq,220679999)
# Out:
# List of files:
# ['/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220679999/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.009999.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220679999/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.009999.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220679999/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.009999.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220679999/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.009999.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220679999/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.009999.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220679999/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.009999.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220679999/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.009999.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220679999/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.009999.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220679999/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.009999.i3.zst']
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220679999/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.009999.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220679999/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.009999.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220679999/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.009999.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220679999/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.009999.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220679999/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.009999.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220679999/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.009999.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220679999/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.009999.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220679999/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.009999.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_220679999/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.009999.i3.zst

# %% [markdown]
# Ideas for Compression:
# - Use GUI to add files to queue and send to one compression folder.
# - Add a subprocess line in movie script to compress the video after making it and direct it to save in the compression folder.

# %%
compressed_path = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/'

# %% [markdown]
# Can't get manifest yet since some subjects are missing and lining it up won't work.

# %%
get_manifest(compressed_path, nue_csv)
# Out:
# {'/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_2900_origidx_10_RF22.mp4': {'event': 2900,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2362623512744903,
#   'pred_cascade': 0.0670378431677818,
#   'pred_tgtrack': 0.0069445576518774,
#   'pred_starttrack': 0.0747869089245796,
#   'pred_stoptrack': 0.6149683594703674,
#   'energy': 12940.108310772484,
#   'zenith': 2.415102611066815,
#   'oneweight': 332498643390.5286,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6149683594703674,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_2583_origidx_11_RF22.mp4': {'event': 2583,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9997615218162536,
#   'pred_cascade': 7.813872571205138e-07,
#   'pred_tgtrack': 4.451688801054843e-05,
#   'pred_starttrack': 2.9352411274885526e-06,
#   'pred_stoptrack': 0.0001901644573081,
#   'energy': 13774.30494793384,
#   'zenith': 0.7609336399520833,
#   'oneweight': 1769294891420.3606,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9997615218162536,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_2784_origidx_4_RF22.mp4': {'event': 2784,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 4.873234865954146e-05,
#   'pred_cascade': 0.9476800560951232,
#   'pred_tgtrack': 3.824919986072928e-06,
#   'pred_starttrack': 0.052230067551136,
#   'pred_stoptrack': 3.7447687645908445e-05,
#   'energy': 346879.77358944464,
#   'zenith': 0.8554778095716427,
#   'oneweight': 2138547397723354.5,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9476800560951232,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_3783_origidx_11_RF22.mp4': {'event': 3783,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.1020949134253897e-05,
#   'pred_cascade': 0.9871729612350464,
#   'pred_tgtrack': 1.395066533405043e-07,
#   'pred_starttrack': 0.0128043806180357,
#   'pred_stoptrack': 1.4084179156270693e-06,
#   'energy': 61915.365460793546,
#   'zenith': 0.9685280605273034,
#   'oneweight': 91551578245288.95,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9871729612350464,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_5704_origidx_11_RF22.mp4': {'event': 5704,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 4.161986726103351e-05,
#   'pred_cascade': 0.9810373187065125,
#   'pred_tgtrack': 5.47144907159236e-09,
#   'pred_starttrack': 0.0189202651381492,
#   'pred_stoptrack': 6.478758223238401e-07,
#   'energy': 145203.8998140009,
#   'zenith': 2.124856263570748,
#   'oneweight': 13066615658616.252,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9810373187065125,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_3706_origidx_6_RF22.mp4': {'event': 3706,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9997674822807312,
#   'pred_cascade': 2.2732430693395145e-07,
#   'pred_tgtrack': 5.480018444359303e-05,
#   'pred_starttrack': 3.967575423757808e-07,
#   'pred_stoptrack': 0.0001771122042555,
#   'energy': 980935.9650008284,
#   'zenith': 2.5598952300072946,
#   'oneweight': 1.809788368833653e+16,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9997674822807312,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_6_origidx_5_RF22.mp4': {'event': 6,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0270204618573188,
#   'pred_cascade': 0.0064673414453864,
#   'pred_tgtrack': 0.0049222409725189,
#   'pred_starttrack': 0.0113910278305411,
#   'pred_stoptrack': 0.9501989483833312,
#   'energy': 359.8821530633211,
#   'zenith': 1.667183995879182,
#   'oneweight': 291788776.93586737,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9501989483833312,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_2601_origidx_12_RF22.mp4': {'event': 2601,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2104445546865463,
#   'pred_cascade': 0.0068074204027652,
#   'pred_tgtrack': 0.7365309596061707,
#   'pred_starttrack': 0.00962445884943,
#   'pred_stoptrack': 0.0365927219390869,
#   'energy': 21164.825603785783,
#   'zenith': 2.611369472234686,
#   'oneweight': 3289081232911.108,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7365309596061707,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_3739_origidx_9_RF22.mp4': {'event': 3739,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1178904324769973,
#   'pred_cascade': 0.0156140401959419,
#   'pred_tgtrack': 0.4342555701732635,
#   'pred_starttrack': 0.0137119246646761,
#   'pred_stoptrack': 0.4185280501842499,
#   'energy': 1740.83436748918,
#   'zenith': 0.7429866487773877,
#   'oneweight': 12239026137.43334,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4342555701732635,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_4310_origidx_24_RF22.mp4': {'event': 4310,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999631643295288,
#   'pred_cascade': 3.50910211999178e-09,
#   'pred_tgtrack': 2.4909556941565825e-06,
#   'pred_starttrack': 5.416066528596275e-07,
#   'pred_stoptrack': 3.382045906619169e-05,
#   'energy': 275018.29544455773,
#   'zenith': 1.5611655076095334,
#   'oneweight': 439342396315379.9,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999631643295288,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_3942_origidx_16_RF22.mp4': {'event': 3942,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0648772940039634,
#   'pred_cascade': 0.0212138798087835,
#   'pred_tgtrack': 0.8922364115715027,
#   'pred_starttrack': 0.0134302275255322,
#   'pred_stoptrack': 0.0082421712577342,
#   'energy': 932.8335325264372,
#   'zenith': 1.4771862412655992,
#   'oneweight': 3957520354.14843,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8922364115715027,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_165_origidx_10_RF22.mp4': {'event': 165,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.00215734844096,
#   'pred_cascade': 0.0983879789710044,
#   'pred_tgtrack': 0.0002680042525753,
#   'pred_starttrack': 0.8963810205459595,
#   'pred_stoptrack': 0.0028055859729647,
#   'energy': 404.54122778599,
#   'zenith': 1.2371867191899784,
#   'oneweight': 302335467.83616906,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.8963810205459595,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_162_origidx_9_RF22.mp4': {'event': 162,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.7721162438392639,
#   'pred_cascade': 0.0006083406624384,
#   'pred_tgtrack': 0.2194368690252304,
#   'pred_starttrack': 0.0001834787690313,
#   'pred_stoptrack': 0.0076551339589059,
#   'energy': 6704.907478178771,
#   'zenith': 2.387503978151588,
#   'oneweight': 241025968580.30197,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7721162438392639,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_2630_origidx_13_RF22.mp4': {'event': 2630,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0799107998609542,
#   'pred_cascade': 0.0176881719380617,
#   'pred_tgtrack': 0.8437932729721069,
#   'pred_starttrack': 0.0178630482405424,
#   'pred_stoptrack': 0.0407447293400764,
#   'energy': 115.43451161580803,
#   'zenith': 1.7678182932092903,
#   'oneweight': 7281891.758314773,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8437932729721069,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_2670_origidx_14_RF22.mp4': {'event': 2670,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.113562636077404,
#   'pred_cascade': 0.0466768853366375,
#   'pred_tgtrack': 0.8084682822227478,
#   'pred_starttrack': 0.0146373184397816,
#   'pred_stoptrack': 0.0166547913104295,
#   'energy': 17325.592203977576,
#   'zenith': 1.3793706893708193,
#   'oneweight': 2197339919673.1748,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8084682822227478,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_9443_origidx_4_RF22.mp4': {'event': 9443,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9997531771659852,
#   'pred_cascade': 2.21460163629672e-06,
#   'pred_tgtrack': 1.955543484655209e-05,
#   'pred_starttrack': 1.9014227291336283e-05,
#   'pred_stoptrack': 0.0002059047110378,
#   'energy': 70842.12746717023,
#   'zenith': 1.399608909688029,
#   'oneweight': 40071842113223.4,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9997531771659852,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_4159_origidx_20_RF22.mp4': {'event': 4159,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0265407375991344,
#   'pred_cascade': 0.944181501865387,
#   'pred_tgtrack': 0.0002024545392487,
#   'pred_starttrack': 0.0289962776005268,
#   'pred_stoptrack': 7.899357296992093e-05,
#   'energy': 337279.9307227295,
#   'zenith': 2.050048074127403,
#   'oneweight': 240484470473765.84,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.944181501865387,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_2555_origidx_10_RF22.mp4': {'event': 2555,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9998791217803956,
#   'pred_cascade': 6.566527765983211e-09,
#   'pred_tgtrack': 1.8686105249798857e-05,
#   'pred_starttrack': 1.8607085650046432e-08,
#   'pred_stoptrack': 0.0001021083808154,
#   'energy': 804647.2616222501,
#   'zenith': 2.122662693685321,
#   'oneweight': 42797098890384.266,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9998791217803956,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_2846_origidx_9_RF22.mp4': {'event': 2846,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9956142902374268,
#   'pred_cascade': 0.0001307977800024,
#   'pred_tgtrack': 0.0002056870434898,
#   'pred_starttrack': 0.0001839932374423,
#   'pred_stoptrack': 0.0038652375806123,
#   'energy': 14545.409660242132,
#   'zenith': 0.2679020789113316,
#   'oneweight': 1618568018083.6304,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9956142902374268,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_4500_origidx_26_RF22.mp4': {'event': 4500,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 1.1632632777036632e-05,
#   'pred_cascade': 0.9828585386276244,
#   'pred_tgtrack': 3.948139806198015e-07,
#   'pred_starttrack': 0.0171197243034839,
#   'pred_stoptrack': 9.77170839178143e-06,
#   'energy': 1060.2772644986492,
#   'zenith': 2.2752277081118857,
#   'oneweight': 4756148359.973777,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9828585386276244,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_235_origidx_16_RF22.mp4': {'event': 235,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0038857669569551,
#   'pred_cascade': 0.0030638561584055,
#   'pred_tgtrack': 0.0111286155879497,
#   'pred_starttrack': 0.975779354572296,
#   'pred_stoptrack': 0.0061423857696354,
#   'energy': 5084.772971611361,
#   'zenith': 1.503545171280771,
#   'oneweight': 508493540651.0344,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.975779354572296,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_3804_origidx_12_RF22.mp4': {'event': 3804,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0007937528425827,
#   'pred_cascade': 0.4769389033317566,
#   'pred_tgtrack': 0.0002848002768587,
#   'pred_starttrack': 0.5219141244888306,
#   'pred_stoptrack': 6.838208355475217e-05,
#   'energy': 1233.8444147607192,
#   'zenith': 0.9181639652126252,
#   'oneweight': 6595196535.102114,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.5219141244888306,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_3847_origidx_14_RF22.mp4': {'event': 3847,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0001469032577006,
#   'pred_cascade': 0.9898171424865724,
#   'pred_tgtrack': 2.672364462341648e-05,
#   'pred_starttrack': 0.0098207676783204,
#   'pred_stoptrack': 0.00018839740369,
#   'energy': 3143.840436469714,
#   'zenith': 1.691457054733216,
#   'oneweight': 40807076168.94619,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9898171424865724,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_3765_origidx_10_RF22.mp4': {'event': 3765,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.8675249814987183,
#   'pred_cascade': 0.0372882671654224,
#   'pred_tgtrack': 0.0009397339890711,
#   'pred_starttrack': 0.0481168814003467,
#   'pred_stoptrack': 0.0461301580071449,
#   'energy': 305.6138360555789,
#   'zenith': 1.4996505303457055,
#   'oneweight': 137061597.70638093,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8675249814987183,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_4052_origidx_19_RF22.mp4': {'event': 4052,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2399895340204239,
#   'pred_cascade': 0.1776047199964523,
#   'pred_tgtrack': 0.1568059772253036,
#   'pred_starttrack': 0.2804218232631683,
#   'pred_stoptrack': 0.1451779454946518,
#   'energy': 775.3595363458846,
#   'zenith': 2.2804212049937127,
#   'oneweight': 2007384132.515868,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.2804218232631683,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_4238_origidx_22_RF22.mp4': {'event': 4238,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0838853195309639,
#   'pred_cascade': 0.0166977401822805,
#   'pred_tgtrack': 0.0576355457305908,
#   'pred_starttrack': 0.3846936523914337,
#   'pred_stoptrack': 0.457087755203247,
#   'energy': 3073.220585590542,
#   'zenith': 1.663389634136785,
#   'oneweight': 113153094809.25449,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.457087755203247,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_4267_origidx_23_RF22.mp4': {'event': 4267,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0005646044737659,
#   'pred_cascade': 0.2739427983760834,
#   'pred_tgtrack': 0.0020985875744372,
#   'pred_starttrack': 0.6896800994873047,
#   'pred_stoptrack': 0.0337139628827571,
#   'energy': 154.15570766563368,
#   'zenith': 0.5133122465663603,
#   'oneweight': 26081988.00408393,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.6896800994873047,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_2524_origidx_9_RF22.mp4': {'event': 2524,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 4.481936775846407e-05,
#   'pred_cascade': 0.9924835562705994,
#   'pred_tgtrack': 1.2775272807630245e-05,
#   'pred_starttrack': 0.0073435129597783,
#   'pred_stoptrack': 0.0001153919292846,
#   'energy': 5304.442103219613,
#   'zenith': 1.1325165778205943,
#   'oneweight': 271387588075.18387,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9924835562705994,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_5398_origidx_5_RF22.mp4': {'event': 5398,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.524017716292292e-05,
#   'pred_cascade': 0.9841080904006958,
#   'pred_tgtrack': 3.282649049651809e-05,
#   'pred_starttrack': 0.0151706971228122,
#   'pred_stoptrack': 0.0006731515750288,
#   'energy': 2287.190264031526,
#   'zenith': 1.166235276600146,
#   'oneweight': 24640668035.09881,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9841080904006958,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_8315_origidx_12_RF22.mp4': {'event': 8315,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.0721476428443566e-05,
#   'pred_cascade': 0.991571307182312,
#   'pred_tgtrack': 6.090789383961237e-07,
#   'pred_starttrack': 0.0084138922393321,
#   'pred_stoptrack': 3.3956050629058154e-06,
#   'energy': 12132.866331848716,
#   'zenith': 0.1877382614658736,
#   'oneweight': 973362063367.0336,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.991571307182312,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_8146_origidx_7_RF22.mp4': {'event': 8146,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9996706247329712,
#   'pred_cascade': 5.362431352295971e-07,
#   'pred_tgtrack': 5.315462112776004e-05,
#   'pred_starttrack': 1.424817014594737e-06,
#   'pred_stoptrack': 0.0002743715594988,
#   'energy': 25323.09651474056,
#   'zenith': 1.519406405548568,
#   'oneweight': 3989394564948.253,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9996706247329712,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_3593_origidx_4_RF22.mp4': {'event': 3593,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9994248151779176,
#   'pred_cascade': 4.022649136459222e-06,
#   'pred_tgtrack': 7.956771150929853e-05,
#   'pred_starttrack': 2.66508891400008e-06,
#   'pred_stoptrack': 0.0004889132105745,
#   'energy': 3122.227538891322,
#   'zenith': 1.4457540229603327,
#   'oneweight': 33914048102.10987,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9994248151779176,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_2435_origidx_6_RF22.mp4': {'event': 2435,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999812841415404,
#   'pred_cascade': 4.552283029701787e-12,
#   'pred_tgtrack': 8.365069334104192e-06,
#   'pred_starttrack': 1.1327012217066112e-08,
#   'pred_stoptrack': 1.042331314238254e-05,
#   'energy': 494893.4871286449,
#   'zenith': 0.5959468555795204,
#   'oneweight': 2270287348686183.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999812841415404,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_45_origidx_7_RF22.mp4': {'event': 45,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999955892562866,
#   'pred_cascade': 2.2110702158073532e-09,
#   'pred_tgtrack': 1.4938103731765295e-06,
#   'pred_starttrack': 7.296699777725736e-08,
#   'pred_stoptrack': 2.8889890018035658e-06,
#   'energy': 88976.64913999266,
#   'zenith': 1.7032719474750526,
#   'oneweight': 65033555749259.484,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999955892562866,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_3993_origidx_18_RF22.mp4': {'event': 3993,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 5.323822915670462e-05,
#   'pred_cascade': 0.9751416444778442,
#   'pred_tgtrack': 2.6457844342075987e-06,
#   'pred_starttrack': 0.024684514850378,
#   'pred_stoptrack': 0.0001179565806523,
#   'energy': 2033.6672024388663,
#   'zenith': 1.5895513823693186,
#   'oneweight': 13976072170.653872,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9751416444778442,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_8234_origidx_9_RF22.mp4': {'event': 8234,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 3.027347702300176e-05,
#   'pred_cascade': 0.9659515023231506,
#   'pred_tgtrack': 7.990609560692974e-07,
#   'pred_starttrack': 0.0339991264045238,
#   'pred_stoptrack': 1.829399298003409e-05,
#   'energy': 579.4160108062288,
#   'zenith': 1.9991782199203272,
#   'oneweight': 850899740.7365189,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9659515023231506,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_5305_origidx_4_RF22.mp4': {'event': 5305,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.5818692445755005,
#   'pred_cascade': 0.0135258082300424,
#   'pred_tgtrack': 0.0005712236161343,
#   'pred_starttrack': 0.0096458084881305,
#   'pred_stoptrack': 0.3943879306316376,
#   'energy': 197.5077681816995,
#   'zenith': 2.1715601765544017,
#   'oneweight': 54745682.893105686,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5818692445755005,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_90_origidx_8_RF22.mp4': {'event': 90,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2894600033760071,
#   'pred_cascade': 0.0780882313847541,
#   'pred_tgtrack': 0.4849023520946502,
#   'pred_starttrack': 0.0747101604938507,
#   'pred_stoptrack': 0.0728392675518989,
#   'energy': 3151.6969267085265,
#   'zenith': 1.1855754942197565,
#   'oneweight': 45390305117.24322,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4849023520946502,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_8226_origidx_8_RF22.mp4': {'event': 8226,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9990944862365724,
#   'pred_cascade': 5.90816398471361e-07,
#   'pred_tgtrack': 0.0007641219999641,
#   'pred_starttrack': 8.234117672145658e-07,
#   'pred_stoptrack': 0.000139887779369,
#   'energy': 191962.9660324851,
#   'zenith': 0.7908998135228693,
#   'oneweight': 356777511396344.1,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9990944862365724,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_7927_origidx_4_RF22.mp4': {'event': 7927,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.7753483057022095,
#   'pred_cascade': 0.1648034900426864,
#   'pred_tgtrack': 0.0469814501702785,
#   'pred_starttrack': 0.0120259970426559,
#   'pred_stoptrack': 0.000840806576889,
#   'energy': 380889.0671316989,
#   'zenith': 1.0463658364831274,
#   'oneweight': 1389675900180402.8,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7753483057022095,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_3966_origidx_17_RF22.mp4': {'event': 3966,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.6618849039077759,
#   'pred_cascade': 0.092807613313198,
#   'pred_tgtrack': 0.000687769439537,
#   'pred_starttrack': 0.0767645016312599,
#   'pred_stoptrack': 0.1678551882505417,
#   'energy': 116.48020822037638,
#   'zenith': 1.5229032986189055,
#   'oneweight': 12340222.887779158,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6618849039077759,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_2377_origidx_4_RF22.mp4': {'event': 2377,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1570859402418136,
#   'pred_cascade': 0.0272215399891138,
#   'pred_tgtrack': 0.029485385864973,
#   'pred_starttrack': 0.0292822998017072,
#   'pred_stoptrack': 0.7569248080253601,
#   'energy': 181.5471846351044,
#   'zenith': 1.70693922518257,
#   'oneweight': 21468584.095985264,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7569248080253601,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_192_origidx_12_RF22.mp4': {'event': 192,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0327522046864032,
#   'pred_cascade': 0.0057169483043253,
#   'pred_tgtrack': 0.926790177822113,
#   'pred_starttrack': 0.0106678595766425,
#   'pred_stoptrack': 0.0240728016942739,
#   'energy': 45900.25826267219,
#   'zenith': 1.4861855878568793,
#   'oneweight': 153080887981278.94,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.926790177822113,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_2838_origidx_8_RF22.mp4': {'event': 2838,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1795986294746399,
#   'pred_cascade': 0.0386880822479724,
#   'pred_tgtrack': 0.6890185475349426,
#   'pred_starttrack': 0.0272452924400568,
#   'pred_stoptrack': 0.0654493868350982,
#   'energy': 194.7213565069426,
#   'zenith': 1.2690713125880586,
#   'oneweight': 44275919.69013816,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6890185475349426,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_2830_origidx_7_RF22.mp4': {'event': 2830,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4289864897727966,
#   'pred_cascade': 0.0919375717639923,
#   'pred_tgtrack': 0.1884951144456863,
#   'pred_starttrack': 0.0581928864121437,
#   'pred_stoptrack': 0.2323880195617675,
#   'energy': 553.9532464471654,
#   'zenith': 1.3658171675590394,
#   'oneweight': 709048484.4523665,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4289864897727966,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_2819_origidx_5_RF22.mp4': {'event': 2819,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999408721923828,
#   'pred_cascade': 1.3363620432471636e-08,
#   'pred_tgtrack': 5.858606527908705e-06,
#   'pred_starttrack': 3.7059091795299544e-08,
#   'pred_stoptrack': 5.331232750904746e-05,
#   'energy': 11017.694152976814,
#   'zenith': 1.6475908996341455,
#   'oneweight': 4286193775844.405,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999408721923828,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_5478_origidx_7_RF22.mp4': {'event': 5478,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.2940835952758789,
#   'pred_cascade': 0.527006983757019,
#   'pred_tgtrack': 0.000189119571587,
#   'pred_starttrack': 0.0488964542746543,
#   'pred_stoptrack': 0.1298238784074783,
#   'energy': 451.5156213905636,
#   'zenith': 1.7157586770017907,
#   'oneweight': 374914261.877952,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.527006983757019,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_31_origidx_6_RF22.mp4': {'event': 31,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2258486151695251,
#   'pred_cascade': 0.048187855631113,
#   'pred_tgtrack': 0.0323988944292068,
#   'pred_starttrack': 0.3188133537769317,
#   'pred_stoptrack': 0.3747512698173523,
#   'energy': 49860.640903262,
#   'zenith': 0.9984153311453264,
#   'oneweight': 59094601020033.74,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3747512698173523,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_995_origidx_4_RF22.mp4': {'event': 995,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9894006848335266,
#   'pred_cascade': 0.000160714611411,
#   'pred_tgtrack': 0.0037641653325408,
#   'pred_starttrack': 0.0001457080361433,
#   'pred_stoptrack': 0.0065286769531667,
#   'energy': 2930.646864243252,
#   'zenith': 1.4893315990658775,
#   'oneweight': 110585565098.80782,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9894006848335266,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_8289_origidx_11_RF22.mp4': {'event': 8289,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.0001713084930088,
#   'pred_cascade': 0.6223215460777283,
#   'pred_tgtrack': 9.431797661818564e-05,
#   'pred_starttrack': 0.3773736655712127,
#   'pred_stoptrack': 3.918349830200896e-05,
#   'energy': 37615.954623199,
#   'zenith': 1.4749292199958262,
#   'oneweight': 11051889377398.438,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.6223215460777283,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_8105_origidx_6_RF22.mp4': {'event': 8105,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.8178426623344421,
#   'pred_cascade': 0.0072009013965725,
#   'pred_tgtrack': 0.0031030834652483,
#   'pred_starttrack': 0.0074544637463986,
#   'pred_stoptrack': 0.1643988639116287,
#   'energy': 478.4263252185795,
#   'zenith': 2.349387932563868,
#   'oneweight': 490592322.2651223,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8178426623344421,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_2721_origidx_15_RF22.mp4': {'event': 2721,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.16379976272583,
#   'pred_cascade': 0.0422817431390285,
#   'pred_tgtrack': 0.334117442369461,
#   'pred_starttrack': 0.1769537329673767,
#   'pred_stoptrack': 0.2828473150730133,
#   'energy': 1746.7464520251658,
#   'zenith': 1.7845938940417925,
#   'oneweight': 26249531317.15633,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.334117442369461,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_207_origidx_13_RF22.mp4': {'event': 207,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1050290837883949,
#   'pred_cascade': 0.0081788776442408,
#   'pred_tgtrack': 0.0062862345948815,
#   'pred_starttrack': 0.1001976430416107,
#   'pred_stoptrack': 0.780308187007904,
#   'energy': 158335.0906540936,
#   'zenith': 0.6159348302521486,
#   'oneweight': 166846462759450.6,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.780308187007904,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_4237_origidx_21_RF22.mp4': {'event': 4237,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4349693357944488,
#   'pred_cascade': 0.1091728881001472,
#   'pred_tgtrack': 0.0391869843006134,
#   'pred_starttrack': 0.0545189902186393,
#   'pred_stoptrack': 0.3621517419815063,
#   'energy': 279.71316448415814,
#   'zenith': 1.5931033072391276,
#   'oneweight': 66798618.87377344,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4349693357944488,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_226_origidx_15_RF22.mp4': {'event': 226,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0010413320269435,
#   'pred_cascade': 0.9982864260673524,
#   'pred_tgtrack': 1.6521373158440156e-10,
#   'pred_starttrack': 0.0006715424824506,
#   'pred_stoptrack': 6.692488341286662e-07,
#   'energy': 254910.51050858892,
#   'zenith': 2.12833643575726,
#   'oneweight': 58569464120840.57,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9982864260673524,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_5456_origidx_6_RF22.mp4': {'event': 5456,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 4.000961780548096e-06,
#   'pred_cascade': 0.995165467262268,
#   'pred_tgtrack': 1.1750311301739202e-07,
#   'pred_starttrack': 0.0048295417800545,
#   'pred_stoptrack': 8.767097483541875e-07,
#   'energy': 116001.51108068923,
#   'zenith': 0.6569703304627691,
#   'oneweight': 249918658750555.7,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.995165467262268,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_1005_origidx_6_RF22.mp4': {'event': 1005,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2335019409656524,
#   'pred_cascade': 0.0607830137014389,
#   'pred_tgtrack': 0.6086506843566895,
#   'pred_starttrack': 0.0309025142341852,
#   'pred_stoptrack': 0.0661618635058403,
#   'energy': 105494.5296039094,
#   'zenith': 1.8107641804633017,
#   'oneweight': 56735870090259.82,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6086506843566895,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_3897_origidx_15_RF22.mp4': {'event': 3897,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 5.43657188245561e-05,
#   'pred_cascade': 0.9775132536888124,
#   'pred_tgtrack': 7.936249062368006e-07,
#   'pred_starttrack': 0.0223923418670892,
#   'pred_stoptrack': 3.9284848753595725e-05,
#   'energy': 1974.672607152336,
#   'zenith': 1.5623968588349106,
#   'oneweight': 33002413684.222908,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9775132536888124,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_7115_origidx_4_RF22.mp4': {'event': 7115,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0985621064901351,
#   'pred_cascade': 0.0257733631879091,
#   'pred_tgtrack': 0.6344039440155029,
#   'pred_starttrack': 0.0132520468905568,
#   'pred_stoptrack': 0.2280085980892181,
#   'energy': 511122.2377778773,
#   'zenith': 1.3959655994083675,
#   'oneweight': 1.0737305356672518e+16,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6344039440155029,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_8477_origidx_13_RF22.mp4': {'event': 8477,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999963402748108,
#   'pred_cascade': 1.0725940274847189e-10,
#   'pred_tgtrack': 2.2658809029962867e-05,
#   'pred_starttrack': 3.2889544421266237e-09,
#   'pred_stoptrack': 1.3915106137574185e-05,
#   'energy': 105056.01158635494,
#   'zenith': 1.0348736434431856,
#   'oneweight': 294465380469050.06,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999963402748108,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_2440_origidx_7_RF22.mp4': {'event': 2440,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0264161117374897,
#   'pred_cascade': 0.0097284903749823,
#   'pred_tgtrack': 0.8130908012390137,
#   'pred_starttrack': 0.0026773484423756,
#   'pred_stoptrack': 0.1480872333049774,
#   'energy': 1161.376953458448,
#   'zenith': 1.844609582182419,
#   'oneweight': 8696415385.084349,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8130908012390137,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_8265_origidx_10_RF22.mp4': {'event': 8265,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4890649318695068,
#   'pred_cascade': 0.1592699140310287,
#   'pred_tgtrack': 0.070357471704483,
#   'pred_starttrack': 0.0836290046572685,
#   'pred_stoptrack': 0.197678729891777,
#   'energy': 25033.022065869834,
#   'zenith': 1.748216688587349,
#   'oneweight': 3716714030557.0938,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4890649318695068,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_5598_origidx_9_RF22.mp4': {'event': 5598,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9976322650909424,
#   'pred_cascade': 1.0357268820371247e-07,
#   'pred_tgtrack': 0.0005482368869706,
#   'pred_starttrack': 1.5196818594631625e-06,
#   'pred_stoptrack': 0.0018177694873884,
#   'energy': 556409.3781412122,
#   'zenith': 1.522863136273815,
#   'oneweight': 2765641214362824.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9976322650909424,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_5663_origidx_10_RF22.mp4': {'event': 5663,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3135777711868286,
#   'pred_cascade': 0.1073552817106247,
#   'pred_tgtrack': 0.3888246119022369,
#   'pred_starttrack': 0.071623146533966,
#   'pred_stoptrack': 0.1186192482709884,
#   'energy': 17768.729023391068,
#   'zenith': 1.7785478539974766,
#   'oneweight': 16286498210859.385,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3888246119022369,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_2515_origidx_8_RF22.mp4': {'event': 2515,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0719200298190116,
#   'pred_cascade': 0.0229515228420496,
#   'pred_tgtrack': 0.0518587604165077,
#   'pred_starttrack': 0.0178125314414501,
#   'pred_stoptrack': 0.8354571461677551,
#   'energy': 132.05610549750526,
#   'zenith': 1.714453645207514,
#   'oneweight': 15505122.593222007,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8354571461677551,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_3713_origidx_7_RF22.mp4': {'event': 3713,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9983648657798768,
#   'pred_cascade': 4.5064797404847923e-07,
#   'pred_tgtrack': 0.0007554275216534,
#   'pred_starttrack': 5.586539941759838e-07,
#   'pred_stoptrack': 0.000878641847521,
#   'energy': 779346.7423448068,
#   'zenith': 0.4994790871185351,
#   'oneweight': 1.1422635893731926e+16,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9983648657798768,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_3644_origidx_5_RF22.mp4': {'event': 3644,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0017491509206593,
#   'pred_cascade': 0.6915566325187683,
#   'pred_tgtrack': 7.399219157377956e-06,
#   'pred_starttrack': 0.3066565990447998,
#   'pred_stoptrack': 3.023567478521727e-05,
#   'energy': 4427.152269484153,
#   'zenith': 1.1421512051073728,
#   'oneweight': 119439714893.4838,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.6915566325187683,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_2401_origidx_5_RF22.mp4': {'event': 2401,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0001218417528434,
#   'pred_cascade': 0.9709153771400452,
#   'pred_tgtrack': 2.9892849852330983e-05,
#   'pred_starttrack': 0.0289059784263372,
#   'pred_stoptrack': 2.681242040125653e-05,
#   'energy': 28692.844823572144,
#   'zenith': 2.083982851724852,
#   'oneweight': 8301251429721.507,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9709153771400452,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_1059_origidx_8_RF22.mp4': {'event': 1059,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9992196559906006,
#   'pred_cascade': 4.49424987891689e-07,
#   'pred_tgtrack': 0.0006996326847001,
#   'pred_starttrack': 1.5325450704040122e-06,
#   'pred_stoptrack': 7.870702393120155e-05,
#   'energy': 7150.351404461844,
#   'zenith': 0.8689255471156081,
#   'oneweight': 373804923494.874,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9992196559906006,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_5589_origidx_8_RF22.mp4': {'event': 5589,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.696864092082251e-05,
#   'pred_cascade': 0.9767201542854308,
#   'pred_tgtrack': 1.6330126300090342e-06,
#   'pred_starttrack': 0.0232360195368528,
#   'pred_stoptrack': 2.5203109544236213e-05,
#   'energy': 663.1124257585207,
#   'zenith': 2.6319976954413966,
#   'oneweight': 1725945478.2863784,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9767201542854308,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_222_origidx_14_RF22.mp4': {'event': 222,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.995704472064972,
#   'pred_cascade': 4.9634081733529456e-08,
#   'pred_tgtrack': 0.0037849629297852,
#   'pred_starttrack': 6.600528479339118e-08,
#   'pred_stoptrack': 0.000510559824761,
#   'energy': 35860.40441943103,
#   'zenith': 1.2640260676682018,
#   'oneweight': 9593643201696.22,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.995704472064972,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_7931_origidx_5_RF22.mp4': {'event': 7931,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0109797650948166,
#   'pred_cascade': 0.0023029358126223,
#   'pred_tgtrack': 0.9342800378799438,
#   'pred_starttrack': 0.0007663937867619,
#   'pred_stoptrack': 0.0516708716750144,
#   'energy': 334.3581765737584,
#   'zenith': 0.957511085630754,
#   'oneweight': 150825567.8871413,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9342800378799438,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_1004_origidx_5_RF22.mp4': {'event': 1004,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0731533840298652,
#   'pred_cascade': 0.0449095107614994,
#   'pred_tgtrack': 0.715796172618866,
#   'pred_starttrack': 0.1431062966585159,
#   'pred_stoptrack': 0.0230345912277698,
#   'energy': 595281.5083460517,
#   'zenith': 0.177573614041032,
#   'oneweight': 3585540877872369.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.715796172618866,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_4458_origidx_25_RF22.mp4': {'event': 4458,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9718596935272216,
#   'pred_cascade': 1.7166335965157486e-05,
#   'pred_tgtrack': 0.0248742327094078,
#   'pred_starttrack': 1.6631964172120206e-05,
#   'pred_stoptrack': 0.0032321780454367,
#   'energy': 12017.526535511026,
#   'zenith': 2.083260593441927,
#   'oneweight': 873691973401.0769,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9718596935272216,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_3736_origidx_8_RF22.mp4': {'event': 3736,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 1.8216527678305283e-05,
#   'pred_cascade': 0.9810007214546204,
#   'pred_tgtrack': 4.007270035799593e-06,
#   'pred_starttrack': 0.0189572870731353,
#   'pred_stoptrack': 1.981487548619043e-05,
#   'energy': 8580.447874574536,
#   'zenith': 1.1966299766775972,
#   'oneweight': 950692865367.1998,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9810007214546204,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_2826_origidx_6_RF22.mp4': {'event': 2826,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999113082885742,
#   'pred_cascade': 1.0748994749842922e-10,
#   'pred_tgtrack': 5.797565245302394e-05,
#   'pred_starttrack': 7.61768070844937e-09,
#   'pred_stoptrack': 3.0778748623561114e-05,
#   'energy': 189274.67978943716,
#   'zenith': 0.8507117377156943,
#   'oneweight': 359147816454859.6,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999113082885742,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_1057_origidx_7_RF22.mp4': {'event': 1057,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9998347759246826,
#   'pred_cascade': 1.1033353786160662e-08,
#   'pred_tgtrack': 0.0001171431576949,
#   'pred_starttrack': 6.429538679242341e-09,
#   'pred_stoptrack': 4.802881085197441e-05,
#   'energy': 439347.23005734605,
#   'zenith': 0.7946553778830389,
#   'oneweight': 3234863001941944.5,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9998347759246826,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_3829_origidx_13_RF22.mp4': {'event': 3829,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0027952033560723,
#   'pred_cascade': 0.0014748746762052,
#   'pred_tgtrack': 0.1029745861887931,
#   'pred_starttrack': 0.0019273839425295,
#   'pred_stoptrack': 0.8908279538154602,
#   'energy': 5720.041920193224,
#   'zenith': 1.4641527613180856,
#   'oneweight': 36260851611.67575,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8908279538154602,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_220679999/compressed_run_22067_event_174_origidx_11_RF22.mp4': {'event': 174,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.1885164529085159,
#   'pred_cascade': 0.6185283064842224,
#   'pred_tgtrack': 0.0997757390141487,
#   'pred_starttrack': 0.0846955701708793,
#   'pred_stoptrack': 0.008483956567943,
#   'energy': 4012.775299179358,
#   'zenith': 2.56747867509473,
#   'oneweight': 65533604354.601456,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.6185283064842224,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 11}}

# %%
make_subject_set('nue_run_22067_subrun_9999_phase1')
# Out:
# Subject Set Name: nue_run_22067_subrun_9999_phase1
# Subject Set ID: 112120
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112109>]

# %%
uploader(compressed_path,nue_csv,112120)
# Out:
# Confirm if subject set 112120 is listed below.
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112109>]
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112109>]
# Number of times loop has ran: 1
# Number of times loop has ran: 2
# Number of times loop has ran: 3
# Number of times loop has ran: 4
# Number of times loop has ran: 5
# Number of times loop has ran: 6
# Number of times loop has ran: 7
# Number of times loop has ran: 8
# Number of times loop has ran: 9
# Number of times loop has ran: 10
# Number of times loop has ran: 11
# Number of times loop has ran: 12
# Number of times loop has ran: 13
# Number of times loop has ran: 14
# Number of times loop has ran: 15
# Number of times loop has ran: 16
# Number of times loop has ran: 17
# Number of times loop has ran: 18
# Number of times loop has ran: 19
# Number of times loop has ran: 20
# Number of times loop has ran: 21
# Number of times loop has ran: 22
# Number of times loop has ran: 23
# Number of times loop has ran: 24
# Number of times loop has ran: 25
# Number of times loop has ran: 26
# Number of times loop has ran: 27
# Number of times loop has ran: 28
# Number of times loop has ran: 29
# Number of times loop has ran: 30
# Number of times loop has ran: 31
# Number of times loop has ran: 32
# Number of times loop has ran: 33
# Number of times loop has ran: 34
# Number of times loop has ran: 35
# Number of times loop has ran: 36
# Number of times loop has ran: 37
# Number of times loop has ran: 38
# Number of times loop has ran: 39
# Number of times loop has ran: 40
# Number of times loop has ran: 41
# Number of times loop has ran: 42
# Number of times loop has ran: 43
# Number of times loop has ran: 44
# Number of times loop has ran: 45
# Number of times loop has ran: 46
# Number of times loop has ran: 47
# Number of times loop has ran: 48
# Number of times loop has ran: 49
# Number of times loop has ran: 50
# Number of times loop has ran: 51
# Number of times loop has ran: 52
# Number of times loop has ran: 53
# Number of times loop has ran: 54
# Number of times loop has ran: 55
# Number of times loop has ran: 56
# Number of times loop has ran: 57
# Number of times loop has ran: 58
# Number of times loop has ran: 59
# Number of times loop has ran: 60
# Number of times loop has ran: 61
# Number of times loop has ran: 62
# Number of times loop has ran: 63
# Number of times loop has ran: 64
# Number of times loop has ran: 65
# Number of times loop has ran: 66
# Number of times loop has ran: 67
# Number of times loop has ran: 68
# Number of times loop has ran: 69
# Number of times loop has ran: 70
# Number of times loop has ran: 71
# Number of times loop has ran: 72
# Number of times loop has ran: 73
# Number of times loop has ran: 74
# Number of times loop has ran: 75
# Number of times loop has ran: 76
# Number of times loop has ran: 77
# Number of times loop has ran: 78
# Number of times loop has ran: 79
