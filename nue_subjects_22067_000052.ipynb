# %% [markdown]
# # Phase 2: Subject Creation
#
# **Description:**
#
# This notebook is to act as the resulting summary file for the creation and upload of subjects for the IceCube Zooniverse project currently called *Name that Neutrino!*. The project is currently being maintained by Elizabeth Warrick (as of March 2023). In this notebook, we take the i3 file and run it through several filters. [note: describe more later].
#
# > Nu Type: NuE
#
# > Run: 22076
#
# > SubRun: 000052
#
# ### Summary Stats:
#
# To be filled in after completing process. Also need to figure out global variables.
#
# **Subject Set Name:**

# %%
#Imports

#My functions: 
from uniformenergydist_filter import *

#General:
import numpy as np
import sys
import os
import subprocess
import argparse
import csv
from tables import *
import pandas as pd
from matplotlib import pyplot as plt
import h5py

#Zooniverse:
from panoptes_client import Panoptes, Project, SubjectSet, Subject
import magic
import glob

#IceCube:
from icecube.icetray import I3Units
import icecube.MuonGun
from icecube import dataio, dataclasses, icetray, MuonGun
from I3Tray import *
from icecube.hdfwriter import I3HDFWriter
from mc_labeler import MCLabeler #make sure that mc_labeler script is in current directory.

# %%
#Specify file paths:

#Initial I3 File:
nue = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/classifier_rehyd_DST_IC86.2020_NuE.022067.000052.i3.zst'

#Desired output directory. Note that creation of this directory is not yet coded and is done manually. 
phase1_dir = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/'

# %%
#Run Filter 1 to label MC truth.
filter1(nue,phase1_dir)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/mc_labeler.py:523: UserWarning: Couldn't find OMKey in MCPESeriesMap
#   warnings.warn("Couldn't find OMKey in MCPESeriesMap")

# %% [markdown]
# Note that the above cell might return an "exception" warning that the *MCPESeriesMap could not be found*. I am unsure why it does that because when I check the i3 file in dataio-shovel, I see the specified mc_pid_series_map (look at mc_labeler.py for exact name of specified key). The resulting file size should be around 400 MB.

# %%
#Path of hdf from above filter.
nue_hdf = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/\
Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000052.i3.zst.hd5'

# %%
#Run uniformenergy_events function which requires hdf from filter 1, 
#number of bins, size of each random choice, and a random seed. 

uniformenergy_events(nue_hdf,25,10,12,subrun = True)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['binned_log10E'] = pd.cut(x = np.log10(df_filtered['energy']), bins = bins, labels = labels, include_lowest = True) #might throw an error?
# Number of Bins: 25
# Number of Events per Bin: 10
# Total Number of Events: 250
# Initial Number of Events: 2716
# Number of Events after filtering: 2627
# Please input subrun number:
# 000052

# %% [markdown]
# The above function throws another warning about pd.cut, currently that is not a problem but I don't know if a new version of pandas will allow this.

# %%
#Path to Random Events CSV
nue_csv = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/random_events_uniform_energy_distrib_22067_000052.csv'

# %%
#Run event_characterization_plots function whick makes some quick 
#plots to get an idea of what data you're dealing with.
#Note that I want to update the plot types, maybe make a 2D histogram as Mike K suggested. 
#For truth labels, check out enums.py or in the .py file that holds the functions.

event_characterization_plots(nue_csv)

# %% [markdown]
# Now that we have the events for this phase chosen, we run the second filter to pick out only those events.

# %%
#Path to i3 file from filter1 with MC truth labels. 
nue_filter1 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000052.i3.zst'

# %%
#Run function to perform second filter which passes through only selected event IDs chosen from 
#the uniformenergy_events function. 
filter2(nue_filter1,phase1_dir,nue_csv)

# %%
#Path to i3 file from filter 2 that holds only specified events. 
nue_filter2 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000052.i3.zst'

# %%
#Run function to perform third filter, which returns only the DAQ frames of the specified events.
#DAQ only file is then split up into many smaller i3 files since SteamShovel can't handle making videos of large
#i3 files at one time. Size limit is approx 2E6 MB (? unsure of units)
filter3(nue_filter2,22067_000052,phase1_dir)

# %%
#Path to NuMu Daq Only folder
nue_daq = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000052/'

# %%
get_steamshovel(nue_daq,22067000052)
# Out:
# List of files:
# ['/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000052/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000052.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000052/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000052.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000052/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000052.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000052/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000052.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000052/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000052.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000052/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000052.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000052/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000052.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000052/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000052.i3.zst']
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000052/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000052.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000052/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000052.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000052/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000052.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000052/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000052.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000052/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000052.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000052/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000052.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000052/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000052.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000052/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000052.i3.zst

# %% [markdown]
# Ideas for Compression:
# - Use GUI to add files to queue and send to one compression folder.
# - Add a subprocess line in movie script to compress the video after making it and direct it to save in the compression folder.

# %%
compressed_path = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/'

# %% [markdown]
# Can't get manifest yet since some subjects are missing and lining it up won't work.

# %%
get_manifest(compressed_path, nue_csv)
# Out:
# {'/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_1578_origidx_4_RF22.mp4': {'event': 1578,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.120659664273262,
#   'pred_cascade': 0.0353125296533107,
#   'pred_tgtrack': 0.0034998818300664,
#   'pred_starttrack': 0.1854608207941055,
#   'pred_stoptrack': 0.6550670862197876,
#   'energy': 15552.981997964373,
#   'zenith': 0.092265715964671,
#   'oneweight': 1504903842787.1248,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6550670862197876,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_3075_origidx_15_RF22.mp4': {'event': 3075,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 6.721564659528667e-06,
#   'pred_cascade': 0.9802085161209106,
#   'pred_tgtrack': 4.625171641237103e-07,
#   'pred_starttrack': 0.0197761841118335,
#   'pred_stoptrack': 8.097577847365756e-06,
#   'energy': 1470.2949517140155,
#   'zenith': 1.247163696824033,
#   'oneweight': 7577402375.141343,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9802085161209106,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_5978_origidx_11_RF22.mp4': {'event': 5978,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.99974125623703,
#   'pred_cascade': 2.9693328684743392e-08,
#   'pred_tgtrack': 0.0001155263671535,
#   'pred_starttrack': 1.266762552631917e-07,
#   'pred_stoptrack': 0.0001431792770745,
#   'energy': 62386.94312653349,
#   'zenith': 0.359787832776979,
#   'oneweight': 48275614781396.94,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.99974125623703,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_3283_origidx_22_RF22.mp4': {'event': 3283,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.3495340428780764e-05,
#   'pred_cascade': 0.9988545179367064,
#   'pred_tgtrack': 1.825678275224618e-08,
#   'pred_starttrack': 0.0011216379934921,
#   'pred_stoptrack': 4.080470432654693e-07,
#   'energy': 27270.178004483598,
#   'zenith': 1.9175458630833324,
#   'oneweight': 6954013649196.659,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9988545179367064,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_9372_origidx_29_RF22.mp4': {'event': 9372,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.9105776775395498e-06,
#   'pred_cascade': 0.9891653656959534,
#   'pred_tgtrack': 3.21268593950208e-08,
#   'pred_starttrack': 0.0108313877135515,
#   'pred_stoptrack': 2.818072175614361e-07,
#   'energy': 196845.58959184267,
#   'zenith': 0.2385211143464049,
#   'oneweight': 508698351150128.06,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9891653656959534,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_8454_origidx_5_RF22.mp4': {'event': 8454,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.0008649856317788,
#   'pred_cascade': 0.8797899484634399,
#   'pred_tgtrack': 3.653601379483007e-05,
#   'pred_starttrack': 0.1192911639809608,
#   'pred_stoptrack': 1.745455119817052e-05,
#   'energy': 70312.97003600745,
#   'zenith': 2.98695586669711,
#   'oneweight': 156261993228.93698,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.8797899484634399,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_8577_origidx_9_RF22.mp4': {'event': 8577,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999897599220276,
#   'pred_cascade': 1.1729095993062709e-11,
#   'pred_tgtrack': 4.105610423721373e-05,
#   'pred_starttrack': 2.154146028221504e-10,
#   'pred_stoptrack': 6.137601303635165e-05,
#   'energy': 738800.3273276333,
#   'zenith': 1.5410215490919188,
#   'oneweight': 4881603204488433.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999897599220276,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_3220_origidx_21_RF22.mp4': {'event': 3220,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.8920634388923645,
#   'pred_cascade': 0.0778528749942779,
#   'pred_tgtrack': 0.0130856996402144,
#   'pred_starttrack': 0.0163180474191904,
#   'pred_stoptrack': 0.000679935212247,
#   'energy': 116968.92036554166,
#   'zenith': 1.933048952198413,
#   'oneweight': 9159827372235.488,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8920634388923645,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_8566_origidx_8_RF22.mp4': {'event': 8566,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.978512406349182,
#   'pred_cascade': 0.0011629612417891,
#   'pred_tgtrack': 0.0197239555418491,
#   'pred_starttrack': 0.0004739702562801,
#   'pred_stoptrack': 0.0001266371255042,
#   'energy': 429668.8250970614,
#   'zenith': 1.6204584721290172,
#   'oneweight': 1389902369707614.5,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.978512406349182,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_9405_origidx_6_RF22.mp4': {'event': 9405,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4128715097904205,
#   'pred_cascade': 0.1024680212140083,
#   'pred_tgtrack': 0.1872891783714294,
#   'pred_starttrack': 0.0706216990947723,
#   'pred_stoptrack': 0.2267495542764663,
#   'energy': 5166.068783813601,
#   'zenith': 0.3715304176019794,
#   'oneweight': 93572562075.171,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4128715097904205,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_2769_origidx_6_RF22.mp4': {'event': 2769,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.1621254533529281,
#   'pred_cascade': 0.0403217114508152,
#   'pred_tgtrack': 0.7469249963760376,
#   'pred_starttrack': 0.0190271288156509,
#   'pred_stoptrack': 0.0316007435321807,
#   'energy': 147.2455360016217,
#   'zenith': 0.6233033922943364,
#   'oneweight': 32233071.280573484,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.7469249963760376,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_4374_origidx_7_RF22.mp4': {'event': 4374,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.8747397234619712e-06,
#   'pred_cascade': 0.9634692668914796,
#   'pred_tgtrack': 4.7236380140702756e-08,
#   'pred_starttrack': 0.0365285575389862,
#   'pred_stoptrack': 3.770477690068219e-07,
#   'energy': 27057.206187050237,
#   'zenith': 1.0119572812951527,
#   'oneweight': 7845565449682.353,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9634692668914796,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_3178_origidx_19_RF22.mp4': {'event': 3178,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.8755572438240051,
#   'pred_cascade': 0.0939252451062202,
#   'pred_tgtrack': 0.019044954329729,
#   'pred_starttrack': 0.0113345831632614,
#   'pred_stoptrack': 0.000137973765959,
#   'energy': 373339.58736524015,
#   'zenith': 0.2961160923865352,
#   'oneweight': 1487553117837684.8,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8755572438240051,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_9345_origidx_28_RF22.mp4': {'event': 9345,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 1.545282248116564e-05,
#   'pred_cascade': 0.9994916915893556,
#   'pred_tgtrack': 3.7101202110534366e-08,
#   'pred_starttrack': 0.0004925435059703,
#   'pred_stoptrack': 2.177427376182095e-07,
#   'energy': 31180.281425083085,
#   'zenith': 1.2123359434602452,
#   'oneweight': 9404418150278.62,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9994916915893556,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_8993_origidx_19_RF22.mp4': {'event': 8993,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0259841568768024,
#   'pred_cascade': 0.0117480847984552,
#   'pred_tgtrack': 0.9438320994377136,
#   'pred_starttrack': 0.0116862012073397,
#   'pred_stoptrack': 0.0067494781687855,
#   'energy': 1745.464966931756,
#   'zenith': 1.5555905023471186,
#   'oneweight': 22256451388.845554,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9438320994377136,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_2820_origidx_10_RF22.mp4': {'event': 2820,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9768273234367372,
#   'pred_cascade': 0.0115129332989454,
#   'pred_tgtrack': 0.000512181490194,
#   'pred_starttrack': 0.0065938606858253,
#   'pred_stoptrack': 0.0045536658726632,
#   'energy': 7464.522204124762,
#   'zenith': 1.3283595195337885,
#   'oneweight': 349610956565.30115,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9768273234367372,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_8523_origidx_7_RF22.mp4': {'event': 8523,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9996215105056764,
#   'pred_cascade': 9.997319239118951e-07,
#   'pred_tgtrack': 4.9794929509516805e-05,
#   'pred_starttrack': 8.525656767233158e-07,
#   'pred_stoptrack': 0.0003268757718615,
#   'energy': 42948.0261012251,
#   'zenith': 1.6339348074709026,
#   'oneweight': 14291191117480.36,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9996215105056764,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_901_origidx_21_RF22.mp4': {'event': 901,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 3.0734872780158184e-06,
#   'pred_cascade': 0.9940343499183656,
#   'pred_tgtrack': 8.840852494529372e-09,
#   'pred_starttrack': 0.0059620444662868,
#   'pred_stoptrack': 6.058748454051965e-07,
#   'energy': 11225.561869851232,
#   'zenith': 1.4351530727605248,
#   'oneweight': 787439027405.7585,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9940343499183656,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_8682_origidx_14_RF22.mp4': {'event': 8682,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1462428420782089,
#   'pred_cascade': 0.0120908711105585,
#   'pred_tgtrack': 0.0172080658376216,
#   'pred_starttrack': 0.0604391396045684,
#   'pred_stoptrack': 0.7640190124511719,
#   'energy': 168.43459782359247,
#   'zenith': 1.699708983098642,
#   'oneweight': 6326726.498088406,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7640190124511719,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_6448_origidx_23_RF22.mp4': {'event': 6448,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2621636688709259,
#   'pred_cascade': 0.0309524666517972,
#   'pred_tgtrack': 0.6513223052024841,
#   'pred_starttrack': 0.0303811095654964,
#   'pred_stoptrack': 0.0251804869621992,
#   'energy': 242.10369495412849,
#   'zenith': 1.28757467827985,
#   'oneweight': 70105440.18398762,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6513223052024841,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_6009_origidx_12_RF22.mp4': {'event': 6009,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 7.529220602009445e-05,
#   'pred_cascade': 0.9750815629959106,
#   'pred_tgtrack': 1.50203254634107e-06,
#   'pred_starttrack': 0.024818392470479,
#   'pred_stoptrack': 2.326993671886157e-05,
#   'energy': 4554.449833848999,
#   'zenith': 0.592867882102663,
#   'oneweight': 140990979767.23892,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9750815629959106,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_5859_origidx_8_RF22.mp4': {'event': 5859,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.018809039145708,
#   'pred_cascade': 0.0013340868754312,
#   'pred_tgtrack': 0.9309619069099426,
#   'pred_starttrack': 0.0271961465477943,
#   'pred_stoptrack': 0.0216989498585462,
#   'energy': 136.29720075128117,
#   'zenith': 0.5610886777515007,
#   'oneweight': 8728669.242466273,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9309619069099426,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_4713_origidx_17_RF22.mp4': {'event': 4713,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1407441943883896,
#   'pred_cascade': 0.020771212875843,
#   'pred_tgtrack': 0.0039743622764945,
#   'pred_starttrack': 0.5366970896720886,
#   'pred_stoptrack': 0.2978130877017975,
#   'energy': 153.62341540778834,
#   'zenith': 2.2236094897895105,
#   'oneweight': 11091603.70323366,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5366970896720886,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_5512_origidx_31_RF22.mp4': {'event': 5512,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0742494165897369,
#   'pred_cascade': 0.0191859472543001,
#   'pred_tgtrack': 0.8613048791885376,
#   'pred_starttrack': 0.0298086795955896,
#   'pred_stoptrack': 0.0154511621221899,
#   'energy': 3497.727083137021,
#   'zenith': 0.829163114649562,
#   'oneweight': 65520317755.19061,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8613048791885376,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_5541_origidx_32_RF22.mp4': {'event': 5541,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1863888651132583,
#   'pred_cascade': 0.0324330106377601,
#   'pred_tgtrack': 0.0160448886454105,
#   'pred_starttrack': 0.0415149927139282,
#   'pred_stoptrack': 0.72361820936203,
#   'energy': 719.0668974354787,
#   'zenith': 1.2440236458336702,
#   'oneweight': 2095253453.7793612,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.72361820936203,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_4455_origidx_10_RF22.mp4': {'event': 4455,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9995526671409608,
#   'pred_cascade': 9.002477097119764e-10,
#   'pred_tgtrack': 1.1638123396551237e-05,
#   'pred_starttrack': 1.4050102414842058e-08,
#   'pred_stoptrack': 0.0004356514546088,
#   'energy': 105578.64433055188,
#   'zenith': 1.8121645994981368,
#   'oneweight': 105298826564400.16,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9995526671409608,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_6576_origidx_5_RF22.mp4': {'event': 6576,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0002468580205459,
#   'pred_cascade': 0.8847019076347351,
#   'pred_tgtrack': 3.4961860365001485e-05,
#   'pred_starttrack': 0.1145426481962204,
#   'pred_stoptrack': 0.0004736571863759,
#   'energy': 37797.598557151854,
#   'zenith': 2.0506755716624747,
#   'oneweight': 15003455159502.137,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8847019076347351,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_9212_origidx_23_RF22.mp4': {'event': 9212,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.0209430456598056e-06,
#   'pred_cascade': 0.9947484135627748,
#   'pred_tgtrack': 2.4872084947169526e-10,
#   'pred_starttrack': 0.0052505037747323,
#   'pred_stoptrack': 1.0423817364824116e-08,
#   'energy': 137507.5723545679,
#   'zenith': 1.372075488867997,
#   'oneweight': 187684465620655.28,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9947484135627748,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_4203_origidx_4_RF22.mp4': {'event': 4203,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9688859581947328,
#   'pred_cascade': 0.0186392124742269,
#   'pred_tgtrack': 0.0009397917310707,
#   'pred_starttrack': 0.0078249871730804,
#   'pred_stoptrack': 0.0037100515328347,
#   'energy': 8471.507075082282,
#   'zenith': 0.4163363494594194,
#   'oneweight': 499939255954.7455,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9688859581947328,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_9423_origidx_7_RF22.mp4': {'event': 9423,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0038852263242006,
#   'pred_cascade': 0.0012131101684644,
#   'pred_tgtrack': 0.6549037098884583,
#   'pred_starttrack': 0.0003339296672493,
#   'pred_stoptrack': 0.339664101600647,
#   'energy': 420.18599069833465,
#   'zenith': 2.6403694982674084,
#   'oneweight': 318958131.0584992,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6549037098884583,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_2632_origidx_4_RF22.mp4': {'event': 2632,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0210295263677835,
#   'pred_cascade': 0.891946017742157,
#   'pred_tgtrack': 4.5865126594435424e-05,
#   'pred_starttrack': 0.0858982279896736,
#   'pred_stoptrack': 0.0010803653858602,
#   'energy': 3740.1226003885913,
#   'zenith': 1.6846092996074655,
#   'oneweight': 56608967372.28597,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.891946017742157,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_2771_origidx_7_RF22.mp4': {'event': 2771,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1654197126626968,
#   'pred_cascade': 0.004827500320971,
#   'pred_tgtrack': 0.369356244802475,
#   'pred_starttrack': 0.0039112498052418,
#   'pred_stoptrack': 0.4564852714538574,
#   'energy': 938161.5253853768,
#   'zenith': 1.974165565454829,
#   'oneweight': 529976169771409.8,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4564852714538574,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_12_origidx_6_RF22.mp4': {'event': 12,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0001165749054052,
#   'pred_cascade': 0.6732235550880432,
#   'pred_tgtrack': 6.077306693441642e-07,
#   'pred_starttrack': 0.3265023827552795,
#   'pred_stoptrack': 0.0001568079460412,
#   'energy': 198.62598610410748,
#   'zenith': 1.2204395856700447,
#   'oneweight': 58295532.50708866,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.6732235550880432,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_650_origidx_17_RF22.mp4': {'event': 650,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.052048023790121,
#   'pred_cascade': 0.0194576568901538,
#   'pred_tgtrack': 0.8518932461738586,
#   'pred_starttrack': 0.0370636209845542,
#   'pred_stoptrack': 0.0395374186336994,
#   'energy': 4533.175570299958,
#   'zenith': 1.2782408865717327,
#   'oneweight': 34453216576.4236,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8518932461738586,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_5637_origidx_33_RF22.mp4': {'event': 5637,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.5063997507095337,
#   'pred_cascade': 0.024104556068778,
#   'pred_tgtrack': 0.4263220727443695,
#   'pred_starttrack': 0.0171213466674089,
#   'pred_stoptrack': 0.0260522309690713,
#   'energy': 168.79291821791986,
#   'zenith': 0.8788443369774285,
#   'oneweight': 43510567.72098804,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5063997507095337,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_5717_origidx_37_RF22.mp4': {'event': 5717,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 6.244324140425306e-06,
#   'pred_cascade': 0.961173951625824,
#   'pred_tgtrack': 6.24362485268648e-07,
#   'pred_starttrack': 0.0388186983764171,
#   'pred_stoptrack': 5.303132297740376e-07,
#   'energy': 761199.7991847973,
#   'zenith': 0.2970795709824266,
#   'oneweight': 6176772495475791.0,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.961173951625824,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_5801_origidx_7_RF22.mp4': {'event': 5801,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3143840730190277,
#   'pred_cascade': 0.024526135995984,
#   'pred_tgtrack': 0.5976362824440002,
#   'pred_starttrack': 0.0314054153859615,
#   'pred_stoptrack': 0.0320480614900589,
#   'energy': 474.5213576028664,
#   'zenith': 1.122619423418558,
#   'oneweight': 574643958.6738192,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5976362824440002,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_3062_origidx_14_RF22.mp4': {'event': 3062,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0272872317582368,
#   'pred_cascade': 0.0073591344989836,
#   'pred_tgtrack': 0.9336605668067932,
#   'pred_starttrack': 0.0281933732330799,
#   'pred_stoptrack': 0.0034997048787772,
#   'energy': 61826.22564066369,
#   'zenith': 1.26054103335774,
#   'oneweight': 24158255325201.867,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9336605668067932,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_2775_origidx_8_RF22.mp4': {'event': 2775,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0005688943201676,
#   'pred_cascade': 0.0007237161626107,
#   'pred_tgtrack': 0.9957045912742616,
#   'pred_starttrack': 0.0014020174276083,
#   'pred_stoptrack': 0.0016008029924705,
#   'energy': 477.4232341561376,
#   'zenith': 1.5133557469823915,
#   'oneweight': 358974676.7301796,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9957045912742616,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_8911_origidx_17_RF22.mp4': {'event': 8911,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.000361313461326,
#   'pred_cascade': 0.9965388774871826,
#   'pred_tgtrack': 1.3579996016588323e-09,
#   'pred_starttrack': 0.0030986571218818,
#   'pred_stoptrack': 1.1627796538959956e-06,
#   'energy': 267816.50879964663,
#   'zenith': 2.9272550404635207,
#   'oneweight': 41569333429815.51,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9965388774871826,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_5729_origidx_4_RF22.mp4': {'event': 5729,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0001911206782096,
#   'pred_cascade': 0.9241420030593872,
#   'pred_tgtrack': 0.0002263805799884,
#   'pred_starttrack': 0.0753834620118141,
#   'pred_stoptrack': 5.694342326023616e-05,
#   'energy': 227048.6735289312,
#   'zenith': 1.2909871741715635,
#   'oneweight': 560411348192392.8,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9241420030593872,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_9565_origidx_9_RF22.mp4': {'event': 9565,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.5573426485061646,
#   'pred_cascade': 0.0751463621854782,
#   'pred_tgtrack': 0.0202846005558967,
#   'pred_starttrack': 0.1094986870884895,
#   'pred_stoptrack': 0.2377277612686157,
#   'energy': 127.36166425652864,
#   'zenith': 1.5950729026534038,
#   'oneweight': 28482232.044876244,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5573426485061646,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_6037_origidx_13_RF22.mp4': {'event': 6037,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0003622167569119,
#   'pred_cascade': 0.7792139053344727,
#   'pred_tgtrack': 0.000137622540933,
#   'pred_starttrack': 0.2124969661235809,
#   'pred_stoptrack': 0.0077893082052469,
#   'energy': 111.66767687303827,
#   'zenith': 2.973217150771028,
#   'oneweight': 11207773.293780347,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7792139053344727,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_4572_origidx_14_RF22.mp4': {'event': 4572,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.7837620377540588,
#   'pred_cascade': 0.2145769745111465,
#   'pred_tgtrack': 1.9488056750560645e-06,
#   'pred_starttrack': 0.0014971874188631,
#   'pred_stoptrack': 0.0001618943642824,
#   'energy': 297520.196249737,
#   'zenith': 1.761789528550516,
#   'oneweight': 1.4316433703545198e+16,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7837620377540588,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_5709_origidx_36_RF22.mp4': {'event': 5709,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1403875350952148,
#   'pred_cascade': 0.012342344969511,
#   'pred_tgtrack': 0.0097728315740823,
#   'pred_starttrack': 0.0559526793658733,
#   'pred_stoptrack': 0.7815446853637695,
#   'energy': 662.5202529166245,
#   'zenith': 0.5630241610299346,
#   'oneweight': 1047027421.2912406,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7815446853637695,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_5408_origidx_29_RF22.mp4': {'event': 5408,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1535264551639557,
#   'pred_cascade': 0.0378906950354576,
#   'pred_tgtrack': 0.6146551966667175,
#   'pred_starttrack': 0.1663707792758941,
#   'pred_stoptrack': 0.0275568608194589,
#   'energy': 290.42681468929663,
#   'zenith': 0.6355528433890155,
#   'oneweight': 39912735.14187117,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6146551966667175,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_295_origidx_10_RF22.mp4': {'event': 295,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999988079071044,
#   'pred_cascade': 3.1790872018211396e-11,
#   'pred_tgtrack': 7.6114233138469e-08,
#   'pred_starttrack': 1.2461424114817987e-09,
#   'pred_stoptrack': 1.0175040188187268e-06,
#   'energy': 749358.8062066042,
#   'zenith': 1.6322243900292577,
#   'oneweight': 4642385367695179.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999988079071044,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_8502_origidx_6_RF22.mp4': {'event': 8502,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9968128800392152,
#   'pred_cascade': 7.749396900180727e-05,
#   'pred_tgtrack': 0.0018353601917624,
#   'pred_starttrack': 7.409512909362093e-05,
#   'pred_stoptrack': 0.001200140803121,
#   'energy': 21699.48084784096,
#   'zenith': 1.1209711488843492,
#   'oneweight': 4264177734726.253,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9968128800392152,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_6350_origidx_20_RF22.mp4': {'event': 6350,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.6397916078567505,
#   'pred_cascade': 0.0649016350507736,
#   'pred_tgtrack': 0.0017188435886055,
#   'pred_starttrack': 0.0705583617091178,
#   'pred_stoptrack': 0.2230295538902282,
#   'energy': 455.49109148298487,
#   'zenith': 2.2976847184757623,
#   'oneweight': 574375729.445371,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6397916078567505,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_7_origidx_5_RF22.mp4': {'event': 7,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.573651727288961e-05,
#   'pred_cascade': 0.9932475090026855,
#   'pred_tgtrack': 5.7406868592124745e-08,
#   'pred_starttrack': 0.006724972743541,
#   'pred_stoptrack': 1.745117856444267e-06,
#   'energy': 12431.855263755586,
#   'zenith': 0.9297864540132054,
#   'oneweight': 1383587429917.6252,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9932475090026855,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_2807_origidx_9_RF22.mp4': {'event': 2807,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3923617005348205,
#   'pred_cascade': 0.002542411442846,
#   'pred_tgtrack': 0.5278826951980591,
#   'pred_starttrack': 0.0017938066739588,
#   'pred_stoptrack': 0.075419396162033,
#   'energy': 442858.4889429626,
#   'zenith': 2.6572745642201743,
#   'oneweight': 26601538062787.81,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5278826951980591,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_938_origidx_23_RF22.mp4': {'event': 938,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.338016539812088,
#   'pred_cascade': 0.0920747742056846,
#   'pred_tgtrack': 0.2145901322364807,
#   'pred_starttrack': 0.0510824471712112,
#   'pred_stoptrack': 0.3042360842227936,
#   'energy': 202.0982071700473,
#   'zenith': 1.965118413106841,
#   'oneweight': 50963805.61634553,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.338016539812088,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_9426_origidx_8_RF22.mp4': {'event': 9426,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3271048665046692,
#   'pred_cascade': 0.0898276716470718,
#   'pred_tgtrack': 0.3957547545433044,
#   'pred_starttrack': 0.1134178265929222,
#   'pred_stoptrack': 0.0738948732614517,
#   'energy': 101.47960896812094,
#   'zenith': 2.683538877821246,
#   'oneweight': 1940280.3095060384,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3957547545433044,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_6620_origidx_7_RF22.mp4': {'event': 6620,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.0035385703667998,
#   'pred_cascade': 0.8560633659362793,
#   'pred_tgtrack': 0.0001942047383636,
#   'pred_starttrack': 0.1327253729104995,
#   'pred_stoptrack': 0.00747841456905,
#   'energy': 262.21418760055025,
#   'zenith': 1.9203682881552664,
#   'oneweight': 109485361.08897868,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.8560633659362793,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_5343_origidx_27_RF22.mp4': {'event': 5343,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3500199615955353,
#   'pred_cascade': 0.206612229347229,
#   'pred_tgtrack': 0.1128030940890312,
#   'pred_starttrack': 0.090609610080719,
#   'pred_stoptrack': 0.2399550527334213,
#   'energy': 17820.440983940807,
#   'zenith': 0.3596006795446841,
#   'oneweight': 2844559449626.263,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3500199615955353,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_3328_origidx_23_RF22.mp4': {'event': 3328,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0009653937886469,
#   'pred_cascade': 0.8532894253730774,
#   'pred_tgtrack': 3.065529017476365e-05,
#   'pred_starttrack': 0.1455673724412918,
#   'pred_stoptrack': 0.0001470565912313,
#   'energy': 942.2895110783518,
#   'zenith': 1.4269085624343902,
#   'oneweight': 3959688314.3221855,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8532894253730774,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_4378_origidx_8_RF22.mp4': {'event': 4378,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1227085962891578,
#   'pred_cascade': 0.0290678385645151,
#   'pred_tgtrack': 0.7443373203277588,
#   'pred_starttrack': 0.017743594944477,
#   'pred_stoptrack': 0.0861426070332527,
#   'energy': 116050.00559717626,
#   'zenith': 1.698435422884305,
#   'oneweight': 1580489701655818.5,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7443373203277588,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_5108_origidx_24_RF22.mp4': {'event': 5108,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.990035355091095,
#   'pred_cascade': 0.0042246333323419,
#   'pred_tgtrack': 0.0043723918497562,
#   'pred_starttrack': 0.0008550568600185,
#   'pred_stoptrack': 0.00051269098185,
#   'energy': 51137.30194938975,
#   'zenith': 1.21653358106224,
#   'oneweight': 25360148155168.656,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.990035355091095,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_5158_origidx_25_RF22.mp4': {'event': 5158,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9989136457443236,
#   'pred_cascade': 3.417662446736358e-05,
#   'pred_tgtrack': 0.0005846145213581,
#   'pred_starttrack': 2.033617965935264e-05,
#   'pred_stoptrack': 0.0004472098080441,
#   'energy': 53987.23623400468,
#   'zenith': 2.229402744371939,
#   'oneweight': 36317956829871.4,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9989136457443236,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_3131_origidx_17_RF22.mp4': {'event': 3131,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.3912094831466675,
#   'pred_cascade': 0.4260662496089935,
#   'pred_tgtrack': 0.0155053045600652,
#   'pred_starttrack': 0.1089692786335945,
#   'pred_stoptrack': 0.0582497604191303,
#   'energy': 711.916605883934,
#   'zenith': 2.264116162501503,
#   'oneweight': 1187789689.2708,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.4260662496089935,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_5755_origidx_5_RF22.mp4': {'event': 5755,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999717473983764,
#   'pred_cascade': 2.812053714884577e-11,
#   'pred_tgtrack': 9.95723166852258e-06,
#   'pred_starttrack': 2.286988376454246e-09,
#   'pred_stoptrack': 1.8180071492679417e-05,
#   'energy': 789609.3257998792,
#   'zenith': 0.0515513972646367,
#   'oneweight': 7376524477343478.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999717473983764,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_6612_origidx_6_RF22.mp4': {'event': 6612,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2571492493152618,
#   'pred_cascade': 0.0340722724795341,
#   'pred_tgtrack': 0.0629625841975212,
#   'pred_starttrack': 0.0364106744527816,
#   'pred_stoptrack': 0.6094052195549011,
#   'energy': 1279.1418212623948,
#   'zenith': 2.419313356816931,
#   'oneweight': 4573221398.650467,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6094052195549011,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_573_origidx_16_RF22.mp4': {'event': 573,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.988393008708954,
#   'pred_cascade': 0.0005319381016306,
#   'pred_tgtrack': 0.0006415282259695,
#   'pred_starttrack': 0.0095053445547819,
#   'pred_stoptrack': 0.0009280860540457,
#   'energy': 53504.5391826366,
#   'zenith': 1.794241307504498,
#   'oneweight': 27121566272459.85,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.988393008708954,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_9099_origidx_21_RF22.mp4': {'event': 9099,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1666192859411239,
#   'pred_cascade': 0.0493817739188671,
#   'pred_tgtrack': 0.2489187121391296,
#   'pred_starttrack': 0.0491295419633388,
#   'pred_stoptrack': 0.485950618982315,
#   'energy': 254.72679216899283,
#   'zenith': 0.4637975744502712,
#   'oneweight': 42686967.06987543,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.485950618982315,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_6066_origidx_16_RF22.mp4': {'event': 6066,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.7544537782669067,
#   'pred_cascade': 0.0656589716672897,
#   'pred_tgtrack': 0.0522536262869834,
#   'pred_starttrack': 0.0546716600656509,
#   'pred_stoptrack': 0.0729619339108467,
#   'energy': 500.421419224852,
#   'zenith': 1.2869769744997206,
#   'oneweight': 364515141.0359309,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7544537782669067,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_3125_origidx_16_RF22.mp4': {'event': 3125,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9994701743125916,
#   'pred_cascade': 5.989558485453017e-05,
#   'pred_tgtrack': 0.0001781336904969,
#   'pred_starttrack': 0.0001335913984803,
#   'pred_stoptrack': 0.0001581969845574,
#   'energy': 25761.341346928784,
#   'zenith': 1.5099456895600725,
#   'oneweight': 5027586799185.834,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9994701743125916,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_9239_origidx_25_RF22.mp4': {'event': 9239,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999384880065918,
#   'pred_cascade': 2.522892783574093e-09,
#   'pred_tgtrack': 2.511292905182927e-06,
#   'pred_starttrack': 3.478601628970068e-09,
#   'pred_stoptrack': 5.905327634536661e-05,
#   'energy': 19451.537348004946,
#   'zenith': 1.8130643104178688,
#   'oneweight': 2962936326382.4272,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999384880065918,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_9278_origidx_26_RF22.mp4': {'event': 9278,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.035952191799879,
#   'pred_cascade': 0.0103340810164809,
#   'pred_tgtrack': 0.0009710535523481,
#   'pred_starttrack': 0.0050085834227502,
#   'pred_stoptrack': 0.9477341175079346,
#   'energy': 286.08366038655555,
#   'zenith': 0.7354339277979228,
#   'oneweight': 1023060.812133298,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9477341175079346,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_5036_origidx_22_RF22.mp4': {'event': 5036,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1606397181749344,
#   'pred_cascade': 0.1836905628442764,
#   'pred_tgtrack': 0.1903544068336486,
#   'pred_starttrack': 0.3149285614490509,
#   'pred_stoptrack': 0.1503867357969284,
#   'energy': 4240.541525781739,
#   'zenith': 0.5382806704621923,
#   'oneweight': 75363595620.50504,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3149285614490509,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_4536_origidx_13_RF22.mp4': {'event': 4536,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999551773071288,
#   'pred_cascade': 1.6998910723486915e-06,
#   'pred_tgtrack': 4.432103196450044e-06,
#   'pred_starttrack': 2.2716543753631413e-05,
#   'pred_stoptrack': 1.594433888385538e-05,
#   'energy': 515404.7068489813,
#   'zenith': 2.310732804773349,
#   'oneweight': 4184428645511889.5,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999551773071288,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_699_origidx_18_RF22.mp4': {'event': 699,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2058617174625396,
#   'pred_cascade': 0.067639946937561,
#   'pred_tgtrack': 0.5314383506774902,
#   'pred_starttrack': 0.0554889813065528,
#   'pred_stoptrack': 0.1395710110664367,
#   'energy': 100.49526003552012,
#   'zenith': 2.8217856993712167,
#   'oneweight': 8018269.747436915,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5314383506774902,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_9220_origidx_24_RF22.mp4': {'event': 9220,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999974012374878,
#   'pred_cascade': 3.9443770472047385e-10,
#   'pred_tgtrack': 6.79422100802185e-06,
#   'pred_starttrack': 1.2428822060428504e-07,
#   'pred_stoptrack': 1.9108219930785708e-05,
#   'energy': 272216.3091086566,
#   'zenith': 1.6132234456255032,
#   'oneweight': 685999297136643.4,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999974012374878,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_463_origidx_14_RF22.mp4': {'event': 463,
#   'run': 22067,
# ...
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_6444_origidx_22_RF22.mp4': {'event': 6444,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9991006851196288,
#   'pred_cascade': 2.239787733060439e-07,
#   'pred_tgtrack': 0.000476236193208,
#   'pred_starttrack': 3.89429658298468e-07,
#   'pred_stoptrack': 0.0004224092408549,
#   'energy': 181978.50010086535,
#   'zenith': 0.96887814559635,
#   'oneweight': 345239870563247.06,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9991006851196288,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_5005_origidx_20_RF22.mp4': {'event': 5005,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1950385570526123,
#   'pred_cascade': 0.0349506773054599,
#   'pred_tgtrack': 0.0063219768926501,
#   'pred_starttrack': 0.0258606597781181,
#   'pred_stoptrack': 0.7378280758857727,
#   'energy': 4336.743197024315,
#   'zenith': 1.0331606753543814,
#   'oneweight': 11754759644.745855,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7378280758857727,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_6072_origidx_17_RF22.mp4': {'event': 6072,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9946050047874452,
#   'pred_cascade': 0.0001645986776566,
#   'pred_tgtrack': 0.0036053752992302,
#   'pred_starttrack': 0.0002026878064498,
#   'pred_stoptrack': 0.0014223096659407,
#   'energy': 3724.355735573065,
#   'zenith': 2.5971054465874515,
#   'oneweight': 56141904554.53073,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9946050047874452,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_803_origidx_19_RF22.mp4': {'event': 803,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 6.66813284624368e-05,
#   'pred_cascade': 0.8580297827720642,
#   'pred_tgtrack': 2.6965919914800907e-06,
#   'pred_starttrack': 0.141866996884346,
#   'pred_stoptrack': 3.3879092370625585e-05,
#   'energy': 2145.639835909692,
#   'zenith': 1.79960457544303,
#   'oneweight': 49577424598.32732,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8580297827720642,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_88_origidx_7_RF22.mp4': {'event': 88,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4097626209259033,
#   'pred_cascade': 0.0141544314101338,
#   'pred_tgtrack': 0.54070645570755,
#   'pred_starttrack': 0.0142744500190019,
#   'pred_stoptrack': 0.0211020484566688,
#   'energy': 614.2381683909186,
#   'zenith': 1.3508806596673122,
#   'oneweight': 872010130.284984,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.54070645570755,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_314_origidx_12_RF22.mp4': {'event': 314,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999464750289916,
#   'pred_cascade': 6.308883371275442e-08,
#   'pred_tgtrack': 1.6567679267609492e-05,
#   'pred_starttrack': 2.7091597075923343e-05,
#   'pred_stoptrack': 9.789736395759974e-06,
#   'energy': 471451.4955875396,
#   'zenith': 1.920890706912004,
#   'oneweight': 1928088699649204.5,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999464750289916,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_3169_origidx_18_RF22.mp4': {'event': 3169,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4414847195148468,
#   'pred_cascade': 0.1045059561729431,
#   'pred_tgtrack': 0.3109112977981567,
#   'pred_starttrack': 0.0440404824912548,
#   'pred_stoptrack': 0.099057525396347,
#   'energy': 137677.97801327938,
#   'zenith': 1.1368609792667446,
#   'oneweight': 589759471379148.6,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4414847195148468,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_3210_origidx_20_RF22.mp4': {'event': 3210,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999508500099182,
#   'pred_cascade': 1.6944323277812146e-08,
#   'pred_tgtrack': 0.0004101942759007,
#   'pred_starttrack': 5.095999995319289e-07,
#   'pred_stoptrack': 8.076199446804821e-05,
#   'energy': 475986.5429186759,
#   'zenith': 0.6740241503466796,
#   'oneweight': 4940771396563225.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999508500099182,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_8664_origidx_13_RF22.mp4': {'event': 8664,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4574381709098816,
#   'pred_cascade': 0.1312714517116546,
#   'pred_tgtrack': 0.1715433895587921,
#   'pred_starttrack': 0.0555090904235839,
#   'pred_stoptrack': 0.1842378675937652,
#   'energy': 1016.2674965970244,
#   'zenith': 1.8500023995267731,
#   'oneweight': 2451832193.834276,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4574381709098816,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_2934_origidx_12_RF22.mp4': {'event': 2934,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 3.607817052397877e-05,
#   'pred_cascade': 0.9884849786758424,
#   'pred_tgtrack': 8.401455488638021e-06,
#   'pred_starttrack': 0.0114160301163792,
#   'pred_stoptrack': 5.45613729627803e-05,
#   'energy': 229947.30678159528,
#   'zenith': 1.4314412792014195,
#   'oneweight': 523838593189844.5,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9884849786758424,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_6062_origidx_15_RF22.mp4': {'event': 6062,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999959468841552,
#   'pred_cascade': 7.857551415080266e-12,
#   'pred_tgtrack': 1.467640686314553e-06,
#   'pred_starttrack': 6.265074237177259e-09,
#   'pred_stoptrack': 2.6241386876790784e-06,
#   'energy': 876027.7016409263,
#   'zenith': 2.158559971035979,
#   'oneweight': 5455544336908725.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999959468841552,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_4531_origidx_12_RF22.mp4': {'event': 4531,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 5.758247061748989e-05,
#   'pred_cascade': 0.6171744465827942,
#   'pred_tgtrack': 0.0002023984270635,
#   'pred_starttrack': 0.3825305700302124,
#   'pred_stoptrack': 3.500099046505056e-05,
#   'energy': 13414.828283281522,
#   'zenith': 0.6517624504822611,
#   'oneweight': 1956900637759.84,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.6171744465827942,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_9289_origidx_27_RF22.mp4': {'event': 9289,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 3.5867513361154124e-05,
#   'pred_cascade': 0.9741604924201964,
#   'pred_tgtrack': 0.0001042507428792,
#   'pred_starttrack': 0.0254674647003412,
#   'pred_stoptrack': 0.0002319402265129,
#   'energy': 12794.289011247663,
#   'zenith': 1.614520458474135,
#   'oneweight': 1052342887375.9824,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9741604924201964,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_5019_origidx_21_RF22.mp4': {'event': 5019,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.26409712433815,
#   'pred_cascade': 0.0602619312703609,
#   'pred_tgtrack': 0.1204164028167724,
#   'pred_starttrack': 0.2554713487625122,
#   'pred_stoptrack': 0.2997532188892364,
#   'energy': 1419.1109523888424,
#   'zenith': 1.5485219097522247,
#   'oneweight': 3967582661.661946,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.2997532188892364,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_8427_origidx_4_RF22.mp4': {'event': 8427,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.8864471460110508e-05,
#   'pred_cascade': 0.973666250705719,
#   'pred_tgtrack': 5.069825874670641e-07,
#   'pred_starttrack': 0.0261892694979906,
#   'pred_stoptrack': 0.000115051974717,
#   'energy': 1123.9063754637125,
#   'zenith': 1.952223758950826,
#   'oneweight': 4116221353.4063296,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.973666250705719,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_9392_origidx_4_RF22.mp4': {'event': 9392,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.0922108888044025e-05,
#   'pred_cascade': 0.9957821369171144,
#   'pred_tgtrack': 2.296038019267144e-06,
#   'pred_starttrack': 0.0041603702120482,
#   'pred_stoptrack': 3.435352846281603e-05,
#   'energy': 10510.520558010743,
#   'zenith': 1.5341994702158073,
#   'oneweight': 656504198084.1045,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9957821369171144,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_6101_origidx_18_RF22.mp4': {'event': 6101,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999985694885254,
#   'pred_cascade': 9.395441091797352e-10,
#   'pred_tgtrack': 4.218371032038704e-06,
#   'pred_starttrack': 7.1361125897340125e-09,
#   'pred_stoptrack': 1.0166774700337555e-05,
#   'energy': 49340.8027797846,
#   'zenith': 1.185115593983524,
#   'oneweight': 23582783483550.023,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999985694885254,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_5393_origidx_28_RF22.mp4': {'event': 5393,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1794416308403015,
#   'pred_cascade': 0.0359950102865695,
#   'pred_tgtrack': 0.1698538959026336,
#   'pred_starttrack': 0.0147271193563938,
#   'pred_stoptrack': 0.5999823212623596,
#   'energy': 1352.854291238834,
#   'zenith': 1.284885023313796,
#   'oneweight': 8409020146.597038,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5999823212623596,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_5767_origidx_6_RF22.mp4': {'event': 5767,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999716281890868,
#   'pred_cascade': 6.405100894113501e-10,
#   'pred_tgtrack': 5.383409643400228e-06,
#   'pred_starttrack': 3.552325322786487e-09,
#   'pred_stoptrack': 2.296219645359088e-05,
#   'energy': 912916.6586915274,
#   'zenith': 1.0795262426224208,
#   'oneweight': 7760786275048522.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999716281890868,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_6627_origidx_8_RF22.mp4': {'event': 6627,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.4982762877480129e-05,
#   'pred_cascade': 0.9714533090591432,
#   'pred_tgtrack': 2.021554564635153e-06,
#   'pred_starttrack': 0.028479253873229,
#   'pred_stoptrack': 5.053578206570819e-05,
#   'energy': 1902.4960868442304,
#   'zenith': 1.7187985718764256,
#   'oneweight': 11622122072.954798,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9714533090591432,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_5506_origidx_30_RF22.mp4': {'event': 5506,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.000766247161664,
#   'pred_cascade': 0.8791193962097168,
#   'pred_tgtrack': 5.471093754749745e-05,
#   'pred_starttrack': 0.1200353577733039,
#   'pred_stoptrack': 2.4307764761033468e-05,
#   'energy': 127238.41600824088,
#   'zenith': 2.4669755753823077,
#   'oneweight': 31898873457405.38,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8791193962097168,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_4971_origidx_19_RF22.mp4': {'event': 4971,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0897114798426628,
#   'pred_cascade': 0.0389910265803337,
#   'pred_tgtrack': 0.7404831647872925,
#   'pred_starttrack': 0.0173976216465234,
#   'pred_stoptrack': 0.113416664302349,
#   'energy': 1301.994993142437,
#   'zenith': 1.6104100708298292,
#   'oneweight': 10087245730.863586,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7404831647872925,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_2746_origidx_5_RF22.mp4': {'event': 2746,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.1441981769166889e-05,
#   'pred_cascade': 0.8312364220619202,
#   'pred_tgtrack': 3.029846538993297e-06,
#   'pred_starttrack': 0.1687471717596054,
#   'pred_stoptrack': 1.943622692124336e-06,
#   'energy': 30614.829562702493,
#   'zenith': 0.7066655877497546,
#   'oneweight': 9811004510289.225,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8312364220619202,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000052/compressed_run_22067_event_4694_origidx_16_RF22.mp4': {'event': 4694,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0021050639916211,
#   'pred_cascade': 0.0003758765815291,
#   'pred_tgtrack': 0.987927258014679,
#   'pred_starttrack': 0.000405604019761,
#   'pred_stoptrack': 0.0091861458495259,
#   'energy': 601.834275225262,
#   'zenith': 1.8111220932259844,
#   'oneweight': 1267450994.2835674,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.987927258014679,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 5}}

# %%
make_subject_set('nue_run_22067_subrun_000052_phase2')
# Out:
# Subject Set Name: nue_run_22067_subrun_000052_phase2
# Subject Set ID: 112473
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112467>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>, <SubjectSet 112464>]

# %%
uploader(compressed_path,nue_csv,112473)
# Out:
# Confirm if subject set 112473 is listed below.
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112467>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>, <SubjectSet 112464>]
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112467>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>, <SubjectSet 112464>]
# Number of times loop has ran: 1
# Number of times loop has ran: 2
# Number of times loop has ran: 3
# Number of times loop has ran: 4
# Number of times loop has ran: 5
# Number of times loop has ran: 6
# Number of times loop has ran: 7
# Number of times loop has ran: 8
# Number of times loop has ran: 9
# Number of times loop has ran: 10
# Number of times loop has ran: 11
# Number of times loop has ran: 12
# Number of times loop has ran: 13
# Number of times loop has ran: 14
# Number of times loop has ran: 15
# Number of times loop has ran: 16
# Number of times loop has ran: 17
# Number of times loop has ran: 18
# Number of times loop has ran: 19
# Number of times loop has ran: 20
# Number of times loop has ran: 21
# Number of times loop has ran: 22
# Number of times loop has ran: 23
# Number of times loop has ran: 24
# Number of times loop has ran: 25
# Number of times loop has ran: 26
# Number of times loop has ran: 27
# Number of times loop has ran: 28
# Number of times loop has ran: 29
# Number of times loop has ran: 30
# Number of times loop has ran: 31
# Number of times loop has ran: 32
# Number of times loop has ran: 33
# Number of times loop has ran: 34
# Number of times loop has ran: 35
# Number of times loop has ran: 36
# Number of times loop has ran: 37
# Number of times loop has ran: 38
# Number of times loop has ran: 39
# Number of times loop has ran: 40
# Number of times loop has ran: 41
# Number of times loop has ran: 42
# Number of times loop has ran: 43
# Number of times loop has ran: 44
# Number of times loop has ran: 45
# Number of times loop has ran: 46
# Number of times loop has ran: 47
# Number of times loop has ran: 48
# Number of times loop has ran: 49
# Number of times loop has ran: 50
# Number of times loop has ran: 51
# Number of times loop has ran: 52
# Number of times loop has ran: 53
# Number of times loop has ran: 54
# Number of times loop has ran: 55
# Number of times loop has ran: 56
# Number of times loop has ran: 57
# Number of times loop has ran: 58
# Number of times loop has ran: 59
# Number of times loop has ran: 60
# Number of times loop has ran: 61
# Number of times loop has ran: 62
# Number of times loop has ran: 63
# Number of times loop has ran: 64
# Number of times loop has ran: 65
# Number of times loop has ran: 66
# Number of times loop has ran: 67
# Number of times loop has ran: 68
# Number of times loop has ran: 69
# Number of times loop has ran: 70
# Number of times loop has ran: 71
# Number of times loop has ran: 72
# Number of times loop has ran: 73
# Number of times loop has ran: 74
# Number of times loop has ran: 75
# Number of times loop has ran: 76
# Number of times loop has ran: 77
# Number of times loop has ran: 78
# Number of times loop has ran: 79
# Number of times loop has ran: 80
# Number of times loop has ran: 81
# Number of times loop has ran: 82
# Number of times loop has ran: 83
# Number of times loop has ran: 84
# Number of times loop has ran: 85
# Number of times loop has ran: 86
# Number of times loop has ran: 87
# Number of times loop has ran: 88
# Number of times loop has ran: 89
# Number of times loop has ran: 90
# Number of times loop has ran: 91
# Number of times loop has ran: 92
# Number of times loop has ran: 93
# Number of times loop has ran: 94
# Number of times loop has ran: 95
# Number of times loop has ran: 96
# Number of times loop has ran: 97
# Number of times loop has ran: 98
# Number of times loop has ran: 99
# Number of times loop has ran: 100
# Number of times loop has ran: 101
# Number of times loop has ran: 102
# Number of times loop has ran: 103
# Number of times loop has ran: 104
# Number of times loop has ran: 105
# Number of times loop has ran: 106
# Number of times loop has ran: 107
# Number of times loop has ran: 108
# Number of times loop has ran: 109
# Number of times loop has ran: 110
# Number of times loop has ran: 111
# Number of times loop has ran: 112
# Number of times loop has ran: 113
# Number of times loop has ran: 114
# Number of times loop has ran: 115
# Number of times loop has ran: 116
# Number of times loop has ran: 117
# Number of times loop has ran: 118
# Number of times loop has ran: 119
# Number of times loop has ran: 120
# Number of times loop has ran: 121
# Number of times loop has ran: 122
# Number of times loop has ran: 123
# Number of times loop has ran: 124
# Number of times loop has ran: 125
# Number of times loop has ran: 126
# Number of times loop has ran: 127
# Number of times loop has ran: 128
# Number of times loop has ran: 129
# Number of times loop has ran: 130
# Number of times loop has ran: 131
# Number of times loop has ran: 132
# Number of times loop has ran: 133
# Number of times loop has ran: 134
# Number of times loop has ran: 135
# Number of times loop has ran: 136
# Number of times loop has ran: 137
# Number of times loop has ran: 138
# Number of times loop has ran: 139
# Number of times loop has ran: 140
