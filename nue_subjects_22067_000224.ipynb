# %% [markdown]
# # Phase 2: Subject Creation
#
# **Description:**
#
# This notebook is to act as the resulting summary file for the creation and upload of subjects for the IceCube Zooniverse project currently called *Name that Neutrino!*. The project is currently being maintained by Elizabeth Warrick (as of March 2023). In this notebook, we take the i3 file and run it through several filters. [note: describe more later].
#
# > Nu Type: NuE
#
# > Run: 22076
#
# > SubRun: 000224
#
# ### Summary Stats:
#
# To be filled in after completing process. Also need to figure out global variables.
#
# **Subject Set Name:**

# %%
#Imports

#My functions: 
from uniformenergydist_filter import *

#General:
import numpy as np
import sys
import os
import subprocess
import argparse
import csv
from tables import *
import pandas as pd
from matplotlib import pyplot as plt
import h5py

#Zooniverse:
from panoptes_client import Panoptes, Project, SubjectSet, Subject
import magic
import glob

#IceCube:
from icecube.icetray import I3Units
import icecube.MuonGun
from icecube import dataio, dataclasses, icetray, MuonGun
from I3Tray import *
from icecube.hdfwriter import I3HDFWriter
from mc_labeler import MCLabeler #make sure that mc_labeler script is in current directory.

# %%
#Specify file paths:

#Initial I3 File:
nue = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/classifier_rehyd_DST_IC86.2020_NuE.022067.000224.i3.zst'

#Desired output directory. Note that creation of this directory is not yet coded and is done manually. 
phase1_dir = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/'

# %%
#Run Filter 1 to label MC truth.
filter1(nue,phase1_dir)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/mc_labeler.py:523: UserWarning: Couldn't find OMKey in MCPESeriesMap
#   warnings.warn("Couldn't find OMKey in MCPESeriesMap")

# %% [markdown]
# Note that the above cell might return an "exception" warning that the *MCPESeriesMap could not be found*. I am unsure why it does that because when I check the i3 file in dataio-shovel, I see the specified mc_pid_series_map (look at mc_labeler.py for exact name of specified key). The resulting file size should be around 400 MB.

# %%
#Path of hdf from above filter.
nue_hdf = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/\
Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000224.i3.zst.hd5'

# %%
#Run uniformenergy_events function which requires hdf from filter 1, 
#number of bins, size of each random choice, and a random seed. 

uniformenergy_events(nue_hdf,25,8,12,subrun = True)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:177: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['binned_log10E'] = pd.cut(x = np.log10(df_filtered['energy']), bins = bins, labels = labels, include_lowest = True) #might throw an error?
# Number of Bins: 25
# Number of Events per Bin: 8
# Total Number of Events: 200
# Initial Number of Events: 2628
# Number of Events after filtering: 2556
# Please input subrun number:
# 000224

# %% [markdown]
# The above function throws another warning about pd.cut, currently that is not a problem but I don't know if a new version of pandas will allow this.

# %%
#Path to Random Events CSV
nue_csv = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/random_events_uniform_energy_distrib_22067_000224.csv'

# %%
#Run event_characterization_plots function whick makes some quick 
#plots to get an idea of what data you're dealing with.
#Note that I want to update the plot types, maybe make a 2D histogram as Mike K suggested. 
#For truth labels, check out enums.py or in the .py file that holds the functions.

event_characterization_plots(nue_csv)

# %% [markdown]
# Now that we have the events for this phase chosen, we run the second filter to pick out only those events.

# %%
#Path to i3 file from filter1 with MC truth labels. 
nue_filter1 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000224.i3.zst'

# %%
#Run function to perform second filter which passes through only selected event IDs chosen from 
#the uniformenergy_events function. 
filter2(nue_filter1,phase1_dir,nue_csv)

# %%
#Path to i3 file from filter 2 that holds only specified events. 
nue_filter2 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000224.i3.zst'

# %%
#Run function to perform third filter, which returns only the DAQ frames of the specified events.
#DAQ only file is then split up into many smaller i3 files since SteamShovel can't handle making videos of large
#i3 files at one time. Size limit is approx 2E6 MB (? unsure of units)
filter3(nue_filter2,22067_000224,phase1_dir)

# %%
#Path to NuMu Daq Only folder
nue_daq = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000224/'

# %%
get_steamshovel(nue_daq,22067000224)
# Out:
# List of files:
# ['/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000224/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000224.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000224/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000224.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000224/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000224.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000224/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000224.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000224/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000224.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000224/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000224.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000224/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000224.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000224/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000224.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000224/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000224.i3.zst']
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000224/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000224.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000224/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000224.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000224/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000224.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000224/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000224.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000224/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000224.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000224/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000224.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000224/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000224.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000224/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000224.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000224/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000224.i3.zst

# %% [markdown]
# Ideas for Compression:
# - Use GUI to add files to queue and send to one compression folder.
# - Add a subprocess line in movie script to compress the video after making it and direct it to save in the compression folder.

# %%
compressed_path = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/'

# %% [markdown]
# Can't get manifest yet since some subjects are missing and lining it up won't work.

# %%
get_manifest(compressed_path, nue_csv)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:418: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   dict_manifest = s3.to_dict('dict')
# {'/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_3810_origidx_12_RF22.mp4': {'event': 3810,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.1591356926364824e-05,
#   'pred_cascade': 0.4587277770042419,
#   'pred_tgtrack': 4.1163715991388023e-08,
#   'pred_starttrack': 0.5411754846572876,
#   'pred_stoptrack': 7.512071897508577e-05,
#   'energy': 254.0312073192933,
#   'zenith': 2.2302189355995496,
#   'oneweight': 135766392.50022355,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.5411754846572876,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_9000_origidx_7_RF22.mp4': {'event': 9000,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.1209811344742775,
#   'pred_cascade': 0.6366045475006104,
#   'pred_tgtrack': 5.292676723911427e-05,
#   'pred_starttrack': 0.1500841379165649,
#   'pred_stoptrack': 0.0922772511839866,
#   'energy': 314.91658356859097,
#   'zenith': 1.2304358890373617,
#   'oneweight': 184608340.82472715,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.6366045475006104,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_702_origidx_17_RF22.mp4': {'event': 702,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.417283212707844e-05,
#   'pred_cascade': 0.9961063265800476,
#   'pred_tgtrack': 1.8336009377506455e-09,
#   'pred_starttrack': 0.0038669467903673,
#   'pred_stoptrack': 2.465934358042432e-06,
#   'energy': 30218.647082102536,
#   'zenith': 2.3886424052612907,
#   'oneweight': 11196248955667.37,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9961063265800476,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_7818_origidx_6_RF22.mp4': {'event': 7818,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 4.831954811379546e-06,
#   'pred_cascade': 0.9867238402366638,
#   'pred_tgtrack': 7.339412633200483e-08,
#   'pred_starttrack': 0.013268768787384,
#   'pred_stoptrack': 2.520078851375729e-06,
#   'energy': 14234.51829083292,
#   'zenith': 1.5962765351104262,
#   'oneweight': 1254457093474.5125,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9867238402366638,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_7825_origidx_7_RF22.mp4': {'event': 7825,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0063039637170732,
#   'pred_cascade': 0.0016055196756497,
#   'pred_tgtrack': 0.8308545351028442,
#   'pred_starttrack': 0.0009494869736954,
#   'pred_stoptrack': 0.1602865904569625,
#   'energy': 1611.095060523058,
#   'zenith': 2.2533317352230524,
#   'oneweight': 22369400620.171955,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8308545351028442,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_8904_origidx_12_RF22.mp4': {'event': 8904,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9910883903503418,
#   'pred_cascade': 6.403296083590249e-06,
#   'pred_tgtrack': 1.9994764443254095e-05,
#   'pred_starttrack': 1.5970088043104624e-06,
#   'pred_stoptrack': 0.0088835675269365,
#   'energy': 6137.159520981324,
#   'zenith': 2.950943903636829,
#   'oneweight': 202459887901.15265,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9910883903503418,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_2626_origidx_7_RF22.mp4': {'event': 2626,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.3158736439654606e-07,
#   'pred_cascade': 0.9944045543670654,
#   'pred_tgtrack': 1.4962868277734742e-08,
#   'pred_starttrack': 0.0055952277034521,
#   'pred_stoptrack': 4.88466938008969e-08,
#   'energy': 135384.1613542032,
#   'zenith': 0.6762620419365313,
#   'oneweight': 276117718795058.62,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9944045543670654,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_6641_origidx_6_RF22.mp4': {'event': 6641,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 1.4776990610698704e-05,
#   'pred_cascade': 0.97558856010437,
#   'pred_tgtrack': 1.322513253398938e-05,
#   'pred_starttrack': 0.0233363900333642,
#   'pred_stoptrack': 0.001047090976499,
#   'energy': 2126.599028540269,
#   'zenith': 2.985405629279465,
#   'oneweight': 15885652781.885698,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.97558856010437,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_6884_origidx_11_RF22.mp4': {'event': 6884,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2590306401252746,
#   'pred_cascade': 0.0615689828991889,
#   'pred_tgtrack': 0.0330794714391231,
#   'pred_starttrack': 0.1838224828243255,
#   'pred_stoptrack': 0.4624984264373779,
#   'energy': 2254.6787575624867,
#   'zenith': 0.7864229231544396,
#   'oneweight': 31031369359.335304,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4624984264373779,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_5681_origidx_5_RF22.mp4': {'event': 5681,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.0008036042563616e-05,
#   'pred_cascade': 0.9552910923957824,
#   'pred_tgtrack': 1.5144476492423564e-05,
#   'pred_starttrack': 0.0446720607578754,
#   'pred_stoptrack': 1.1565763998078182e-05,
#   'energy': 1660.846043122289,
#   'zenith': 1.8134889605046467,
#   'oneweight': 9004696262.079725,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9552910923957824,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_9248_origidx_15_RF22.mp4': {'event': 9248,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2682117521762848,
#   'pred_cascade': 0.0603893063962459,
#   'pred_tgtrack': 0.5437560081481934,
#   'pred_starttrack': 0.0341406352818012,
#   'pred_stoptrack': 0.0935023128986358,
#   'energy': 2170.64352894942,
#   'zenith': 1.168878542675704,
#   'oneweight': 43120667422.01205,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5437560081481934,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_7691_origidx_4_RF22.mp4': {'event': 7691,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999653100967408,
#   'pred_cascade': 2.2271534616535857e-10,
#   'pred_tgtrack': 1.2658085324801505e-05,
#   'pred_starttrack': 9.25353305092358e-08,
#   'pred_stoptrack': 2.198096990468912e-05,
#   'energy': 274154.4721380217,
#   'zenith': 2.2483291937447163,
#   'oneweight': 167973286164849.5,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999653100967408,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_2166_origidx_5_RF22.mp4': {'event': 2166,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.000466622353997,
#   'pred_cascade': 0.8824407458305359,
#   'pred_tgtrack': 5.344593773770612e-06,
#   'pred_starttrack': 0.1170784905552864,
#   'pred_stoptrack': 8.758569492783863e-06,
#   'energy': 389358.0182109549,
#   'zenith': 1.8793445342429005,
#   'oneweight': 75694998534020.98,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8824407458305359,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_8869_origidx_10_RF22.mp4': {'event': 8869,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0299509391188621,
#   'pred_cascade': 0.0046725156717002,
#   'pred_tgtrack': 0.0037062605842947,
#   'pred_starttrack': 0.0116614717990159,
#   'pred_stoptrack': 0.9500088095664978,
#   'energy': 120684.51436482742,
#   'zenith': 1.831537289228771,
#   'oneweight': 1872917671416332.8,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9500088095664978,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_4198_origidx_19_RF22.mp4': {'event': 4198,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0453913509845733,
#   'pred_cascade': 0.0117596639320254,
#   'pred_tgtrack': 0.018003175035119,
#   'pred_starttrack': 0.0056124017573893,
#   'pred_stoptrack': 0.9192334413528442,
#   'energy': 1413.3245921586365,
#   'zenith': 0.8904895559760024,
#   'oneweight': 1049162451.7041194,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9192334413528442,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_2411_origidx_10_RF22.mp4': {'event': 2411,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9997982382774352,
#   'pred_cascade': 2.902109282054699e-11,
#   'pred_tgtrack': 0.0001550746092107,
#   'pred_starttrack': 8.57551918365118e-10,
#   'pred_stoptrack': 4.6701126848347485e-05,
#   'energy': 209281.23099390863,
#   'zenith': 1.98307622694664,
#   'oneweight': 148841114805885.75,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9997982382774352,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_445_origidx_9_RF22.mp4': {'event': 445,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0002837250940501,
#   'pred_cascade': 0.9691634774208068,
#   'pred_tgtrack': 2.58284603660286e-06,
#   'pred_starttrack': 0.030549569055438,
#   'pred_stoptrack': 6.073643135096063e-07,
#   'energy': 243782.19531479583,
#   'zenith': 1.630930295904205,
#   'oneweight': 537550261076366.9,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9691634774208068,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_2299_origidx_7_RF22.mp4': {'event': 2299,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 8.000947673281189e-06,
#   'pred_cascade': 0.9983077049255372,
#   'pred_tgtrack': 5.4191637288703014e-11,
#   'pred_starttrack': 0.0016843067714944,
#   'pred_stoptrack': 2.818866207121573e-08,
#   'energy': 84823.92838252653,
#   'zenith': 1.871103075073164,
#   'oneweight': 74651264901077.78,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9983077049255372,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_366_origidx_8_RF22.mp4': {'event': 366,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9932489395141602,
#   'pred_cascade': 0.000113730886369,
#   'pred_tgtrack': 0.0058993413113057,
#   'pred_starttrack': 0.0001184322900371,
#   'pred_stoptrack': 0.000619460537564,
#   'energy': 53160.71608753828,
#   'zenith': 0.9051669997305628,
#   'oneweight': 38488169233676.66,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9932489395141602,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_8821_origidx_9_RF22.mp4': {'event': 8821,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0001910199498524,
#   'pred_cascade': 0.8958238363265991,
#   'pred_tgtrack': 1.0908287549682427e-05,
#   'pred_starttrack': 0.1037902534008026,
#   'pred_stoptrack': 0.0001840447366703,
#   'energy': 381.41681749766576,
#   'zenith': 1.6389012351545735,
#   'oneweight': 239431985.96379963,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8958238363265991,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_2355_origidx_8_RF22.mp4': {'event': 2355,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.1693537089740856e-05,
#   'pred_cascade': 0.9967909455299376,
#   'pred_tgtrack': 1.2364906876172201e-09,
#   'pred_starttrack': 0.0031973964069038,
#   'pred_stoptrack': 2.1461286081603248e-08,
#   'energy': 995856.447927344,
#   'zenith': 0.3517514541109965,
#   'oneweight': 1.1100332278216738e+16,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9967909455299376,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_3843_origidx_13_RF22.mp4': {'event': 3843,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999026656150818,
#   'pred_cascade': 0.0005458782543428,
#   'pred_tgtrack': 4.4028514821548015e-05,
#   'pred_starttrack': 0.0003249942092224,
#   'pred_stoptrack': 5.834532203152776e-05,
#   'energy': 697460.2675021123,
#   'zenith': 1.453949973720296,
#   'oneweight': 4277156052487396.0,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999026656150818,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_6877_origidx_10_RF22.mp4': {'event': 6877,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.6125823259353638,
#   'pred_cascade': 0.1549590528011322,
#   'pred_tgtrack': 0.0465802885591983,
#   'pred_starttrack': 0.0972796380519867,
#   'pred_stoptrack': 0.0885986015200614,
#   'energy': 61943.39265975702,
#   'zenith': 2.3679508048139697,
#   'oneweight': 49647907985865.99,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6125823259353638,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_2665_origidx_8_RF22.mp4': {'event': 2665,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1274771690368652,
#   'pred_cascade': 0.0493029989302158,
#   'pred_tgtrack': 0.7466212511062622,
#   'pred_starttrack': 0.0279033612459898,
#   'pred_stoptrack': 0.048695221543312,
#   'energy': 221.2229890870433,
#   'zenith': 0.8720383023865956,
#   'oneweight': 76055191.5082206,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7466212511062622,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_4221_origidx_20_RF22.mp4': {'event': 4221,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0658860877156257,
#   'pred_cascade': 0.8570575714111328,
#   'pred_tgtrack': 0.004794793203473,
#   'pred_starttrack': 0.0705719143152237,
#   'pred_stoptrack': 0.0016896473243832,
#   'energy': 631082.348163638,
#   'zenith': 1.2031151098795123,
#   'oneweight': 4560821149778232.0,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8570575714111328,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_4716_origidx_26_RF22.mp4': {'event': 4716,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0006055849953554,
#   'pred_cascade': 0.8007525205612183,
#   'pred_tgtrack': 7.5122072303202e-05,
#   'pred_starttrack': 0.198148488998413,
#   'pred_stoptrack': 0.0004182812117505,
#   'energy': 2237.408979668302,
#   'zenith': 1.02486152893994,
#   'oneweight': 22054049778.064037,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8007525205612183,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_9032_origidx_8_RF22.mp4': {'event': 9032,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2747971415519714,
#   'pred_cascade': 0.0403848215937614,
#   'pred_tgtrack': 0.0636996701359748,
#   'pred_starttrack': 0.0855669304728508,
#   'pred_stoptrack': 0.5355514287948608,
#   'energy': 674.2060392227303,
#   'zenith': 1.418113282483129,
#   'oneweight': 590319634.5431489,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5355514287948608,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_2075_origidx_4_RF22.mp4': {'event': 2075,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999977350234984,
#   'pred_cascade': 4.230880978894902e-09,
#   'pred_tgtrack': 1.0501804581508625e-06,
#   'pred_starttrack': 1.4024151084868208e-07,
#   'pred_stoptrack': 1.122430148825515e-06,
#   'energy': 154517.38132001265,
#   'zenith': 0.7266583628742318,
#   'oneweight': 128171886899035.28,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999977350234984,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_4531_origidx_23_RF22.mp4': {'event': 4531,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3143055438995361,
#   'pred_cascade': 0.1245847716927528,
#   'pred_tgtrack': 0.1253664642572403,
#   'pred_starttrack': 0.2924807071685791,
#   'pred_stoptrack': 0.1432624906301498,
#   'energy': 45299.42159562749,
#   'zenith': 2.4854870811100773,
#   'oneweight': 10480465806144.129,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3143055438995361,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_8681_origidx_4_RF22.mp4': {'event': 8681,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 7.336670387303457e-05,
#   'pred_cascade': 0.6514365077018738,
#   'pred_tgtrack': 7.821368490112945e-05,
#   'pred_starttrack': 0.3481029868125915,
#   'pred_stoptrack': 0.0003089527017436,
#   'energy': 78727.14767679413,
#   'zenith': 1.5950948822949895,
#   'oneweight': 44788325373746.24,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.6514365077018738,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_3974_origidx_16_RF22.mp4': {'event': 3974,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 3.1512740861217026e-06,
#   'pred_cascade': 0.9981456995010376,
#   'pred_tgtrack': 2.910082841367512e-08,
#   'pred_starttrack': 0.0018493459792807,
#   'pred_stoptrack': 1.812709228943277e-06,
#   'energy': 3897.906444037552,
#   'zenith': 1.2891377231360066,
#   'oneweight': 69632945059.90639,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9981456995010376,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_21_origidx_6_RF22.mp4': {'event': 21,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0598864257335662,
#   'pred_cascade': 0.0181128848344087,
#   'pred_tgtrack': 0.2854597270488739,
#   'pred_starttrack': 0.6277650594711304,
#   'pred_stoptrack': 0.0087758731096982,
#   'energy': 760.2395199144577,
#   'zenith': 1.5839971301445035,
#   'oneweight': 1414838196.0254126,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6277650594711304,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_6134_origidx_8_RF22.mp4': {'event': 6134,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1209597364068031,
#   'pred_cascade': 0.0209506917744874,
#   'pred_tgtrack': 0.0050151515752077,
#   'pred_starttrack': 0.0214771702885627,
#   'pred_stoptrack': 0.8315972685813904,
#   'energy': 839363.8504060942,
#   'zenith': 1.6868655764647145,
#   'oneweight': 3255715859339506.0,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8315972685813904,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_629_origidx_14_RF22.mp4': {'event': 629,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.3340309780905955e-05,
#   'pred_cascade': 0.9813470840454102,
#   'pred_tgtrack': 2.796865032905771e-07,
#   'pred_starttrack': 0.0186202079057693,
#   'pred_stoptrack': 8.962366337073036e-06,
#   'energy': 4432.644880312236,
#   'zenith': 1.7461726794695978,
#   'oneweight': 99247496818.49084,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9813470840454102,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_2256_origidx_6_RF22.mp4': {'event': 2256,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3193798065185547,
#   'pred_cascade': 0.0327173173427581,
#   'pred_tgtrack': 0.0188007876276969,
#   'pred_starttrack': 0.0545230843126773,
#   'pred_stoptrack': 0.5745790004730225,
#   'energy': 289.5052794883626,
#   'zenith': 1.699440668959444,
#   'oneweight': 127029559.04435244,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5745790004730225,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_579_origidx_13_RF22.mp4': {'event': 579,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0125869968906044,
#   'pred_cascade': 0.0041477610357105,
#   'pred_tgtrack': 0.5726740956306458,
#   'pred_starttrack': 0.002686794148758,
#   'pred_stoptrack': 0.4079042971134186,
#   'energy': 43288.402473055816,
#   'zenith': 0.855448224992379,
#   'oneweight': 35815538742321.05,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5726740956306458,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_8934_origidx_4_RF22.mp4': {'event': 8934,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9992332458496094,
#   'pred_cascade': 2.8899460176035063e-06,
#   'pred_tgtrack': 0.0003438526764512,
#   'pred_starttrack': 3.1121549000090454e-06,
#   'pred_stoptrack': 0.0004168811428826,
#   'energy': 30155.80431605476,
#   'zenith': 2.0574324790723617,
#   'oneweight': 8849684458760.775,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9992332458496094,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_2431_origidx_4_RF22.mp4': {'event': 2431,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 2.8777709303540178e-05,
#   'pred_cascade': 0.99649977684021,
#   'pred_tgtrack': 1.3013628574753966e-07,
#   'pred_starttrack': 0.0034491880796849,
#   'pred_stoptrack': 2.210117418144364e-05,
#   'energy': 44948.884955815534,
#   'zenith': 1.975945044900484,
#   'oneweight': 21032543535361.41,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.99649977684021,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_9312_origidx_16_RF22.mp4': {'event': 9312,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0788233205676078,
#   'pred_cascade': 0.0208054464310407,
#   'pred_tgtrack': 0.8699862360954285,
#   'pred_starttrack': 0.0117689035832881,
#   'pred_stoptrack': 0.0186160914599895,
#   'energy': 101.63516070269824,
#   'zenith': 1.023784333073684,
#   'oneweight': 10510576.15112987,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8699862360954285,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_9164_origidx_14_RF22.mp4': {'event': 9164,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2966892719268799,
#   'pred_cascade': 0.0651668906211853,
#   'pred_tgtrack': 0.504974901676178,
#   'pred_starttrack': 0.0376183688640594,
#   'pred_stoptrack': 0.0955504551529884,
#   'energy': 1877.5934728674677,
#   'zenith': 2.272271981331572,
#   'oneweight': 36065013318.57921,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.504974901676178,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_3316_origidx_4_RF22.mp4': {'event': 3316,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.0319452485418878e-05,
#   'pred_cascade': 0.9640264511108398,
#   'pred_tgtrack': 4.3154578577286884e-08,
#   'pred_starttrack': 0.0359559059143066,
#   'pred_stoptrack': 7.204667781479657e-06,
#   'energy': 714.9483237950658,
#   'zenith': 2.6918796633344075,
#   'oneweight': 1501568584.739866,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9640264511108398,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_6581_origidx_4_RF22.mp4': {'event': 6581,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0051853829063475,
#   'pred_cascade': 0.9540863633155824,
#   'pred_tgtrack': 0.0001048900594469,
#   'pred_starttrack': 0.0405285619199276,
#   'pred_stoptrack': 9.484915062785149e-05,
#   'energy': 17480.287028541872,
#   'zenith': 2.2521166867278315,
#   'oneweight': 731828847111.1023,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9540863633155824,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_5968_origidx_7_RF22.mp4': {'event': 5968,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 7.750914846837986e-06,
#   'pred_cascade': 0.997933268547058,
#   'pred_tgtrack': 3.783466429041482e-09,
#   'pred_starttrack': 0.0020560605917125,
#   'pred_stoptrack': 3.003065785378567e-06,
#   'energy': 22698.824519553604,
#   'zenith': 1.7890532846140117,
#   'oneweight': 4278814806565.9194,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.997933268547058,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_9133_origidx_12_RF22.mp4': {'event': 9133,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1148295402526855,
#   'pred_cascade': 0.0311737321317195,
#   'pred_tgtrack': 0.7615333199501038,
#   'pred_starttrack': 0.0300524178892374,
#   'pred_stoptrack': 0.0624109432101249,
#   'energy': 1411.004820162779,
#   'zenith': 2.141237257071274,
#   'oneweight': 5711303669.023576,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7615333199501038,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_3964_origidx_15_RF22.mp4': {'event': 3964,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999855756759644,
#   'pred_cascade': 1.2218285938558893e-08,
#   'pred_tgtrack': 2.3077761852619005e-06,
#   'pred_starttrack': 5.36912921234034e-06,
#   'pred_stoptrack': 6.772718734282535e-06,
#   'energy': 883670.3942047321,
#   'zenith': 1.57628306106129,
#   'oneweight': 6708879162664287.0,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999855756759644,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_6842_origidx_9_RF22.mp4': {'event': 6842,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3758755028247833,
#   'pred_cascade': 0.5447213053703308,
#   'pred_tgtrack': 0.0011366816470399,
#   'pred_starttrack': 0.03979267552495,
#   'pred_stoptrack': 0.0384738035500049,
#   'energy': 1051.5353357147565,
#   'zenith': 1.568257953169107,
#   'oneweight': 2523251272.273627,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5447213053703308,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_3317_origidx_5_RF22.mp4': {'event': 3317,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.8654903173446655,
#   'pred_cascade': 0.062924787402153,
#   'pred_tgtrack': 0.0019493708387017,
#   'pred_starttrack': 0.0238599404692649,
#   'pred_stoptrack': 0.0457755886018276,
#   'energy': 7001.702832032106,
#   'zenith': 2.4856779880367488,
#   'oneweight': 298518648922.7345,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8654903173446655,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_3492_origidx_6_RF22.mp4': {'event': 3492,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2586694061756134,
#   'pred_cascade': 0.0313047021627426,
#   'pred_tgtrack': 0.6290605664253235,
#   'pred_starttrack': 0.0425396636128425,
#   'pred_stoptrack': 0.0384257212281227,
#   'energy': 234601.2148858615,
#   'zenith': 1.225416597753663,
#   'oneweight': 1949246810124656.0,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6290605664253235,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_457_origidx_11_RF22.mp4': {'event': 457,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0538890846073627,
#   'pred_cascade': 0.0134853310883045,
#   'pred_tgtrack': 0.8982970714569092,
#   'pred_starttrack': 0.0227911081165075,
#   'pred_stoptrack': 0.0115373991429805,
#   'energy': 123.86103032468142,
#   'zenith': 2.280960229092604,
#   'oneweight': 4546172.061252622,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8982970714569092,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_8885_origidx_11_RF22.mp4': {'event': 8885,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.8871109205065292e-05,
#   'pred_cascade': 0.9983055591583252,
#   'pred_tgtrack': 8.148668545482352e-11,
#   'pred_starttrack': 0.0016755039105191,
#   'pred_stoptrack': 1.7093176651883368e-08,
#   'energy': 417473.4270302397,
#   'zenith': 1.1405896870273808,
#   'oneweight': 2134989774669308.0,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9983055591583252,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_2392_origidx_9_RF22.mp4': {'event': 2392,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 5.343700831872411e-05,
#   'pred_cascade': 0.9160781502723694,
#   'pred_tgtrack': 0.0002233419800177,
#   'pred_starttrack': 0.0830254331231117,
#   'pred_stoptrack': 0.0006197802722454,
#   'energy': 780.0945741910031,
#   'zenith': 2.1489268315606376,
#   'oneweight': 1692499652.042137,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9160781502723694,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_3635_origidx_8_RF22.mp4': {'event': 3635,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 7.859714969526976e-06,
#   'pred_cascade': 0.9946879148483276,
#   'pred_tgtrack': 1.6749297060414395e-07,
#   'pred_starttrack': 0.0053032566793262,
#   'pred_stoptrack': 8.886746627467801e-07,
#   'energy': 3954.058451279127,
#   'zenith': 1.588855919544961,
#   'oneweight': 66750150197.08937,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9946879148483276,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_448_origidx_10_RF22.mp4': {'event': 448,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 1.330077247985173e-05,
#   'pred_cascade': 0.8670457005500793,
#   'pred_tgtrack': 7.069094465350646e-08,
#   'pred_starttrack': 0.1329326331615448,
#   'pred_stoptrack': 8.284945579362102e-06,
#   'energy': 537.6599988142603,
#   'zenith': 2.161186208237386,
#   'oneweight': 823235128.9264607,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.8670457005500793,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_2715_origidx_10_RF22.mp4': {'event': 2715,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9991958737373352,
#   'pred_cascade': 7.285650838184665e-08,
#   'pred_tgtrack': 7.5505580753088e-05,
#   'pred_starttrack': 1.5516285145622533e-07,
#   'pred_stoptrack': 0.0007284186431206,
#   'energy': 16365.222530580808,
#   'zenith': 2.091887094740647,
#   'oneweight': 2118008936757.8608,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9991958737373352,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_9126_origidx_11_RF22.mp4': {'event': 9126,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2160016298294067,
#   'pred_cascade': 0.0581278949975967,
#   'pred_tgtrack': 0.6515964269638062,
#   'pred_starttrack': 0.0361311733722686,
#   'pred_stoptrack': 0.038142904639244,
#   'energy': 162.0442655160899,
#   'zenith': 2.3045436005631976,
#   'oneweight': 26003286.163783696,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6515964269638062,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_9119_origidx_10_RF22.mp4': {'event': 9119,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0040563656948506,
#   'pred_cascade': 0.0015625816304236,
#   'pred_tgtrack': 0.0954776927828788,
#   'pred_starttrack': 0.0008685973007231,
#   'pred_stoptrack': 0.8980347514152527,
#   'energy': 272.66103653167823,
#   'zenith': 2.18976746155995,
#   'oneweight': 112785666.58617878,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8980347514152527,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_4704_origidx_24_RF22.mp4': {'event': 4704,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 4.603392881108448e-05,
#   'pred_cascade': 0.9865131974220276,
#   'pred_tgtrack': 2.087327175104292e-06,
#   'pred_starttrack': 0.0134267611429095,
#   'pred_stoptrack': 1.2053232239850333e-05,
#   'energy': 11838.554112746748,
#   'zenith': 0.3804428206477174,
#   'oneweight': 1104344301253.8965,
#   '#truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9865131974220276,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_508_origidx_12_RF22.mp4': {'event': 508,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 5.909538958803751e-05,
#   'pred_cascade': 0.9966715574264526,
#   'pred_tgtrack': 6.911883509985728e-09,
#   'pred_starttrack': 0.0032691895030438,
#   'pred_stoptrack': 1.5755004767470385e-07,
#   'energy': 17803.947638637204,
#   'zenith': 2.41432848038584,
#   'oneweight': 3886610354653.8784,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9966715574264526,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_8961_origidx_5_RF22.mp4': {'event': 8961,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9389674067497252,
#   'pred_cascade': 0.0459418408572673,
#   'pred_tgtrack': 0.0006640465580858,
#   'pred_starttrack': 0.0096267741173505,
#   'pred_stoptrack': 0.0047999122180044,
#   'energy': 5576.73324591598,
#   'zenith': 1.260636517688119,
#   'oneweight': 186883753649.54904,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9389674067497252,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_79_origidx_7_RF22.mp4': {'event': 79,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9968045949935912,
#   'pred_cascade': 2.47833810362863e-07,
#   'pred_tgtrack': 0.0029726028442382,
#   'pred_starttrack': 2.70039976157932e-07,
#   'pred_stoptrack': 0.0002223330666311,
#   'energy': 625126.2527886104,
#   'zenith': 1.6055884156036804,
#   'oneweight': 3074842561851637.0,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9968045949935912,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_5588_origidx_4_RF22.mp4': {'event': 5588,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.150399848818779,
#   'pred_cascade': 0.0421680510044097,
#   'pred_tgtrack': 0.7366065979003906,
#   'pred_starttrack': 0.0261267274618148,
#   'pred_stoptrack': 0.0446987003087997,
#   'energy': 1131.7025959505315,
#   'zenith': 1.069902901282879,
#   'oneweight': 6111678859.8852415,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7366065979003906,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_8795_origidx_7_RF22.mp4': {'event': 8795,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 5.8845369466098425e-08,
#   'pred_cascade': 0.8775862455368042,
#   'pred_tgtrack': 3.001024850846079e-08,
#   'pred_starttrack': 0.1224135905504226,
#   'pred_stoptrack': 1.5386786955673415e-08,
#   'energy': 48413.6900608878,
#   'zenith': 1.04290789044326,
#   'oneweight': 26780482716746.77,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8775862455368042,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_9103_origidx_9_RF22.mp4': {'event': 9103,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1560927480459213,
#   'pred_cascade': 0.0318164825439453,
#   'pred_tgtrack': 0.0089630465954542,
#   'pred_starttrack': 0.0198792926967144,
#   'pred_stoptrack': 0.7832484245300293,
#   'energy': 103.87820157490268,
#   'zenith': 0.6160543359182918,
#   'oneweight': 6542493.403874577,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7832484245300293,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_7751_origidx_5_RF22.mp4': {'event': 7751,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0001274938113056,
#   'pred_cascade': 0.892562985420227,
#   'pred_tgtrack': 9.070212399819866e-06,
#   'pred_starttrack': 0.1072439551353454,
#   'pred_stoptrack': 5.646087811328471e-05,
#   'energy': 2833.42321615468,
#   'zenith': 1.6398455303663004,
#   'oneweight': 98572377218.7958,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.892562985420227,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_8814_origidx_8_RF22.mp4': {'event': 8814,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 6.274754559854046e-05,
#   'pred_cascade': 0.8792856931686401,
#   'pred_tgtrack': 2.188281769122113e-06,
#   'pred_starttrack': 0.1206462606787681,
#   'pred_stoptrack': 3.032269660252496e-06,
#   'energy': 575939.795301474,
#   'zenith': 1.7836642106974487,
#   'oneweight': 841764990761376.1,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8792856931686401,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_4021_origidx_18_RF22.mp4': {'event': 4021,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2253060936927795,
#   'pred_cascade': 0.0699518397450447,
#   'pred_tgtrack': 0.2110203355550766,
#   'pred_starttrack': 0.390666663646698,
#   'pred_stoptrack': 0.1030550450086593,
#   'energy': 840.3981487418508,
#   'zenith': 1.105694736376926,
#   'oneweight': 1633194936.8163404,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.390666663646698,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_3494_origidx_7_RF22.mp4': {'event': 3494,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3966900110244751,
#   'pred_cascade': 0.0834962353110313,
#   'pred_tgtrack': 0.211942434310913,
#   'pred_starttrack': 0.0501693710684776,
#   'pred_stoptrack': 0.2577018737792969,
#   'energy': 19278.0238980589,
#   'zenith': 2.721048401598467,
#   'oneweight': 3106321365123.1104,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3966900110244751,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_4292_origidx_21_RF22.mp4': {'event': 4292,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.97712641954422,
#   'pred_cascade': 9.574085561325774e-05,
#   'pred_tgtrack': 0.0146391838788986,
#   'pred_starttrack': 4.698069460573606e-05,
#   'pred_stoptrack': 0.0080917216837406,
#   'energy': 2549.8018365291528,
#   'zenith': 0.850424966387363,
#   'oneweight': 24092103111.60456,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.97712641954422,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_6177_origidx_9_RF22.mp4': {'event': 6177,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.5482681192224845e-05,
#   'pred_cascade': 0.971633791923523,
#   'pred_tgtrack': 4.9931841203942895e-06,
#   'pred_starttrack': 0.0283204596489667,
#   'pred_stoptrack': 2.526033495087177e-05,
#   'energy': 5473.148083648474,
#   'zenith': 0.8196161882337165,
#   'oneweight': 260407697145.43372,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.971633791923523,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_649_origidx_15_RF22.mp4': {'event': 649,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.000183536147233,
#   'pred_cascade': 0.9542484283447266,
#   'pred_tgtrack': 0.0002805941039696,
#   'pred_starttrack': 0.0450042001903057,
#   'pred_stoptrack': 0.0002832688333,
#   'energy': 1061.9693461798192,
#   'zenith': 1.414969194839186,
#   'oneweight': 5986064783.574263,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9542484283447266,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_6775_origidx_7_RF22.mp4': {'event': 6775,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0335836075246334,
#   'pred_cascade': 0.0068819765001535,
#   'pred_tgtrack': 0.9234431385993958,
#   'pred_starttrack': 0.0049639176577329,
#   'pred_stoptrack': 0.0311274081468582,
#   'energy': 6813.432738086691,
#   'zenith': 1.562681086755049,
#   'oneweight': 342116013213.5768,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9234431385993958,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_4712_origidx_25_RF22.mp4': {'event': 4712,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999783039093018,
#   'pred_cascade': 6.638979144213408e-09,
#   'pred_tgtrack': 4.465272922971053e-06,
#   'pred_starttrack': 2.37888087895044e-07,
#   'pred_stoptrack': 1.703883390291594e-05,
#   'energy': 201755.6739012492,
#   'zenith': 1.1065621482976808,
#   'oneweight': 439302538480642.8,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999783039093018,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_770_origidx_18_RF22.mp4': {'event': 770,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999661445617676,
#   'pred_cascade': 8.760366321247658e-10,
#   'pred_tgtrack': 5.385398253565654e-06,
#   'pred_starttrack': 1.3108919505455672e-09,
#   'pred_stoptrack': 2.845419112418313e-05,
#   'energy': 84299.53138059525,
#   'zenith': 1.1736120884251608,
#   'oneweight': 254747045691448.8,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999661445617676,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_654_origidx_16_RF22.mp4': {'event': 654,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1697000414133072,
#   'pred_cascade': 0.0698724910616874,
#   'pred_tgtrack': 0.6568821668624878,
#   'pred_starttrack': 0.0709010511636734,
#   'pred_stoptrack': 0.0326442830264568,
#   'energy': 168.65930511947917,
#   'zenith': 2.245345034390461,
#   'oneweight': 28923450.477443594,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6568821668624878,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_6804_origidx_8_RF22.mp4': {'event': 6804,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9736430048942566,
#   'pred_cascade': 3.585861486499198e-05,
#   'pred_tgtrack': 0.001809062086977,
#   'pred_starttrack': 0.0001163904016721,
#   'pred_stoptrack': 0.0243957694619894,
#   'energy': 98474.01081696808,
#   'zenith': 1.6338010975184134,
#   'oneweight': 77036623821175.83,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9736430048942566,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_3672_origidx_9_RF22.mp4': {'event': 3672,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999879598617554,
#   'pred_cascade': 2.3457225745149298e-12,
#   'pred_tgtrack': 4.303829882701393e-06,
#   'pred_starttrack': 3.6618180709879766e-11,
#   'pred_stoptrack': 7.703096343902871e-06,
#   'energy': 778064.4373109734,
#   'zenith': 1.400333301399734,
#   'oneweight': 4276062834085175.0,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999879598617554,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_4470_origidx_22_RF22.mp4': {'event': 4470,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4182859361171722,
#   'pred_cascade': 0.0594957843422889,
#   'pred_tgtrack': 0.0255675911903381,
#   'pred_starttrack': 0.0759992524981498,
#   'pred_stoptrack': 0.4206514358520508,
#   'energy': 147.2282880560456,
#   'zenith': 1.375278139527949,
#   'oneweight': 19035144.263381545,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4206514358520508,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_8968_origidx_6_RF22.mp4': {'event': 8968,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0024493495002388,
#   'pred_cascade': 0.0003043380565941,
#   'pred_tgtrack': 0.001987459603697,
#   'pred_starttrack': 0.0005238373996689,
#   'pred_stoptrack': 0.9947350025177002,
#   'energy': 147.00105997652824,
#   'zenith': 0.220581860630782,
#   'oneweight': 17679159.475127157,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9947350025177002,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_3684_origidx_10_RF22.mp4': {'event': 3684,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999908208847046,
#   'pred_cascade': 1.4151285698815738e-10,
#   'pred_tgtrack': 2.774072072497802e-06,
#   'pred_starttrack': 1.5704808120631242e-08,
#   'pred_stoptrack': 6.491360181826167e-06,
#   'energy': 393939.0890727788,
#   'zenith': 1.9874555172964576,
#   'oneweight': 2.911184890252841e+16,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999908208847046,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_9143_origidx_13_RF22.mp4': {'event': 9143,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1451606303453445,
#   'pred_cascade': 0.0485580265522003,
#   'pred_tgtrack': 0.4777306318283081,
#   'pred_starttrack': 0.0543932244181633,
#   'pred_stoptrack': 0.2741574645042419,
#   'energy': 351.3739662229919,
#   'zenith': 0.8317655113007231,
#   'oneweight': 189749826.34070417,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4777306318283081,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_3802_origidx_11_RF22.mp4': {'event': 3802,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3050520420074463,
#   'pred_cascade': 0.3406043946743011,
#   'pred_tgtrack': 0.0643106028437614,
#   'pred_starttrack': 0.1966057121753692,
#   'pred_stoptrack': 0.0934272184967994,
#   'energy': 32718.5816835611,
#   'zenith': 2.0482551168544387,
#   'oneweight': 84481989956605.11,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3406043946743011,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_2503_origidx_5_RF22.mp4': {'event': 2503,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9997738003730774,
#   'pred_cascade': 5.069469466434384e-08,
#   'pred_tgtrack': 0.0001184590291813,
#   'pred_starttrack': 9.538296126265775e-07,
#   'pred_stoptrack': 0.0001068056299118,
#   'energy': 274462.52795261284,
#   'zenith': 1.1905658713972724,
#   'oneweight': 2285975368180637.0,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9997738003730774,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_6612_origidx_5_RF22.mp4': {'event': 6612,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.8621557950973511,
#   'pred_cascade': 0.050061859190464,
#   'pred_tgtrack': 0.0071326745674014,
#   'pred_starttrack': 0.0410299561917781,
#   'pred_stoptrack': 0.0396196618676185,
#   'energy': 774.2338902681539,
#   'zenith': 2.395154953552115,
#   'oneweight': 1955759073.355572,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8621557950973511,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_9_origidx_5_RF22.mp4': {'event': 9,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0053116446360945,
#   'pred_cascade': 0.0035257204435765,
#   'pred_tgtrack': 0.854947566986084,
#   'pred_starttrack': 0.0017756100278347,
#   'pred_stoptrack': 0.1344394236803054,
#   'energy': 163.1327678486344,
#   'zenith': 1.178764015755314,
#   'oneweight': 15553379.249915237,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.854947566986084,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_3866_origidx_14_RF22.mp4': {'event': 3866,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9996970891952516,
#   'pred_cascade': 7.071872687447468e-08,
#   'pred_tgtrack': 3.034787550859619e-05,
#   'pred_starttrack': 7.622315933986101e-08,
#   'pred_stoptrack': 0.000272440171102,
#   'energy': 58082.20522420796,
#   'zenith': 0.5934609460769976,
#   'oneweight': 18626223871702.742,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9996970891952516,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_8778_origidx_6_RF22.mp4': {'event': 8778,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 4.993468974134885e-05,
#   'pred_cascade': 0.7046435475349426,
#   'pred_tgtrack': 3.277156065450981e-05,
#   'pred_starttrack': 0.2952197790145874,
#   'pred_stoptrack': 5.398615030571818e-05,
#   'energy': 2826.9121311514355,
#   'zenith': 0.532574259234196,
#   'oneweight': 41163468843.210526,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7046435475349426,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_5790_origidx_6_RF22.mp4': {'event': 5790,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0015813435893505,
#   'pred_cascade': 0.7365571856498718,
#   'pred_tgtrack': 6.542411938426085e-06,
#   'pred_starttrack': 0.2605855166912079,
#   'pred_stoptrack': 0.001269405009225,
#   'energy': 831.2991451521987,
#   'zenith': 1.5329533976484264,
#   'oneweight': 1601770881.1656835,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7365571856498718,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_8718_origidx_5_RF22.mp4': {'event': 8718,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.825038731098175,
#   'pred_cascade': 5.856883944943547e-06,
#   'pred_tgtrack': 0.1568295359611511,
#   'pred_starttrack': 5.550725745706586e-06,
#   'pred_stoptrack': 0.0181202124804258,
#   'energy': 197136.3722553943,
#   'zenith': 2.0323643623056924,
#   'oneweight': 28777568614238.67,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.825038731098175,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_7840_origidx_8_RF22.mp4': {'event': 7840,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1676190346479416,
#   'pred_cascade': 0.0509768463671207,
#   'pred_tgtrack': 0.6633639931678772,
#   'pred_starttrack': 0.0664425939321518,
#   'pred_stoptrack': 0.0515974722802639,
#   'energy': 4008.1210045862986,
#   'zenith': 0.2115350441256118,
#   'oneweight': 70580834410.22469,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6633639931678772,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_3984_origidx_17_RF22.mp4': {'event': 3984,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0375050380825996,
#   'pred_cascade': 0.7821938991546631,
#   'pred_tgtrack': 9.067550854524598e-05,
#   'pred_starttrack': 0.16667141020298,
#   'pred_stoptrack': 0.0135390795767307,
#   'energy': 249.13909516686368,
#   'zenith': 1.4584290554192536,
#   'oneweight': 80958664.23405616,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.7821938991546631,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_2588_origidx_6_RF22.mp4': {'event': 2588,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.990068256855011,
#   'pred_cascade': 9.256709017790854e-05,
#   'pred_tgtrack': 0.0002318775659659,
#   'pred_starttrack': 7.466160604963079e-05,
#   'pred_stoptrack': 0.0095326136797666,
#   'energy': 36554.87370866387,
#   'zenith': 2.304346613554375,
#   'oneweight': 17150066903644.035,
#   '#truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.990068256855011,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000224/compressed_run_22067_event_2704_origidx_9_RF22.mp4': {'event': 2704,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0002134492533514,
#   'pred_cascade': 0.8685770630836487,
#   'pred_tgtrack': 4.644059117708821e-06,
#   'pred_starttrack': 0.131193071603775,
#   'pred_stoptrack': 1.1842271305795292e-05,
#   'energy': 18826.623011217223,
#   'zenith': 1.6257839556286473,
#   'oneweight': 2174925236803.948,
#   '#truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8685770630836487,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 15}}

# %%
make_subject_set('nue_run_22067_subrun_000224_phase2')
# Out:
# Subject Set Name: nue_run_22067_subrun_000224_phase2
# Subject Set ID: 112492
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112473>, <SubjectSet 112487>, <SubjectSet 112467>, <SubjectSet 112481>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>, <SubjectSet 112464>]

# %%
uploader(compressed_path,nue_csv,112492)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:469: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   dict_manifest = s3.to_dict('dict')
# Confirm if subject set 112492 is listed below.
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112473>, <SubjectSet 112487>, <SubjectSet 112467>, <SubjectSet 112481>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>, <SubjectSet 112464>]
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112414>, <SubjectSet 112418>, <SubjectSet 112473>, <SubjectSet 112487>, <SubjectSet 112467>, <SubjectSet 112481>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>, <SubjectSet 112425>, <SubjectSet 112433>, <SubjectSet 112464>]
# Number of times loop has ran: 1
# Number of times loop has ran: 2
# Number of times loop has ran: 3
# Number of times loop has ran: 4
# Number of times loop has ran: 5
# Number of times loop has ran: 6
# Number of times loop has ran: 7
# Number of times loop has ran: 8
# Number of times loop has ran: 9
# Number of times loop has ran: 10
# Number of times loop has ran: 11
# Number of times loop has ran: 12
# Number of times loop has ran: 13
# Number of times loop has ran: 14
# Number of times loop has ran: 15
# Number of times loop has ran: 16
# Number of times loop has ran: 17
# Number of times loop has ran: 18
# Number of times loop has ran: 19
# Number of times loop has ran: 20
# Number of times loop has ran: 21
# Number of times loop has ran: 22
# Number of times loop has ran: 23
# Number of times loop has ran: 24
# Number of times loop has ran: 25
# Number of times loop has ran: 26
# Number of times loop has ran: 27
# Number of times loop has ran: 28
# Number of times loop has ran: 29
# Number of times loop has ran: 30
# Number of times loop has ran: 31
# Number of times loop has ran: 32
# Number of times loop has ran: 33
# Number of times loop has ran: 34
# Number of times loop has ran: 35
# Number of times loop has ran: 36
# Number of times loop has ran: 37
# Number of times loop has ran: 38
# Number of times loop has ran: 39
# Number of times loop has ran: 40
# Number of times loop has ran: 41
# Number of times loop has ran: 42
# Number of times loop has ran: 43
# Number of times loop has ran: 44
# Number of times loop has ran: 45
# Number of times loop has ran: 46
# Number of times loop has ran: 47
# Number of times loop has ran: 48
# Number of times loop has ran: 49
# Number of times loop has ran: 50
# Number of times loop has ran: 51
# Number of times loop has ran: 52
# Number of times loop has ran: 53
# Number of times loop has ran: 54
# Number of times loop has ran: 55
# Number of times loop has ran: 56
# Number of times loop has ran: 57
# Number of times loop has ran: 58
# Number of times loop has ran: 59
# Number of times loop has ran: 60
# Number of times loop has ran: 61
# Number of times loop has ran: 62
# Number of times loop has ran: 63
# Number of times loop has ran: 64
# Number of times loop has ran: 65
# Number of times loop has ran: 66
# Number of times loop has ran: 67
# Number of times loop has ran: 68
# Number of times loop has ran: 69
# Number of times loop has ran: 70
# Number of times loop has ran: 71
# Number of times loop has ran: 72
# Number of times loop has ran: 73
# Number of times loop has ran: 74
# Number of times loop has ran: 75
# Number of times loop has ran: 76
# Number of times loop has ran: 77
# Number of times loop has ran: 78
# Number of times loop has ran: 79
# Number of times loop has ran: 80
# Number of times loop has ran: 81
# Number of times loop has ran: 82
# Number of times loop has ran: 83
# Number of times loop has ran: 84
# Number of times loop has ran: 85
# Number of times loop has ran: 86
# Number of times loop has ran: 87
# Number of times loop has ran: 88
# Number of times loop has ran: 89
# Number of times loop has ran: 90
# Number of times loop has ran: 91
# Number of times loop has ran: 92
