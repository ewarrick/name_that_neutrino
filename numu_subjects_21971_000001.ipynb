# %% [markdown]
# # Phase 2: Subject Creation
#
# **Description:**
#
# This notebook is to act as the resulting summary file for the creation and upload of subjects for the IceCube Zooniverse project currently called *Name that Neutrino!*. The project is currently being maintained by Elizabeth Warrick (as of March 2023). In this notebook, we take the i3 file and run it through several filters. [note: describe more later].
#
# > Nu Type: NuMu
#
# > Run: 21971
#
# > SubRun: 000001
#
# ### Summary Stats:
#
# To be filled in after completing process. Also need to figure out global variables.
#
# **Subject Set Name:**

# %%
#Imports

#My functions: 
from uniformenergydist_filter import *

#General:
import numpy as np
import sys
import os
import subprocess
import argparse
import csv
from tables import *
import pandas as pd
from matplotlib import pyplot as plt
import h5py

#Zooniverse:
from panoptes_client import Panoptes, Project, SubjectSet, Subject
import magic
import glob

#IceCube:
from icecube.icetray import I3Units
import icecube.MuonGun
from icecube import dataio, dataclasses, icetray, MuonGun
from I3Tray import *
from icecube.hdfwriter import I3HDFWriter
from mc_labeler import MCLabeler #make sure that mc_labeler script is in current directory.

# %%
#Specify file paths:

#Initial I3 File:
numu = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst'

#Desired output directory. Note that creation of this directory is not yet coded and is done manually. 
phase1_dir = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/'

# %%
#Run Filter 1 to label MC truth.
filter1(numu,phase1_dir)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/mc_labeler.py:523: UserWarning: Couldn't find OMKey in MCPESeriesMap
#   warnings.warn("Couldn't find OMKey in MCPESeriesMap")

# %% [markdown]
# Note that the above cell might return an "exception" warning that the *MCPESeriesMap could not be found*. I am unsure why it does that because when I check the i3 file in dataio-shovel, I see the specified mc_pid_series_map (look at mc_labeler.py for exact name of specified key). The resulting file size should be around 400 MB.

# %%
#Path of hdf from above filter.
numu_hdf = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/\
Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst.hd5'

# %%
#Run uniformenergy_events function which requires hdf from filter 1, 
#number of bins, size of each random choice, and a random seed. 

uniformenergy_events(numu_hdf,25,15,12,subrun = True)
# Out:
# Number of Bins: 25
# Number of Events per Bin: 15
# Total Number of Events: 375
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['binned_log10E'] = pd.cut(x = np.log10(df_filtered['energy']), bins = bins, labels = labels, include_lowest = True) #might throw an error?
# Initial Number of Events: 8699
# Number of Events after filtering: 8068
# Please input subrun number:
# 000001

# %% [markdown]
# The above function throws another warning about pd.cut, currently that is not a problem but I don't know if a new version of pandas will allow this.

# %%
#Path to Random Events CSV
numu_csv = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/random_events_uniform_energy_distrib_21971_000001.csv'

# %%
#Run event_characterization_plots function whick makes some quick 
#plots to get an idea of what data you're dealing with.
#Note that I want to update the plot types, maybe make a 2D histogram as Mike K suggested. 
#For truth labels, check out enums.py or in the .py file that holds the functions.

event_characterization_plots(numu_csv)

# %% [markdown]
# Now that we have the events for this phase chosen, we run the second filter to pick out only those events.

# %%
#Path to i3 file from filter1 with MC truth labels. 
numu_filter1 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst'

# %%
#Run function to perform second filter which passes through only selected event IDs chosen from 
#the uniformenergy_events function. 
filter2(numu_filter1,phase1_dir,numu_csv)

# %%
#Path to i3 file from filter 2 that holds only specified events. 
numu_filter2 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst'

# %%
#Run function to perform third filter, which returns only the DAQ frames of the specified events.
#DAQ only file is then split up into many smaller i3 files since SteamShovel can't handle making videos of large
#i3 files at one time. Size limit is approx 2E6 MB (? unsure of units)
filter3(numu_filter2,21971_000001,phase1_dir)

# %%
#Path to NuMu Daq Only folder
numu_daq = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000001/'

# %%
get_steamshovel(numu_daq,21971000001)
# Out:
# List of files:
# ['/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000001/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000001/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000001/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000001/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000001/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000001/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000001/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000001/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000001/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000001/daq_only-0009_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst']
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000001/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000001/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000001/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000001/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000001/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000001/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000001/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000001/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000001/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_21971000001/daq_only-0009_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuMu.021971.000001.i3.zst

# %% [markdown]
# Ideas for Compression:
# - Use GUI to add files to queue and send to one compression folder.
# - Add a subprocess line in movie script to compress the video after making it and direct it to save in the compression folder.

# %%
compressed_path = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/'

# %% [markdown]
# Can't get manifest yet since some subjects are missing and lining it up won't work.

# %%
get_manifest(compressed_path, numu_csv)
# Out:
# {'/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_29549_origidx_6_RF22.mp4': {'event': 29549,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.3493600785732269,
#   'pred_cascade': 0.15666264295578,
#   'pred_tgtrack': 0.168604165315628,
#   'pred_starttrack': 0.1307197362184524,
#   'pred_stoptrack': 0.1946533322334289,
#   'energy': 15125.301709323248,
#   'zenith': 0.573439743738038,
#   'oneweight': 2506798549548.6226,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.3493600785732269,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_26278_origidx_27_RF22.mp4': {'event': 26278,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0003606725949794,
#   'pred_cascade': 3.21611478284467e-05,
#   'pred_tgtrack': 0.9951640367507936,
#   'pred_starttrack': 0.0043610683642327,
#   'pred_stoptrack': 8.214398985728621e-05,
#   'energy': 162280.3534108483,
#   'zenith': 1.2944234420745977,
#   'oneweight': 1392889265628597.5,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9951640367507936,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_11707_origidx_15_RF22.mp4': {'event': 11707,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.999984860420227,
#   'pred_cascade': 1.2751832575985668e-11,
#   'pred_tgtrack': 4.251249720255146e-06,
#   'pred_starttrack': 1.6986934525675682e-08,
#   'pred_stoptrack': 1.0850461876543704e-05,
#   'energy': 373033.9200369464,
#   'zenith': 0.5281406327868544,
#   'oneweight': 2519933326019658.0,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.999984860420227,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_25794_origidx_20_RF22.mp4': {'event': 25794,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.9958707690238952,
#   'pred_cascade': 6.0503731219796464e-05,
#   'pred_tgtrack': 0.001624547294341,
#   'pred_starttrack': 0.0001270699867745,
#   'pred_stoptrack': 0.0023169696796685,
#   'energy': 95262.0327974064,
#   'zenith': 0.8416383684183559,
#   'oneweight': 174375334735884.56,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9958707690238952,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_343_origidx_8_RF22.mp4': {'event': 343,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.9981836676597596,
#   'pred_cascade': 1.0832488442247268e-05,
#   'pred_tgtrack': 0.0016644113929942,
#   'pred_starttrack': 1.0636725164658856e-05,
#   'pred_stoptrack': 0.000130461732624,
#   'energy': 162136.58849586474,
#   'zenith': 0.6038456454418181,
#   'oneweight': 476386059668147.8,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9981836676597596,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_19242_origidx_10_RF22.mp4': {'event': 19242,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.1770850867033004,
#   'pred_cascade': 0.0593390613794326,
#   'pred_tgtrack': 0.6611194610595703,
#   'pred_starttrack': 0.0521351657807827,
#   'pred_stoptrack': 0.0503212660551071,
#   'energy': 128.76236885662746,
#   'zenith': 2.130087452746844,
#   'oneweight': 24224246.12927754,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6611194610595703,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_17616_origidx_15_RF22.mp4': {'event': 17616,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0001614688371773,
#   'pred_cascade': 0.0001828647218644,
#   'pred_tgtrack': 0.9919671416282654,
#   'pred_starttrack': 0.0063857813365757,
#   'pred_stoptrack': 0.0013026850065216,
#   'energy': 961024.1100036468,
#   'zenith': 0.6143460582089991,
#   'oneweight': 1.3387236518505028e+16,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9919671416282654,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_17427_origidx_12_RF22.mp4': {'event': 17427,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.3526490330696106,
#   'pred_cascade': 0.1026129275560379,
#   'pred_tgtrack': 0.2764220833778381,
#   'pred_starttrack': 0.11773032695055,
#   'pred_stoptrack': 0.1505856215953827,
#   'energy': 699941.4924463051,
#   'zenith': 0.3679626085705852,
#   'oneweight': 8229973947929091.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3526490330696106,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_32264_origidx_9_RF22.mp4': {'event': 32264,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.2480726093053817,
#   'pred_cascade': 0.0680397599935531,
#   'pred_tgtrack': 0.5379673838615417,
#   'pred_starttrack': 0.0830839425325393,
#   'pred_stoptrack': 0.0628363192081451,
#   'energy': 396.1880717115115,
#   'zenith': 1.5269479815191782,
#   'oneweight': 280820094.6267974,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5379673838615417,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_16112_origidx_16_RF22.mp4': {'event': 16112,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.6425482630729675,
#   'pred_cascade': 2.8308202672633342e-05,
#   'pred_tgtrack': 0.2916783392429352,
#   'pred_starttrack': 1.2860120477853345e-05,
#   'pred_stoptrack': 0.0657321736216545,
#   'energy': 1709.868034402976,
#   'zenith': 1.5566137680325816,
#   'oneweight': 36289209074.957146,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.6425482630729675,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_19176_origidx_9_RF22.mp4': {'event': 19176,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.8751877546310425,
#   'pred_cascade': 6.598747404495953e-06,
#   'pred_tgtrack': 0.1245079785585403,
#   'pred_starttrack': 7.691654900554568e-05,
#   'pred_stoptrack': 0.0002207931538578,
#   'energy': 16697.659077748598,
#   'zenith': 1.5832369929498284,
#   'oneweight': 16930421425110.33,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.8751877546310425,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_16566_origidx_4_RF22.mp4': {'event': 16566,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.1261777877807617,
#   'pred_cascade': 0.0545319132506847,
#   'pred_tgtrack': 0.7366784811019897,
#   'pred_starttrack': 0.0601334832608699,
#   'pred_stoptrack': 0.0224782954901456,
#   'energy': 13941.127740164844,
#   'zenith': 1.03303196435037,
#   'oneweight': 3219644030906.864,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.7366784811019897,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_16218_origidx_17_RF22.mp4': {'event': 16218,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 2.3348830424652082e-08,
#   'pred_cascade': 0.0007278930279426,
#   'pred_tgtrack': 1.4462915487456485e-06,
#   'pred_starttrack': 0.9992703795433044,
#   'pred_stoptrack': 1.813641716807979e-07,
#   'energy': 10253.9137633049,
#   'zenith': 1.398300093175453,
#   'oneweight': 5243623657663.07,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.9992703795433044,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_11370_origidx_12_RF22.mp4': {'event': 11370,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.0306495428085327,
#   'pred_cascade': 0.008239772170782,
#   'pred_tgtrack': 0.2426691800355911,
#   'pred_starttrack': 0.0057579549029469,
#   'pred_stoptrack': 0.7126836180686951,
#   'energy': 369628.2293118096,
#   'zenith': 1.927726087602474,
#   'oneweight': 2.3362916572746964e+16,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.7126836180686951,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_10312_origidx_6_RF22.mp4': {'event': 10312,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.3337063193321228,
#   'pred_cascade': 0.0106021575629711,
#   'pred_tgtrack': 0.3166545629501343,
#   'pred_starttrack': 0.107179969549179,
#   'pred_stoptrack': 0.2318569421768188,
#   'energy': 451.33802390061015,
#   'zenith': 2.784412226489065,
#   'oneweight': 875695212.0728545,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.3337063193321228,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_12668_origidx_23_RF22.mp4': {'event': 12668,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 4.896641257801093e-06,
#   'pred_cascade': 6.718523071214122e-09,
#   'pred_tgtrack': 0.9984391331672668,
#   'pred_starttrack': 0.0003427213523536,
#   'pred_stoptrack': 0.0012133551063016,
#   'energy': 760607.0296594574,
#   'zenith': 2.518821730436289,
#   'oneweight': 3.206383125612472e+16,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9984391331672668,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_12861_origidx_25_RF22.mp4': {'event': 12861,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.3946803212165832,
#   'pred_cascade': 0.130624771118164,
#   'pred_tgtrack': 0.2156222462654113,
#   'pred_starttrack': 0.1323971599340438,
#   'pred_stoptrack': 0.1266755312681198,
#   'energy': 148.30650593253878,
#   'zenith': 0.6972281168413829,
#   'oneweight': 38644340.476976216,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3946803212165832,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_25610_origidx_17_RF22.mp4': {'event': 25610,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 1.1009791705873797e-05,
#   'pred_cascade': 1.6719232007744722e-06,
#   'pred_tgtrack': 0.6358045339584351,
#   'pred_starttrack': 0.0305797830224037,
#   'pred_stoptrack': 0.333603024482727,
#   'energy': 798.9814773862483,
#   'zenith': 2.254343297062368,
#   'oneweight': 3160172637.5788875,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.6358045339584351,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_18915_origidx_4_RF22.mp4': {'event': 18915,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.3458354473114013,
#   'pred_cascade': 0.0641364380717277,
#   'pred_tgtrack': 0.0190047621726989,
#   'pred_starttrack': 0.2804068624973297,
#   'pred_stoptrack': 0.2906164228916168,
#   'energy': 77380.82242930595,
#   'zenith': 0.4805490920582896,
#   'oneweight': 67990287644989.46,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.3458354473114013,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_26226_origidx_25_RF22.mp4': {'event': 26226,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.9998420476913452,
#   'pred_cascade': 3.3383933395469967e-09,
#   'pred_tgtrack': 0.0001374448474962,
#   'pred_starttrack': 8.515709737366707e-08,
#   'pred_stoptrack': 2.0360886992421e-05,
#   'energy': 583396.2653669844,
#   'zenith': 1.0519470288895991,
#   'oneweight': 1.165929451102147e+16,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9998420476913452,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_32256_origidx_8_RF22.mp4': {'event': 32256,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 1.6315068762651208e-07,
#   'pred_cascade': 1.1425719748103803e-07,
#   'pred_tgtrack': 0.977110743522644,
#   'pred_starttrack': 0.0157091412693262,
#   'pred_stoptrack': 0.0071798977442085,
#   'energy': 76499.92623094517,
#   'zenith': 1.9107146978961111,
#   'oneweight': 650962011018920.9,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.977110743522644,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_17693_origidx_17_RF22.mp4': {'event': 17693,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 5.462322587845847e-05,
#   'pred_cascade': 3.1973963814380117e-06,
#   'pred_tgtrack': 0.7720621824264526,
#   'pred_starttrack': 0.050651267170906,
#   'pred_stoptrack': 0.1772287189960479,
#   'energy': 1208.0997369871577,
#   'zenith': 2.410636753138508,
#   'oneweight': 17602717106.233845,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.7720621824264526,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_25393_origidx_11_RF22.mp4': {'event': 25393,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.1915876567363739,
#   'pred_cascade': 0.0158055014908313,
#   'pred_tgtrack': 0.0192413926124572,
#   'pred_starttrack': 0.0457851663231849,
#   'pred_stoptrack': 0.7275803089141846,
#   'energy': 1746.7059372609283,
#   'zenith': 0.075449625639159,
#   'oneweight': 13239793519.671736,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7275803089141846,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_17636_origidx_16_RF22.mp4': {'event': 17636,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 2.095517993438989e-05,
#   'pred_cascade': 0.0001320802111877,
#   'pred_tgtrack': 0.3179114162921905,
#   'pred_starttrack': 0.6755886673927307,
#   'pred_stoptrack': 0.0063468860462307,
#   'energy': 5969.878366142826,
#   'zenith': 1.697053946179244,
#   'oneweight': 844681499100.239,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.6755886673927307,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_14079_origidx_36_RF22.mp4': {'event': 14079,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.0110552525147795,
#   'pred_cascade': 0.0016502308426424,
#   'pred_tgtrack': 0.7228615880012512,
#   'pred_starttrack': 0.0026193060912191,
#   'pred_stoptrack': 0.26181361079216,
#   'energy': 150.62621531278583,
#   'zenith': 2.7500715475737096,
#   'oneweight': 14114168.744808692,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.7228615880012512,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_32378_origidx_10_RF22.mp4': {'event': 32378,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.0276964101940393,
#   'pred_cascade': 0.0123140970245003,
#   'pred_tgtrack': 0.8882023096084595,
#   'pred_starttrack': 0.0259267650544643,
#   'pred_stoptrack': 0.0458604730665683,
#   'energy': 421.701092827389,
#   'zenith': 2.2022611362502715,
#   'oneweight': 337682450.3209812,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.8882023096084595,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_29606_origidx_8_RF22.mp4': {'event': 29606,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.3500849604606628,
#   'pred_cascade': 0.0763989612460136,
#   'pred_tgtrack': 0.4281138181686401,
#   'pred_starttrack': 0.099220372736454,
#   'pred_stoptrack': 0.046181920915842,
#   'energy': 968922.452581402,
#   'zenith': 0.594473076929529,
#   'oneweight': 1.873149331303012e+16,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4281138181686401,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_16552_origidx_22_RF22.mp4': {'event': 16552,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 5.0043247028952464e-05,
#   'pred_cascade': 2.8113861844758503e-05,
#   'pred_tgtrack': 0.929198682308197,
#   'pred_starttrack': 0.0035675661638379,
#   'pred_stoptrack': 0.0671555325388908,
#   'energy': 1959.0879956985536,
#   'zenith': 1.663835168278465,
#   'oneweight': 34870948995.62657,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.929198682308197,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_15935_origidx_14_RF22.mp4': {'event': 15935,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.8615214824676514,
#   'pred_cascade': 9.02283936738968e-05,
#   'pred_tgtrack': 0.1379497945308685,
#   'pred_starttrack': 0.0001083106399164,
#   'pred_stoptrack': 0.0003301956749055,
#   'energy': 107752.6361793697,
#   'zenith': 1.360797045349019,
#   'oneweight': 465173432681594.0,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.8615214824676514,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_15683_origidx_10_RF22.mp4': {'event': 15683,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 4.731333547169925e-07,
#   'pred_cascade': 0.0054098861292004,
#   'pred_tgtrack': 7.78003377490677e-05,
#   'pred_starttrack': 0.994510531425476,
#   'pred_stoptrack': 1.2907790960525745e-06,
#   'energy': 987464.43297998,
#   'zenith': 0.1700112423310013,
#   'oneweight': 1.3297379582178068e+16,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.994510531425476,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_13539_origidx_30_RF22.mp4': {'event': 13539,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.1802762597799301,
#   'pred_cascade': 0.1197009608149528,
#   'pred_tgtrack': 0.4521363973617553,
#   'pred_starttrack': 0.1453159749507904,
#   'pred_stoptrack': 0.1025704145431518,
#   'energy': 146844.70654666369,
#   'zenith': 2.6449564657351647,
#   'oneweight': 26945155418576.48,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.4521363973617553,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_12058_origidx_18_RF22.mp4': {'event': 12058,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.9997292160987854,
#   'pred_cascade': 1.2387094128207818e-10,
#   'pred_tgtrack': 0.0002639759331941,
#   'pred_starttrack': 8.224863456973708e-09,
#   'pred_stoptrack': 6.758092695235973e-06,
#   'energy': 665422.5199325329,
#   'zenith': 1.9001551144250728,
#   'oneweight': 2.2234105339193576e+16,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9997292160987854,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_16748_origidx_8_RF22.mp4': {'event': 16748,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0001053260348271,
#   'pred_cascade': 1.5036042896099389e-05,
#   'pred_tgtrack': 0.8951010704040527,
#   'pred_starttrack': 0.0007596015348099,
#   'pred_stoptrack': 0.1040189042687416,
#   'energy': 8876.080521524904,
#   'zenith': 1.7922737870064742,
#   'oneweight': 3943259701994.429,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.8951010704040527,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_26104_origidx_22_RF22.mp4': {'event': 26104,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 5.707575110136531e-05,
#   'pred_cascade': 6.496965852420544e-06,
#   'pred_tgtrack': 0.9839870929718018,
#   'pred_starttrack': 0.0038563890848308,
#   'pred_stoptrack': 0.0120929330587387,
#   'energy': 184109.50459161072,
#   'zenith': 1.4946541903187656,
#   'oneweight': 2992759028817650.5,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9839870929718018,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_26922_origidx_7_RF22.mp4': {'event': 26922,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0002526453754398,
#   'pred_cascade': 3.2930984161794186e-05,
#   'pred_tgtrack': 0.9954648613929749,
#   'pred_starttrack': 0.0040345690213143,
#   'pred_stoptrack': 0.0002149492356693,
#   'energy': 52371.23325187788,
#   'zenith': 1.2812526090744512,
#   'oneweight': 87530333797779.78,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9954648613929749,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_29674_origidx_9_RF22.mp4': {'event': 29674,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.1218356415629386,
#   'pred_cascade': 0.0324381031095981,
#   'pred_tgtrack': 0.7410749197006226,
#   'pred_starttrack': 0.012260022573173,
#   'pred_stoptrack': 0.0923912599682807,
#   'energy': 72022.62413803066,
#   'zenith': 0.8810680073550986,
#   'oneweight': 112737407216311.08,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7410749197006226,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_19399_origidx_11_RF22.mp4': {'event': 19399,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.099167488515377,
#   'pred_cascade': 0.0124431299045681,
#   'pred_tgtrack': 0.8141561150550842,
#   'pred_starttrack': 0.0571018829941749,
#   'pred_stoptrack': 0.017131382599473,
#   'energy': 441.4852164464987,
#   'zenith': 2.7871128182055216,
#   'oneweight': 667919500.0940019,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.8141561150550842,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_1030_origidx_15_RF22.mp4': {'event': 1030,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 2.8587101041921414e-07,
#   'pred_cascade': 1.7927539374795742e-05,
#   'pred_tgtrack': 1.581517244630959e-05,
#   'pred_starttrack': 0.9999656677246094,
#   'pred_stoptrack': 1.9359295322374242e-07,
#   'energy': 20041.977178736062,
#   'zenith': 0.7995281182170942,
#   'oneweight': 7126123332347.502,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.9999656677246094,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_16008_origidx_15_RF22.mp4': {'event': 16008,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 8.203574907383882e-06,
#   'pred_cascade': 3.583707075449638e-05,
#   'pred_tgtrack': 0.9975222945213318,
#   'pred_starttrack': 0.0016955055762082,
#   'pred_stoptrack': 0.0007382530602626,
#   'energy': 615310.3264915425,
#   'zenith': 0.7070570979561568,
#   'oneweight': 6783674500846128.0,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9975222945213318,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_29571_origidx_7_RF22.mp4': {'event': 29571,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0658207088708877,
#   'pred_cascade': 0.0014794640010222,
#   'pred_tgtrack': 0.921155035495758,
#   'pred_starttrack': 0.0080369086936116,
#   'pred_stoptrack': 0.003507895860821,
#   'energy': 5782.085254451074,
#   'zenith': 0.6023222384662033,
#   'oneweight': 389937938227.1221,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.921155035495758,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_15402_origidx_4_RF22.mp4': {'event': 15402,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 2.5471534172538668e-05,
#   'pred_cascade': 0.0016541798831894,
#   'pred_tgtrack': 4.278517008060589e-05,
#   'pred_starttrack': 0.9982500672340392,
#   'pred_stoptrack': 2.7375614081393e-05,
#   'energy': 5237.404000651124,
#   'zenith': 0.7726798921484477,
#   'oneweight': 369527253045.9788,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.9982500672340392,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_31871_origidx_4_RF22.mp4': {'event': 31871,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.2152205407619476,
#   'pred_cascade': 0.0002247708471259,
#   'pred_tgtrack': 0.7516670227050781,
#   'pred_starttrack': 0.0205519013106822,
#   'pred_stoptrack': 0.0123357400298118,
#   'energy': 2857.2964556307074,
#   'zenith': 1.6072392718946076,
#   'oneweight': 161245590433.2141,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.7516670227050781,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_18923_origidx_5_RF22.mp4': {'event': 18923,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0093101439997553,
#   'pred_cascade': 0.0039124344475567,
#   'pred_tgtrack': 0.8218371868133545,
#   'pred_starttrack': 0.0221004374325275,
#   'pred_stoptrack': 0.1428398042917251,
#   'energy': 45030.23697669654,
#   'zenith': 1.3428687114154063,
#   'oneweight': 101919295920007.12,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.8218371868133545,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_1095_origidx_17_RF22.mp4': {'event': 1095,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.1871243268251419,
#   'pred_cascade': 0.0749327465891838,
#   'pred_tgtrack': 0.6187720894813538,
#   'pred_starttrack': 0.0801260471343994,
#   'pred_stoptrack': 0.0390447005629539,
#   'energy': 6720.56116459929,
#   'zenith': 1.0215067645512714,
#   'oneweight': 723548272207.8093,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.6187720894813538,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_17006_origidx_11_RF22.mp4': {'event': 17006,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.9189714789390564,
#   'pred_cascade': 0.0379859954118728,
#   'pred_tgtrack': 0.0009735056664794,
#   'pred_starttrack': 0.0111902561038732,
#   'pred_stoptrack': 0.0308787003159523,
#   'energy': 1750.041798892449,
#   'zenith': 2.3098361138070875,
#   'oneweight': 31332563728.529537,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9189714789390564,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_17535_origidx_13_RF22.mp4': {'event': 17535,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.0109298946335911,
#   'pred_cascade': 0.0022403032053261,
#   'pred_tgtrack': 0.5931023955345154,
#   'pred_starttrack': 0.0042320913635194,
#   'pred_stoptrack': 0.3894952833652496,
#   'energy': 485.85243807113415,
#   'zenith': 2.113126811845419,
#   'oneweight': 990128228.8766316,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5931023955345154,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_16707_origidx_7_RF22.mp4': {'event': 16707,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.994923174381256,
#   'pred_cascade': 2.206126191595104e-05,
#   'pred_tgtrack': 0.0028342180885374,
#   'pred_starttrack': 0.0001945625408552,
#   'pred_stoptrack': 0.002025936730206,
#   'energy': 285775.4574353936,
#   'zenith': 1.516483759830772,
#   'oneweight': 1.1929709398779464e+16,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.994923174381256,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_12188_origidx_19_RF22.mp4': {'event': 12188,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 2.118254940342013e-07,
#   'pred_cascade': 9.316575955153895e-08,
#   'pred_tgtrack': 0.9998809099197388,
#   'pred_starttrack': 9.48687084019184e-05,
#   'pred_stoptrack': 2.386058258707635e-05,
#   'energy': 325630.4249468128,
#   'zenith': 1.5553463470104256,
#   'oneweight': 1.521697373253655e+16,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9998809099197388,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_25538_origidx_15_RF22.mp4': {'event': 25538,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 1.0377908665759605e-07,
#   'pred_cascade': 3.2652598747517914e-05,
#   'pred_tgtrack': 1.629675693948229e-06,
#   'pred_starttrack': 0.9999655485153198,
#   'pred_stoptrack': 3.4915530022772145e-08,
#   'energy': 12337.23612445964,
#   'zenith': 1.081808313100746,
#   'oneweight': 2468312916394.656,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.9999655485153198,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_15799_origidx_12_RF22.mp4': {'event': 15799,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 2.009701529459562e-05,
#   'pred_cascade': 1.2476192523536156e-08,
#   'pred_tgtrack': 0.9863254427909852,
#   'pred_starttrack': 4.061437266500434e-06,
#   'pred_stoptrack': 0.0136503921821713,
#   'energy': 2408.2195181051934,
#   'zenith': 2.0127360928808447,
#   'oneweight': 74894234119.73746,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9863254427909852,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_4926_origidx_4_RF22.mp4': {'event': 4926,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.2033832818269729,
#   'pred_cascade': 0.0002892230113502,
#   'pred_tgtrack': 0.7928071022033691,
#   'pred_starttrack': 0.0005463463021442,
#   'pred_stoptrack': 0.0029739937745034,
#   'energy': 1955.323007234254,
#   'zenith': 1.0105690022467575,
#   'oneweight': 14602157729.692078,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7928071022033691,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_13849_origidx_33_RF22.mp4': {'event': 13849,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0263899136334657,
#   'pred_cascade': 0.016276640817523,
#   'pred_tgtrack': 0.3290546238422394,
#   'pred_starttrack': 0.173019677400589,
#   'pred_stoptrack': 0.4552591145038605,
#   'energy': 4230.868337265939,
#   'zenith': 0.8829100867606912,
#   'oneweight': 160599198899.3659,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.4552591145038605,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_25454_origidx_12_RF22.mp4': {'event': 25454,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0022877026349306,
#   'pred_cascade': 0.0006351264892145,
#   'pred_tgtrack': 0.4805091619491577,
#   'pred_starttrack': 0.4564237892627716,
#   'pred_stoptrack': 0.0601441748440265,
#   'energy': 2902.074192205053,
#   'zenith': 1.571351499851676,
#   'oneweight': 163568406754.86868,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.4805091619491577,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_15567_origidx_7_RF22.mp4': {'event': 15567,
#   'run': 21971,
#   'truth_classification': 7,
#   'pred_skim': 0.1529907435178756,
#   'pred_cascade': 0.7847011685371399,
#   'pred_tgtrack': 0.0001011465647025,
#   'pred_starttrack': 0.0616015009582042,
#   'pred_stoptrack': 0.0006054561818018,
#   'energy': 391245.3525725884,
#   'zenith': 0.274459797232244,
#   'oneweight': 2164936886407281.5,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.7847011685371399,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_26707_origidx_6_RF22.mp4': {'event': 26707,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 1.693508527855769e-10,
#   'pred_cascade': 9.351345475749896e-09,
#   'pred_tgtrack': 2.876740268220601e-07,
#   'pred_starttrack': 0.9999997615814208,
#   'pred_stoptrack': 1.6619985943044924e-10,
#   'energy': 176166.99681147776,
#   'zenith': 0.9541979056818258,
#   'oneweight': 847468455721501.0,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.9999997615814208,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_26200_origidx_24_RF22.mp4': {'event': 26200,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 5.9338020719224e-07,
#   'pred_cascade': 0.0005624103941954,
#   'pred_tgtrack': 6.522463536384748e-06,
#   'pred_starttrack': 0.9993941783905028,
#   'pred_stoptrack': 3.622998337959871e-05,
#   'energy': 3155.176577302194,
#   'zenith': 1.286943145246393,
#   'oneweight': 192584896628.99103,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.9993941783905028,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_15427_origidx_6_RF22.mp4': {'event': 15427,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 7.796713180141523e-05,
#   'pred_cascade': 2.502498682588339e-05,
#   'pred_tgtrack': 0.8227435946464539,
#   'pred_starttrack': 0.0062197530642151,
#   'pred_stoptrack': 0.1709336787462234,
#   'energy': 3984.969052492253,
#   'zenith': 2.1102611812115595,
#   'oneweight': 57185639045.39404,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.8227435946464539,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_18944_origidx_6_RF22.mp4': {'event': 18944,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.9985878467559814,
#   'pred_cascade': 0.0001537272764835,
#   'pred_tgtrack': 0.0001221489947056,
#   'pred_starttrack': 0.0002012327895499,
#   'pred_stoptrack': 0.0009350717882625,
#   'energy': 115140.0558596162,
#   'zenith': 1.5552677013547325,
#   'oneweight': 1671593506552283.8,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.9985878467559814,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_30558_origidx_16_RF22.mp4': {'event': 30558,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 1.5356633742413806e-09,
#   'pred_cascade': 4.13138880744901e-12,
#   'pred_tgtrack': 0.991076111793518,
#   'pred_starttrack': 0.0089225647971034,
#   'pred_stoptrack': 1.2445918855519269e-06,
#   'energy': 83083.6165443535,
#   'zenith': 2.338818837032037,
#   'oneweight': 92946452512642.84,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.991076111793518,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_25524_origidx_14_RF22.mp4': {'event': 25524,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.999772608280182,
#   'pred_cascade': 6.440536992613487e-10,
#   'pred_tgtrack': 0.000140868476592,
#   'pred_starttrack': 4.480187776323419e-09,
#   'pred_stoptrack': 8.655065903440118e-05,
#   'energy': 997388.079658562,
#   'zenith': 1.0446877068162066,
#   'oneweight': 3.402510411629856e+16,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.999772608280182,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_11986_origidx_17_RF22.mp4': {'event': 11986,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.3428260385990143,
#   'pred_cascade': 0.1177812963724136,
#   'pred_tgtrack': 0.2362946718931198,
#   'pred_starttrack': 0.0797206684947013,
#   'pred_stoptrack': 0.2233772873878479,
#   'energy': 141.09195366899468,
#   'zenith': 0.5459303983435488,
#   'oneweight': 7291275.520938259,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.3428260385990143,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_16303_origidx_19_RF22.mp4': {'event': 16303,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.2521913349628448,
#   'pred_cascade': 0.0989897027611732,
#   'pred_tgtrack': 0.2015078067779541,
#   'pred_starttrack': 0.228786826133728,
#   'pred_stoptrack': 0.2185242921113968,
#   'energy': 945.8027060964296,
#   'zenith': 0.7024072500447963,
#   'oneweight': 3265254945.188559,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.2521913349628448,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_35_origidx_6_RF22.mp4': {'event': 35,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 3.6541624126584793e-07,
#   'pred_cascade': 1.509983071912302e-08,
#   'pred_tgtrack': 0.9419129490852356,
#   'pred_starttrack': 0.0568686500191688,
#   'pred_stoptrack': 0.0012180450139567,
#   'energy': 6463.684137346734,
#   'zenith': 2.463083980762746,
#   'oneweight': 1932459758374.2356,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9419129490852356,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_14177_origidx_37_RF22.mp4': {'event': 14177,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.0005923802964389,
#   'pred_cascade': 0.0002555898681748,
#   'pred_tgtrack': 0.0297613460570573,
#   'pred_starttrack': 0.0001372349652228,
#   'pred_stoptrack': 0.9692534804344176,
#   'energy': 1246.266723972724,
#   'zenith': 2.791753785065183,
#   'oneweight': 7927245593.346912,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9692534804344176,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_30214_origidx_12_RF22.mp4': {'event': 30214,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 0.0007610456086695,
#   'pred_cascade': 0.2698200345039367,
#   'pred_tgtrack': 0.0007952690357342,
#   'pred_starttrack': 0.7195941805839539,
#   'pred_stoptrack': 0.0090294480323791,
#   'energy': 2380.643379300856,
#   'zenith': 1.0304685987183442,
#   'oneweight': 33099974743.38348,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.7195941805839539,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_16254_origidx_18_RF22.mp4': {'event': 16254,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0001353054976789,
#   'pred_cascade': 7.300834113266319e-05,
#   'pred_tgtrack': 0.2479741424322128,
#   'pred_starttrack': 0.6354724764823914,
#   'pred_stoptrack': 0.1163450106978416,
#   'energy': 39018.94541040381,
#   'zenith': 2.60821291984336,
#   'oneweight': 31706583881936.047,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.6354724764823914,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_25513_origidx_13_RF22.mp4': {'event': 25513,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0421240404248237,
#   'pred_cascade': 0.0077059753239154,
#   'pred_tgtrack': 0.8716809749603271,
#   'pred_starttrack': 0.0450676828622818,
#   'pred_stoptrack': 0.0334213599562644,
#   'energy': 3959.3002074386,
#   'zenith': 1.2993031425031227,
#   'oneweight': 324920180625.2756,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.8716809749603271,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_25284_origidx_10_RF22.mp4': {'event': 25284,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.2560884356498718,
#   'pred_cascade': 0.0672944113612175,
#   'pred_tgtrack': 0.3233034610748291,
#   'pred_starttrack': 0.0383826531469821,
#   'pred_stoptrack': 0.3149310946464538,
#   'energy': 4137.636177191649,
#   'zenith': 1.9789794127247973,
#   'oneweight': 476154566842.2529,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3233034610748291,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_12506_origidx_21_RF22.mp4': {'event': 12506,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 1.4551645790561452e-06,
#   'pred_cascade': 4.82219438708853e-05,
#   'pred_tgtrack': 0.0073270057328045,
#   'pred_starttrack': 0.9911454319953918,
#   'pred_stoptrack': 0.0014780076453462,
#   'energy': 277.41202029124736,
#   'zenith': 1.97471180914142,
#   'oneweight': 126162271.50639436,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.9911454319953918,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_646_origidx_10_RF22.mp4': {'event': 646,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 1.0944187124550808e-05,
#   'pred_cascade': 3.08942662741174e-06,
#   'pred_tgtrack': 0.9996211528778076,
#   'pred_starttrack': 0.0003109176759608,
#   'pred_stoptrack': 5.386244447436184e-05,
#   'energy': 378481.9831265877,
#   'zenith': 1.2758920412446937,
#   'oneweight': 6306658831368037.0,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9996211528778076,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_12559_origidx_22_RF22.mp4': {'event': 12559,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 8.666070812068938e-07,
#   'pred_cascade': 1.4208912034519017e-05,
#   'pred_tgtrack': 0.0003174639423377,
#   'pred_starttrack': 0.9996652603149414,
#   'pred_stoptrack': 2.1033552002336364e-06,
#   'energy': 1706.4943112256012,
#   'zenith': 2.106827594564433,
#   'oneweight': 28381253974.38766,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.9996652603149414,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_13232_origidx_28_RF22.mp4': {'event': 13232,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 2.726360435190145e-06,
#   'pred_cascade': 4.762463134966311e-08,
#   'pred_tgtrack': 0.6115378737449646,
#   'pred_starttrack': 7.571949390694499e-05,
#   'pred_stoptrack': 0.3883836269378662,
#   'energy': 5045.231781123849,
#   'zenith': 2.582873720732452,
#   'oneweight': 948451491604.6318,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.6115378737449646,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_11600_origidx_14_RF22.mp4': {'event': 11600,
#   'run': 21971,
# ...
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_29762_origidx_10_RF22.mp4': {'event': 29762,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.2942516207695007,
#   'pred_cascade': 0.0528116300702095,
#   'pred_tgtrack': 0.5209253430366516,
#   'pred_starttrack': 0.0706922113895416,
#   'pred_stoptrack': 0.0613191872835159,
#   'energy': 102.65603190695106,
#   'zenith': 0.907342119014072,
#   'oneweight': 14240198.762545343,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.5209253430366516,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_30375_origidx_14_RF22.mp4': {'event': 30375,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.0244960207492113,
#   'pred_cascade': 0.0035158440005034,
#   'pred_tgtrack': 0.4487518966197967,
#   'pred_starttrack': 0.0008821000228635,
#   'pred_stoptrack': 0.5223541855812073,
#   'energy': 104.97525193936706,
#   'zenith': 2.78509383637261,
#   'oneweight': 11119675.909790492,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5223541855812073,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_31929_origidx_5_RF22.mp4': {'event': 31929,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0043812207877635,
#   'pred_cascade': 0.0015522631583735,
#   'pred_tgtrack': 0.9864566326141356,
#   'pred_starttrack': 0.0024138980079442,
#   'pred_stoptrack': 0.0051960749551653,
#   'energy': 20577.261026027594,
#   'zenith': 1.0322269858478703,
#   'oneweight': 10069107129958.752,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9864566326141356,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_13104_origidx_27_RF22.mp4': {'event': 13104,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.9894310235977172,
#   'pred_cascade': 3.525112697388977e-05,
#   'pred_tgtrack': 0.0097981188446283,
#   'pred_starttrack': 2.5374361939611845e-05,
#   'pred_stoptrack': 0.000710173160769,
#   'energy': 205735.88671091385,
#   'zenith': 1.8638425113096624,
#   'oneweight': 6300496938802500.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9894310235977172,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_15300_origidx_41_RF22.mp4': {'event': 15300,
#   'run': 21971,
#   'truth_classification': 7,
#   'pred_skim': 9.854423842625692e-05,
#   'pred_cascade': 0.5326380133628845,
#   'pred_tgtrack': 0.0001115793493227,
#   'pred_starttrack': 0.4609115123748779,
#   'pred_stoptrack': 0.0062403255142271,
#   'energy': 443.3609973015456,
#   'zenith': 1.904485176115694,
#   'oneweight': 891040882.2497017,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.5326380133628845,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_1032_origidx_16_RF22.mp4': {'event': 1032,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0850786194205284,
#   'pred_cascade': 0.0252955704927444,
#   'pred_tgtrack': 0.6522535681724548,
#   'pred_starttrack': 0.0757176652550697,
#   'pred_stoptrack': 0.1616546064615249,
#   'energy': 277268.2139480969,
#   'zenith': 1.8737991595229424,
#   'oneweight': 1.3818887696116382e+16,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.6522535681724548,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_25123_origidx_9_RF22.mp4': {'event': 25123,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 3.69098961527925e-06,
#   'pred_cascade': 0.8318184018135071,
#   'pred_tgtrack': 8.588026503275614e-07,
#   'pred_starttrack': 0.1681765615940094,
#   'pred_stoptrack': 4.87500017243292e-07,
#   'energy': 221290.73692973275,
#   'zenith': 0.889593070581195,
#   'oneweight': 1404546363771422.5,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.8318184018135071,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_25092_origidx_8_RF22.mp4': {'event': 25092,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 5.961876325955018e-09,
#   'pred_cascade': 6.806188945773782e-11,
#   'pred_tgtrack': 0.9990076422691344,
#   'pred_starttrack': 0.000491119979415,
#   'pred_stoptrack': 0.0005012684268876,
#   'energy': 48892.9129242392,
#   'zenith': 2.6747095604865,
#   'oneweight': 29630610480796.586,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9990076422691344,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 17},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_29906_origidx_11_RF22.mp4': {'event': 29906,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.0156066128984093,
#   'pred_cascade': 0.0102682933211326,
#   'pred_tgtrack': 0.7129675149917603,
#   'pred_starttrack': 0.0055693732574582,
#   'pred_stoptrack': 0.2555882334709167,
#   'energy': 131350.60379805768,
#   'zenith': 2.323809593632985,
#   'oneweight': 2859768784420133.0,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.7129675149917603,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_16663_origidx_5_RF22.mp4': {'event': 16663,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 8.732557716939482e-07,
#   'pred_cascade': 2.747474070474709e-08,
#   'pred_tgtrack': 0.9969235062599182,
#   'pred_starttrack': 0.0030573760159313,
#   'pred_stoptrack': 1.8136461221729405e-05,
#   'energy': 18195.768036799054,
#   'zenith': 1.465808274051836,
#   'oneweight': 22776668682937.73,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9969235062599182,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_25747_origidx_19_RF22.mp4': {'event': 25747,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.98826664686203,
#   'pred_cascade': 0.0045863478444516,
#   'pred_tgtrack': 0.0010410716058686,
#   'pred_starttrack': 0.0015255507314577,
#   'pred_stoptrack': 0.0045803901739418,
#   'energy': 13137.439558692216,
#   'zenith': 1.2142502446642474,
#   'oneweight': 4137022832190.4526,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.98826664686203,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_10818_origidx_8_RF22.mp4': {'event': 10818,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 0.0701071396470069,
#   'pred_cascade': 0.0176746547222137,
#   'pred_tgtrack': 0.8644863963127136,
#   'pred_starttrack': 0.0221179630607366,
#   'pred_stoptrack': 0.0256138369441032,
#   'energy': 4594.573364842561,
#   'zenith': 0.6895187640504812,
#   'oneweight': 157819857021.88486,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.8644863963127136,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_15326_origidx_42_RF22.mp4': {'event': 15326,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 1.5471308678627336e-09,
#   'pred_cascade': 3.8495218745993043e-07,
#   'pred_tgtrack': 4.823080157478898e-09,
#   'pred_starttrack': 0.9999996423721312,
#   'pred_stoptrack': 3.398184858505182e-11,
#   'energy': 129571.504132821,
#   'zenith': 1.0320508370491204,
#   'oneweight': 433752331196257.0,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.9999996423721312,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_16328_origidx_20_RF22.mp4': {'event': 16328,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 2.0171273718005978e-05,
#   'pred_cascade': 2.0077395674888976e-06,
#   'pred_tgtrack': 0.1575140357017517,
#   'pred_starttrack': 0.0003282839606981,
#   'pred_stoptrack': 0.8421355485916138,
#   'energy': 3191.7069138879237,
#   'zenith': 2.557645849227699,
#   'oneweight': 274769057671.12323,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.8421355485916138,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_26174_origidx_23_RF22.mp4': {'event': 26174,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.0559927970170974,
#   'pred_cascade': 0.0065341861918568,
#   'pred_tgtrack': 0.0015934822149574,
#   'pred_starttrack': 0.0098119638860225,
#   'pred_stoptrack': 0.926067590713501,
#   'energy': 172.0214883487571,
#   'zenith': 2.9341602246217926,
#   'oneweight': 13046951.116993591,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.926067590713501,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_29526_origidx_5_RF22.mp4': {'event': 29526,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 3.7889644199928796e-10,
#   'pred_cascade': 1.7113192277252317e-17,
#   'pred_tgtrack': 0.9999464750289916,
#   'pred_starttrack': 5.3674696687266994e-08,
#   'pred_stoptrack': 5.357827467378229e-05,
#   'energy': 16126.191280600213,
#   'zenith': 2.424762462368049,
#   'oneweight': 14270750653288.797,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9999464750289916,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_16515_origidx_21_RF22.mp4': {'event': 16515,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 4.219602942612255e-06,
#   'pred_cascade': 2.3192271783045726e-06,
#   'pred_tgtrack': 0.9991220831871032,
#   'pred_starttrack': 0.0008631644304841,
#   'pred_stoptrack': 8.203443940146826e-06,
#   'energy': 139297.40022401282,
#   'zenith': 1.3143343183310667,
#   'oneweight': 931122291664886.0,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9991220831871032,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_11731_origidx_16_RF22.mp4': {'event': 11731,
#   'run': 21971,
#   'truth_classification': 8,
#   'pred_skim': 0.9913784265518188,
#   'pred_cascade': 7.764738256810233e-05,
#   'pred_tgtrack': 0.0019711032509803,
#   'pred_starttrack': 0.0002111165958922,
#   'pred_stoptrack': 0.0063617075793445,
#   'energy': 10381.749951633015,
#   'zenith': 0.4867773550909551,
#   'oneweight': 902808016695.581,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9913784265518188,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_25897_origidx_21_RF22.mp4': {'event': 25897,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.4025375843048095,
#   'pred_cascade': 0.0966032370924949,
#   'pred_tgtrack': 0.1966247409582138,
#   'pred_starttrack': 0.0581444054841995,
#   'pred_stoptrack': 0.2460900396108627,
#   'energy': 27419.20298479695,
#   'zenith': 2.4615734623695684,
#   'oneweight': 969445149937.5226,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.4025375843048095,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_825_origidx_12_RF22.mp4': {'event': 825,
#   'run': 21971,
#   'truth_classification': 4,
#   'pred_skim': 0.3252762258052826,
#   'pred_cascade': 0.0699392408132553,
#   'pred_tgtrack': 0.2355842888355255,
#   'pred_starttrack': 0.2712415754795074,
#   'pred_stoptrack': 0.0979586541652679,
#   'energy': 738.5144704754845,
#   'zenith': 2.171396765308716,
#   'oneweight': 1565991711.2237897,
#   'truth_classification_label': 'skimming_track',
#   'max_score_val': 0.3252762258052826,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_13526_origidx_29_RF22.mp4': {'event': 13526,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 7.389812253677519e-06,
#   'pred_cascade': 4.542364422377432e-07,
#   'pred_tgtrack': 0.9542399644851683,
#   'pred_starttrack': 0.0044024721719324,
#   'pred_stoptrack': 0.0413497276604175,
#   'energy': 10476.98772887896,
#   'zenith': 2.581514077369512,
#   'oneweight': 6511489159432.785,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9542399644851683,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_16846_origidx_9_RF22.mp4': {'event': 16846,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 6.140474511084903e-07,
#   'pred_cascade': 7.786495004324934e-09,
#   'pred_tgtrack': 0.9901898503303528,
#   'pred_starttrack': 2.740330273809377e-05,
#   'pred_stoptrack': 0.0097822118550539,
#   'energy': 21748.53269484605,
#   'zenith': 2.5025726255262795,
#   'oneweight': 30587356614555.31,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.9901898503303528,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_13073_origidx_26_RF22.mp4': {'event': 13073,
#   'run': 21971,
#   'truth_classification': 2,
#   'pred_skim': 8.327324394485913e-06,
#   'pred_cascade': 0.0020897509530186,
#   'pred_tgtrack': 1.6476911696372554e-05,
#   'pred_starttrack': 0.9978748559951782,
#   'pred_stoptrack': 1.0632764315232636e-05,
#   'energy': 7426.135492848509,
#   'zenith': 0.7102350338774596,
#   'oneweight': 631346967194.6062,
#   'truth_classification_label': 'starting_track',
#   'max_score_val': 0.9978748559951782,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_21971000001/compressed_run_21971_event_9953_origidx_4_RF22.mp4': {'event': 9953,
#   'run': 21971,
#   'truth_classification': 1,
#   'pred_skim': 9.276559285353868e-05,
#   'pred_cascade': 8.667346264701337e-06,
#   'pred_tgtrack': 0.8705990314483643,
#   'pred_starttrack': 0.0122783267870545,
#   'pred_stoptrack': 0.117021232843399,
#   'energy': 1603.900601107921,
#   'zenith': 2.0315472082090964,
#   'oneweight': 39129770895.679184,
#   'truth_classification_label': 'throughgoing_track',
#   'max_score_val': 0.8705990314483643,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 8}}

# %%
make_subject_set('numu_run_21971_subrun_000001_phase2')
# Out:
# Subject Set Name: numu_run_21971_subrun_000001_phase2
# Subject Set ID: 112391
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>]

# %%
uploader(compressed_path,numu_csv,112391)
# Out:
# Confirm if subject set 112391 is listed below.
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>]
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>]
# Number of times loop has ran: 1
# Number of times loop has ran: 2
# Number of times loop has ran: 3
# Number of times loop has ran: 4
# Number of times loop has ran: 5
# Number of times loop has ran: 6
# Number of times loop has ran: 7
# Number of times loop has ran: 8
# Number of times loop has ran: 9
# Number of times loop has ran: 10
# Number of times loop has ran: 11
# Number of times loop has ran: 12
# Number of times loop has ran: 13
# Number of times loop has ran: 14
# Number of times loop has ran: 15
# Number of times loop has ran: 16
# Number of times loop has ran: 17
# Number of times loop has ran: 18
# Number of times loop has ran: 19
# Number of times loop has ran: 20
# Number of times loop has ran: 21
# Number of times loop has ran: 22
# Number of times loop has ran: 23
# Number of times loop has ran: 24
# Number of times loop has ran: 25
# Number of times loop has ran: 26
# Number of times loop has ran: 27
# Number of times loop has ran: 28
# Number of times loop has ran: 29
# Number of times loop has ran: 30
# Number of times loop has ran: 31
# Number of times loop has ran: 32
# Number of times loop has ran: 33
# Number of times loop has ran: 34
# Number of times loop has ran: 35
# Number of times loop has ran: 36
# Number of times loop has ran: 37
# Number of times loop has ran: 38
# Number of times loop has ran: 39
# Number of times loop has ran: 40
# Number of times loop has ran: 41
# Number of times loop has ran: 42
# Number of times loop has ran: 43
# Number of times loop has ran: 44
# Number of times loop has ran: 45
# Number of times loop has ran: 46
# Number of times loop has ran: 47
# Number of times loop has ran: 48
# Number of times loop has ran: 49
# Number of times loop has ran: 50
# Number of times loop has ran: 51
# Number of times loop has ran: 52
# Number of times loop has ran: 53
# Number of times loop has ran: 54
# Number of times loop has ran: 55
# Number of times loop has ran: 56
# Number of times loop has ran: 57
# Number of times loop has ran: 58
# Number of times loop has ran: 59
# Number of times loop has ran: 60
# Number of times loop has ran: 61
# Number of times loop has ran: 62
# Number of times loop has ran: 63
# Number of times loop has ran: 64
# Number of times loop has ran: 65
# Number of times loop has ran: 66
# Number of times loop has ran: 67
# Number of times loop has ran: 68
# Number of times loop has ran: 69
# Number of times loop has ran: 70
# Number of times loop has ran: 71
# Number of times loop has ran: 72
# Number of times loop has ran: 73
# Number of times loop has ran: 74
# Number of times loop has ran: 75
# Number of times loop has ran: 76
# Number of times loop has ran: 77
# Number of times loop has ran: 78
# Number of times loop has ran: 79
# Number of times loop has ran: 80
# Number of times loop has ran: 81
# Number of times loop has ran: 82
# Number of times loop has ran: 83
# Number of times loop has ran: 84
# Number of times loop has ran: 85
# Number of times loop has ran: 86
# Number of times loop has ran: 87
# Number of times loop has ran: 88
# Number of times loop has ran: 89
# Number of times loop has ran: 90
# Number of times loop has ran: 91
# Number of times loop has ran: 92
# Number of times loop has ran: 93
# Number of times loop has ran: 94
# Number of times loop has ran: 95
# Number of times loop has ran: 96
# Number of times loop has ran: 97
# Number of times loop has ran: 98
# Number of times loop has ran: 99
# Number of times loop has ran: 100
# Number of times loop has ran: 101
# Number of times loop has ran: 102
# Number of times loop has ran: 103
# Number of times loop has ran: 104
# Number of times loop has ran: 105
# Number of times loop has ran: 106
# Number of times loop has ran: 107
# Number of times loop has ran: 108
# Number of times loop has ran: 109
# Number of times loop has ran: 110
# Number of times loop has ran: 111
# Number of times loop has ran: 112
# Number of times loop has ran: 113
# Number of times loop has ran: 114
# Number of times loop has ran: 115
# Number of times loop has ran: 116
# Number of times loop has ran: 117
# Number of times loop has ran: 118
# Number of times loop has ran: 119
# Number of times loop has ran: 120
# Number of times loop has ran: 121
# Number of times loop has ran: 122
# Number of times loop has ran: 123
# Number of times loop has ran: 124
# Number of times loop has ran: 125
# Number of times loop has ran: 126
# Number of times loop has ran: 127
# Number of times loop has ran: 128
# Number of times loop has ran: 129
# Number of times loop has ran: 130
# Number of times loop has ran: 131
# Number of times loop has ran: 132
# Number of times loop has ran: 133
# Number of times loop has ran: 134
# Number of times loop has ran: 135
# Number of times loop has ran: 136
# Number of times loop has ran: 137
# Number of times loop has ran: 138
# Number of times loop has ran: 139
# Number of times loop has ran: 140
# Number of times loop has ran: 141
# Number of times loop has ran: 142
# Number of times loop has ran: 143
# Number of times loop has ran: 144
# Number of times loop has ran: 145
# Number of times loop has ran: 146
