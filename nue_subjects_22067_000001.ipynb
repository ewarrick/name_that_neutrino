# %% [markdown]
# # Phase 2: Subject Creation
#
# **Description:**
#
# This notebook is to act as the resulting summary file for the creation and upload of subjects for the IceCube Zooniverse project currently called *Name that Neutrino!*. The project is currently being maintained by Elizabeth Warrick (as of March 2023). In this notebook, we take the i3 file and run it through several filters. [note: describe more later].
#
# > Nu Type: NuE
#
# > Run: 22076
#
# > SubRun: 000001
#
# ### Summary Stats:
#
# To be filled in after completing process. Also need to figure out global variables.
#
# **Subject Set Name:**

# %%
#Imports

#My functions: 
from uniformenergydist_filter import *

#General:
import numpy as np
import sys
import os
import subprocess
import argparse
import csv
from tables import *
import pandas as pd
from matplotlib import pyplot as plt
import h5py

#Zooniverse:
from panoptes_client import Panoptes, Project, SubjectSet, Subject
import magic
import glob

#IceCube:
from icecube.icetray import I3Units
import icecube.MuonGun
from icecube import dataio, dataclasses, icetray, MuonGun
from I3Tray import *
from icecube.hdfwriter import I3HDFWriter
from mc_labeler import MCLabeler #make sure that mc_labeler script is in current directory.

# %%
#Specify file paths:

#Initial I3 File:
nue = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst'

#Desired output directory. Note that creation of this directory is not yet coded and is done manually. 
phase1_dir = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/'

# %%
#Run Filter 1 to label MC truth.
filter1(nue,phase1_dir)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/mc_labeler.py:523: UserWarning: Couldn't find OMKey in MCPESeriesMap
#   warnings.warn("Couldn't find OMKey in MCPESeriesMap")

# %% [markdown]
# Note that the above cell might return an "exception" warning that the *MCPESeriesMap could not be found*. I am unsure why it does that because when I check the i3 file in dataio-shovel, I see the specified mc_pid_series_map (look at mc_labeler.py for exact name of specified key). The resulting file size should be around 400 MB.

# %%
#Path of hdf from above filter.
nue_hdf = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/\
Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst.hd5'

# %%
#Run uniformenergy_events function which requires hdf from filter 1, 
#number of bins, size of each random choice, and a random seed. 

uniformenergy_events(nue_hdf,25,13,12,subrun = True)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['binned_log10E'] = pd.cut(x = np.log10(df_filtered['energy']), bins = bins, labels = labels, include_lowest = True) #might throw an error?
# Number of Bins: 25
# Number of Events per Bin: 13
# Total Number of Events: 325
# Initial Number of Events: 2557
# Number of Events after filtering: 2484
# Please input subrun number:
# 000001

# %% [markdown]
# The above function throws another warning about pd.cut, currently that is not a problem but I don't know if a new version of pandas will allow this.

# %%
#Path to Random Events CSV
nue_csv = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/random_events_uniform_energy_distrib_22067_000001.csv'

# %%
#Run event_characterization_plots function whick makes some quick 
#plots to get an idea of what data you're dealing with.
#Note that I want to update the plot types, maybe make a 2D histogram as Mike K suggested. 
#For truth labels, check out enums.py or in the .py file that holds the functions.

event_characterization_plots(nue_csv)

# %% [markdown]
# Now that we have the events for this phase chosen, we run the second filter to pick out only those events.

# %%
#Path to i3 file from filter1 with MC truth labels. 
nue_filter1 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/\
launch/Phase1/mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst'

# %%
#Run function to perform second filter which passes through only selected event IDs chosen from 
#the uniformenergy_events function. 
filter2(nue_filter1,phase1_dir,nue_csv)

# %%
#Path to i3 file from filter 2 that holds only specified events. 
nue_filter2 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst'

# %%
#Run function to perform third filter, which returns only the DAQ frames of the specified events.
#DAQ only file is then split up into many smaller i3 files since SteamShovel can't handle making videos of large
#i3 files at one time. Size limit is approx 2E6 MB (? unsure of units)
filter3(nue_filter2,22067_000001,phase1_dir)

# %%
#Path to NuMu Daq Only folder
nue_daq = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/'

# %%
get_steamshovel(nue_daq,22067000001)
# Out:
# List of files:
# ['/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/daq_only-0009_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst', '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/daq_only-0010_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst']
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/daq_only-0000_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/daq_only-0001_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/daq_only-0002_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/daq_only-0003_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/daq_only-0004_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/daq_only-0005_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/daq_only-0006_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/daq_only-0007_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/daq_only-0008_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/daq_only-0009_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst
# Finished Videos in: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/daq_22067000001/daq_only-0010_uniform_energy_mc_labeled_classifier_rehyd_DST_IC86.2020_NuE.022067.000001.i3.zst

# %% [markdown]
# Ideas for Compression:
# - Use GUI to add files to queue and send to one compression folder.
# - Add a subprocess line in movie script to compress the video after making it and direct it to save in the compression folder.

# %%
compressed_path = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/'

# %% [markdown]
# Can't get manifest yet since some subjects are missing and lining it up won't work.

# %%
get_manifest(compressed_path, nue_csv)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:417: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   dict_manifest = s3.to_dict('dict')
# {'/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_6869_origidx_6_RF22.mp4': {'event': 6869,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.997774064540863,
#   'pred_cascade': 8.049516327446327e-05,
#   'pred_tgtrack': 1.115742520596541e-06,
#   'pred_starttrack': 1.3215570788815969e-06,
#   'pred_stoptrack': 0.00214304192923,
#   'energy': 16829.522856377887,
#   'zenith': 2.817789910865412,
#   'oneweight': 2293727743439.723,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.997774064540863,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_7142_origidx_14_RF22.mp4': {'event': 7142,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1249460652470588,
#   'pred_cascade': 0.0394317209720611,
#   'pred_tgtrack': 0.1203333288431167,
#   'pred_starttrack': 0.6880122423171997,
#   'pred_stoptrack': 0.0272766184061765,
#   'energy': 145.93181351827283,
#   'zenith': 1.9517557073574183,
#   'oneweight': 23019522.547314554,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6880122423171997,
#   'idx_max_score': 'pred_starttrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_695_origidx_14_RF22.mp4': {'event': 695,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.4092285457300026e-05,
#   'pred_cascade': 0.9489572048187256,
#   'pred_tgtrack': 2.184067852795124e-06,
#   'pred_starttrack': 0.0508150570094585,
#   'pred_stoptrack': 0.0002014498168136,
#   'energy': 1285.1282155963474,
#   'zenith': 1.396425630005394,
#   'oneweight': 5159746333.516971,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9489572048187256,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_7516_origidx_28_RF22.mp4': {'event': 7516,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 7.957869092933834e-05,
#   'pred_cascade': 0.646476149559021,
#   'pred_tgtrack': 2.510548620193731e-05,
#   'pred_starttrack': 0.3529614210128784,
#   'pred_stoptrack': 0.0004576780484057,
#   'energy': 216.34582955342995,
#   'zenith': 0.9723923851021384,
#   'oneweight': 71645262.92633335,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.646476149559021,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_6165_origidx_10_RF22.mp4': {'event': 6165,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2268456369638443,
#   'pred_cascade': 0.0742215886712074,
#   'pred_tgtrack': 0.536133885383606,
#   'pred_starttrack': 0.0862315818667411,
#   'pred_stoptrack': 0.0765672326087951,
#   'energy': 20571.02410090689,
#   'zenith': 2.205452399687769,
#   'oneweight': 25307923651702.21,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.536133885383606,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_7076_origidx_12_RF22.mp4': {'event': 7076,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.8282371204113588e-05,
#   'pred_cascade': 0.9878346920013428,
#   'pred_tgtrack': 1.8086972204400809e-06,
#   'pred_starttrack': 0.0120854461565613,
#   'pred_stoptrack': 4.985177656635642e-05,
#   'energy': 2682.453993367754,
#   'zenith': 0.741147411136497,
#   'oneweight': 38853295525.81469,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9878346920013428,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9328_origidx_6_RF22.mp4': {'event': 9328,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0040746410377323,
#   'pred_cascade': 0.0003927769721485,
#   'pred_tgtrack': 0.0078307026997208,
#   'pred_starttrack': 0.000778351444751,
#   'pred_stoptrack': 0.9869235157966614,
#   'energy': 25055.618193294184,
#   'zenith': 0.3625850059641175,
#   'oneweight': 3607233348645.06,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9869235157966614,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9402_origidx_9_RF22.mp4': {'event': 9402,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2448364794254303,
#   'pred_cascade': 0.0494524128735065,
#   'pred_tgtrack': 0.3709863424301147,
#   'pred_starttrack': 0.1752929836511612,
#   'pred_stoptrack': 0.1594318449497223,
#   'energy': 4453.706098872422,
#   'zenith': 2.1491297878211397,
#   'oneweight': 426112765844.3094,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3709863424301147,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9059_origidx_22_RF22.mp4': {'event': 9059,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.8871170282363892,
#   'pred_cascade': 0.0372721850872039,
#   'pred_tgtrack': 0.0018253261223435,
#   'pred_starttrack': 0.0333171673119068,
#   'pred_stoptrack': 0.040468256920576,
#   'energy': 576.7339118419036,
#   'zenith': 1.7857294002648103,
#   'oneweight': 743047048.1581337,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8871170282363892,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_7289_origidx_21_RF22.mp4': {'event': 7289,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9708718061447144,
#   'pred_cascade': 0.0009624980739317,
#   'pred_tgtrack': 0.0156159456819295,
#   'pred_starttrack': 0.0008459045784547,
#   'pred_stoptrack': 0.0117039261385798,
#   'energy': 1373.820012051717,
#   'zenith': 2.1849050802090817,
#   'oneweight': 8236172784.777204,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9708718061447144,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9209_origidx_33_RF22.mp4': {'event': 9209,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3652301728725433,
#   'pred_cascade': 0.0860344916582107,
#   'pred_tgtrack': 0.2869759500026703,
#   'pred_starttrack': 0.0303142163902521,
#   'pred_stoptrack': 0.2314451485872268,
#   'energy': 376395.0225930277,
#   'zenith': 0.7053990482529658,
#   'oneweight': 615411474611043.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3652301728725433,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_579_origidx_11_RF22.mp4': {'event': 579,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 6.645639587077312e-06,
#   'pred_cascade': 0.993598699569702,
#   'pred_tgtrack': 1.9033031151138857e-08,
#   'pred_starttrack': 0.006391966715455,
#   'pred_stoptrack': 2.7177297852176707e-06,
#   'energy': 3895.205527218551,
#   'zenith': 0.5548856223146085,
#   'oneweight': 100171553695.41849,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.993598699569702,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9431_origidx_10_RF22.mp4': {'event': 9431,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.837981017160928e-06,
#   'pred_cascade': 0.9992502331733704,
#   'pred_tgtrack': 1.6190070117882982e-11,
#   'pred_starttrack': 0.0007480070926249,
#   'pred_stoptrack': 1.202443833392408e-08,
#   'energy': 624437.6663341058,
#   'zenith': 0.7122775399914612,
#   'oneweight': 6288850885898432.0,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9992502331733704,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_7192_origidx_17_RF22.mp4': {'event': 7192,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.996921181678772,
#   'pred_cascade': 4.756465221689155e-10,
#   'pred_tgtrack': 0.000642527535092,
#   'pred_starttrack': 3.097874179402993e-09,
#   'pred_stoptrack': 0.002436262788251,
#   'energy': 168142.86673785545,
#   'zenith': 0.5803183835435632,
#   'oneweight': 268042958471112.47,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.996921181678772,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_8762_origidx_10_RF22.mp4': {'event': 8762,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1214325204491615,
#   'pred_cascade': 0.0234826374799013,
#   'pred_tgtrack': 0.004473146982491,
#   'pred_starttrack': 0.0273975729942321,
#   'pred_stoptrack': 0.8232141137123108,
#   'energy': 1159.1229994938876,
#   'zenith': 1.0863257446226111,
#   'oneweight': 1729841846.3186529,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8232141137123108,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_7352_origidx_23_RF22.mp4': {'event': 7352,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9501293301582336,
#   'pred_cascade': 0.0079946015030145,
#   'pred_tgtrack': 0.0037244625855237,
#   'pred_starttrack': 0.0093677900731563,
#   'pred_stoptrack': 0.0287838205695152,
#   'energy': 20954.897915230435,
#   'zenith': 1.5682929705435165,
#   'oneweight': 2761562864277.625,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9501293301582336,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_7274_origidx_20_RF22.mp4': {'event': 7274,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9997881054878236,
#   'pred_cascade': 1.1936004739254711e-05,
#   'pred_tgtrack': 3.7484325730474666e-05,
#   'pred_starttrack': 1.4473590454144867e-05,
#   'pred_stoptrack': 0.0001479703205404,
#   'energy': 52707.49016174347,
#   'zenith': 2.1169779891862923,
#   'oneweight': 282445621249189.5,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9997881054878236,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9671_origidx_18_RF22.mp4': {'event': 9671,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2136245369911193,
#   'pred_cascade': 0.0690789669752121,
#   'pred_tgtrack': 0.6436442732810974,
#   'pred_starttrack': 0.0434779487550258,
#   'pred_stoptrack': 0.0301741920411586,
#   'energy': 330650.230160995,
#   'zenith': 0.3199430564635159,
#   'oneweight': 559863283219705.25,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6436442732810974,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9593_origidx_13_RF22.mp4': {'event': 9593,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.022777309641242,
#   'pred_cascade': 0.0075559290125966,
#   'pred_tgtrack': 0.9581254720687866,
#   'pred_starttrack': 0.0071568125858902,
#   'pred_stoptrack': 0.004384518135339,
#   'energy': 56341.65953914995,
#   'zenith': 1.6700200963823015,
#   'oneweight': 24569227672324.25,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9581254720687866,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9292_origidx_4_RF22.mp4': {'event': 9292,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 4.290415745344944e-05,
#   'pred_cascade': 0.9799781441688538,
#   'pred_tgtrack': 2.4810094600979937e-07,
#   'pred_starttrack': 0.0199593659490346,
#   'pred_stoptrack': 1.943118513736408e-05,
#   'energy': 8210.697968704659,
#   'zenith': 1.1459795353385298,
#   'oneweight': 458574969189.6629,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9799781441688538,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 12},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_759_origidx_17_RF22.mp4': {'event': 759,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9974013566970824,
#   'pred_cascade': 4.6849996579112485e-05,
#   'pred_tgtrack': 0.0019743139855563,
#   'pred_starttrack': 2.114115886797663e-06,
#   'pred_stoptrack': 0.0005753219593316,
#   'energy': 19460.18557814108,
#   'zenith': 2.139973845800288,
#   'oneweight': 3767081274136.764,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9974013566970824,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_8760_origidx_9_RF22.mp4': {'event': 8760,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.0001011647691484,
#   'pred_cascade': 0.9900751709938048,
#   'pred_tgtrack': 2.5586619045725456e-08,
#   'pred_starttrack': 0.0098208505660295,
#   'pred_stoptrack': 2.8259428290766664e-06,
#   'energy': 54363.18820611646,
#   'zenith': 1.38312785902175,
#   'oneweight': 139366361685916.05,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.9900751709938048,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_7243_origidx_19_RF22.mp4': {'event': 7243,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999826967716217,
#   'pred_cascade': 4.534776110176608e-09,
#   'pred_tgtrack': 6.786154699511826e-05,
#   'pred_starttrack': 1.880266040643619e-07,
#   'pred_stoptrack': 0.0001049807979143,
#   'energy': 52951.48250783191,
#   'zenith': 0.7698227382513823,
#   'oneweight': 48495976751968.22,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999826967716217,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_514_origidx_9_RF22.mp4': {'event': 514,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 5.162094385013916e-05,
#   'pred_cascade': 0.9997281432151794,
#   'pred_tgtrack': 7.358277182012428e-11,
#   'pred_starttrack': 0.0002202166942879,
#   'pred_stoptrack': 2.8391895057211517e-08,
#   'energy': 451509.8160551066,
#   'zenith': 2.1733978922992927,
#   'oneweight': 4.118825559854554e+16,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9997281432151794,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_6196_origidx_11_RF22.mp4': {'event': 6196,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 5.913780114497058e-06,
#   'pred_cascade': 0.6077998280525208,
#   'pred_tgtrack': 3.1499715987592936e-05,
#   'pred_starttrack': 0.3921583294868469,
#   'pred_stoptrack': 4.31538092016126e-06,
#   'energy': 1727.8794994453417,
#   'zenith': 0.667737906810655,
#   'oneweight': 11462531419.301256,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.6077998280525208,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_8787_origidx_12_RF22.mp4': {'event': 8787,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0022143961396068,
#   'pred_cascade': 0.0006553931743837,
#   'pred_tgtrack': 0.0010054110316559,
#   'pred_starttrack': 0.0007268328336067,
#   'pred_stoptrack': 0.9953979849815368,
#   'energy': 19073.16194055625,
#   'zenith': 2.529658370021684,
#   'oneweight': 1455898190865.954,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9953979849815368,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_7441_origidx_26_RF22.mp4': {'event': 7441,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9988414645195008,
#   'pred_cascade': 4.005270602647215e-05,
#   'pred_tgtrack': 0.0007965641561895,
#   'pred_starttrack': 3.251371890655719e-05,
#   'pred_stoptrack': 0.0002895197831094,
#   'energy': 64932.39654065009,
#   'zenith': 1.830954411619861,
#   'oneweight': 38525604327734.16,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9988414645195008,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 18},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9468_origidx_11_RF22.mp4': {'event': 9468,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9256924390792848,
#   'pred_cascade': 0.0042028776369988,
#   'pred_tgtrack': 0.03780497610569,
#   'pred_starttrack': 0.0038624901790171,
#   'pred_stoptrack': 0.0284372549504041,
#   'energy': 654.9625815246214,
#   'zenith': 1.852733725030923,
#   'oneweight': 986444763.85784,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9256924390792848,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_6094_origidx_7_RF22.mp4': {'event': 6094,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9993441700935364,
#   'pred_cascade': 2.84521178173236e-07,
#   'pred_tgtrack': 2.7713360395864584e-05,
#   'pred_starttrack': 2.936381179097225e-06,
#   'pred_stoptrack': 0.0006249702419154,
#   'energy': 18718.767146198446,
#   'zenith': 1.807192047053859,
#   'oneweight': 2091883358914.223,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9993441700935364,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_1153_origidx_29_RF22.mp4': {'event': 1153,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.9171100575476885e-05,
#   'pred_cascade': 0.8713704943656921,
#   'pred_tgtrack': 2.3344066448771628e-06,
#   'pred_starttrack': 0.1285680681467056,
#   'pred_stoptrack': 3.983911301475018e-05,
#   'energy': 556.9545556575201,
#   'zenith': 0.6713436973891724,
#   'oneweight': 847513278.3267305,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8713704943656921,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9081_origidx_24_RF22.mp4': {'event': 9081,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.998931348323822,
#   'pred_cascade': 5.177817365620285e-05,
#   'pred_tgtrack': 0.0001756526035023,
#   'pred_starttrack': 4.084269312443212e-05,
#   'pred_stoptrack': 0.0008003932307474,
#   'energy': 5668.748630469501,
#   'zenith': 2.6072144019021017,
#   'oneweight': 235987686038.1113,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.998931348323822,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_7121_origidx_13_RF22.mp4': {'event': 7121,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.999862790107727,
#   'pred_cascade': 8.848998755972558e-10,
#   'pred_tgtrack': 8.855032501742244e-05,
#   'pred_starttrack': 3.718160144217109e-07,
#   'pred_stoptrack': 4.831144178751856e-05,
#   'energy': 490578.9600775532,
#   'zenith': 0.8143534399810095,
#   'oneweight': 6119981993156727.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.999862790107727,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_2505_origidx_4_RF22.mp4': {'event': 2505,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 9.60065449362446e-07,
#   'pred_cascade': 0.9882551431655884,
#   'pred_tgtrack': 2.024862055804988e-07,
#   'pred_starttrack': 0.0117416232824325,
#   'pred_stoptrack': 2.173902885260759e-06,
#   'energy': 9059.612977481404,
#   'zenith': 0.4681733915372165,
#   'oneweight': 656164241823.538,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9882551431655884,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9303_origidx_5_RF22.mp4': {'event': 9303,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3184059858322143,
#   'pred_cascade': 0.0571569018065929,
#   'pred_tgtrack': 0.2668918669223785,
#   'pred_starttrack': 0.0139547623693943,
#   'pred_stoptrack': 0.3435905277729034,
#   'energy': 122.57656303400476,
#   'zenith': 2.4020649712448088,
#   'oneweight': 16771674.085952789,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3435905277729034,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9046_origidx_20_RF22.mp4': {'event': 9046,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.2975104368706525e-07,
#   'pred_cascade': 0.9955112934112548,
#   'pred_tgtrack': 1.139959571183624e-09,
#   'pred_starttrack': 0.0044884346425533,
#   'pred_stoptrack': 2.630267772474326e-07,
#   'energy': 20415.81073677805,
#   'zenith': 1.966673820218814,
#   'oneweight': 3491396292638.056,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9955112934112548,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_4501_origidx_6_RF22.mp4': {'event': 4501,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.531474117655307e-05,
#   'pred_cascade': 0.9780187606811525,
#   'pred_tgtrack': 3.553450866888852e-08,
#   'pred_starttrack': 0.0219635963439941,
#   'pred_stoptrack': 2.3135894480219577e-06,
#   'energy': 3576.0839230288448,
#   'zenith': 1.553106598043103,
#   'oneweight': 53953996492.51827,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9780187606811525,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_7035_origidx_11_RF22.mp4': {'event': 7035,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9385164380073548,
#   'pred_cascade': 0.0312510766088962,
#   'pred_tgtrack': 4.36334521509707e-05,
#   'pred_starttrack': 0.0297334603965282,
#   'pred_stoptrack': 0.0004555010527838,
#   'energy': 130187.55268328724,
#   'zenith': 0.6980963881071088,
#   'oneweight': 173786752411106.84,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9385164380073548,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_3570_origidx_5_RF22.mp4': {'event': 3570,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3046486377716064,
#   'pred_cascade': 0.6424881219863892,
#   'pred_tgtrack': 0.0001883271615952,
#   'pred_starttrack': 0.0497428849339485,
#   'pred_stoptrack': 0.0029319382738322,
#   'energy': 13289.374698762776,
#   'zenith': 1.048858612601093,
#   'oneweight': 2834292920882.638,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6424881219863892,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_7187_origidx_16_RF22.mp4': {'event': 7187,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0001458275073673,
#   'pred_cascade': 0.9835438132286072,
#   'pred_tgtrack': 1.4893977606789124e-07,
#   'pred_starttrack': 0.0163052026182413,
#   'pred_stoptrack': 4.893605819233926e-06,
#   'energy': 10812.207051329053,
#   'zenith': 1.2219482668857506,
#   'oneweight': 869727162582.6741,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9835438132286072,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_3684_origidx_9_RF22.mp4': {'event': 3684,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9988391995429992,
#   'pred_cascade': 4.3602434743661433e-05,
#   'pred_tgtrack': 0.0003122213238384,
#   'pred_starttrack': 6.657307676505297e-05,
#   'pred_stoptrack': 0.0007384801283478,
#   'energy': 573594.5163525104,
#   'zenith': 2.445989947467821,
#   'oneweight': 217143224502351.72,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9988391995429992,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9087_origidx_25_RF22.mp4': {'event': 9087,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.8792245984077454,
#   'pred_cascade': 0.0556394346058368,
#   'pred_tgtrack': 0.0023196379188448,
#   'pred_starttrack': 0.0260483566671609,
#   'pred_stoptrack': 0.0367679893970489,
#   'energy': 1294.2672038438673,
#   'zenith': 2.183164143051707,
#   'oneweight': 5380219482.767896,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8792245984077454,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 7},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_637_origidx_12_RF22.mp4': {'event': 637,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999992847442628,
#   'pred_cascade': 4.1922315618947437e-10,
#   'pred_tgtrack': 2.7064385221819975e-07,
#   'pred_starttrack': 5.2239535364151386e-08,
#   'pred_stoptrack': 3.6901019484503205e-07,
#   'energy': 771819.3580570351,
#   'zenith': 1.2279957088015627,
#   'oneweight': 5705175729329293.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999992847442628,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_8813_origidx_13_RF22.mp4': {'event': 8813,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9599222540855408,
#   'pred_cascade': 0.0290292743593454,
#   'pred_tgtrack': 0.0002073489158647,
#   'pred_starttrack': 0.007803360465914,
#   'pred_stoptrack': 0.0030377726070582,
#   'energy': 3663.604997050397,
#   'zenith': 1.505176047288507,
#   'oneweight': 58089726374.35234,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9599222540855408,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_2548_origidx_5_RF22.mp4': {'event': 2548,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4265033900737762,
#   'pred_cascade': 0.0740045681595802,
#   'pred_tgtrack': 0.3220970332622528,
#   'pred_starttrack': 0.0493018180131912,
#   'pred_stoptrack': 0.1280931234359741,
#   'energy': 4794.370754809297,
#   'zenith': 2.2453491192766357,
#   'oneweight': 87444720033.08508,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4265033900737762,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_8916_origidx_17_RF22.mp4': {'event': 8916,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.0002419322408968,
#   'pred_cascade': 0.985458254814148,
#   'pred_tgtrack': 2.6779596851156384e-07,
#   'pred_starttrack': 0.014260628260672,
#   'pred_stoptrack': 3.900482988683507e-05,
#   'energy': 1608.4620246136642,
#   'zenith': 2.3551756170796154,
#   'oneweight': 13830587692.149569,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.985458254814148,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_839_origidx_19_RF22.mp4': {'event': 839,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9989795088768004,
#   'pred_cascade': 3.070541509941904e-08,
#   'pred_tgtrack': 0.0005024300771765,
#   'pred_starttrack': 1.546685126641023e-07,
#   'pred_stoptrack': 0.0005179682630114,
#   'energy': 151249.8253730207,
#   'zenith': 1.7716601554046758,
#   'oneweight': 152772675583196.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9989795088768004,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_915_origidx_23_RF22.mp4': {'event': 915,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9524328708648682,
#   'pred_cascade': 0.0305958669632673,
#   'pred_tgtrack': 0.0029199204873293,
#   'pred_starttrack': 0.0097528183832764,
#   'pred_stoptrack': 0.0042984983883798,
#   'energy': 30992.300809070668,
#   'zenith': 1.7062885351362516,
#   'oneweight': 5730541634102.116,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9524328708648682,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 16},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_450_origidx_6_RF22.mp4': {'event': 450,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.6262394189834595,
#   'pred_cascade': 0.3589442074298858,
#   'pred_tgtrack': 0.0001455079764127,
#   'pred_starttrack': 0.0143403280526399,
#   'pred_stoptrack': 0.0003305875579826,
#   'energy': 411703.1658280955,
#   'zenith': 1.502175789140112,
#   'oneweight': 1605114194874278.5,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6262394189834595,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_7514_origidx_27_RF22.mp4': {'event': 7514,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999799728393556,
#   'pred_cascade': 2.443315827438397e-10,
#   'pred_tgtrack': 5.279963716020575e-06,
#   'pred_starttrack': 7.45384980405106e-08,
#   'pred_stoptrack': 1.4709584320371503e-05,
#   'energy': 322008.34132659907,
#   'zenith': 1.348940511564132,
#   'oneweight': 709885118048630.1,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999799728393556,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_6970_origidx_9_RF22.mp4': {'event': 6970,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4173059463500976,
#   'pred_cascade': 0.1025578677654266,
#   'pred_tgtrack': 0.1031296104192733,
#   'pred_starttrack': 0.0439308173954486,
#   'pred_stoptrack': 0.3330757319927215,
#   'energy': 353770.6476627403,
#   'zenith': 0.8416273571286185,
#   'oneweight': 1340530168817128.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4173059463500976,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_7355_origidx_24_RF22.mp4': {'event': 7355,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.998804211616516,
#   'pred_cascade': 2.3758577754051657e-06,
#   'pred_tgtrack': 0.0011444413103163,
#   'pred_starttrack': 1.26536576772196e-06,
#   'pred_stoptrack': 4.7724199248477817e-05,
#   'energy': 841346.379359491,
#   'zenith': 1.7136678417132167,
#   'oneweight': 6681738634291372.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.998804211616516,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_8573_origidx_5_RF22.mp4': {'event': 8573,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9984079003334044,
#   'pred_cascade': 0.000161912976182,
#   'pred_tgtrack': 0.0009511209209449,
#   'pred_starttrack': 0.0001213444920722,
#   'pred_stoptrack': 0.0003577157913241,
#   'energy': 80371.52141890212,
#   'zenith': 1.572132235385393,
#   'oneweight': 45541461757706.805,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9984079003334044,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9692_origidx_19_RF22.mp4': {'event': 9692,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 1.0777811439766085e-05,
#   'pred_cascade': 0.997707724571228,
#   'pred_tgtrack': 3.0605540324302183e-09,
#   'pred_starttrack': 0.0022808404173702,
#   'pred_stoptrack': 5.357529744287604e-07,
#   'energy': 225977.78180594143,
#   'zenith': 0.7376109853622509,
#   'oneweight': 1122029770627055.0,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.997707724571228,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_786_origidx_18_RF22.mp4': {'event': 786,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1747678220272064,
#   'pred_cascade': 0.0592209994792938,
#   'pred_tgtrack': 0.5420181751251221,
#   'pred_starttrack': 0.0497663542628288,
#   'pred_stoptrack': 0.1742266416549682,
#   'energy': 1953.02796464414,
#   'zenith': 1.4276989946799563,
#   'oneweight': 7091574574.179683,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5420181751251221,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_7174_origidx_15_RF22.mp4': {'event': 7174,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.7999032735824585,
#   'pred_cascade': 0.0041364943608641,
#   'pred_tgtrack': 0.0059807915240526,
#   'pred_starttrack': 0.0121109886094927,
#   'pred_stoptrack': 0.177868440747261,
#   'energy': 296.1177388487471,
#   'zenith': 1.5998433322828116,
#   'oneweight': 100956634.53007276,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7999032735824585,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9630_origidx_16_RF22.mp4': {'event': 9630,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.1408162266016006,
#   'pred_cascade': 0.7985913753509521,
#   'pred_tgtrack': 0.0001073048915714,
#   'pred_starttrack': 0.0601742044091224,
#   'pred_stoptrack': 0.0003108816163148,
#   'energy': 152353.40762221257,
#   'zenith': 0.3483248993401123,
#   'oneweight': 254344016113202.8,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.7985913753509521,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_6162_origidx_9_RF22.mp4': {'event': 6162,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 4.443507805262925e-06,
#   'pred_cascade': 0.9979629516601562,
#   'pred_tgtrack': 7.051745853914326e-08,
#   'pred_starttrack': 0.0020304499194025,
#   'pred_stoptrack': 2.1925959572399734e-06,
#   'energy': 4516.3042510375,
#   'zenith': 2.397422126975376,
#   'oneweight': 455995222751.1712,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9979629516601562,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9112_origidx_28_RF22.mp4': {'event': 9112,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 4.2041781853185967e-05,
#   'pred_cascade': 0.934561252593994,
#   'pred_tgtrack': 4.387572516861837e-06,
#   'pred_starttrack': 0.0652484595775604,
#   'pred_stoptrack': 0.0001438594626961,
#   'energy': 630.3798422718701,
#   'zenith': 2.419168571314424,
#   'oneweight': 1434921929.722921,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.934561252593994,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_969_origidx_25_RF22.mp4': {'event': 969,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.8120368719100952,
#   'pred_cascade': 0.0001393278507748,
#   'pred_tgtrack': 0.1439602375030517,
#   'pred_starttrack': 0.0315769575536251,
#   'pred_stoptrack': 0.0122866565361619,
#   'energy': 162509.4343757484,
#   'zenith': 1.50516999183366,
#   'oneweight': 244447918159463.03,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8120368719100952,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_3619_origidx_6_RF22.mp4': {'event': 3619,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4743084609508514,
#   'pred_cascade': 0.4059585332870483,
#   'pred_tgtrack': 0.0282108448445796,
#   'pred_starttrack': 0.0791234150528907,
#   'pred_stoptrack': 0.0123987579718232,
#   'energy': 2578.100955366413,
#   'zenith': 1.69968644108219,
#   'oneweight': 23796453878.893154,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4743084609508514,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9055_origidx_21_RF22.mp4': {'event': 9055,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3894134759902954,
#   'pred_cascade': 0.0547953024506568,
#   'pred_tgtrack': 0.3413105010986328,
#   'pred_starttrack': 0.0201670937240123,
#   'pred_stoptrack': 0.1943136602640152,
#   'energy': 164.46801890048425,
#   'zenith': 1.9279638106668755,
#   'oneweight': 24272338.899809446,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.3894134759902954,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_8786_origidx_11_RF22.mp4': {'event': 8786,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.835362854762934e-05,
#   'pred_cascade': 0.94613778591156,
#   'pred_tgtrack': 1.017597810459847e-06,
#   'pred_starttrack': 0.0538371205329895,
#   'pred_stoptrack': 5.7693305279826745e-06,
#   'energy': 23807.64945393947,
#   'zenith': 1.1358865652429415,
#   'oneweight': 5921447061073.329,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.94613778591156,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 15},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_3542_origidx_4_RF22.mp4': {'event': 3542,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9993767142295836,
#   'pred_cascade': 2.0260509359104617e-07,
#   'pred_tgtrack': 3.068646037718281e-05,
#   'pred_starttrack': 4.79106120110373e-07,
#   'pred_stoptrack': 0.0005918471142649,
#   'energy': 12270.540556082706,
#   'zenith': 1.0601588931419792,
#   'oneweight': 1094251932892.9327,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9993767142295836,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_1162_origidx_30_RF22.mp4': {'event': 1162,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2853460311889648,
#   'pred_cascade': 0.0658884868025779,
#   'pred_tgtrack': 0.5118384957313538,
#   'pred_starttrack': 0.0583553984761238,
#   'pred_stoptrack': 0.0785715654492378,
#   'energy': 316.7877703003459,
#   'zenith': 1.190398993767792,
#   'oneweight': 97604889.60158604,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5118384957313538,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_7003_origidx_10_RF22.mp4': {'event': 7003,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1690674126148224,
#   'pred_cascade': 0.0553534589707851,
#   'pred_tgtrack': 0.537521481513977,
#   'pred_starttrack': 0.0196225959807634,
#   'pred_stoptrack': 0.2184350490570068,
#   'energy': 17269.26967056486,
#   'zenith': 2.1191753631650028,
#   'oneweight': 830396642893.6205,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.537521481513977,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_2555_origidx_6_RF22.mp4': {'event': 2555,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.1659803092479705,
#   'pred_cascade': 0.0010602753609418,
#   'pred_tgtrack': 0.8218591809272766,
#   'pred_starttrack': 0.0052624070085585,
#   'pred_stoptrack': 0.0058378805406391,
#   'energy': 395.6790288774147,
#   'zenith': 0.8466876654101597,
#   'oneweight': 330491376.13969034,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8218591809272766,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 4},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_481_origidx_7_RF22.mp4': {'event': 481,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0952065736055374,
#   'pred_cascade': 0.0346177816390991,
#   'pred_tgtrack': 0.6526280045509338,
#   'pred_starttrack': 0.025691095739603,
#   'pred_stoptrack': 0.1918565481901168,
#   'energy': 134828.5163006204,
#   'zenith': 1.4276279848766111,
#   'oneweight': 633774614091245.2,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6526280045509338,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9618_origidx_15_RF22.mp4': {'event': 9618,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 0.0387027226388454,
#   'pred_cascade': 0.947372555732727,
#   'pred_tgtrack': 8.379861355933826e-06,
#   'pred_starttrack': 0.0128528233617544,
#   'pred_stoptrack': 0.0010635227663442,
#   'energy': 10220.498653237775,
#   'zenith': 1.7724720416426465,
#   'oneweight': 669076369444.891,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.947372555732727,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 13},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_8673_origidx_8_RF22.mp4': {'event': 8673,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 0.000113997120934,
#   'pred_cascade': 0.9659350514411926,
#   'pred_tgtrack': 2.384505535246717e-07,
#   'pred_starttrack': 0.0339485555887222,
#   'pred_stoptrack': 2.145881353499135e-06,
#   'energy': 112310.67220667304,
#   'zenith': 1.816470107204536,
#   'oneweight': 32693177720284.05,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9659350514411926,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_8932_origidx_18_RF22.mp4': {'event': 8932,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999239444732666,
#   'pred_cascade': 3.763219957875208e-09,
#   'pred_tgtrack': 5.718395186704584e-05,
#   'pred_starttrack': 8.535563722489314e-08,
#   'pred_stoptrack': 1.882558717625216e-05,
#   'energy': 399750.2040980196,
#   'zenith': 1.0344324378747796,
#   'oneweight': 1572698752473382.5,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999239444732666,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 23},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_7642_origidx_4_RF22.mp4': {'event': 7642,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.0131138878932688e-05,
#   'pred_cascade': 0.9945979118347168,
#   'pred_tgtrack': 2.6489528348605518e-09,
#   'pred_starttrack': 0.0053917928598821,
#   'pred_stoptrack': 2.042866498186413e-07,
#   'energy': 489485.3263883724,
#   'zenith': 1.7495767681486902,
#   'oneweight': 507839437453267.3,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9945979118347168,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_3625_origidx_7_RF22.mp4': {'event': 3625,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3658095598220825,
#   'pred_cascade': 0.069017082452774,
#   'pred_tgtrack': 0.4321848154067993,
#   'pred_starttrack': 0.0418638698756694,
#   'pred_stoptrack': 0.0911246985197067,
#   'energy': 37555.73309309044,
#   'zenith': 1.375153870464849,
#   'oneweight': 34488326543564.69,
# ...
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 25},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_6873_origidx_7_RF22.mp4': {'event': 6873,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.016681283712387,
#   'pred_cascade': 0.0059748282656073,
#   'pred_tgtrack': 0.8462229371070862,
#   'pred_starttrack': 0.0111586218699812,
#   'pred_stoptrack': 0.1199624240398407,
#   'energy': 1948.4638004762087,
#   'zenith': 1.197543378714651,
#   'oneweight': 34985893954.6032,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8462229371070862,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_6090_origidx_6_RF22.mp4': {'event': 6090,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0379920192062854,
#   'pred_cascade': 0.0095575526356697,
#   'pred_tgtrack': 0.6379697918891907,
#   'pred_starttrack': 0.0153194600716233,
#   'pred_stoptrack': 0.2991611957550049,
#   'energy': 1347.3710560440536,
#   'zenith': 2.6540608721422814,
#   'oneweight': 11208519327.284668,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6379697918891907,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_538_origidx_10_RF22.mp4': {'event': 538,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9283522963523864,
#   'pred_cascade': 3.935928179998882e-05,
#   'pred_tgtrack': 0.0113350199535489,
#   'pred_starttrack': 0.0002174701076,
#   'pred_stoptrack': 0.0600557401776313,
#   'energy': 16835.143439368272,
#   'zenith': 1.7606044252505837,
#   'oneweight': 1521817752594.6147,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9283522963523864,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 14},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_4495_origidx_5_RF22.mp4': {'event': 4495,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.3277040719985962,
#   'pred_cascade': 0.1046201214194297,
#   'pred_tgtrack': 0.4127543568611145,
#   'pred_starttrack': 0.0884082242846489,
#   'pred_stoptrack': 0.066513143479824,
#   'energy': 153.02968926232404,
#   'zenith': 2.285245584598678,
#   'oneweight': 30179122.8503596,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4127543568611145,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 2},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_6101_origidx_8_RF22.mp4': {'event': 6101,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.5279302000999451,
#   'pred_cascade': 0.3417079746723175,
#   'pred_tgtrack': 0.0378551855683326,
#   'pred_starttrack': 0.0921079292893409,
#   'pred_stoptrack': 0.0003986772790085,
#   'energy': 112702.0341838527,
#   'zenith': 0.3976817649699049,
#   'oneweight': 143696712591412.88,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.5279302000999451,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 20},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_4555_origidx_7_RF22.mp4': {'event': 4555,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9937211275100708,
#   'pred_cascade': 4.63880569441244e-05,
#   'pred_tgtrack': 9.937892900779843e-05,
#   'pred_starttrack': 0.0002073930663755,
#   'pred_stoptrack': 0.0059256698004901,
#   'energy': 2469.9021356759854,
#   'zenith': 2.5209185329971624,
#   'oneweight': 29672631543.313644,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9937211275100708,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 9},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_7715_origidx_6_RF22.mp4': {'event': 7715,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.7025848031044006,
#   'pred_cascade': 0.0069790543057024,
#   'pred_tgtrack': 0.1578873842954635,
#   'pred_starttrack': 0.0371716506779193,
#   'pred_stoptrack': 0.0953771471977233,
#   'energy': 540.5713986967296,
#   'zenith': 2.0421315433612803,
#   'oneweight': 911765827.4222616,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.7025848031044006,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9187_origidx_31_RF22.mp4': {'event': 9187,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.7171813599125016e-06,
#   'pred_cascade': 0.8811770081520081,
#   'pred_tgtrack': 1.7829883347530997e-07,
#   'pred_starttrack': 0.1188086792826652,
#   'pred_stoptrack': 1.1301997801638208e-05,
#   'energy': 453.0311290298565,
#   'zenith': 2.0028627818613005,
#   'oneweight': 560527381.1386148,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.8811770081520081,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_6802_origidx_4_RF22.mp4': {'event': 6802,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999983310699464,
#   'pred_cascade': 2.0099330186318376e-11,
#   'pred_tgtrack': 4.514257625487517e-07,
#   'pred_starttrack': 8.471207024740579e-08,
#   'pred_stoptrack': 1.1728664048860082e-06,
#   'energy': 495119.75566030113,
#   'zenith': 1.7954007416162434,
#   'oneweight': 1841672435715036.0,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999983310699464,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 24},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_7533_origidx_29_RF22.mp4': {'event': 7533,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0473917201161384,
#   'pred_cascade': 0.0176820531487464,
#   'pred_tgtrack': 0.8007274270057678,
#   'pred_starttrack': 0.0487829595804214,
#   'pred_stoptrack': 0.0854158475995063,
#   'energy': 1467.376933031838,
#   'zenith': 1.353979923019903,
#   'oneweight': 16253942260.57627,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.8007274270057678,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_7681_origidx_5_RF22.mp4': {'event': 7681,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.0207042325637303e-05,
#   'pred_cascade': 0.9231413006782532,
#   'pred_tgtrack': 3.261851134084281e-06,
#   'pred_starttrack': 0.0767499282956123,
#   'pred_stoptrack': 8.525284647475928e-05,
#   'energy': 264.7486770569643,
#   'zenith': 2.659547626806012,
#   'oneweight': 117874255.54131947,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9231413006782532,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 3},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9129_origidx_29_RF22.mp4': {'event': 9129,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0418555326759815,
#   'pred_cascade': 0.0164431538432836,
#   'pred_tgtrack': 0.4587962627410888,
#   'pred_starttrack': 0.0025760931894183,
#   'pred_stoptrack': 0.4803288877010345,
#   'energy': 443.8762895450372,
#   'zenith': 0.9778592161126146,
#   'oneweight': 77156976.45463724,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4803288877010345,
#   'idx_max_score': 'pred_stoptrack',
#   'binned_log10E': 5},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_8641_origidx_6_RF22.mp4': {'event': 8641,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 2.9448923669406213e-05,
#   'pred_cascade': 0.9979065656661988,
#   'pred_tgtrack': 7.683097180688493e-08,
#   'pred_starttrack': 0.0020629428327083,
#   'pred_stoptrack': 9.927473456627922e-07,
#   'energy': 306528.91352714784,
#   'zenith': 1.1142285414678348,
#   'oneweight': 3239637201211004.0,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9979065656661988,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_741_origidx_15_RF22.mp4': {'event': 741,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.4646643996238708,
#   'pred_cascade': 0.1009500846266746,
#   'pred_tgtrack': 0.1590495407581329,
#   'pred_starttrack': 0.0457815043628215,
#   'pred_stoptrack': 0.2295545190572738,
#   'energy': 125.58254104788124,
#   'zenith': 1.3505881075229416,
#   'oneweight': 16056925.837517764,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.4646643996238708,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 1},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9607_origidx_14_RF22.mp4': {'event': 9607,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 1.6392879842896946e-05,
#   'pred_cascade': 0.9762091040611268,
#   'pred_tgtrack': 2.057914798569982e-07,
#   'pred_starttrack': 0.0237475372850894,
#   'pred_stoptrack': 2.672512709978037e-05,
#   'energy': 5530.374432269474,
#   'zenith': 1.056787630200287,
#   'oneweight': 284931520876.6462,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9762091040611268,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_879_origidx_21_RF22.mp4': {'event': 879,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9995840191841124,
#   'pred_cascade': 9.12257860363752e-07,
#   'pred_tgtrack': 0.0001912753650685,
#   'pred_starttrack': 4.571937097352929e-06,
#   'pred_stoptrack': 0.0002191661478718,
#   'energy': 105407.97764873662,
#   'zenith': 1.0970706484986978,
#   'oneweight': 110075072483304.8,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9995840191841124,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 19},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_8553_origidx_4_RF22.mp4': {'event': 8553,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999920129776,
#   'pred_cascade': 1.0750703722806063e-06,
#   'pred_tgtrack': 1.2346307585175964e-06,
#   'pred_starttrack': 4.949622223193728e-08,
#   'pred_stoptrack': 5.602846158581087e-06,
#   'energy': 194766.7455072607,
#   'zenith': 1.5349323935764965,
#   'oneweight': 313212542485662.5,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999920129776,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 21},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9182_origidx_30_RF22.mp4': {'event': 9182,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0644773840904235,
#   'pred_cascade': 0.0162459686398506,
#   'pred_tgtrack': 0.875599205493927,
#   'pred_starttrack': 0.011479509063065,
#   'pred_stoptrack': 0.0321978405117988,
#   'energy': 1764.210596623027,
#   'zenith': 1.3537289191760111,
#   'oneweight': 9121622478.719444,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.875599205493927,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 8},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_1208_origidx_31_RF22.mp4': {'event': 1208,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9957985281944276,
#   'pred_cascade': 0.0003605597303248,
#   'pred_tgtrack': 0.0027367409784346,
#   'pred_starttrack': 0.000443447206635,
#   'pred_stoptrack': 0.0006607444956898,
#   'energy': 4979.181168814066,
#   'zenith': 1.753736226232055,
#   'oneweight': 115985422180.74866,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9957985281944276,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 11},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_1217_origidx_32_RF22.mp4': {'event': 1217,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.2085098177194595,
#   'pred_cascade': 0.0640647411346435,
#   'pred_tgtrack': 0.6090760231018066,
#   'pred_starttrack': 0.066372238099575,
#   'pred_stoptrack': 0.0519772879779338,
#   'energy': 2937.2848771783497,
#   'zenith': 0.8528659330102928,
#   'oneweight': 15844416817.37498,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.6090760231018066,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 10},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_9022_origidx_19_RF22.mp4': {'event': 9022,
#   'run': 22067,
#   'truth_classification': 6,
#   'pred_skim': 9.238606435246766e-05,
#   'pred_cascade': 0.9212257266044616,
#   'pred_tgtrack': 1.1826147783722265e-05,
#   'pred_starttrack': 0.0785248205065727,
#   'pred_stoptrack': 0.0001452644210075,
#   'energy': 659.5751913213649,
#   'zenith': 1.3808907356260802,
#   'oneweight': 934757433.5377082,
#   'truth_classification_label': 'contained_em_hadr_cascade',
#   'max_score_val': 0.9212257266044616,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_7593_origidx_30_RF22.mp4': {'event': 7593,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.9999986886978148,
#   'pred_cascade': 1.192939080851829e-09,
#   'pred_tgtrack': 2.904089910771291e-07,
#   'pred_starttrack': 5.6359322542220986e-08,
#   'pred_stoptrack': 9.25090944292606e-07,
#   'energy': 245148.54614492392,
#   'zenith': 1.1664861930790609,
#   'oneweight': 526738873560685.7,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9999986886978148,
#   'idx_max_score': 'pred_skim',
#   'binned_log10E': 22},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_6052_origidx_4_RF22.mp4': {'event': 6052,
#   'run': 22067,
#   'truth_classification': 8,
#   'pred_skim': 0.0112941153347492,
#   'pred_cascade': 0.0021260960493236,
#   'pred_tgtrack': 0.9475634694099426,
#   'pred_starttrack': 0.0014819233911111,
#   'pred_stoptrack': 0.037534411996603,
#   'energy': 899.872737178474,
#   'zenith': 2.1311898214013345,
#   'oneweight': 697246946.8642817,
#   'truth_classification_label': 'uncontained_cascade',
#   'max_score_val': 0.9475634694099426,
#   'idx_max_score': 'pred_tgtrack',
#   'binned_log10E': 6},
#  '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/compressed_22067000001/compressed_run_22067_event_1015_origidx_27_RF22.mp4': {'event': 1015,
#   'run': 22067,
#   'truth_classification': 7,
#   'pred_skim': 3.197642945451662e-05,
#   'pred_cascade': 0.8594353199005127,
#   'pred_tgtrack': 4.078950496477773e-06,
#   'pred_starttrack': 0.1404126733541488,
#   'pred_stoptrack': 0.0001159803432528,
#   'energy': 54807.03894629079,
#   'zenith': 0.9715626282671171,
#   'oneweight': 36163076039055.945,
#   'truth_classification_label': 'contained_hadron_cascade',
#   'max_score_val': 0.8594353199005127,
#   'idx_max_score': 'pred_cascade',
#   'binned_log10E': 18}}

# %%
make_subject_set('nue_run_22067_subrun_000001_phase2')
# Out:
# Subject Set Name: nue_run_22067_subrun_000001_phase2
# Subject Set ID: 112414
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>]

# %%
uploader(compressed_path,nue_csv,112414)
# Out:
# /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/launch/Phase1/uniformenergydist_filter.py:468: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   dict_manifest = s3.to_dict('dict')
# Confirm if subject set 112414 is listed below.
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>]
# [<SubjectSet 106374>, <SubjectSet 107341>, <SubjectSet 106373>, <SubjectSet 107347>, <SubjectSet 111475>, <SubjectSet 111473>, <SubjectSet 112392>, <SubjectSet 112119>, <SubjectSet 112116>, <SubjectSet 112118>, <SubjectSet 112120>, <SubjectSet 112109>, <SubjectSet 112391>]
# Number of times loop has ran: 1
# Number of times loop has ran: 2
# Number of times loop has ran: 3
# Number of times loop has ran: 4
# Number of times loop has ran: 5
# Number of times loop has ran: 6
# Number of times loop has ran: 7
# Number of times loop has ran: 8
# Number of times loop has ran: 9
# Number of times loop has ran: 10
# Number of times loop has ran: 11
# Number of times loop has ran: 12
# Number of times loop has ran: 13
# Number of times loop has ran: 14
# Number of times loop has ran: 15
# Number of times loop has ran: 16
# Number of times loop has ran: 17
# Number of times loop has ran: 18
# Number of times loop has ran: 19
# Number of times loop has ran: 20
# Number of times loop has ran: 21
# Number of times loop has ran: 22
# Number of times loop has ran: 23
# Number of times loop has ran: 24
# Number of times loop has ran: 25
# Number of times loop has ran: 26
# Number of times loop has ran: 27
# Number of times loop has ran: 28
# Number of times loop has ran: 29
# Number of times loop has ran: 30
# Number of times loop has ran: 31
# Number of times loop has ran: 32
# Number of times loop has ran: 33
# Number of times loop has ran: 34
# Number of times loop has ran: 35
# Number of times loop has ran: 36
# Number of times loop has ran: 37
# Number of times loop has ran: 38
# Number of times loop has ran: 39
# Number of times loop has ran: 40
# Number of times loop has ran: 41
# Number of times loop has ran: 42
# Number of times loop has ran: 43
# Number of times loop has ran: 44
# Number of times loop has ran: 45
# Number of times loop has ran: 46
# Number of times loop has ran: 47
# Number of times loop has ran: 48
# Number of times loop has ran: 49
# Number of times loop has ran: 50
# Number of times loop has ran: 51
# Number of times loop has ran: 52
# Number of times loop has ran: 53
# Number of times loop has ran: 54
# Number of times loop has ran: 55
# Number of times loop has ran: 56
# Number of times loop has ran: 57
# Number of times loop has ran: 58
# Number of times loop has ran: 59
# Number of times loop has ran: 60
# Number of times loop has ran: 61
# Number of times loop has ran: 62
# Number of times loop has ran: 63
# Number of times loop has ran: 64
# Number of times loop has ran: 65
# Number of times loop has ran: 66
# Number of times loop has ran: 67
# Number of times loop has ran: 68
# Number of times loop has ran: 69
# Number of times loop has ran: 70
# Number of times loop has ran: 71
# Number of times loop has ran: 72
# Number of times loop has ran: 73
# Number of times loop has ran: 74
# Number of times loop has ran: 75
# Number of times loop has ran: 76
# Number of times loop has ran: 77
# Number of times loop has ran: 78
# Number of times loop has ran: 79
# Number of times loop has ran: 80
# Number of times loop has ran: 81
# Number of times loop has ran: 82
# Number of times loop has ran: 83
# Number of times loop has ran: 84
# Number of times loop has ran: 85
# Number of times loop has ran: 86
# Number of times loop has ran: 87
# Number of times loop has ran: 88
# Number of times loop has ran: 89
# Number of times loop has ran: 90
# Number of times loop has ran: 91
# Number of times loop has ran: 92
# Number of times loop has ran: 93
# Number of times loop has ran: 94
# Number of times loop has ran: 95
# Number of times loop has ran: 96
# Number of times loop has ran: 97
# Number of times loop has ran: 98
# Number of times loop has ran: 99
# Number of times loop has ran: 100
# Number of times loop has ran: 101
# Number of times loop has ran: 102
# Number of times loop has ran: 103
# Number of times loop has ran: 104
# Number of times loop has ran: 105
# Number of times loop has ran: 106
# Number of times loop has ran: 107
# Number of times loop has ran: 108
# Number of times loop has ran: 109
# Number of times loop has ran: 110
# Number of times loop has ran: 111
# Number of times loop has ran: 112
# Number of times loop has ran: 113
# Number of times loop has ran: 114
# Number of times loop has ran: 115
# Number of times loop has ran: 116
# Number of times loop has ran: 117
# Number of times loop has ran: 118
# Number of times loop has ran: 119
# Number of times loop has ran: 120
# Number of times loop has ran: 121
# Number of times loop has ran: 122
# Number of times loop has ran: 123
# Number of times loop has ran: 124
# Number of times loop has ran: 125
# Number of times loop has ran: 126
# Number of times loop has ran: 127
# Number of times loop has ran: 128
# Number of times loop has ran: 129
# Number of times loop has ran: 130
# Number of times loop has ran: 131
# Number of times loop has ran: 132
